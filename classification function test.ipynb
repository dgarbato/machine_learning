# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

from scipy import stats

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
model_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\model_vars_data.csv',index_col=0)

test_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\test_vars_data.csv',index_col=0)

price_train = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\y_train.csv',index_col=0)

price_test = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\y_test.csv',index_col=0)

# %%
pd.set_option('display.max_columns', None)

model_vars_data.head(3)
# Out:
#       Neighborhood_Crawfor  YearRemodAdd  Neighborhood_Greens  GarageType_No  \
# 1711                     0          1953                    0              0
# 1729                     0          1950                    0              0
# 2407                     0          1950                    0              0
#
#       ExterCond  Neighborhood_SWISU  Exterior1st_PreCast  YearBuilt  \
# 1711          3                   0                    0       1953
# 1729          3                   0                    0       1946
# 2407          3                   0                    0       1922
#
#       Exterior1st_HdBoard  Neighborhood_SawyerW  OverallQual  GarageQual  \
# 1711                    0                     0            5           3
# 1729                    0                     0            6           3
# 2407                    0                     0            5           2
#
#       GarageType_Detchd  Exterior1st_WdShing  Foundation_Stone  \
# 1711                  0                    0                 0
# 1729                  1                    0                 0
# 2407                  1                    0                 0
#
#       log_MasVnrArea  HouseStyle_2.5Unf  SaleCondition_Alloca  \
# 1711             0.0                  0                     0
# 1729             0.0                  0                     0
# 2407             0.0                  0                     0
#
#       Exterior1st_BrkComm  LotShape  HeatingQC  CentralAir_Y  YrSold  \
# 1711                    0         4          3             1    2009
# 1729                    0         4          5             1    2009
# 2407                    0         4          5             1    2008
#
#       Alley_Pave  Foundation_PConc  BldgType_Twnhs  Condition2_RRAe  \
# 1711           0                 1               0                0
# 1729           0                 0               0                0
# 2407           0                 0               0                0
#
#       Condition1_RRAe  TotRmsAbvGrd  RoofStyle_Hip  log_LotArea  \
# 1711                0             5              0     9.271812
# 1729                0             6              1     9.143132
# 2407                0             7              0     9.290629
#
#       log_BsmtFinSF1  Neighborhood_Edwards  SaleCondition_AdjLand  \
# 1711        6.061457                     0                      0
# 1729        5.837730                     1                      0
# 2407        0.000000                     0                      0
#
#       Exterior1st_MetalSd  Heating_GasW  log_WoodDeckSF  GarageCars  \
# 1711                    1             0        4.204693         1.0
# 1729                    1             0        0.000000         1.0
# 2407                    0             0        0.000000         4.0
#
#       Exterior1st_AsphShn  Exterior2nd_AsphShn  Exterior2nd_Wd Sdng  \
# 1711                    0                    0                    0
# 1729                    0                    0                    0
# 2407                    0                    0                    1
#
#       Condition2_RRAn  GarageType_Attchd  MasVnrType_Stone  has_pool  \
# 1711                0                  1                 0     False
# 1729                0                  0                 0     False
# 2407                0                  0                 0     False
#
#       BsmtFinType1  SaleCondition_Normal  MSZoning_I (all)  \
# 1711             4                     1                 0
# 1729             4                     1                 0
# 2407             1                     1                 0
#
#       Exterior1st_ImStucc  log_OpenPorchSF  Heating_Wall  LotConfig_CulDSac  \
# 1711                    0         0.000000             0                  0
# 1729                    0         3.931826             0                  0
# 2407                    0         0.000000             0                  0
#
#       yeo_TotalBsmtSF  Electrical_FuseP  Fireplaces  Exterior2nd_PreCast  \
# 1711       197.803808                 0           0                    0
# 1729       232.839924                 0           1                    0
# 2407       267.944962                 0           1                    0
#
#       yeo_GarageArea  Neighborhood_BrDale  Neighborhood_Gilbert  MSZoning_FV  \
# 1711      115.298257                    0                     0            0
# 1729      104.706663                    0                     0            0
# 2407      463.732557                    0                     0            0
#
#       LandContour_Low  Foundation_Wood  HouseStyle_1.5Unf  log_first_FlrSF  \
# 1711                0                0                  0         7.184629
# 1729                0                0                  0         6.793466
# 2407                0                0                  0         7.134094
#
#       GarageCond  Fence_GdWo  Exterior2nd_CBlock  Foundation_CBlock  \
# 1711           3           1                   0                  0
# 1729           3           0                   0                  1
# 2407           3           1                   0                  0
#
#       FireplaceQu  LandSlope  FullBath  Neighborhood_StoneBr  \
# 1711            0          3         1                     0
# 1729            4          3         1                     0
# 2407            4          3         1                     0
#
#       Exterior1st_Wd Sdng  Fence_MnPrv  Exterior2nd_CmentBd  Condition2_RRNn  \
# 1711                    0            0                    0                0
# 1729                    0            0                    0                0
# 2407                    1            0                    0                0
#
#       Neighborhood_BrkSide  Condition2_Norm  HouseStyle_2.5Fin  Street_Pave  \
# 1711                     0                1                  0            1
# 1729                     0                1                  0            1
# 2407                     0                1                  0            1
#
#       Utilities_NoSewr  PavedDrive_Y  KitchenQual  RoofStyle_Gable  \
# 1711                 0             1            3                1
# 1729                 0             1            4                0
# 2407                 0             0            3                1
#
#       Exterior1st_CBlock  Fence_MnWw  Neighborhood_ClearCr  \
# 1711                   0           0                     0
# 1729                   0           0                     0
# 2407                   0           0                     0
#
#       Neighborhood_Sawyer  HouseStyle_2Story  Heating_GasA  GarageFinish_RFn  \
# 1711                    0                  0             1                 0
# 1729                    0                  1             1                 0
# 2407                    0                  0             1                 0
#
#       Condition1_Feedr  Condition1_PosA  Exterior1st_CemntBd  \
# 1711                 0                0                    0
# 1729                 0                0                    0
# 2407                 0                0                    0
#
#       Neighborhood_NAmes  Exterior1st_BrkFace  Exterior2nd_Stucco  \
# 1711                   1                    0                   0
# 1729                   0                    0                   0
# 2407                   0                    0                   0
#
#       Foundation_Slab  Condition1_RRNn  SalePrice  BsmtExposure  MSZoning_RM  \
# 1711                0                0     123000             0            0
# 1729                0                0     154400             0            0
# 2407                0                0     139000             0            0
#
#       Condition1_RRNe  EnclosedPorch  BsmtHalfBath  Neighborhood_Blueste  \
# 1711                0              0           0.0                     0
# 1729                0              0           0.0                     0
# 2407                0            100           1.0                     0
#
#       BsmtFinType2  Electrical_SBrkr  Condition2_Feedr  LotConfig_FR3  MoSold  \
# 1711             2                 1                 0              0      11
# 1729             1                 1                 0              0       7
# 2407             1                 1                 0              0       6
#
#       GarageType_Basment  Neighborhood_MeadowV  BsmtFullBath  \
# 1711                   0                     0           1.0
# 1729                   0                     0           0.0
# 2407                   0                     0           0.0
#
#       Exterior2nd_BrkFace  Exterior2nd_MetalSd  Neighborhood_NoRidge  \
# 1711                    0                    1                     0
# 1729                    0                    1                     0
# 2407                    0                    0                     0
#
#       MSZoning_C (all)  Condition2_PosA  Exterior2nd_Wd Shng  Alley_None  \
# 1711                 0                0                    0           1
# 1729                 0                0                    0           1
# 2407                 0                0                    0           0
#
#       Condition1_RRAn  RoofMatl_Membran  Exterior2nd_Plywood  LandContour_Lvl  \
# 1711                0                 0                    0                1
# 1729                0                 0                    0                0
# 2407                0                 0                    0                1
#
#       Electrical_Mixed  Electrical_FuseF  Neighborhood_Mitchel  \
# 1711                 0                 0                     0
# 1729                 0                 0                     0
# 2407                 0                 0                     0
#
#       Exterior2nd_ImStucc  GarageType_CarPort  LotConfig_Inside  \
# 1711                    0                   0                 1
# 1729                    0                   0                 1
# 2407                    0                   0                 1
#
#       Neighborhood_NWAmes  HouseStyle_1Story  HouseStyle_SLvl  \
# 1711                    0                  1                0
# 1729                    0                  0                0
# 2407                    0                  0                0
#
#       Exterior1st_Stucco  Neighborhood_Landmrk  Condition1_Norm  \
# 1711                   0                     0                1
# 1729                   0                     0                1
# 2407                   0                     0                1
#
#       Exterior1st_Plywood  RoofStyle_Gambrel  MasVnrType_None  BedroomAbvGr  \
# 1711                    0                  0                1             3
# 1729                    0                  0                1             3
# 2407                    0                  0                1             3
#
#       LotConfig_FR2  Exterior2nd_Stone  GarageFinish_Unf  ExterQual  \
# 1711              0                  0                 1          3
# 1729              0                  0                 1          3
# 2407              0                  0                 1          3
#
#       OverallCond  MSZoning_RH  Neighborhood_NridgHt  MasVnrType_BrkFace  \
# 1711            6            0                     0                   0
# 1729            7            0                     0                   0
# 2407            5            0                     0                   0
#
#       MSSubClass  RoofMatl_Metal  BldgType_2fmCon  SaleCondition_Partial  \
# 1711          20               0                0                      0
# 1729          60               0                0                      0
# 2407          50               0                0                      0
#
#       Fence_No  Neighborhood_CollgCr  RoofStyle_Mansard  bc_GrLivArea  \
# 1711         0                     0                  0      8.306749
# 1729         1                     0                  0      8.596412
# 2407         0                     0                  0      8.419789
#
#       RoofMatl_Roll  BsmtFinSF2  Neighborhood_Veenker  Exterior2nd_HdBoard  \
# 1711              0       180.0                     0                    0
# 1729              0         0.0                     0                    0
# 2407              0         0.0                     0                    0
#
#       Neighborhood_GrnHill  Heating_Grav  SaleCondition_Family  Heating_OthW  \
# 1711                     0             0                     0             0
# 1729                     0             0                     0             0
# 2407                     0             0                     0             0
#
#       LandContour_HLS  ScreenPorch  Condition2_PosN  Exterior1st_VinylSd  \
# 1711                0            0                0                    0
# 1729                0            0                0                    0
# 2407                0            0                0                    0
#
#       Condition1_PosN  BsmtFinSF1  HalfBath  LotFrontage  Neighborhood_IDOTRR  \
# 1711                0       428.0         0         79.0                    0
# 1729                0       342.0         1         50.0                    0
# 2407                0         0.0         0         60.0                    0
#
#       RoofStyle_Shed  PavedDrive_P  BsmtQual  RoofMatl_WdShngl  \
# 1711               0             0         3                 0
# 1729               0             0         3                 0
# 2407               0             0         3                 0
#
#       Neighborhood_Timber  Neighborhood_NPkVill  BldgType_TwnhsE  \
# 1711                    0                     0                0
# 1729                    0                     0                0
# 2407                    0                     0                0
#
#       BldgType_Duplex  MSZoning_RL  RoofMatl_WdShake  KitchenAbvGr  \
# 1711                0            1                 0             1
# 1729                0            1                 0             1
# 2407                0            1                 0             1
#
#       GarageYrBlt  HouseStyle_SFoyer  GarageFinish_No  GarageType_BuiltIn  \
# 1711       1953.0                  0                0                   0
# 1729       1946.0                  0                0                   0
# 2407       1968.0                  0                0                   0
#
#       Neighborhood_Somerst  Functional  Exterior2nd_VinylSd  \
# 1711                     0           6                    0
# 1729                     0           8                    0
# 2407                     0           8                    0
#
#       Neighborhood_OldTown  Exterior2nd_Brk Cmn  BsmtCond  RoofMatl_Tar&Grv
# 1711                     0                    0         3                 0
# 1729                     0                    0         3                 0
# 2407                     1                    0         3                 0

# %%
pd.set_option('display.max_columns', None)

test_vars_data.head(3)
# Out:
#      Neighborhood_Crawfor  YearRemodAdd  Neighborhood_Greens  GarageType_No  \
# 953                     0          1963                    0              0
# 330                     0          1976                    0              0
# 670                     0          1950                    0              0
#
#      ExterCond  Neighborhood_SWISU  Exterior1st_PreCast  YearBuilt  \
# 953          3                   0                    0       1963
# 330          3                   0                    0       1976
# 670          4                   0                    0       1920
#
#      Exterior1st_HdBoard  Neighborhood_SawyerW  OverallQual  GarageQual  \
# 953                    0                     0            5           3
# 330                    1                     0            6           3
# 670                    0                     0            4           3
#
#      GarageType_Detchd  Exterior1st_WdShing  Foundation_Stone  log_MasVnrArea  \
# 953                  0                    0                 0        0.000000
# 330                  1                    0                 0        4.442651
# 670                  1                    0                 0        0.000000
#
#      HouseStyle_2.5Unf  SaleCondition_Alloca  Exterior1st_BrkComm  LotShape  \
# 953                  0                     0                    0         4
# 330                  0                     0                    0         4
# 670                  0                     0                    0         4
#
#      HeatingQC  CentralAir_Y  YrSold  Alley_Pave  Foundation_PConc  \
# 953          4             1    2007           0                 0
# 330          3             1    2008           0                 0
# 670          3             1    2010           0                 0
#
#      BldgType_Twnhs  Condition2_RRAe  Condition1_RRAe  TotRmsAbvGrd  \
# 953               0                0                0             6
# 330               0                0                0             6
# 670               0                0                0             6
#
#      RoofStyle_Hip  log_LotArea  log_BsmtFinSF1  Neighborhood_Edwards  \
# 953              0     9.017968        5.666427                     0
# 330              1     8.779557        6.941190                     1
# 670              0     8.922658        0.000000                     0
#
#      SaleCondition_AdjLand  Exterior1st_MetalSd  Heating_GasW  log_WoodDeckSF  \
# 953                      0                    1             0        5.484797
# 330                      0                    0             0        0.000000
# 670                      0                    1             0        3.433987
#
#      GarageCars  Exterior1st_AsphShn  Exterior2nd_AsphShn  \
# 953         2.0                    0                    0
# 330         2.0                    0                    0
# 670         2.0                    0                    0
#
#      Exterior2nd_Wd Sdng  Condition2_RRAn  GarageType_Attchd  \
# 953                    0                0                  0
# 330                    0                0                  0
# 670                    0                0                  0
#
#      MasVnrType_Stone  has_pool  BsmtFinType1  SaleCondition_Normal  \
# 953                 0     False             5                     1
# 330                 0     False             4                     1
# 670                 0     False             1                     0
#
#      MSZoning_I (all)  Exterior1st_ImStucc  log_OpenPorchSF  Heating_Wall  \
# 953                 0                    0              0.0             0
# 330                 0                    0              0.0             0
# 670                 0                    0              0.0             0
#
#      LotConfig_CulDSac  yeo_TotalBsmtSF  Electrical_FuseP  Fireplaces  \
# 953                  0       345.800416                 0           0
# 330                  0       365.411431                 0           1
# 670                  0       247.578605                 0           0
#
#      Exterior2nd_PreCast  yeo_GarageArea  Neighborhood_BrDale  \
# 953                    0      247.305063                    0
# 330                    0      183.582468                    0
# 670                    0      198.408819                    0
#
#      Neighborhood_Gilbert  MSZoning_FV  LandContour_Low  Foundation_Wood  \
# 953                     0            0                0                0
# 330                     0            0                0                0
# 670                     0            0                0                0
#
#      HouseStyle_1.5Unf  log_first_FlrSF  GarageCond  Fence_GdWo  \
# 953                  0         6.959399           3           0
# 330                  0         7.027315           3           0
# 670                  0         6.548219           3           0
#
#      Exterior2nd_CBlock  Foundation_CBlock  FireplaceQu  LandSlope  FullBath  \
# 953                   0                  1            0          3         1
# 330                   0                  1            1          3         1
# 670                   0                  1            0          3         1
#
#      Neighborhood_StoneBr  Exterior1st_Wd Sdng  Fence_MnPrv  \
# 953                     0                    0            0
# 330                     0                    0            0
# 670                     0                    0            0
#
#      Exterior2nd_CmentBd  Condition2_RRNn  Neighborhood_BrkSide  \
# 953                    0                0                     0
# 330                    0                0                     0
# 670                    0                0                     0
#
#      Condition2_Norm  HouseStyle_2.5Fin  Street_Pave  Utilities_NoSewr  \
# 953                1                  0            1                 0
# 330                1                  0            1                 0
# 670                1                  0            1                 0
#
#      PavedDrive_Y  KitchenQual  RoofStyle_Gable  Exterior1st_CBlock  \
# 953             1            4                1                   0
# 330             1            3                0                   0
# 670             1            3                1                   0
#
#      Fence_MnWw  Neighborhood_ClearCr  Neighborhood_Sawyer  HouseStyle_2Story  \
# 953           0                     0                    0                  0
# 330           0                     0                    0                  0
# 670           0                     0                    0                  0
#
#      Heating_GasA  GarageFinish_RFn  Condition1_Feedr  Condition1_PosA  \
# 953             1                 1                 0                0
# 330             1                 0                 0                0
# 670             1                 1                 0                0
#
#      Exterior1st_CemntBd  Neighborhood_NAmes  Exterior1st_BrkFace  \
# 953                    0                   1                    0
# 330                    0                   0                    0
# 670                    0                   0                    0
#
#      Exterior2nd_Stucco  Foundation_Slab  Condition1_RRNn  SalePrice  \
# 953                   0                0                0     142100
# 330                   0                0                0     135000
# 670                   0                0                0      68400
#
#      BsmtExposure  MSZoning_RM  Condition1_RRNe  EnclosedPorch  BsmtHalfBath  \
# 953             0            0                0              0           0.0
# 330             0            0                0            138           1.0
# 670             0            0                0            164           0.0
#
#      Neighborhood_Blueste  BsmtFinType2  Electrical_SBrkr  Condition2_Feedr  \
# 953                     0             1                 1                 0
# 330                     0             1                 1                 0
# 670                     0             1                 0                 0
#
#      LotConfig_FR3  MoSold  GarageType_Basment  Neighborhood_MeadowV  \
# 953              0       7                   0                     0
# 330              0       5                   0                     0
# 670              0       4                   0                     0
#
#      BsmtFullBath  Exterior2nd_BrkFace  Exterior2nd_MetalSd  \
# 953           1.0                    0                    1
# 330           0.0                    0                    0
# 670           0.0                    0                    1
#
#      Neighborhood_NoRidge  MSZoning_C (all)  Condition2_PosA  \
# 953                     0                 0                0
# 330                     0                 0                0
# 670                     0                 1                0
#
#      Exterior2nd_Wd Shng  Alley_None  Condition1_RRAn  RoofMatl_Membran  \
# 953                    0           1                0                 0
# 330                    0           1                0                 0
# 670                    0           1                0                 0
#
#      Exterior2nd_Plywood  LandContour_Lvl  Electrical_Mixed  Electrical_FuseF  \
# 953                    0                1                 0                 0
# 330                    1                1                 0                 0
# 670                    0                1                 0                 0
#
#      Neighborhood_Mitchel  Exterior2nd_ImStucc  GarageType_CarPort  \
# 953                     0                    0                   0
# 330                     0                    0                   0
# 670                     0                    0                   0
#
#      LotConfig_Inside  Neighborhood_NWAmes  HouseStyle_1Story  \
# 953                 0                    0                  1
# 330                 1                    0                  1
# 670                 1                    0                  0
#
#      HouseStyle_SLvl  Exterior1st_Stucco  Neighborhood_Landmrk  \
# 953                0                   0                     0
# 330                0                   0                     0
# 670                0                   0                     0
#
#      Condition1_Norm  Exterior1st_Plywood  RoofStyle_Gambrel  MasVnrType_None  \
# 953                1                    0                  0                1
# 330                1                    0                  0                0
# 670                1                    0                  0                1
#
#      BedroomAbvGr  LotConfig_FR2  Exterior2nd_Stone  GarageFinish_Unf  \
# 953             3              0                  0                 0
# 330             3              0                  0                 1
# 670             2              0                  0                 0
#
#      ExterQual  OverallCond  MSZoning_RH  Neighborhood_NridgHt  \
# 953          3            7            0                     0
# 330          3            6            0                     0
# 670          3            4            0                     0
#
#      MasVnrType_BrkFace  MSSubClass  RoofMatl_Metal  BldgType_2fmCon  \
# 953                   0          20               0                0
# 330                   1          20               0                0
# 670                   0          50               0                0
#
#      SaleCondition_Partial  Fence_No  Neighborhood_CollgCr  RoofStyle_Mansard  \
# 953                      0         1                     0                  0
# 330                      0         1                     0                  0
# 670                      0         1                     0                  0
#
#      bc_GrLivArea  RoofMatl_Roll  BsmtFinSF2  Neighborhood_Veenker  \
# 953     10.766258              0         0.0                     0
# 330     10.920659              0         0.0                     0
# 670     10.922684              0         0.0                     0
#
#      Exterior2nd_HdBoard  Neighborhood_GrnHill  Heating_Grav  \
# 953                    0                     0             0
# 330                    0                     0             0
# 670                    0                     0             0
#
#      SaleCondition_Family  Heating_OthW  LandContour_HLS  ScreenPorch  \
# 953                     0             0                0          109
# 330                     0             0                0            0
# 670                     0             0                0            0
#
#      Condition2_PosN  Exterior1st_VinylSd  Condition1_PosN  BsmtFinSF1  \
# 953                0                    0                0       288.0
# 330                0                    0                0      1033.0
# 670                0                    0                0         0.0
#
#      HalfBath  LotFrontage  Neighborhood_IDOTRR  RoofStyle_Shed  PavedDrive_P  \
# 953         0         60.0                    0               0             0
# 330         1         65.0                    0               0             0
# 670         0         60.0                    1               0             0
#
#      BsmtQual  RoofMatl_WdShngl  Neighborhood_Timber  Neighborhood_NPkVill  \
# 953         3                 0                    0                     0
# 330         3                 0                    0                     0
# 670         3                 0                    0                     0
#
#      BldgType_TwnhsE  BldgType_Duplex  MSZoning_RL  RoofMatl_WdShake  \
# 953                0                0            1                 0
# 330                0                0            1                 0
# 670                0                0            0                 0
#
#      KitchenAbvGr  GarageYrBlt  HouseStyle_SFoyer  GarageFinish_No  \
# 953             1       1994.0                  0                0
# 330             1       1991.0                  0                0
# 670             1       1980.0                  0                0
#
#      GarageType_BuiltIn  Neighborhood_Somerst  Functional  \
# 953                   0                     0           8
# 330                   0                     0           8
# 670                   0                     0           8
#
#      Exterior2nd_VinylSd  Neighborhood_OldTown  Exterior2nd_Brk Cmn  BsmtCond  \
# 953                    0                     0                    0         3
# 330                    0                     0                    0         5
# 670                    0                     0                    0         3
#
#      RoofMatl_Tar&Grv
# 953                 0
# 330                 0
# 670                 0

# %%
price_train.head(3)
# Out:
#       SalePrice
# 1711     123000
# 1729     154400
# 2407     139000

# %%
price_test.head(3)
# Out:
#      SalePrice
# 953     142100
# 330     135000
# 670      68400

# %%
def miss_cols(df):
    missing = np.sum(df.isnull(),axis=0)
    
    miss_ind = np.sum(df.isnull(),axis=0) > 0
    
    vals = pd.Series(filter(lambda x: x != 0,missing))
     
    cols_miss = df.columns[miss_ind]

    L=list(zip(cols_miss,vals, round(vals/df.shape[0],4)))
    
    return sorted(L,reverse=True,key=lambda x: x[2])

# %%
miss_cols(model_vars_data)
# Out:
# [('GarageYrBlt', 95, 0.0526)]

# %%
# df.drop(['C', 'D'], axis = 1)
  
model_vars_data.drop(['GarageYrBlt'], axis = 1, inplace = True)

# %%
test_vars_data.drop(['GarageYrBlt'], axis = 1, inplace = True)

# %%
model= Lasso(max_iter=3000), 
x_train=, x_test=, y_train = np.log(price_train.SalePrice), y_test = np.log(price_test.SalePrice), params=, cv_=, linear_reg = True

# %%
model= Lasso(max_iter=3000)
x_train = model_vars_data
x_test = test_vars_data
y_train = np.log(price_train.SalePrice)
y_test = np.log(price_test.SalePrice)
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10]}
cv_ = 5
linear_reg = True
tree_based = False
#model_importances = 


# want to return the dataframe with the features

# %%
features = list(x_train.columns)

ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.transform(x_test)



model

params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10]}
gs = GridSearchCV(model, params, cv=cv_, return_train_score=True, refit=True)
gs.fit(x_train,y_train)
gs.best_params_
###################################    
    
print('best params: ',gs.best_params_)
print('score: ',gs.score(x_train,y_train))
print('  ')
print('test score: ',gs.score(x_test,y_test))


if linear_reg:
    adj_r2 = 1-(1-gs.score(x_train,y_train))*(x_train.shape[0] - 1) / (x_train.shape[0] - x_train.shape[1] - 1)
    print('adj_r2: ', adj_r2)
    adj_r2_test = 1-(1-gs.score(x_test,y_test))*(x_test.shape[0] - 1) / (x_test.shape[0] - x_test.shape[1] - 1)
    print('  ')
    print('adj_r2_test: ',adj_r2_test)
    print(' ')


train_pred = gs.best_estimator_.predict(x_train)
print('train RMSE: ' + str(mean_squared_error(train_pred,y_train)**0.5))
print('  ')

test_pred = gs.best_estimator_.predict(x_test)
print('test RMSE: ' + str(mean_squared_error(test_pred,y_test)**0.5))

if linear_reg:

    coefs = pd.Series(gs.best_estimator_.coef_, name = 'coef' )

    varnames = pd.Series(features, name = 'features')

    pd.set_option('display.max_rows', None) # or 1000.

    abs_coefs = pd.Series(np.abs(coefs),name = 'abs_val')

    coefs_ = pd.concat([varnames,coefs, abs_coefs], axis=1)
    
    #return:
    model_importances = coefs_.sort_values(by=['abs_val'], ascending=False)
    
    print(model_importances)
    print(' ')

elif tree_based:
    pd.set_option('display.max_rows', None) # or 1000.
    
    #return
    model_importances = pd.Series(model.feature_importances_, index = features).sort_values(ascending=False)
    
    print(model_importances)


if linear_reg:
    residuals = y_train - train_pred
    print('skewness: ',stats.skew(residuals))
    print(' ')
    sns.set_theme(style='darkgrid')
    sns.histplot(residuals, bins=20);
# Out:
# best params:  {'alpha': 0.001}
# score:  0.9755924551207849
#
# test score:  -0.5036694217743198
# adj_r2:  0.9726362617969048
#
# adj_r2_test:  -1.0109627388089089
#
# train RMSE: 0.05990705932179521
#
# test RMSE: 0.4855566256169002
#                   features      coef   abs_val
# 99               SalePrice  0.223579  0.223579
# 156           bc_GrLivArea  0.067188  0.067188
# 7                YearBuilt  0.032029  0.032029
# 10             OverallQual  0.028214  0.028214
# 145            OverallCond  0.028104  0.028104
# 63         log_first_FlrSF  0.015608  0.015608
# 30             log_LotArea  0.014003  0.014003
# 112   Neighborhood_MeadowV -0.013892  0.013892
# 21            CentralAir_Y  0.012681  0.012681
# 117       MSZoning_C (all) -0.012184  0.012184
# 193               BsmtCond  0.010483  0.010483
# 189             Functional  0.010477  0.010477
# 1             YearRemodAdd  0.009199  0.009199
# 32    Neighborhood_Edwards -0.008227  0.008227
# 45            BsmtFinType1  0.008198  0.008198
# 0     Neighborhood_Crawfor  0.008172  0.008172
# 177       RoofMatl_WdShngl -0.007977  0.007977
# 136        Condition1_Norm  0.007933  0.007933
# 64              GarageCond  0.007230  0.007230
# 147   Neighborhood_NridgHt -0.007105  0.007105
# 116   Neighborhood_NoRidge -0.007102  0.007102
# 68             FireplaceQu  0.007057  0.007057
# 167        Condition2_PosN -0.006995  0.006995
# 101            MSZoning_RM -0.006890  0.006890
# 20               HeatingQC  0.006587  0.006587
# 180        BldgType_TwnhsE  0.006137  0.006137
# 188   Neighborhood_Somerst  0.005632  0.005632
# 56          yeo_GarageArea  0.005609  0.005609
# 81            PavedDrive_Y  0.005600  0.005600
# 103          EnclosedPorch  0.005517  0.005517
# 57     Neighborhood_BrDale -0.004999  0.004999
# 24        Foundation_PConc  0.004941  0.004941
# 185      HouseStyle_SFoyer  0.004734  0.004734
# 161   Neighborhood_GrnHill  0.004519  0.004519
# 95     Exterior1st_BrkFace  0.004465  0.004465
# 191   Neighborhood_OldTown -0.004381  0.004381
# 35            Heating_GasW  0.004129  0.004129
# 166            ScreenPorch  0.004121  0.004121
# 37              GarageCars  0.004053  0.004053
# 163   SaleCondition_Family -0.003899  0.003899
# 173    Neighborhood_IDOTRR -0.003864  0.003864
# 77         Condition2_Norm  0.003720  0.003720
# 2      Neighborhood_Greens  0.003574  0.003574
# 86    Neighborhood_ClearCr  0.003477  0.003477
# 162           Heating_Grav -0.003457  0.003457
# 42       GarageType_Attchd  0.003425  0.003425
# 107       Electrical_SBrkr  0.003406  0.003406
# 113           BsmtFullBath  0.003374  0.003374
# 90        GarageFinish_RFn  0.003372  0.003372
# 46    SaleCondition_Normal  0.003237  0.003237
# 17    SaleCondition_Alloca  0.003134  0.003134
# 29           RoofStyle_Hip -0.002980  0.002980
# 138      RoofStyle_Gambrel -0.002746  0.002746
# 31          log_BsmtFinSF1  0.002721  0.002721
# 22                  YrSold -0.002595  0.002595
# 9     Neighborhood_SawyerW -0.002491  0.002491
# 118        Condition2_PosA -0.002457  0.002457
# 36          log_WoodDeckSF  0.002402  0.002402
# 33   SaleCondition_AdjLand  0.002319  0.002319
# 44                has_pool -0.002292  0.002292
# 168    Exterior1st_VinylSd  0.002233  0.002233
# 155      RoofStyle_Mansard -0.002066  0.002066
# 47        MSZoning_I (all) -0.002034  0.002034
# 114    Exterior2nd_BrkFace -0.001971  0.001971
# 169        Condition1_PosN  0.001950  0.001950
# 133        HouseStyle_SLvl  0.001864  0.001864
# 182            MSZoning_RL  0.001802  0.001802
# 84      Exterior1st_CBlock -0.001697  0.001697
# 18     Exterior1st_BrkComm  0.001652  0.001652
# 15          log_MasVnrArea -0.001624  0.001624
# 12       GarageType_Detchd -0.001603  0.001603
# 146            MSZoning_RH -0.001580  0.001580
# 176               BsmtQual  0.001577  0.001577
# 130       LotConfig_Inside  0.001504  0.001504
# 71    Neighborhood_StoneBr -0.001447  0.001447
# 80        Utilities_NoSewr -0.001339  0.001339
# 88       HouseStyle_2Story -0.001331  0.001331
# 134     Exterior1st_Stucco -0.001174  0.001174
# 58    Neighborhood_Gilbert  0.001174  0.001174
# 143       GarageFinish_Unf -0.001161  0.001161
# 122       RoofMatl_Membran  0.001062  0.001062
# 98         Condition1_RRNn  0.001021  0.001021
# 49         log_OpenPorchSF  0.001011  0.001011
# 183       RoofMatl_WdShake  0.000998  0.000998
# 181        BldgType_Duplex -0.000936  0.000936
# 23              Alley_Pave  0.000930  0.000930
# 13     Exterior1st_WdShing  0.000804  0.000804
# 97         Foundation_Slab -0.000752  0.000752
# 16       HouseStyle_2.5Unf  0.000728  0.000728
# 14        Foundation_Stone -0.000713  0.000713
# 165        LandContour_HLS -0.000663  0.000663
# 158             BsmtFinSF2  0.000554  0.000554
# 53        Electrical_FuseP  0.000476  0.000476
# 85              Fence_MnWw -0.000467  0.000467
# 144              ExterQual -0.000418  0.000418
# 140           BedroomAbvGr  0.000397  0.000397
# 123    Exterior2nd_Plywood -0.000369  0.000369
# 151        BldgType_2fmCon  0.000304  0.000304
# 175           PavedDrive_P  0.000291  0.000291
# 111     GarageType_Basment -0.000288  0.000288
# 92         Condition1_PosA  0.000228  0.000228
# 60         LandContour_Low  0.000206  0.000206
# 48     Exterior1st_ImStucc  0.000195  0.000195
# 27         Condition1_RRAe -0.000195  0.000195
# 119    Exterior2nd_Wd Shng  0.000180  0.000180
# 178    Neighborhood_Timber  0.000178  0.000178
# 79             Street_Pave -0.000171  0.000171
# 50            Heating_Wall  0.000159  0.000159
# 73             Fence_MnPrv -0.000133  0.000133
# 40     Exterior2nd_Wd Sdng  0.000089  0.000089
# 67       Foundation_CBlock  0.000045  0.000045
# 152  SaleCondition_Partial  0.000025  0.000025
# 105   Neighborhood_Blueste  0.000024  0.000024
# 172            LotFrontage  0.000010  0.000010
# 160    Exterior2nd_HdBoard  0.000000  0.000000
# 43        MasVnrType_Stone  0.000000  0.000000
# 159   Neighborhood_Veenker -0.000000  0.000000
# 38     Exterior1st_AsphShn -0.000000  0.000000
# 41         Condition2_RRAn -0.000000  0.000000
# 157          RoofMatl_Roll  0.000000  0.000000
# 154   Neighborhood_CollgCr  0.000000  0.000000
# 164           Heating_OthW  0.000000  0.000000
# 153               Fence_No -0.000000  0.000000
# 150         RoofMatl_Metal  0.000000  0.000000
# 39     Exterior2nd_AsphShn  0.000000  0.000000
# 87     Neighborhood_Sawyer  0.000000  0.000000
# 34     Exterior1st_MetalSd -0.000000  0.000000
# 28            TotRmsAbvGrd -0.000000  0.000000
# 3            GarageType_No  0.000000  0.000000
# 192    Exterior2nd_Brk Cmn -0.000000  0.000000
# 4                ExterCond -0.000000  0.000000
# 190    Exterior2nd_VinylSd  0.000000  0.000000
# 5       Neighborhood_SWISU -0.000000  0.000000
# 6      Exterior1st_PreCast  0.000000  0.000000
# 187     GarageType_BuiltIn -0.000000  0.000000
# 186        GarageFinish_No  0.000000  0.000000
# 8      Exterior1st_HdBoard  0.000000  0.000000
# 184           KitchenAbvGr -0.000000  0.000000
# 11              GarageQual  0.000000  0.000000
# 19                LotShape -0.000000  0.000000
# 179   Neighborhood_NPkVill -0.000000  0.000000
# 25          BldgType_Twnhs  0.000000  0.000000
# 26         Condition2_RRAe -0.000000  0.000000
# 174         RoofStyle_Shed -0.000000  0.000000
# 148     MasVnrType_BrkFace  0.000000  0.000000
# 171               HalfBath -0.000000  0.000000
# 170             BsmtFinSF1 -0.000000  0.000000
# 149             MSSubClass  0.000000  0.000000
# 141          LotConfig_FR2 -0.000000  0.000000
# 51       LotConfig_CulDSac -0.000000  0.000000
# 75         Condition2_RRNn  0.000000  0.000000
# 115    Exterior2nd_MetalSd -0.000000  0.000000
# 70                FullBath  0.000000  0.000000
# 72     Exterior1st_Wd Sdng -0.000000  0.000000
# 110                 MoSold  0.000000  0.000000
# 109          LotConfig_FR3 -0.000000  0.000000
# 108       Condition2_Feedr -0.000000  0.000000
# 74     Exterior2nd_CmentBd -0.000000  0.000000
# 106           BsmtFinType2  0.000000  0.000000
# 104           BsmtHalfBath  0.000000  0.000000
# 102        Condition1_RRNe  0.000000  0.000000
# 52         yeo_TotalBsmtSF  0.000000  0.000000
# 76    Neighborhood_BrkSide  0.000000  0.000000
# 100           BsmtExposure  0.000000  0.000000
# 78       HouseStyle_2.5Fin -0.000000  0.000000
# 82             KitchenQual  0.000000  0.000000
# 96      Exterior2nd_Stucco  0.000000  0.000000
# 83         RoofStyle_Gable  0.000000  0.000000
# 94      Neighborhood_NAmes  0.000000  0.000000
# 93     Exterior1st_CemntBd -0.000000  0.000000
# 91        Condition1_Feedr -0.000000  0.000000
# 69               LandSlope -0.000000  0.000000
# 66      Exterior2nd_CBlock  0.000000  0.000000
# 120             Alley_None -0.000000  0.000000
# 121        Condition1_RRAn  0.000000  0.000000
# 54              Fireplaces  0.000000  0.000000
# 142      Exterior2nd_Stone  0.000000  0.000000
# 89            Heating_GasA -0.000000  0.000000
# 139        MasVnrType_None -0.000000  0.000000
# 55     Exterior2nd_PreCast  0.000000  0.000000
# 137    Exterior1st_Plywood -0.000000  0.000000
# 59             MSZoning_FV  0.000000  0.000000
# 135   Neighborhood_Landmrk -0.000000  0.000000
# 61         Foundation_Wood  0.000000  0.000000
# 132      HouseStyle_1Story -0.000000  0.000000
# 131    Neighborhood_NWAmes -0.000000  0.000000
# 62       HouseStyle_1.5Unf  0.000000  0.000000
# 129     GarageType_CarPort -0.000000  0.000000
# 128    Exterior2nd_ImStucc  0.000000  0.000000
# 127   Neighborhood_Mitchel -0.000000  0.000000
# 126       Electrical_FuseF -0.000000  0.000000
# 125       Electrical_Mixed  0.000000  0.000000
# 124        LandContour_Lvl  0.000000  0.000000
# 65              Fence_GdWo -0.000000  0.000000
# 194       RoofMatl_Tar&Grv  0.000000  0.000000
#
# skewness:  -1.7013808510222332
