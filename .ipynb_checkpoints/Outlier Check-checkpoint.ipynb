# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import numpy as np
import pandas as pd
from scipy import stats
# %matplotlib inline

housing = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\Ames_HousePrice.csv')

# %%
housing.shape
# Out:
# (2580, 82)

# %%
housing2 = housing.copy()

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     2580 non-null   int64
#  1   PID            2580 non-null   int64
#  2   GrLivArea      2580 non-null   int64
#  3   SalePrice      2580 non-null   int64
#  4   MSSubClass     2580 non-null   int64
#  5   MSZoning       2580 non-null   object
#  6   LotFrontage    2118 non-null   float64
#  7   LotArea        2580 non-null   int64
#  8   Street         2580 non-null   object
#  9   Alley          168 non-null    object
#  10  LotShape       2580 non-null   object
#  11  LandContour    2580 non-null   object
#  12  Utilities      2580 non-null   object
#  13  LotConfig      2580 non-null   object
#  14  LandSlope      2580 non-null   object
#  15  Neighborhood   2580 non-null   object
#  16  Condition1     2580 non-null   object
#  17  Condition2     2580 non-null   object
#  18  BldgType       2580 non-null   object
#  19  HouseStyle     2580 non-null   object
#  20  OverallQual    2580 non-null   int64
#  21  OverallCond    2580 non-null   int64
#  22  YearBuilt      2580 non-null   int64
#  23  YearRemodAdd   2580 non-null   int64
#  24  RoofStyle      2580 non-null   object
#  25  RoofMatl       2580 non-null   object
#  26  Exterior1st    2580 non-null   object
#  27  Exterior2nd    2580 non-null   object
#  28  MasVnrType     2566 non-null   object
#  29  MasVnrArea     2566 non-null   float64
#  30  ExterQual      2580 non-null   object
#  31  ExterCond      2580 non-null   object
#  32  Foundation     2580 non-null   object
#  33  BsmtQual       2511 non-null   object
#  34  BsmtCond       2511 non-null   object
#  35  BsmtExposure   2509 non-null   object
#  36  BsmtFinType1   2511 non-null   object
#  37  BsmtFinSF1     2579 non-null   float64
#  38  BsmtFinType2   2510 non-null   object
#  39  BsmtFinSF2     2579 non-null   float64
#  40  BsmtUnfSF      2579 non-null   float64
#  41  TotalBsmtSF    2579 non-null   float64
#  42  Heating        2580 non-null   object
#  43  HeatingQC      2580 non-null   object
#  44  CentralAir     2580 non-null   object
#  45  Electrical     2579 non-null   object
#  46  1stFlrSF       2580 non-null   int64
#  47  2ndFlrSF       2580 non-null   int64
#  48  LowQualFinSF   2580 non-null   int64
#  49  BsmtFullBath   2578 non-null   float64
#  50  BsmtHalfBath   2578 non-null   float64
#  51  FullBath       2580 non-null   int64
#  52  HalfBath       2580 non-null   int64
#  53  BedroomAbvGr   2580 non-null   int64
#  54  KitchenAbvGr   2580 non-null   int64
#  55  KitchenQual    2580 non-null   object
#  56  TotRmsAbvGrd   2580 non-null   int64
#  57  Functional     2580 non-null   object
#  58  Fireplaces     2580 non-null   int64
#  59  FireplaceQu    1339 non-null   object
#  60  GarageType     2453 non-null   object
#  61  GarageYrBlt    2451 non-null   float64
#  62  GarageFinish   2451 non-null   object
#  63  GarageCars     2579 non-null   float64
#  64  GarageArea     2579 non-null   float64
#  65  GarageQual     2451 non-null   object
#  66  GarageCond     2451 non-null   object
#  67  PavedDrive     2580 non-null   object
#  68  WoodDeckSF     2580 non-null   int64
#  69  OpenPorchSF    2580 non-null   int64
#  70  EnclosedPorch  2580 non-null   int64
#  71  3SsnPorch      2580 non-null   int64
#  72  ScreenPorch    2580 non-null   int64
#  73  PoolArea       2580 non-null   int64
#  74  PoolQC         9 non-null      object
#  75  Fence          525 non-null    object
#  76  MiscFeature    97 non-null     object
#  77  MiscVal        2580 non-null   int64
#  78  MoSold         2580 non-null   int64
#  79  YrSold         2580 non-null   int64
#  80  SaleType       2580 non-null   object
#  81  SaleCondition  2580 non-null   object
# dtypes: float64(11), int64(28), object(43)
# memory usage: 1.6+ MB

# %%
pd.set_option('display.max_columns', None)


housing.head()
# Out:
#    Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 0           1  909176150        856     126000          30       RL
# 1           2  905476230       1049     139500         120       RL
# 2           3  911128020       1001     124900          30  C (all)
# 3           4  535377150       1039     114000          70       RL
# 4           5  534177230       1665     227000          60       RL
#
#    LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig  \
# 0          NaN     7890   Pave   NaN      Reg         Lvl    AllPub    Corner
# 1         42.0     4235   Pave   NaN      Reg         Lvl    AllPub    Inside
# 2         60.0     6060   Pave   NaN      Reg         Lvl    AllPub    Inside
# 3         80.0     8146   Pave   NaN      Reg         Lvl    AllPub    Corner
# 4         70.0     8400   Pave   NaN      Reg         Lvl    AllPub    Inside
#
#   LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0       Gtl        SWISU       Norm       Norm     1Fam     1Story
# 1       Gtl      Edwards       Norm       Norm   TwnhsE     1Story
# 2       Gtl       IDOTRR       Norm       Norm     1Fam     1Story
# 3       Gtl      OldTown       Norm       Norm     1Fam     2Story
# 4       Gtl       NWAmes       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# 0            6            6       1939          1950     Gable  CompShg
# 1            5            5       1984          1984     Gable  CompShg
# 2            5            9       1930          2007       Hip  CompShg
# 3            4            8       1900          2003     Gable  CompShg
# 4            8            6       2001          2001     Gable  CompShg
#
#   Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0     Wd Sdng     Wd Sdng       None         0.0        TA        TA
# 1     HdBoard     HdBoard    BrkFace       149.0        Gd        TA
# 2     MetalSd     MetalSd       None         0.0        Gd        TA
# 3     MetalSd     MetalSd       None         0.0        Gd        Gd
# 4     VinylSd     VinylSd       None         0.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0     CBlock       TA       TA           No          Rec       238.0
# 1     CBlock       Gd       TA           Mn          GLQ       552.0
# 2     BrkTil       TA       TA           No          ALQ       737.0
# 3     BrkTil       Fa       TA           No          Unf         0.0
# 4      PConc       Gd       TA           No          GLQ       643.0
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf         0.0      618.0        856.0    GasA        TA
# 1          ALQ       393.0      104.0       1049.0    GasA        TA
# 2          Unf         0.0      100.0        837.0    GasA        Ex
# 3          Unf         0.0      405.0        405.0    GasA        Gd
# 4          Unf         0.0      167.0        810.0    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  \
# 0          Y      SBrkr       856         0             0           1.0
# 1          Y      SBrkr      1049         0             0           1.0
# 2          Y      SBrkr      1001         0             0           0.0
# 3          Y      SBrkr       717       322             0           0.0
# 4          Y      SBrkr       810       855             0           1.0
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0           0.0         1         0             2             1          TA
# 1           0.0         2         0             2             1          Gd
# 2           0.0         1         0             2             1          Gd
# 3           0.0         1         0             2             1          TA
# 4           0.0         2         1             3             1          Gd
#
#    TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0             4        Typ           1          Gd     Detchd       1939.0
# 1             5        Typ           0         NaN     Attchd       1984.0
# 2             5        Typ           0         NaN     Detchd       1930.0
# 3             6        Typ           0         NaN     Detchd       1940.0
# 4             6        Typ           0         NaN     Attchd       2001.0
#
#   GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0          Unf         2.0       399.0         TA         TA          Y
# 1          Fin         1.0       266.0         TA         TA          Y
# 2          Unf         1.0       216.0         TA         Po          N
# 3          Unf         1.0       281.0         TA         TA          N
# 4          Fin         2.0       528.0         TA         TA          Y
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0            0              0          0          166         0
# 1           0          105              0          0            0         0
# 2         154            0             42         86            0         0
# 3           0            0            168          0          111         0
# 4           0           45              0          0            0         0
#
#   PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition
# 0    NaN   NaN         NaN        0       3    2010      WD         Normal
# 1    NaN   NaN         NaN        0       2    2009      WD         Normal
# 2    NaN   NaN         NaN        0      11    2007      WD         Normal
# 3    NaN   NaN         NaN        0       5    2009      WD         Normal
# 4    NaN   NaN         NaN        0      11    2009      WD         Normal

# %%
housing.SalePrice
# Out:
# 0       126000
# 1       139500
# 2       124900
# 3       114000
# 4       227000
#          ...
# 2575    121000
# 2576    139600
# 2577    145000
# 2578    217500
# 2579    215000
# Name: SalePrice, Length: 2580, dtype: int64

# %%
housing.shape
# Out:
# (2580, 82)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(housing.SalePrice, bins=20);

# %%
log_price = np.log(housing.SalePrice)

# %%
sns.histplot(log_price, bins=20);

# %%
size_related = housing.filter(regex='SF$|Area$')#filter out columns that end with SF or that end with Area
size_related.columns
# Out:
# Index(['GrLivArea', 'LotArea', 'MasVnrArea', 'BsmtUnfSF', 'TotalBsmtSF',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'PoolArea'],
#       dtype='object')

# %%
check_outliers = list(size_related.columns)  + ['LotFrontage']
check_outliers
# Out:
# ['GrLivArea',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'PoolArea',
#  'LotFrontage']

# %% [markdown]
# #

# %%
 price        = housing['SalePrice']
# size_related = housing.filter(regex='SF$|Area$')#filter out columns that end with SF or that end with Area
# size_related.head()

# %%
size_related.describe()
# Out:
#          GrLivArea        LotArea   MasVnrArea    BsmtUnfSF  TotalBsmtSF  \
# count  2580.000000    2580.000000  2566.000000  2579.000000  2579.000000
# mean   1486.039922   10120.153488    99.308262   539.101590  1036.686700
# std     488.650181    8126.937892   175.872330   425.199639   418.555417
# min     334.000000    1300.000000     0.000000     0.000000     0.000000
# 25%    1112.000000    7406.750000     0.000000   215.000000   792.000000
# 50%    1436.000000    9391.000000     0.000000   448.000000   979.000000
# 75%    1733.000000   11494.000000   158.000000   784.000000  1266.500000
# max    4676.000000  215245.000000  1600.000000  2336.000000  3206.000000
#
#           1stFlrSF     2ndFlrSF  LowQualFinSF   GarageArea   WoodDeckSF  \
# count  2580.000000  2580.000000   2580.000000  2579.000000  2580.000000
# mean   1144.975194   336.820155      4.244574   466.842575    95.919767
# std     375.958955   424.072452     44.403603   207.476842   129.052016
# min     334.000000     0.000000      0.000000     0.000000     0.000000
# 25%     871.750000     0.000000      0.000000   318.000000     0.000000
# 50%    1071.000000     0.000000      0.000000   474.000000     0.000000
# 75%    1364.000000   703.000000      0.000000   576.000000   168.000000
# max    3820.000000  1872.000000   1064.000000  1488.000000  1424.000000
#
#        OpenPorchSF     PoolArea
# count  2580.000000  2580.000000
# mean     46.085271     1.662016
# std      66.060664    30.339396
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%      25.500000     0.000000
# 75%      68.000000     0.000000
# max     742.000000   800.000000

# %% [markdown]
# # GrLivArea

# %%
sns.set_theme(style='darkgrid')
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.boxplot(x=housing["GrLivArea"])

# %%
housing['log_GrLivArea'] =np.log(housing.GrLivArea)

# %%
housing[['GrLivArea', 'SalePrice']].plot(kind='scatter', x='GrLivArea', y='SalePrice')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(housing.GrLivArea, bins=20);

# %%
sum(housing.GrLivArea > 4000)
mask = housing.GrLivArea > 4000
housing[mask]
# Out:
#       Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 309          310  908154205       4676     184750          60       RL
# 1007           8  528351010       4316     755000          60       RL
#
#       LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 309         130.0    40094   Pave   NaN      IR1         Bnk    AllPub
# 1007        104.0    21535   Pave   NaN      IR1         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 309     Inside       Gtl      Edwards       PosN       PosN     1Fam
# 1007    Corner       Gtl      NoRidge       Norm       Norm     1Fam
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 309      2Story           10            5       2007          2008       Hip
# 1007     2Story           10            6       1994          1995     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 309   CompShg     CemntBd     CmentBd      Stone       762.0        Ex
# 1007  WdShngl     HdBoard     HdBoard    BrkFace      1170.0        Ex
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 309         TA      PConc       Ex       TA           Gd          GLQ
# 1007        TA      PConc       Ex       TA           Gd          GLQ
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 309       2260.0          Unf         0.0      878.0       3138.0    GasA
# 1007      1455.0          Unf         0.0      989.0       2444.0    GasA
#
#      HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 309         Ex          Y      SBrkr      3138      1538             0
# 1007        Ex          Y      SBrkr      2444      1872             0
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 309            1.0           0.0         3         1             3
# 1007           0.0           1.0         3         1             4
#
#       KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 309              1          Ex            11        Typ           1
# 1007             1          Ex            10        Typ           2
#
#      FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 309           Gd    BuiltIn       2007.0          Fin         3.0       884.0
# 1007          Ex     Attchd       1994.0          Fin         3.0       832.0
#
#      GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 309          TA         TA          Y         208          406              0
# 1007         TA         TA          Y         382           50              0
#
#       3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 309           0            0         0    NaN   NaN         NaN        0
# 1007          0            0         0    NaN   NaN         NaN        0
#
#       MoSold  YrSold SaleType SaleCondition  log_GrLivArea  bc_GrLivArea  \
# 309       10    2007      New       Partial       8.450198     10.953638
# 1007       1    2007      WD         Normal       8.370084     10.822086
#
#       log_price  log_LotArea  bc_LotArea
# 309   12.126759    10.598982   22.671291
# 1007  13.534473     9.977435   20.327213

# %% [markdown]
# ####  outliers deleted a little later

# %%
housing[['GrLivArea', 'SalePrice']].plot(kind='scatter', x='GrLivArea', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
from scipy import stats

# %%
housing['bc_GrLivArea'],_ = stats.boxcox(housing.GrLivArea)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(housing.bc_GrLivArea, bins=20);

# %%
log_price.corr((housing['bc_GrLivArea']))
# Out:
# 0.7349082414036684

# %%
housing['log_GrLivArea'] = np.log(housing.GrLivArea)

# %%
housing['log_price'] = np.log(housing.SalePrice)

# %% [markdown]
# ### 'bc_GrLivArea', 'log_price'

# %%
housing[['bc_GrLivArea', 'log_price']].plot(kind='scatter', x='bc_GrLivArea', y='log_price' ) #logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='bc_GrLivArea', ylabel='log_price'>

# %%
# np.logical_and(bool1, bool2)
sum(np.logical_and((housing['bc_GrLivArea'] < 8.5), (housing['log_price'] < 9.5)))

filt = np.logical_and((housing['bc_GrLivArea'] < 8.5), (housing['log_price'] < 9.5))

housing[filt]
# Out:
#      Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 427         428  902207130        832      12789          30       RM
#
#      LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 427         68.0     9656   Pave   NaN      Reg         Lvl    AllPub
#
#     LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 427    Inside       Gtl      OldTown       Norm       Norm     1Fam
#
#     HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 427     1Story            2            2       1923          1970     Gable
#
#     RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 427  CompShg     AsbShng     AsbShng       None         0.0        TA
#
#     ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 427        Fa     BrkTil       Fa       Fa           No          Unf
#
#      BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 427         0.0          Unf         0.0      678.0        678.0    GasA
#
#     HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 427        TA          N      SBrkr       832         0             0
#
#      BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 427           0.0           0.0         1         0             2
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 427             1          TA             5        Typ           1
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 427          Gd     Detchd       1928.0          Unf         2.0       780.0
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 427         Fa         Fa          N           0            0              0
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 427          0            0         0    NaN   NaN         NaN        0
#
#      MoSold  YrSold SaleType SaleCondition  log_GrLivArea  bc_GrLivArea  \
# 427       6    2010      WD        Abnorml       6.723832      8.251993
#
#      log_price  log_LotArea  bc_LotArea
# 427   9.456341     9.175335   17.567111

# %% [markdown]
# #### make a copy of housing

# %%
housing_copy = housing.copy()

# %%
housing.shape
# Out:
# (2580, 87)

# %% [markdown]
# #### delete outlier

# %%
#code deletes outlier
filt = np.logical_and((housing['bc_GrLivArea'] < 8.5), (housing['log_price'] < 9.5))

housing[~ filt]

housing = housing[~ filt]

# %%
housing.shape
# Out:
# (2579, 87)

# %% [markdown]
# #### delete outliers

# %%
mask = housing.GrLivArea > 4000
housing = housing[~ mask]

# %%
# sns.histplot(data=housing, x='log_GrLivArea', bins=20);

# %%
# sns.histplot(data=housing, x='bc_GrLivArea', bins=20);

# %% [markdown]
# # 'LotArea'

# %%
housing[['LotArea', 'SalePrice']].plot(kind='scatter', x='LotArea', y='SalePrice',logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
# sns.histplot(data=housing, x='LotArea', bins=20);

# %%
# housing['log_LotArea'] = np.log(housing['LotArea'])

# %%
# sum(housing.log_LotArea > 10**5)

# filt2 = np.logical_and((housing['log_LotArea'] < 11), (housing['log_price'] < 9.5))

# housing[filt2]

# %%
housing[['LotArea', 'SalePrice']].plot(kind='scatter', x='LotArea', y='SalePrice') #,logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sum(housing.LotArea > 100000)
filt2 = housing.LotArea > 100000
housing[filt2]
# Out:
#       Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 249          250  906426060       2144     277000          50       RL
# 355          356  916176125       2036     375000          20       RL
# 1271         272  905301050       1824     302000          20       RL
# 1634         635  916125425       1786     228950         190       RL
#
#       LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 249           NaN   159000   Pave   NaN      IR2         Low    AllPub
# 355         150.0   215245   Pave   NaN      IR3         Low    AllPub
# 1271          NaN   115149   Pave   NaN      IR2         Low    AllPub
# 1634          NaN   164660   Grvl   NaN      IR1         HLS    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 249    CulDSac       Sev      ClearCr       Norm       Norm     1Fam
# 355     Inside       Sev       Timber       Norm       Norm     1Fam
# 1271   CulDSac       Sev      ClearCr       Norm       Norm     1Fam
# 1634    Corner       Sev       Timber       Norm       Norm   2fmCon
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 249      1.5Fin            6            7       1958          2006     Gable
# 355      1Story            7            5       1965          1965       Hip
# 1271     1Story            7            5       1971          2002     Gable
# 1634     1.5Fin            5            6       1965          1965     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 249   CompShg     Wd Sdng     HdBoard     BrkCmn       472.0        Gd
# 355   CompShg     BrkFace     BrkFace       None         0.0        TA
# 1271  CompShg     Plywood     Plywood      Stone       351.0        TA
# 1634  CompShg     Plywood     Plywood       None         0.0        TA
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 249         TA     CBlock       Gd       TA           Gd          Rec
# 355         TA     CBlock       Gd       TA           Gd          ALQ
# 1271        TA     CBlock       Gd       TA           Gd          GLQ
# 1634        TA     CBlock       TA       TA           Gd          ALQ
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 249        697.0          Unf         0.0      747.0       1444.0    GasA
# 355       1236.0          Rec       820.0       80.0       2136.0    GasW
# 1271      1219.0          Unf         0.0      424.0       1643.0    GasA
# 1634      1249.0          BLQ       147.0      103.0       1499.0    GasA
#
#      HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 249         Gd          Y      SBrkr      1444       700             0
# 355         TA          Y      SBrkr      2036         0             0
# 1271        TA          Y      SBrkr      1824         0             0
# 1634        Ex          Y      SBrkr      1619       167             0
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 249            0.0           1.0         2         0             4
# 355            2.0           0.0         2         0             3
# 1271           1.0           0.0         2         0             2
# 1634           2.0           0.0         2         0             3
#
#       KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 249              1          Gd             7        Typ           2
# 355              1          TA             8        Typ           2
# 1271             1          Gd             5        Typ           2
# 1634             1          TA             7        Typ           2
#
#      FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 249           TA     Attchd       1958.0          Fin         2.0       389.0
# 355           Gd     Attchd       1965.0          RFn         2.0       513.0
# 1271          TA     Attchd       1971.0          Unf         2.0       739.0
# 1634          Gd     Attchd       1965.0          Fin         2.0       529.0
#
#      GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 249          TA         TA          Y           0           98              0
# 355          TA         TA          Y           0            0              0
# 1271         TA         TA          Y         380           48              0
# 1634         TA         TA          Y         670            0              0
#
#       3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 249           0            0         0    NaN   NaN        Shed      500
# 355           0            0         0    NaN   NaN         NaN        0
# 1271          0            0         0    NaN   NaN         NaN        0
# 1634          0            0         0    NaN   NaN        Shed      700
#
#       MoSold  YrSold SaleType SaleCondition  log_GrLivArea  bc_GrLivArea  \
# 249        6    2007      WD         Normal       7.670429      9.699244
# 355        6    2009      WD         Normal       7.618742      9.618118
# 1271       6    2007      WD         Normal       7.508787      9.446356
# 1634       8    2008      WD         Normal       7.487734      9.413595
#
#       log_price  log_LotArea  bc_LotArea
# 249   12.531773    11.976659   28.588304
# 355   12.834681    12.279532   30.036230
# 1271  12.618182    11.653982   27.106688
# 1634  12.341259    12.011638   28.752649

# %% [markdown]
# #### drop outliers

# %%
filt2 = housing.LotArea > 100000
housing[~ filt2]
housing = housing[~ filt2]

# %%
housing.shape
# Out:
# (2575, 87)

# %%
# sum(housing.SalePrice > 700000)
# filt3 = housing.SalePrice > 700000
# housing[filt3]
# Out:
# 0

# %%
housing[['LotArea', 'SalePrice']].plot(kind='scatter', x='LotArea', y='SalePrice') #,logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sum( housing.LotArea > 70000)
filt_ = housing.LotArea > 70000
housing[filt_]
# Out:
#       Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 1955         139  906475200       1533     280000          20       RL
#
#       LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 1955         62.0    70761   Pave   NaN      IR1         Low    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 1955    Inside       Mod      ClearCr       Norm       Norm     1Fam
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 1955     1Story            7            5       1975          1975     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 1955  WdShngl     Plywood     Plywood       None         0.0        TA
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 1955        TA     CBlock       Gd       TA           Gd          ALQ
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 1955       655.0          Unf         0.0      878.0       1533.0    GasA
#
#      HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 1955        TA          Y      SBrkr      1533         0             0
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 1955           1.0           0.0         2         0             2
#
#       KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 1955             1          Gd             5        Typ           2
#
#      FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 1955          TA     Attchd       1975.0          Unf         2.0       576.0
#
#      GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 1955         TA         TA          Y         200           54              0
#
#       3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 1955          0            0         0    NaN   NaN         NaN        0
#
#       MoSold  YrSold SaleType SaleCondition  log_GrLivArea  bc_GrLivArea  \
# 1955      12    2006      WD         Normal       7.334982      9.177113
#
#       log_price  log_LotArea  bc_LotArea
# 1955  12.542545    11.167063    24.98449

# %%
housing.reset_index()
# Out:
#       index  Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 0         0           1  909176150        856     126000          30       RL
# 1         1           2  905476230       1049     139500         120       RL
# 2         2           3  911128020       1001     124900          30  C (all)
# 3         3           4  535377150       1039     114000          70       RL
# 4         4           5  534177230       1665     227000          60       RL
# ...     ...         ...        ...        ...        ...         ...      ...
# 2568   2575         759  903205040        952     121000          30       RL
# 2569   2576         760  905402060       1733     139600          20       RL
# 2570   2577         761  909275030       2002     145000          90       RH
# 2571   2578         762  907192040       1842     217500          60       RL
# 2572   2579         763  906223180       1911     215000          60       RL
#
#       LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 0             NaN     7890   Pave   NaN      Reg         Lvl    AllPub
# 1            42.0     4235   Pave   NaN      Reg         Lvl    AllPub
# 2            60.0     6060   Pave   NaN      Reg         Lvl    AllPub
# 3            80.0     8146   Pave   NaN      Reg         Lvl    AllPub
# 4            70.0     8400   Pave   NaN      Reg         Lvl    AllPub
# ...           ...      ...    ...   ...      ...         ...       ...
# 2568          NaN     8854   Pave   NaN      Reg         Lvl    AllPub
# 2569          NaN    13680   Pave   NaN      IR1         Lvl    AllPub
# 2570         82.0     6270   Pave   NaN      Reg         HLS    AllPub
# 2571          NaN     8826   Pave   NaN      Reg         Lvl    AllPub
# 2572         80.0     9554   Pave   NaN      IR1         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0       Corner       Gtl        SWISU       Norm       Norm     1Fam
# 1       Inside       Gtl      Edwards       Norm       Norm   TwnhsE
# 2       Inside       Gtl       IDOTRR       Norm       Norm     1Fam
# 3       Corner       Gtl      OldTown       Norm       Norm     1Fam
# 4       Inside       Gtl       NWAmes       Norm       Norm     1Fam
# ...        ...       ...          ...        ...        ...      ...
# 2568    Inside       Gtl      BrkSide       Norm       Norm     1Fam
# 2569   CulDSac       Gtl      Edwards       Norm       Norm     1Fam
# 2570    Inside       Gtl      Crawfor       Norm       Norm   Duplex
# 2571    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 2572    Inside       Gtl      SawyerW       Norm       Norm     1Fam
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0        1Story            6            6       1939          1950     Gable
# 1        1Story            5            5       1984          1984     Gable
# 2        1Story            5            9       1930          2007       Hip
# 3        2Story            4            8       1900          2003     Gable
# 4        2Story            8            6       2001          2001     Gable
# ...         ...          ...          ...        ...           ...       ...
# 2568     1.5Unf            6            6       1916          1950     Gable
# 2569     1Story            3            5       1955          1955       Hip
# 2570     2Story            5            6       1949          1950     Gable
# 2571     2Story            7            5       2000          2000     Gable
# 2572     2Story            8            5       1993          1994     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 0     CompShg     Wd Sdng     Wd Sdng       None         0.0        TA
# 1     CompShg     HdBoard     HdBoard    BrkFace       149.0        Gd
# 2     CompShg     MetalSd     MetalSd       None         0.0        Gd
# 3     CompShg     MetalSd     MetalSd       None         0.0        Gd
# 4     CompShg     VinylSd     VinylSd       None         0.0        Gd
# ...       ...         ...         ...        ...         ...       ...
# 2568  CompShg     Wd Sdng     Wd Sdng       None         0.0        TA
# 2569  CompShg     BrkFace     Wd Sdng       None         0.0        TA
# 2570  CompShg     MetalSd     MetalSd       None         0.0        TA
# 2571  CompShg     VinylSd     VinylSd    BrkFace       144.0        Gd
# 2572  CompShg     VinylSd     VinylSd    BrkFace       125.0        Gd
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0           TA     CBlock       TA       TA           No          Rec
# 1           TA     CBlock       Gd       TA           Mn          GLQ
# 2           TA     BrkTil       TA       TA           No          ALQ
# 3           Gd     BrkTil       Fa       TA           No          Unf
# 4           TA      PConc       Gd       TA           No          GLQ
# ...        ...        ...      ...      ...          ...          ...
# 2568        TA     BrkTil       TA       TA           No          Unf
# 2569        TA       Slab      NaN      NaN          NaN          NaN
# 2570        TA     CBlock       TA       TA           No          BLQ
# 2571        TA      PConc       Gd       TA           No          GLQ
# 2572        TA      PConc       Gd       TA           No          GLQ
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 0          238.0          Unf         0.0      618.0        856.0    GasA
# 1          552.0          ALQ       393.0      104.0       1049.0    GasA
# 2          737.0          Unf         0.0      100.0        837.0    GasA
# 3            0.0          Unf         0.0      405.0        405.0    GasA
# 4          643.0          Unf         0.0      167.0        810.0    GasA
# ...          ...          ...         ...        ...          ...     ...
# 2568         0.0          Unf         0.0      952.0        952.0    Grav
# 2569         0.0          NaN         0.0        0.0          0.0    GasA
# 2570       284.0          Unf         0.0      717.0       1001.0    GasA
# 2571       841.0          Unf         0.0      144.0        985.0    GasA
# 2572       380.0          Unf         0.0      397.0        777.0    GasA
#
#      HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0           TA          Y      SBrkr       856         0             0
# 1           TA          Y      SBrkr      1049         0             0
# 2           Ex          Y      SBrkr      1001         0             0
# 3           Gd          Y      SBrkr       717       322             0
# 4           Ex          Y      SBrkr       810       855             0
# ...        ...        ...        ...       ...       ...           ...
# 2568        Fa          N      FuseF       952         0             0
# 2569        Ex          Y      FuseA      1733         0             0
# 2570        TA          N      FuseA      1001      1001             0
# 2571        Ex          Y      SBrkr       985       857             0
# 2572        Ex          Y      SBrkr      1065       846             0
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0              1.0           0.0         1         0             2
# 1              1.0           0.0         2         0             2
# 2              0.0           0.0         1         0             2
# 3              0.0           0.0         1         0             2
# 4              1.0           0.0         2         1             3
# ...            ...           ...       ...       ...           ...
# 2568           0.0           0.0         1         0             2
# 2569           0.0           0.0         2         0             4
# 2570           0.0           0.0         2         0             4
# 2571           1.0           0.0         2         1             3
# 2572           0.0           0.0         2         1             3
#
#       KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 0                1          TA             4        Typ           1
# 1                1          Gd             5        Typ           0
# 2                1          Gd             5        Typ           0
# 3                1          TA             6        Typ           0
# 4                1          Gd             6        Typ           0
# ...            ...         ...           ...        ...         ...
# 2568             1          Fa             4        Typ           1
# 2569             1          TA             8       Min2           1
# 2570             2          TA             8        Typ           0
# 2571             1          Gd             7        Typ           1
# 2572             1          Gd             8        Typ           1
#
#      FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 0             Gd     Detchd       1939.0          Unf         2.0       399.0
# 1            NaN     Attchd       1984.0          Fin         1.0       266.0
# 2            NaN     Detchd       1930.0          Unf         1.0       216.0
# 3            NaN     Detchd       1940.0          Unf         1.0       281.0
# 4            NaN     Attchd       2001.0          Fin         2.0       528.0
# ...          ...        ...          ...          ...         ...         ...
# 2568          Gd     Detchd       1916.0          Unf         1.0       192.0
# 2569          Gd     Attchd       1955.0          Unf         2.0       452.0
# 2570         NaN     2Types       1949.0          Unf         3.0       871.0
# 2571          TA     Attchd       2000.0          Fin         2.0       486.0
# 2572          TA     Attchd       1993.0          RFn         2.0       471.0
#
#      GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 0            TA         TA          Y           0            0              0
# 1            TA         TA          Y           0          105              0
# 2            TA         Po          N         154            0             42
# 3            TA         TA          N           0            0            168
# 4            TA         TA          Y           0           45              0
# ...         ...        ...        ...         ...          ...            ...
# 2568         Fa         Po          P           0           98              0
# 2569         TA         TA          Y           0            0              0
# 2570         TA         TA          Y           0            0              0
# 2571         TA         TA          Y         193           96              0
# 2572         TA         TA          Y         182           81              0
#
#       3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 0             0          166         0    NaN   NaN         NaN        0
# 1             0            0         0    NaN   NaN         NaN        0
# 2            86            0         0    NaN   NaN         NaN        0
# 3             0          111         0    NaN   NaN         NaN        0
# 4             0            0         0    NaN   NaN         NaN        0
# ...         ...          ...       ...    ...   ...         ...      ...
# 2568          0           40         0    NaN   NaN         NaN        0
# 2569          0            0         0    NaN   NaN         NaN        0
# 2570          0            0         0    NaN   NaN         NaN        0
# 2571          0            0         0    NaN   NaN         NaN        0
# 2572          0            0         0    NaN   NaN         NaN        0
#
#       MoSold  YrSold SaleType SaleCondition  log_GrLivArea  bc_GrLivArea  \
# 0          3    2010      WD         Normal       6.752270      8.294305
# 1          2    2009      WD         Normal       6.955593      8.598898
# 2         11    2007      WD         Normal       6.908755      8.528407
# 3          5    2009      WD         Normal       6.946014      8.584466
# 4         11    2009      WD         Normal       7.417580      9.304723
# ...      ...     ...      ...           ...            ...           ...
# 2568       5    2009      WD         Normal       6.858565      8.453087
# 2569       6    2009      WD         Normal       7.457609      9.366789
# 2570       8    2007      WD         Normal       7.601902      9.591739
# 2571       7    2007      WD         Normal       7.518607      9.461650
# 2572       9    2006      WD         Normal       7.555382      9.519006
#
#       log_price  log_LotArea  bc_LotArea
# 0     11.744037     8.973351   16.915926
# 1     11.845820     8.351139   15.013336
# 2     11.735269     8.709465   16.090335
# 3     11.643954     9.005282   17.017744
# 4     12.332705     9.035987   17.116048
# ...         ...          ...         ...
# 2568  11.703546     9.088625   17.285482
# 2569  11.846536     9.523690   18.730840
# 2570  11.884489     8.743532   16.195342
# 2571  12.289954     9.085457   17.275254
# 2572  12.278393     9.164715   17.532450
#
# [2573 rows x 88 columns]

# %%
# Nbr_quantile = housing.groupby('Neighborhood')['GrLivArea'].quantile(0.8)  #bottom 80 percent of gross living are
# joint_Nbr_quantile = pd.merge(housing[['Neighborhood']], Nbr_quantile, how='left', left_on='Neighborhood', right_index=True)

# %%
housing['bc_LotArea'],_ = stats.boxcox(housing['LotArea'])

# %%
housing[['bc_LotArea', 'log_price']].plot(kind='scatter', x='bc_LotArea', y='log_price') #,logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='bc_LotArea', ylabel='log_price'>

# %% [markdown]
# # MasVnrArea

# %%
housing[['MasVnrArea', 'SalePrice']].plot(kind='scatter', x='MasVnrArea', y='SalePrice') #, logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='MasVnrArea', ylabel='SalePrice'>

# %%
housing[['MasVnrArea', 'SalePrice']].plot(kind='scatter', x='MasVnrArea', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='MasVnrArea', ylabel='SalePrice'>

# %%
# housing['yeo_MasVnrArea'],_ = stats.yeojohnson(housing['MasVnrArea'])

# %%
log_price.corr(np.log(housing['MasVnrArea'] + 1))

# %%
housing['log_MasVnrArea'] = np.log(housing['MasVnrArea'] + 1)

# %%
log_price.corr(housing['yeo_MasVnrArea'])

# %%
housing['log_MasVnrArea'] = np.log(size_related['MasVnrArea'] + 1)

# %%
sns.histplot(data=housing, x='MasVnrArea', bins=20);

# %%
sns.histplot(data=housing, x='log_MasVnrArea', bins=20);

# %%
sns.histplot(data=housing, x='log_MasVnrArea', bins=20);

# %% [markdown]
# # BsmtUnfSF

# %%
housing[['BsmtUnfSF', 'SalePrice']].plot(kind='scatter', x='BsmtUnfSF', y='SalePrice') #, logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtUnfSF', ylabel='SalePrice'>

# %%
housing[['BsmtUnfSF', 'SalePrice']].plot(kind='scatter', x='BsmtUnfSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtUnfSF', ylabel='SalePrice'>

# %%
housing[['BsmtUnfSF', 'SalePrice']].plot(kind='scatter', x='BsmtUnfSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtUnfSF', ylabel='SalePrice'>

# %% [markdown]
# # TotalBsmtSF

# %%
housing[['TotalBsmtSF', 'SalePrice']].plot(kind='scatter', x='TotalBsmtSF', y='SalePrice') #, logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
# TotalBsmtSF 
housing[['TotalBsmtSF', 'SalePrice']].plot(kind='scatter', x='TotalBsmtSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %% [markdown]
# # 1stFlrSF

# %%
housing[['1stFlrSF', 'SalePrice']].plot(kind='scatter', x='1stFlrSF', y='SalePrice')#, logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %%
# 1stFlrSF

housing[['1stFlrSF', 'SalePrice']].plot(kind='scatter', x='1stFlrSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %% [markdown]
# #  2ndFlrSF

# %%
housing[['2ndFlrSF', 'SalePrice']].plot(kind='scatter', x='2ndFlrSF', y='SalePrice')#, logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='2ndFlrSF', ylabel='SalePrice'>

# %%
# 2ndFlrSF

housing[['2ndFlrSF', 'SalePrice']].plot(kind='scatter', x='2ndFlrSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='2ndFlrSF', ylabel='SalePrice'>

# %% [markdown]
# # LowQualFinSF: Low quality finished square feet (all floors)

# %%
#LowQualFinSF: Low quality finished square feet (all floors)
housing[['LowQualFinSF', 'SalePrice']].plot(kind='scatter', x='LowQualFinSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LowQualFinSF', ylabel='SalePrice'>

# %% [markdown]
# # GarageArea

# %%
# GarageArea 

housing[['GarageArea', 'SalePrice']].plot(kind='scatter', x='GarageArea', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %% [markdown]
# # WoodDeckSF

# %%
# WoodDeckSF 
housing[['WoodDeckSF', 'SalePrice']].plot(kind='scatter', x='WoodDeckSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='WoodDeckSF', ylabel='SalePrice'>

# %% [markdown]
# #  OpenPorchSF

# %%
# OpenPorchSF 
housing[['OpenPorchSF', 'SalePrice']].plot(kind='scatter', x='OpenPorchSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='OpenPorchSF', ylabel='SalePrice'>

# %% [markdown]
# # Pool

# %%
housing[['PoolArea', 'SalePrice']].plot(kind='scatter', x='PoolArea', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='PoolArea', ylabel='SalePrice'>

# %% [markdown]
# # 'LotFrontage'

# %%
housing[['LotFrontage', 'SalePrice']].plot(kind='scatter', x='LotFrontage', y='SalePrice')#, logx=True, logy=True
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %%
housing[['LotFrontage', 'SalePrice']].plot(kind='scatter', x='LotFrontage', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %%
sum(housing['LotFrontage'] > 300)
filt3 = housing['LotFrontage'] > 300
housing[filt3]
# Out:
#      Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 981         982  535427070       2069     242000          20       RL
#
#      LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 981        313.0    27650   Pave   NaN      IR2         HLS    AllPub
#
#     LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 981    Inside       Mod        NAmes       PosA       Norm     1Fam
#
#     HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 981     1Story            7            7       1960          2007      Flat
#
#     RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 981  Tar&Grv     Wd Sdng     Wd Sdng       None         0.0        TA
#
#     ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 981        TA     CBlock       Gd       TA           Gd          GLQ
#
#      BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 981       425.0          Unf         0.0      160.0        585.0    GasA
#
#     HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 981        Ex          Y      SBrkr      2069         0             0
#
#      BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 981           1.0           0.0         2         0             4
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 981             1          Gd             9        Typ           1
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 981          Gd     Attchd       1960.0          RFn         2.0       505.0
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 981         TA         TA          Y           0            0              0
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 981          0            0         0    NaN   NaN         NaN        0
#
#      MoSold  YrSold SaleType SaleCondition  log_GrLivArea  bc_GrLivArea  \
# 981      11    2008      WD         Normal       7.634821      9.643328
#
#      log_price  log_LotArea  bc_LotArea
# 981  12.396693    10.227381   21.247319

# %% [markdown]
# #### remove outlier

# %%
filt3 = housing['LotFrontage'] > 300
housing = housing[~filt3]

# %%
# sns.heatmap(other_numerics.corr(), cmap="Blues", center=0); #cmap="Blues", cmap='RdBu',
# log_price.corr(housing['YearRemodAdd'])

# %%
# 'GrLivArea',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'PoolArea']

# %% [markdown]
# # BsmtFinSF1: Type 1 finished square feet

# %%
# BsmtFinSF1

# sns.set_theme(style='darkgrid')

# ax = sns.barplot(x="BsmtFinSF1", y="SalePrice", data=other_numerics, color='skyblue' ,ci=None)

housing[['BsmtFinSF1', 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtFinSF1', ylabel='SalePrice'>

# %% [markdown]
# # BsmtUnfSF

# %%
# BsmtUnfSF

housing[['BsmtUnfSF', 'SalePrice']].plot(kind='scatter', x='BsmtUnfSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtUnfSF', ylabel='SalePrice'>

# %% [markdown]
# # EnclosedPorch

# %%
housing[['EnclosedPorch', 'SalePrice']].plot(kind='scatter', x='EnclosedPorch', y='SalePrice', logx=True, logy=True) #logx=True,    ,, 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='EnclosedPorch', ylabel='SalePrice'>
