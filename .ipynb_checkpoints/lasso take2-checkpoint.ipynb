# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import GridSearchCV

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
from scipy import stats
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
model_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\model_vars_data_n.csv',index_col=0)

test_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\test_vars_data_n.csv',index_col=0)

price_train = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\ny_train.csv',index_col=0)

price_test = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\ny_test.csv',index_col=0)

# %%
# list(model_vars_data.columns) 
model_vars_data = model_vars_data.drop(['MoSold','MSSubClass','LotArea'], axis = 1)
test_vars_data = test_vars_data.drop(['MoSold','MSSubClass','LotArea'], axis = 1) 
#there is a transformed version of LotArea

# %%
# Fucntion returns dictionary

def regx3(
model=  None,
x_train = None,
x_test = None,
y_train = None,
y_test =  None,
params = None,
cv_ = 5,
linear_reg = True,
tree_based = False):
######################################
#########################################

    features = list(x_train.columns)

    ss = StandardScaler()
    x_train = pd.DataFrame(ss.fit_transform(x_train), columns = features)
    x_test = pd.DataFrame(ss.fit_transform(x_test), columns = features)

    #     print('train ',x_train.head())
    #     print(' ')
    #     print('test ', x_test.head())


    gs = GridSearchCV(model, params, cv=cv_, return_train_score=True, refit=True)
    gs.fit(x_train,y_train)
    gs.best_params_

    reg_dict = {}
    model= gs.best_estimator_
    reg_dict['mod'] = model
    ###################################    

    print('best params: ',gs.best_params_)
    reg_dict['best params'] = gs.best_params_

    print('score: ',gs.score(x_train,y_train))
    reg_dict['score'] = gs.score(x_train,y_train)

    print('  ')
    print('test score: ',gs.score(x_test,y_test))
    reg_dict['test score'] = gs.score(x_test,y_test)

    if linear_reg:
        adj_r2 = 1-(1-gs.score(x_train,y_train))*(x_train.shape[0] - 1) / (x_train.shape[0] - x_train.shape[1] - 1)
        print('adj_r2: ', adj_r2)
        reg_dict['adj_r2'] = adj_r2

        adj_r2_test = 1-(1-gs.score(x_test,y_test))*(x_test.shape[0] - 1) / (x_test.shape[0] - x_test.shape[1] - 1)
        print('  ')
        print('adj_r2_test: ',adj_r2_test)
        reg_dict['adj_r2_test'] = adj_r2_test

        print(' ')

    train_pred = gs.best_estimator_.predict(x_train)
    print('train RMSE: ' + str(mean_squared_error(train_pred,y_train)**0.5))
    print('  ')
    reg_dict['train RMSE'] = mean_squared_error(train_pred,y_train)**0.5

    test_pred = gs.best_estimator_.predict(x_test)
    print('test RMSE: ' + str(mean_squared_error(test_pred,y_test)**0.5))
    ###
    reg_dict['test RMSE'] = mean_squared_error(test_pred,y_test)**0.5

    if linear_reg:

        coefs = pd.Series(gs.best_estimator_.coef_, name = 'coef' )

        varnames = pd.Series(features, name = 'features')

        pd.set_option('display.max_rows', None) # or 1000.

        abs_coefs = pd.Series(np.abs(coefs),name = 'abs_val')

        coefs_ = pd.concat([varnames,coefs, abs_coefs], axis=1)

        #return:
        model_importances = coefs_.sort_values(by=['abs_val'], ascending=False)
        model_importances.index=(range(model_importances.shape[0]))
        model_importances
        reg_dict['model_importances'] = model_importances

        print(model_importances)
        print(' ')

    elif tree_based:
        pd.set_option('display.max_rows', None) # or 1000.

        #return
        varnames = pd.Series(features, name = 'features')

        importances_ = pd.Series(model.feature_importances_, name = 'importances')

        df = pd.concat([varnames,importances_], axis=1)

        model_importances = df.sort_values(by=['importances'], ascending=False)

        model_importances.index=(range(model_importances.shape[0]))

        reg_dict['model_importances'] = model_importances



    #         model_importances = pd.Series(model.feature_importances_, index = features).sort_values(ascending=False)

        print(model_importances)


    if linear_reg:
        residuals = y_train - train_pred
        print('skewness: ',stats.skew(residuals))
        print(' ')
        sns.set_theme(style='darkgrid')
        sns.histplot(residuals, bins=20);

    print('model_importances.shape: ',model_importances.shape)
    
    return reg_dict

# %%
def to_keep(mod, amt):
    mod = mod['model_importances']
    keeps1 = mod.loc[mod['abs_val'] > amt,['features']]
    list_keeps1 = list(keeps1.features)
    return list_keeps1

# %% [markdown]
# remove due to mulicollinearity - see Correlations Analysis notebook

# %%
remove = ['log_first_FlrSF','BsmtFinSF1', 'BsmtUnfSF','yeo_GarageArea','GarageCars',
          'yeo_LotFrontage', 'BsmtFinSF2' ] #remove due to mulicollinearity #drop GarageYrBlt
#see Correlations Analysis notebook

# %%
keeps_set = set(model_vars_data.columns) - set(remove)
keeps_set
keeps = list(keeps_set)

# %%
lasso1 = regx3(model= Lasso(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.9452412273148416
#
# test score:  0.9258763584989563
# adj_r2:  0.9383228732169062
#
# adj_r2_test:  0.899591379243267
#
# train RMSE: 0.08832901542732452
#
# test RMSE: 0.10146907642713004
#                                               features      coef   abs_val
# 0                                         bc_GrLivArea  0.158234  0.158234
# 1                                           house_age_ -0.068357  0.068357
# 2                                          OverallQual  0.065812  0.065812
# 3                                          OverallCond  0.046934  0.046934
# 4                                           bc_LotArea  0.037804  0.037804
# 5                                      yeo_TotalBsmtSF  0.034306  0.034306
# 6                                      log_OpenPorchSF  0.027678  0.027678
# 7                                        has_openporch -0.024300  0.024300
# 8         Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.022361  0.022361
# 9                                         BsmtFullBath  0.021774  0.021774
# 10                                         MSZoning_RM -0.018907  0.018907
# 11                                     Condition1_Norm  0.018700  0.018700
# 12                                          Functional  0.018654  0.018654
# 13                                         KitchenQual  0.016542  0.016542
# 14                                        BsmtFinType1  0.016129  0.016129
# 15                                          GarageCond  0.015839  0.015839
# 16                                          Fireplaces  0.015772  0.015772
# 17                                 Exterior1st_BrkFace  0.015591  0.015591
# 18                                        BsmtExposure  0.015460  0.015460
# 19   Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.014730  0.014730
# 20                                      log_MasVnrArea  0.014471  0.014471
# 21                                     MasVnrType_None  0.014277  0.014277
# 22                               SaleCondition_Partial  0.013411  0.013411
# 23                                      MSSubClass_160 -0.013024  0.013024
# 24                                        BedroomAbvGr -0.012636  0.012636
# 25                                            2ndFlrSF  0.012427  0.012427
# 26                                SaleCondition_Family -0.011696  0.011696
# 27                                 Exterior2nd_VinylSd  0.011576  0.011576
# 28                                           HeatingQC  0.011523  0.011523
# 29                                         ScreenPorch  0.010805  0.010805
# 30                                       MSSubClass_60 -0.009611  0.009611
# 31                                     Condition1_PosN  0.009551  0.009551
# 32                                        KitchenAbvGr -0.009474  0.009474
# 33                                     LandContour_HLS  0.009358  0.009358
# 34                         Neighborhood_Somerst_Timber  0.009271  0.009271
# 35                     Neighborhood_NAmes_SWISU_Sawyer -0.009145  0.009145
# 36                                    MasVnrType_Stone  0.008787  0.008787
# 37                              years_since_remodeled_ -0.008411  0.008411
# 38                                 Exterior1st_VinylSd -0.008389  0.008389
# 39                                   HouseStyle_1Story  0.008383  0.008383
# 40                                      BldgType_Twnhs -0.007772  0.007772
# 41                                        CentralAir_Y  0.007128  0.007128
# 42                                    GarageFinish_RFn -0.007083  0.007083
# 43                                   GarageType_Detchd  0.006943  0.006943
# 44                                         MSZoning_RH -0.006698  0.006698
# 45                                        BsmtHalfBath  0.006516  0.006516
# 46                                SaleCondition_Normal  0.006435  0.006435
# 47                                Neighborhood_SawyerW -0.006298  0.006298
# 48                                           ExterQual  0.006189  0.006189
# 49                                  Exterior2nd_CBlock  0.006152  0.006152
# 50                                       MSSubClass_85  0.006112  0.006112
# 51                                         MSZoning_RL -0.006110  0.006110
# 52                         Neighborhood_Gilbert_NWAmes -0.005992  0.005992
# 53                                 Exterior1st_MetalSd  0.005795  0.005795
# 54                                    Foundation_PConc  0.005722  0.005722
# 55                                 Exterior2nd_Brk Cmn  0.005675  0.005675
# 56                                   RoofStyle_Mansard -0.005594  0.005594
# 57                                     Condition1_PosA  0.005486  0.005486
# 58                                  MasVnrType_BrkFace  0.005155  0.005155
# 59                                  Exterior1st_CBlock -0.005097  0.005097
# 60                                    GarageFinish_Unf -0.004896  0.004896
# 61                                    Condition2_Feedr -0.004839  0.004839
# 62                                 Exterior1st_PreCast  0.004715  0.004715
# 63                                    RoofMatl_WdShngl  0.004509  0.004509
# 64                              has_finsished_basement -0.004507  0.004507
# 65                                            HalfBath  0.004387  0.004387
# 66                                     Condition2_PosA  0.004368  0.004368
# 67                                    Electrical_SBrkr  0.004273  0.004273
# 68                                       MSSubClass_70  0.004132  0.004132
# 69                                       MSSubClass_20  0.004100  0.004100
# 70                                   HouseStyle_SFoyer  0.003979  0.003979
# 71                                         FireplaceQu  0.003855  0.003855
# 72                                      MSSubClass_150 -0.003716  0.003716
# 73                                   HouseStyle_1.5Unf  0.003616  0.003616
# 74                                   HouseStyle_2Story -0.003300  0.003300
# 75                                         GarageYrBlt  0.003278  0.003278
# 76                                        Heating_Grav -0.003202  0.003202
# 77                                 Exterior2nd_BrkFace -0.003123  0.003123
# 78                                   has_EnclosedPorch  0.002958  0.002958
# 79                                      has_wood_deck   0.002848  0.002848
# 80                                            MoSold_3 -0.002753  0.002753
# 81                                            MoSold_7  0.002743  0.002743
# 82                                        PavedDrive_Y  0.002722  0.002722
# 83                                        Heating_Wall  0.002628  0.002628
# 84                                 Exterior1st_Plywood -0.002574  0.002574
# 85                                        LowQualFinSF -0.002544  0.002544
# 86                                       MSSubClass_30  0.002518  0.002518
# 87                                     BldgType_TwnhsE -0.002507  0.002507
# 88                                           3SsnPorch  0.002506  0.002506
# 89                                     Condition1_RRAn  0.002468  0.002468
# 90                                 Exterior2nd_PreCast  0.002465  0.002465
# 91                                        alley_access -0.002449  0.002449
# 92                                    Foundation_Stone  0.002353  0.002353
# 93                                    RoofMatl_Membran  0.002330  0.002330
# 94                Neighborhood_ClearCr_CollgCr_Crawfor  0.002322  0.002322
# 95                                       RoofStyle_Hip  0.002230  0.002230
# 96                                        Heating_OthW -0.002197  0.002197
# 97                                     Foundation_Wood -0.002171  0.002171
# 98                                        BsmtFinType2  0.002019  0.002019
# 99                                   RoofStyle_Gambrel -0.002011  0.002011
# 100                                     MSSubClass_180 -0.002005  0.002005
# 101                                      LotConfig_FR2 -0.001929  0.001929
# 102                                    BldgType_Duplex -0.001852  0.001852
# 103                                 GarageType_Basment -0.001823  0.001823
# 104                                    Condition2_RRNn  0.001806  0.001806
# 105                                    Condition1_RRNn  0.001804  0.001804
# 106                                Exterior2nd_Plywood -0.001726  0.001726
# 107                                           Fence_No -0.001621  0.001621
# 108                                      MSSubClass_40 -0.001334  0.001334
# 109                                    LandContour_Low  0.001326  0.001326
# 110                                Exterior1st_Wd Sdng  0.001323  0.001323
# 111                                      MSSubClass_75  0.001296  0.001296
# 112                                Exterior1st_WdShing -0.001292  0.001292
# 113                                    Condition2_RRAn -0.001275  0.001275
# 114                                           MoSold_6  0.001111  0.001111
# 115                                       TotRmsAbvGrd  0.001046  0.001046
# 116                                      LotConfig_FR3 -0.001020  0.001020
# 117                                   Condition1_Feedr  0.001004  0.001004
# 118                                           MoSold_9 -0.000991  0.000991
# 119                                         Fence_MnWw -0.000953  0.000953
# 120                                    LandContour_Lvl  0.000942  0.000942
# 121                                    Condition1_RRAe -0.000847  0.000847
# 122                                   LotConfig_Inside  0.000830  0.000830
# 123                                           BsmtCond -0.000807  0.000807
# 124                                  Foundation_CBlock -0.000762  0.000762
# 125                                       PavedDrive_P -0.000707  0.000707
# 126                                          LandSlope -0.000663  0.000663
# 127                                          MoSold_11 -0.000528  0.000528
# 128                                           has_pool  0.000497  0.000497
# 129                                Exterior2nd_AsphShn  0.000487  0.000487
# 130                                    BldgType_2fmCon -0.000462  0.000462
# 131                                Exterior1st_AsphShn  0.000433  0.000433
# 132                                    Condition1_RRNe  0.000366  0.000366
# 133                                   RoofMatl_WdShake  0.000362  0.000362
# 134                                    Foundation_Slab -0.000348  0.000348
# 135                                  Exterior2nd_Stone -0.000296  0.000296
# 136                                   RoofMatl_Tar&Grv  0.000272  0.000272
# 137                                 GarageType_BuiltIn -0.000219  0.000219
# 138                                      MSSubClass_45  0.000216  0.000216
# 139                                          MoSold_10 -0.000205  0.000205
# 140                       Neighborhood_Mitchel_NPkVill  0.000175  0.000175
# 141                                   Electrical_FuseF -0.000154  0.000154
# 142                                  HouseStyle_2.5Unf  0.000032  0.000032
# 143                                          MoSold_12 -0.000024  0.000024
# 144                               SaleCondition_Alloca  0.000000  0.000000
# 145                                     log_WoodDeckSF  0.000000  0.000000
# 146                                     MSSubClass_190 -0.000000  0.000000
# 147                                           FullBath  0.000000  0.000000
# 148                                    Condition2_PosN  0.000000  0.000000
# 149                                  LotConfig_CulDSac -0.000000  0.000000
# 150                                           BsmtQual  0.000000  0.000000
# 151                                 Exterior2nd_Stucco  0.000000  0.000000
# 152                                           PoolArea -0.000000  0.000000
# 153                                Exterior2nd_CmentBd  0.000000  0.000000
# 154                                 GarageType_CarPort  0.000000  0.000000
# 155                                      MSSubClass_90 -0.000000  0.000000
# 156                                           MoSold_4 -0.000000  0.000000
# 157                                Exterior2nd_MetalSd -0.000000  0.000000
# 158                                  log_EnclosedPorch  0.000000  0.000000
# 159                                   Electrical_FuseP -0.000000  0.000000
# 160                                           MoSold_8  0.000000  0.000000
# 161                                     RoofMatl_Metal  0.000000  0.000000
# 162                                Exterior1st_CemntBd  0.000000  0.000000
# 163                                    has_miscfeature  0.000000  0.000000
# 164                                         GarageQual  0.000000  0.000000
# 165                                Exterior1st_ImStucc  0.000000  0.000000
# 166                                    Condition2_Norm -0.000000  0.000000
# 167                                           LotShape  0.000000  0.000000
# 168                                 Exterior1st_Stucco -0.000000  0.000000
# 169                                Exterior2nd_HdBoard  0.000000  0.000000
# 170                                        Street_Pave  0.000000  0.000000
# 171                                            MiscVal -0.000000  0.000000
# 172                                Exterior1st_HdBoard  0.000000  0.000000
# 173                                Exterior2nd_Wd Shng  0.000000  0.000000
# 174                                           MoSold_5  0.000000  0.000000
# 175                                   Electrical_Mixed  0.000000  0.000000
# 176                                    HouseStyle_SLvl  0.000000  0.000000
# 177                              SaleCondition_AdjLand  0.000000  0.000000
# 178                                     RoofStyle_Shed -0.000000  0.000000
# 179                                      GarageType_No -0.000000  0.000000
# 180                                  GarageType_Attchd  0.000000  0.000000
# 181                                    Condition2_RRAe  0.000000  0.000000
# 182                                    GarageFinish_No -0.000000  0.000000
# 183                                    RoofStyle_Gable -0.000000  0.000000
# 184                                        Fence_MnPrv  0.000000  0.000000
# 185                                Exterior2nd_Wd Sdng  0.000000  0.000000
# 186                                Exterior1st_BrkComm  0.000000  0.000000
# 187                                       Heating_GasW  0.000000  0.000000
# 188                Neighborhood_Greens_SawyerW_Blmngtn -0.000000  0.000000
# 189                                Exterior2nd_ImStucc  0.000000  0.000000
# 190                                   Utilities_NoSewr  0.000000  0.000000
# 191                                      MSSubClass_80 -0.000000  0.000000
# 192                                       Heating_GasA -0.000000  0.000000
# 193                                           MoSold_2 -0.000000  0.000000
# 194                                      MSSubClass_50  0.000000  0.000000
# 195                                      RoofMatl_Roll -0.000000  0.000000
# 196                                       has_basement -0.000000  0.000000
# 197                                  HouseStyle_2.5Fin -0.000000  0.000000
# 198                                          ExterCond -0.000000  0.000000
# 199                                         Fence_GdWo  0.000000  0.000000
#
# skewness:  -0.3690584244679914
#
# model_importances.shape:  (200, 3)

# %%
keeps = to_keep(lasso1, 0.0002)

# %%
lasso2 = regx3(model= Lasso(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.9451033273955944
#
# test score:  0.9253331857178297
# adj_r2:  0.9404255829253468
#
# adj_r2_test:  0.90858101584683
#
# train RMSE: 0.08844016570069387
#
# test RMSE: 0.1018401769117426
#                                               features      coef   abs_val
# 0                                         bc_GrLivArea  0.132527  0.132527
# 1                                          OverallQual  0.069599  0.069599
# 2                                           house_age_ -0.063325  0.063325
# 3                                      yeo_TotalBsmtSF  0.047000  0.047000
# 4                                          OverallCond  0.045726  0.045726
# 5                                           bc_LotArea  0.041862  0.041862
# 6                                             2ndFlrSF  0.028131  0.028131
# 7                                          MSZoning_RM -0.022636  0.022636
# 8                                      Condition1_Norm  0.022013  0.022013
# 9         Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.021874  0.021874
# 10                                        BsmtFullBath  0.020696  0.020696
# 11                                          Fireplaces  0.020671  0.020671
# 12                                        BsmtExposure  0.017940  0.017940
# 13                                        BsmtFinType1  0.016860  0.016860
# 14                                          GarageCond  0.016653  0.016653
# 15                                          Functional  0.016540  0.016540
# 16                                         KitchenQual  0.016063  0.016063
# 17                                           HeatingQC  0.015482  0.015482
# 18                               SaleCondition_Partial  0.015321  0.015321
# 19                                 Exterior1st_BrkFace  0.015086  0.015086
# 20   Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.012629  0.012629
# 21                                   HouseStyle_1Story  0.011425  0.011425
# 22                                     Condition1_PosN  0.011223  0.011223
# 23                                SaleCondition_Family -0.010796  0.010796
# 24                                           ExterQual  0.010738  0.010738
# 25                                         MSZoning_RL -0.010409  0.010409
# 26                                         ScreenPorch  0.010220  0.010220
# 27                                        BedroomAbvGr -0.009728  0.009728
# 28                                      log_MasVnrArea  0.009186  0.009186
# 29                         Neighborhood_Somerst_Timber  0.009160  0.009160
# 30                                     LandContour_HLS  0.008935  0.008935
# 31                                        CentralAir_Y  0.008591  0.008591
# 32                                        KitchenAbvGr -0.008336  0.008336
# 33                                      BldgType_Twnhs -0.008326  0.008326
# 34                                   HouseStyle_2Story -0.008145  0.008145
# 35                                      MSSubClass_160 -0.007840  0.007840
# 36                                     Condition1_PosA  0.007534  0.007534
# 37                              years_since_remodeled_ -0.007497  0.007497
# 38                     Neighborhood_NAmes_SWISU_Sawyer -0.007428  0.007428
# 39                                SaleCondition_Normal  0.007272  0.007272
# 40                                       MSSubClass_70  0.007043  0.007043
# 41                                         MSZoning_RH -0.006941  0.006941
# 42                                Neighborhood_SawyerW -0.006193  0.006193
# 43                                        BsmtHalfBath  0.005790  0.005790
# 44                                       MSSubClass_85  0.005764  0.005764
# 45                         Neighborhood_Gilbert_NWAmes -0.005649  0.005649
# 46                                 Exterior2nd_Brk Cmn  0.005448  0.005448
# 47                                   RoofStyle_Mansard -0.005212  0.005212
# 48                                 Exterior1st_MetalSd  0.005206  0.005206
# 49                                         GarageYrBlt  0.005139  0.005139
# 50                                  Exterior2nd_CBlock  0.005093  0.005093
# 51                                            BsmtCond -0.004645  0.004645
# 52                                 Exterior1st_PreCast  0.004576  0.004576
# 53                                    Condition2_Feedr -0.004480  0.004480
# 54                                     Condition2_PosA  0.004266  0.004266
# 55                                    GarageFinish_RFn -0.004077  0.004077
# 56                                   Foundation_CBlock -0.003944  0.003944
# 57                                    RoofMatl_WdShngl  0.003900  0.003900
# 58                                    Condition1_Feedr  0.003791  0.003791
# 59                                     BldgType_TwnhsE -0.003662  0.003662
# 60                                  Exterior1st_CBlock -0.003492  0.003492
# 61                                   HouseStyle_1.5Unf  0.003424  0.003424
# 62                                       MSSubClass_60 -0.003184  0.003184
# 63                                   HouseStyle_SFoyer  0.003151  0.003151
# 64                                            Fence_No -0.002886  0.002886
# 65                                    MasVnrType_Stone  0.002873  0.002873
# 66                                        TotRmsAbvGrd  0.002862  0.002862
# 67                                        Heating_Grav -0.002861  0.002861
# 68                                     Condition1_RRAn  0.002845  0.002845
# 69                                        Heating_Wall  0.002838  0.002838
# 70                                 Exterior2nd_BrkFace -0.002825  0.002825
# 71                                      MSSubClass_150 -0.002683  0.002683
# 72                                            MoSold_7  0.002677  0.002677
# 73                                            MoSold_3 -0.002584  0.002584
# 74                                     Foundation_Wood -0.002559  0.002559
# 75                                     log_OpenPorchSF  0.002516  0.002516
# 76                                  MasVnrType_BrkFace -0.002498  0.002498
# 77                              has_finsished_basement -0.002497  0.002497
# 78                                    Electrical_SBrkr  0.002429  0.002429
# 79                                           3SsnPorch  0.002428  0.002428
# 80                                 Exterior2nd_Plywood -0.002392  0.002392
# 81                                 Exterior2nd_VinylSd  0.002339  0.002339
# 82                                            HalfBath  0.002283  0.002283
# 83                                       LotConfig_FR2 -0.002275  0.002275
# 84                                            has_pool  0.002179  0.002179
# 85                                 Exterior2nd_PreCast  0.002114  0.002114
# 86                                    Foundation_PConc  0.002086  0.002086
# 87                                     Condition1_RRNn  0.002078  0.002078
# 88                                   GarageType_Detchd  0.002074  0.002074
# 89                Neighborhood_ClearCr_CollgCr_Crawfor  0.002066  0.002066
# 90                                     Condition2_RRNn  0.001950  0.001950
# 91                                    Foundation_Stone  0.001930  0.001930
# 92                                       MSSubClass_40 -0.001925  0.001925
# 93                                  GarageType_Basment -0.001755  0.001755
# 94                                       MSSubClass_75  0.001712  0.001712
# 95                                       RoofStyle_Hip  0.001710  0.001710
# 96                                       MSSubClass_20  0.001699  0.001699
# 97                                        Heating_OthW -0.001589  0.001589
# 98                                    RoofMatl_Membran  0.001528  0.001528
# 99                                       LotConfig_FR3 -0.001501  0.001501
# 100                                  RoofStyle_Gambrel -0.001490  0.001490
# 101                                    Condition2_RRAn -0.001237  0.001237
# 102                                       PavedDrive_P -0.001218  0.001218
# 103                                  has_EnclosedPorch  0.001159  0.001159
# 104                                     MSSubClass_180 -0.001090  0.001090
# 105                                   RoofMatl_Tar&Grv  0.001069  0.001069
# 106                                Exterior1st_Plywood -0.001068  0.001068
# 107                                       alley_access -0.000970  0.000970
# 108                                    BldgType_Duplex -0.000936  0.000936
# 109                                           MoSold_9 -0.000915  0.000915
# 110                                Exterior1st_Wd Sdng  0.000913  0.000913
# 111                                           MoSold_6  0.000889  0.000889
# 112                                       PavedDrive_Y  0.000787  0.000787
# 113                                          MoSold_11 -0.000768  0.000768
# 114                                         Fence_MnWw -0.000735  0.000735
# 115                                Exterior1st_AsphShn  0.000697  0.000697
# 116                                          LandSlope -0.000616  0.000616
# 117                                        FireplaceQu  0.000565  0.000565
# 118                                     has_wood_deck   0.000558  0.000558
# 119                                Exterior2nd_AsphShn  0.000528  0.000528
# 120                                       LowQualFinSF -0.000436  0.000436
# 121                                    Condition1_RRNe  0.000423  0.000423
# 122                                    LandContour_Low  0.000391  0.000391
# 123                                Exterior1st_WdShing -0.000242  0.000242
# 124                                   LotConfig_Inside  0.000233  0.000233
# 125                                   RoofMatl_WdShake  0.000086  0.000086
# 126                                       BsmtFinType2  0.000000  0.000000
# 127                                      MSSubClass_45  0.000000  0.000000
# 128                                 GarageType_BuiltIn -0.000000  0.000000
# 129                                   GarageFinish_Unf -0.000000  0.000000
# 130                                  Exterior2nd_Stone -0.000000  0.000000
# 131                                    Foundation_Slab  0.000000  0.000000
# 132                                      has_openporch  0.000000  0.000000
# 133                                    BldgType_2fmCon -0.000000  0.000000
# 134                                      MSSubClass_30  0.000000  0.000000
# 135                                    MasVnrType_None  0.000000  0.000000
# 136                                    LandContour_Lvl  0.000000  0.000000
# 137                                    Condition1_RRAe -0.000000  0.000000
# 138                                Exterior1st_VinylSd  0.000000  0.000000
# 139                                          MoSold_10 -0.000000  0.000000
#
# skewness:  -0.3864703613153601
#
# model_importances.shape:  (140, 3)

# %%
keeps = to_keep(lasso2, 0.0002)

# %%
lasso3 = regx3(model= Lasso(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.9451539734281995
#
# test score:  0.9251044276355093
# adj_r2:  0.941019019675802
#
# adj_r2_test:  0.9104534940743804
#
# train RMSE: 0.08839936015765279
#
# test RMSE: 0.10199606241053542
#                                               features      coef   abs_val
# 0                                         bc_GrLivArea  0.142292  0.142292
# 1                                           house_age_ -0.077582  0.077582
# 2                                          OverallQual  0.063318  0.063318
# 3                                          OverallCond  0.047714  0.047714
# 4                                      yeo_TotalBsmtSF  0.044157  0.044157
# 5                                           bc_LotArea  0.041382  0.041382
# 6                                             2ndFlrSF  0.030467  0.030467
# 7                                          MSZoning_RM -0.026430  0.026430
# 8         Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.022425  0.022425
# 9                                      Condition1_Norm  0.022312  0.022312
# 10                                          Fireplaces  0.020964  0.020964
# 11                                        BsmtFullBath  0.020890  0.020890
# 12                                        BsmtExposure  0.018695  0.018695
# 13                                          Functional  0.017657  0.017657
# 14                                        BsmtFinType1  0.016380  0.016380
# 15                                         KitchenQual  0.015713  0.015713
# 16                                           HeatingQC  0.015411  0.015411
# 17                                          GarageCond  0.015383  0.015383
# 18                               SaleCondition_Partial  0.015075  0.015075
# 19                                         MSZoning_RL -0.014685  0.014685
# 20                                           ExterQual  0.014395  0.014395
# 21                                 Exterior1st_BrkFace  0.013969  0.013969
# 22                                   HouseStyle_1Story  0.013489  0.013489
# 23                                       MSSubClass_60 -0.013108  0.013108
# 24                                        BedroomAbvGr -0.012218  0.012218
# 25                                     Condition1_PosN  0.011519  0.011519
# 26   Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.011332  0.011332
# 27                                      MSSubClass_160 -0.011331  0.011331
# 28                                SaleCondition_Family -0.010472  0.010472
# 29                                         ScreenPorch  0.010208  0.010208
# 30                                      BldgType_Twnhs -0.009503  0.009503
# 31                                        KitchenAbvGr -0.009340  0.009340
# 32                                     LandContour_HLS  0.008739  0.008739
# 33                                         MSZoning_RH -0.008153  0.008153
# 34                         Neighborhood_Somerst_Timber  0.007796  0.007796
# 35                                     Condition1_PosA  0.007553  0.007553
# 36                                SaleCondition_Normal  0.007490  0.007490
# 37                                        CentralAir_Y  0.007479  0.007479
# 38                                 Exterior1st_PreCast  0.006555  0.006555
# 39                                Neighborhood_SawyerW -0.006541  0.006541
# 40                                 Exterior2nd_Brk Cmn  0.006074  0.006074
# 41                                      log_MasVnrArea  0.006029  0.006029
# 42                                        BsmtHalfBath  0.005983  0.005983
# 43                              years_since_remodeled_ -0.005524  0.005524
# 44                     Neighborhood_NAmes_SWISU_Sawyer -0.005450  0.005450
# 45                                     BldgType_TwnhsE -0.005411  0.005411
# 46                                   RoofStyle_Mansard -0.005403  0.005403
# 47                                   GarageType_Detchd  0.005340  0.005340
# 48                                   Foundation_CBlock -0.005148  0.005148
# 49                                       MSSubClass_70  0.004944  0.004944
# 50                         Neighborhood_Gilbert_NWAmes -0.004835  0.004835
# 51                                       MSSubClass_85  0.004810  0.004810
# 52                                     Condition2_PosA  0.004526  0.004526
# 53                                  Exterior2nd_CBlock  0.004374  0.004374
# 54                                    GarageFinish_RFn -0.004352  0.004352
# 55                                    Condition2_Feedr -0.004295  0.004295
# 56                                    RoofMatl_WdShngl  0.004205  0.004205
# 57                                    Condition1_Feedr  0.003895  0.003895
# 58                                   HouseStyle_1.5Unf  0.003881  0.003881
# 59                                   HouseStyle_SFoyer  0.003797  0.003797
# 60                                 Exterior1st_MetalSd  0.003686  0.003686
# 61                                    MasVnrType_Stone  0.003602  0.003602
# 62                                            BsmtCond -0.003249  0.003249
# 63                                        Heating_Grav -0.003109  0.003109
# 64                                     Condition1_RRAn  0.003035  0.003035
# 65                                     BldgType_Duplex -0.002984  0.002984
# 66                                  Exterior1st_CBlock -0.002984  0.002984
# 67                                         GarageYrBlt  0.002884  0.002884
# 68                                            Fence_No -0.002827  0.002827
# 69                                     Foundation_Wood -0.002802  0.002802
# 70                                      MSSubClass_150 -0.002758  0.002758
# 71                                            MoSold_3 -0.002696  0.002696
# 72                              has_finsished_basement -0.002567  0.002567
# 73                                        Heating_Wall  0.002420  0.002420
# 74                                    Electrical_SBrkr  0.002384  0.002384
# 75                Neighborhood_ClearCr_CollgCr_Crawfor  0.002378  0.002378
# 76                                        TotRmsAbvGrd  0.002310  0.002310
# 77                                 Exterior2nd_BrkFace -0.002266  0.002266
# 78                                           3SsnPorch  0.002255  0.002255
# 79                                   HouseStyle_2Story -0.002246  0.002246
# 80                                            MoSold_7  0.002206  0.002206
# 81                                       LotConfig_FR2 -0.002197  0.002197
# 82                                     Condition2_RRNn  0.002159  0.002159
# 83                                     Condition1_RRNn  0.002144  0.002144
# 84                                       MSSubClass_40 -0.002131  0.002131
# 85                                   RoofStyle_Gambrel -0.002051  0.002051
# 86                                    RoofMatl_Membran  0.001970  0.001970
# 87                                 Exterior2nd_Plywood -0.001954  0.001954
# 88                                 Exterior1st_Plywood -0.001914  0.001914
# 89                                            has_pool  0.001912  0.001912
# 90                                  GarageType_Basment -0.001908  0.001908
# 91                                    Foundation_Stone  0.001782  0.001782
# 92                                   has_EnclosedPorch  0.001659  0.001659
# 93                                       RoofStyle_Hip  0.001572  0.001572
# 94                                        Heating_OthW -0.001534  0.001534
# 95                                       LotConfig_FR3 -0.001517  0.001517
# 96                                        PavedDrive_P -0.001366  0.001366
# 97                                       MSSubClass_75  0.001238  0.001238
# 98                                     Condition2_RRAn -0.001193  0.001193
# 99                                    RoofMatl_Tar&Grv  0.001181  0.001181
# 100                                       alley_access -0.001167  0.001167
# 101                                     MSSubClass_180 -0.001138  0.001138
# 102                                           HalfBath  0.001032  0.001032
# 103                                           MoSold_6  0.000863  0.000863
# 104                                           MoSold_9 -0.000829  0.000829
# 105                                         Fence_MnWw -0.000694  0.000694
# 106                                       LowQualFinSF -0.000605  0.000605
# 107                                Exterior1st_WdShing -0.000600  0.000600
# 108                                          MoSold_11 -0.000596  0.000596
# 109                                Exterior1st_Wd Sdng  0.000552  0.000552
# 110                                Exterior1st_AsphShn  0.000535  0.000535
# 111                                    log_OpenPorchSF  0.000478  0.000478
# 112                                    Condition1_RRNe  0.000378  0.000378
# 113                                Exterior2nd_AsphShn  0.000374  0.000374
# 114                                     has_wood_deck   0.000326  0.000326
# 115                                    LandContour_Low  0.000308  0.000308
# 116                                          LandSlope -0.000298  0.000298
# 117                                   LotConfig_Inside  0.000205  0.000205
# 118                                       PavedDrive_Y  0.000050  0.000050
# 119                                 MasVnrType_BrkFace -0.000033  0.000033
# 120                                Exterior2nd_PreCast  0.000003  0.000003
# 121                                      MSSubClass_20  0.000000  0.000000
# 122                                Exterior2nd_VinylSd  0.000000  0.000000
# 123                                        FireplaceQu  0.000000  0.000000
# 124                                   Foundation_PConc  0.000000  0.000000
#
# skewness:  -0.38734517807918917
#
# model_importances.shape:  (125, 3)

# %%
keeps = to_keep(lasso3, 0.0005)

# %%
lasso4 = regx3(model= Lasso(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.9448012040914859
#
# test score:  0.9251156936646697
# adj_r2:  0.9411366907267461
#
# adj_r2_test:  0.9123865083611143
#
# train RMSE: 0.08868319657614915
#
# test RMSE: 0.10198839083668397
#                                               features      coef   abs_val
# 0                                         bc_GrLivArea  0.142845  0.142845
# 1                                           house_age_ -0.072768  0.072768
# 2                                          OverallQual  0.071246  0.071246
# 3                                          OverallCond  0.045872  0.045872
# 4                                      yeo_TotalBsmtSF  0.042891  0.042891
# 5                                           bc_LotArea  0.042646  0.042646
# 6                                             2ndFlrSF  0.029921  0.029921
# 7                                      Condition1_Norm  0.022244  0.022244
# 8                                          MSZoning_RM -0.021238  0.021238
# 9         Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.021042  0.021042
# 10                                        BsmtFullBath  0.020925  0.020925
# 11                                          Fireplaces  0.020004  0.020004
# 12                                        BsmtExposure  0.017617  0.017617
# 13                                          Functional  0.017336  0.017336
# 14                                        BsmtFinType1  0.016671  0.016671
# 15                                           HeatingQC  0.015398  0.015398
# 16                                          GarageCond  0.015323  0.015323
# 17                               SaleCondition_Partial  0.015092  0.015092
# 18                                         KitchenQual  0.014031  0.014031
# 19                                   HouseStyle_1Story  0.013667  0.013667
# 20                                           ExterQual  0.013584  0.013584
# 21                                 Exterior1st_BrkFace  0.013324  0.013324
# 22                                        BedroomAbvGr -0.012097  0.012097
# 23                                     Condition1_PosN  0.011235  0.011235
# 24                                SaleCondition_Family -0.010787  0.010787
# 25                                   HouseStyle_2Story -0.010287  0.010287
# 26                                         ScreenPorch  0.010172  0.010172
# 27   Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.009522  0.009522
# 28                         Neighborhood_Somerst_Timber  0.009489  0.009489
# 29                                        KitchenAbvGr -0.008856  0.008856
# 30                                     LandContour_HLS  0.008687  0.008687
# 31                                      BldgType_Twnhs -0.008539  0.008539
# 32                                         MSZoning_RL -0.008470  0.008470
# 33                                     Condition1_PosA  0.007620  0.007620
# 34                                        CentralAir_Y  0.007592  0.007592
# 35                                SaleCondition_Normal  0.007265  0.007265
# 36                                       MSSubClass_70  0.007171  0.007171
# 37                                         MSZoning_RH -0.006933  0.006933
# 38                                      MSSubClass_160 -0.006813  0.006813
# 39                              years_since_remodeled_ -0.006592  0.006592
# 40                                 Exterior1st_PreCast  0.006417  0.006417
# 41                                Neighborhood_SawyerW -0.006350  0.006350
# 42                                        BsmtHalfBath  0.006023  0.006023
# 43                                       MSSubClass_85  0.005916  0.005916
# 44                                   Foundation_CBlock -0.005483  0.005483
# 45                                   RoofStyle_Mansard -0.005384  0.005384
# 46                         Neighborhood_Gilbert_NWAmes -0.005327  0.005327
# 47                                 Exterior2nd_Brk Cmn  0.005283  0.005283
# 48                                      log_MasVnrArea  0.005096  0.005096
# 49                                  Exterior2nd_CBlock  0.004726  0.004726
# 50                     Neighborhood_NAmes_SWISU_Sawyer -0.004411  0.004411
# 51                                    Condition2_Feedr -0.004380  0.004380
# 52                                    GarageFinish_RFn -0.004321  0.004321
# 53                                       MSSubClass_60 -0.004278  0.004278
# 54                                     Condition2_PosA  0.004229  0.004229
# 55                                     BldgType_TwnhsE -0.004146  0.004146
# 56                                    MasVnrType_Stone  0.004005  0.004005
# 57                                 Exterior1st_MetalSd  0.003860  0.003860
# 58                                    RoofMatl_WdShngl  0.003837  0.003837
# 59                                   GarageType_Detchd  0.003783  0.003783
# 60                                    Condition1_Feedr  0.003700  0.003700
# 61                                   HouseStyle_1.5Unf  0.003631  0.003631
# 62                                        Heating_Grav -0.003328  0.003328
# 63                                   HouseStyle_SFoyer  0.003263  0.003263
# 64                                  Exterior1st_CBlock -0.003221  0.003221
# 65                                            Fence_No -0.003211  0.003211
# 66                                     Foundation_Wood -0.003128  0.003128
# 67                                     Condition1_RRAn  0.002924  0.002924
# 68                Neighborhood_ClearCr_CollgCr_Crawfor  0.002897  0.002897
# 69                                      MSSubClass_150 -0.002841  0.002841
# 70                                            BsmtCond -0.002765  0.002765
# 71                                            MoSold_3 -0.002555  0.002555
# 72                                         GarageYrBlt  0.002521  0.002521
# 73                                            MoSold_7  0.002492  0.002492
# 74                                        Heating_Wall  0.002464  0.002464
# 75                                           3SsnPorch  0.002339  0.002339
# 76                                       MSSubClass_40 -0.002310  0.002310
# 77                                 Exterior2nd_Plywood -0.002289  0.002289
# 78                                    Electrical_SBrkr  0.002287  0.002287
# 79                                       LotConfig_FR2 -0.002248  0.002248
# 80                              has_finsished_basement -0.002161  0.002161
# 81                                     Condition2_RRNn  0.002157  0.002157
# 82                                  GarageType_Basment -0.002071  0.002071
# 83                                 Exterior2nd_BrkFace -0.002053  0.002053
# 84                                        Heating_OthW -0.002021  0.002021
# 85                                            has_pool  0.001943  0.001943
# 86                                     Condition1_RRNn  0.001928  0.001928
# 87                                    RoofMatl_Membran  0.001727  0.001727
# 88                                 Exterior1st_Plywood -0.001694  0.001694
# 89                                       RoofStyle_Hip  0.001673  0.001673
# 90                                   RoofStyle_Gambrel -0.001660  0.001660
# 91                                    Foundation_Stone  0.001642  0.001642
# 92                                     BldgType_Duplex -0.001468  0.001468
# 93                                       LotConfig_FR3 -0.001423  0.001423
# 94                                        PavedDrive_P -0.001392  0.001392
# 95                                     Condition2_RRAn -0.001169  0.001169
# 96                                    RoofMatl_Tar&Grv  0.001146  0.001146
# 97                                        alley_access -0.001123  0.001123
# 98                                 Exterior1st_AsphShn  0.001118  0.001118
# 99                                            MoSold_9 -0.001108  0.001108
# 100                                           MoSold_6  0.001056  0.001056
# 101                                      MSSubClass_75  0.001049  0.001049
# 102                                  has_EnclosedPorch  0.001021  0.001021
# 103                                Exterior1st_WdShing -0.000870  0.000870
# 104                                         Fence_MnWw -0.000701  0.000701
# 105                                       TotRmsAbvGrd  0.000662  0.000662
# 106                                          MoSold_11 -0.000654  0.000654
# 107                                           HalfBath  0.000634  0.000634
# 108                                     MSSubClass_180 -0.000555  0.000555
# 109                                       LowQualFinSF -0.000525  0.000525
# 110                                Exterior1st_Wd Sdng  0.000000  0.000000
#
# skewness:  -0.3915546018835516
#
# model_importances.shape:  (111, 3)

# %%
features4 = to_keep(lasso4,0)
dummies=[]
for f in features4:
    if model_vars_data[f].max() == 1:
        dummies.append(f)


dummy_drops = []
for feature in dummies:
    if round(model_vars_data[feature].mean(),2) < 0.05:
        dummy_drops.append(feature)
dummy_drops
# Out:
# ['SaleCondition_Partial',
#  'Exterior1st_BrkFace',
#  'Condition1_PosN',
#  'SaleCondition_Family',
#  'LandContour_HLS',
#  'BldgType_Twnhs',
#  'Condition1_PosA',
#  'MSZoning_RH',
#  'MSSubClass_160',
#  'Exterior1st_PreCast',
#  'Neighborhood_SawyerW',
#  'MSSubClass_85',
#  'RoofStyle_Mansard',
#  'Exterior2nd_Brk Cmn',
#  'Exterior2nd_CBlock',
#  'Condition2_Feedr',
#  'Condition2_PosA',
#  'RoofMatl_WdShngl',
#  'HouseStyle_1.5Unf',
#  'Heating_Grav',
#  'HouseStyle_SFoyer',
#  'Exterior1st_CBlock',
#  'Foundation_Wood',
#  'Condition1_RRAn',
#  'MSSubClass_150',
#  'Heating_Wall',
#  'MSSubClass_40',
#  'LotConfig_FR2',
#  'Condition2_RRNn',
#  'GarageType_Basment',
#  'Exterior2nd_BrkFace',
#  'Heating_OthW',
#  'has_pool',
#  'Condition1_RRNn',
#  'RoofMatl_Membran',
#  'RoofStyle_Gambrel',
#  'Foundation_Stone',
#  'BldgType_Duplex',
#  'LotConfig_FR3',
#  'PavedDrive_P',
#  'Condition2_RRAn',
#  'RoofMatl_Tar&Grv',
#  'Exterior1st_AsphShn',
#  'MSSubClass_75',
#  'Exterior1st_WdShing',
#  'Fence_MnWw',
#  'MoSold_11',
#  'MSSubClass_180']

# %%
keep_set = set(features4) - set(dummy_drops)
keeps = list(keep_set)
# keeps

# %%
lasso5 = regx3(model= Lasso(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.9354804886552655
#
# test score:  0.9235802862052476
# adj_r2:  0.9331561367067626
#
# adj_r2_test:  0.9168309667532893
#
# train RMSE: 0.0958786855506625
#
# test RMSE: 0.10302865668098982
#                                              features      coef   abs_val
# 0                                        bc_GrLivArea  0.137791  0.137791
# 1                                         OverallQual  0.065903  0.065903
# 2                                          house_age_ -0.056878  0.056878
# 3                                     yeo_TotalBsmtSF  0.049589  0.049589
# 4                                         OverallCond  0.049199  0.049199
# 5                                          bc_LotArea  0.045680  0.045680
# 6                                            2ndFlrSF  0.028387  0.028387
# 7        Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.027287  0.027287
# 8                                          Fireplaces  0.023696  0.023696
# 9                                        BsmtExposure  0.022168  0.022168
# 10                                       BsmtFullBath  0.020916  0.020916
# 11                        Neighborhood_Somerst_Timber  0.018126  0.018126
# 12                                         Functional  0.017718  0.017718
# 13                                        MSZoning_RM -0.016318  0.016318
# 14                                        KitchenQual  0.016028  0.016028
# 15                                       BsmtFinType1  0.015926  0.015926
# 16                                       BedroomAbvGr -0.015788  0.015788
# 17                                         GarageCond  0.015110  0.015110
# 18                                  HouseStyle_1Story  0.014319  0.014319
# 19                                    Condition1_Norm  0.013243  0.013243
# 20                                        GarageYrBlt  0.013140  0.013140
# 21                                          HeatingQC  0.012547  0.012547
# 22                                  HouseStyle_2Story -0.012309  0.012309
# 23                                          ExterQual  0.011099  0.011099
# 24               Neighborhood_ClearCr_CollgCr_Crawfor  0.010951  0.010951
# 25                                       KitchenAbvGr -0.010321  0.010321
# 26                                       CentralAir_Y  0.010229  0.010229
# 27                                        ScreenPorch  0.009794  0.009794
# 28                                           BsmtCond -0.007036  0.007036
# 29                                  Foundation_CBlock -0.006981  0.006981
# 30                             years_since_remodeled_ -0.006578  0.006578
# 31                                   MasVnrType_Stone  0.006061  0.006061
# 32                                       TotRmsAbvGrd  0.005896  0.005896
# 33                                      MSSubClass_70  0.005697  0.005697
# 34                                       BsmtHalfBath  0.005438  0.005438
# 35                                Exterior2nd_Plywood -0.004501  0.004501
# 36                                   GarageFinish_RFn -0.004457  0.004457
# 37                                      RoofStyle_Hip  0.004143  0.004143
# 38                                           MoSold_7  0.003681  0.003681
# 39  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.003648  0.003648
# 40                                          3SsnPorch  0.003547  0.003547
# 41                                       LowQualFinSF -0.002903  0.002903
# 42                                           MoSold_3 -0.002312  0.002312
# 43                                           MoSold_9 -0.002216  0.002216
# 44                                           Fence_No -0.002154  0.002154
# 45                                   Electrical_SBrkr  0.001524  0.001524
# 46                                Exterior1st_MetalSd  0.001424  0.001424
# 47                                           MoSold_6  0.001276  0.001276
# 48                                           HalfBath  0.001253  0.001253
# 49                             has_finsished_basement -0.001180  0.001180
# 50                                Exterior1st_Plywood -0.000627  0.000627
# 51                               SaleCondition_Normal  0.000616  0.000616
# 52                    Neighborhood_NAmes_SWISU_Sawyer  0.000593  0.000593
# 53                                    BldgType_TwnhsE -0.000344  0.000344
# 54                                  GarageType_Detchd  0.000188  0.000188
# 55                                        MSZoning_RL -0.000000  0.000000
# 56                                     log_MasVnrArea  0.000000  0.000000
# 57                                  has_EnclosedPorch  0.000000  0.000000
# 58                                   Condition1_Feedr -0.000000  0.000000
# 59                        Neighborhood_Gilbert_NWAmes -0.000000  0.000000
# 60                                      MSSubClass_60 -0.000000  0.000000
# 61                                       alley_access -0.000000  0.000000
#
# skewness:  -0.5949357865682229
#
# model_importances.shape:  (62, 3)

# %%
combine = pd.concat([price_train, model_vars_data], axis=1)
combine["log_price"] = np.log(combine.SalePrice)
combine.head(3)

# %%
features5 = to_keep(lasso5,0)
set5 = set(features5)
set5.add('log_price')
set5

list5 = list(set5)
type(list5)
combine[list5]

# %%
pd.set_option('display.max_rows', None)


print("look at correlations with target")
df4a = combine[list5]
type(df4a)
corr = df4a.corr()
corr.sort_values(["log_price"], ascending = False, inplace = True)


# # type(corr.SalePrice)
# # # type(corr)
print(corr.log_price)
# type(combine)
# Out:
# look at correlations with target
# log_price                                              1.000000
# OverallQual                                            0.812202
# bc_GrLivArea                                           0.731467
# ExterQual                                              0.681508
# KitchenQual                                            0.658549
# yeo_TotalBsmtSF                                        0.641523
# GarageYrBlt                                            0.591040
# Neighborhood_NoRidge_NridgHt_Veenker_StoneBr           0.516683
# Fireplaces                                             0.505697
# TotRmsAbvGrd                                           0.496065
# HeatingQC                                              0.479445
# bc_LotArea                                             0.406382
# BsmtExposure                                           0.369880
# BsmtFinType1                                           0.367016
# CentralAir_Y                                           0.328941
# GarageCond                                             0.313011
# HalfBath                                               0.310577
# BsmtFullBath                                           0.272287
# Electrical_SBrkr                                       0.271050
# 2ndFlrSF                                               0.269383
# BsmtCond                                               0.256942
# MasVnrType_Stone                                       0.246733
# GarageFinish_RFn                                       0.237073
# Neighborhood_Somerst_Timber                            0.233979
# HouseStyle_2Story                                      0.220636
# RoofStyle_Hip                                          0.204512
# Neighborhood_ClearCr_CollgCr_Crawfor                   0.170597
# Fence_No                                               0.170001
# BedroomAbvGr                                           0.168161
# Functional                                             0.138144
# ScreenPorch                                            0.131325
# Condition1_Norm                                        0.124592
# BldgType_TwnhsE                                        0.060609
# 3SsnPorch                                              0.053087
# MoSold_7                                               0.035360
# MoSold_6                                               0.015722
# Exterior1st_Plywood                                   -0.001401
# MoSold_9                                              -0.008847
# MoSold_3                                              -0.023706
# Exterior2nd_Plywood                                   -0.029774
# HouseStyle_1Story                                     -0.030151
# LowQualFinSF                                          -0.031946
# BsmtHalfBath                                          -0.039473
# has_finsished_basement                                -0.043921
# MSSubClass_70                                         -0.050593
# OverallCond                                           -0.082731
# KitchenAbvGr                                          -0.107536
# SaleCondition_Normal                                  -0.118064
# Exterior1st_MetalSd                                   -0.141880
# Neighborhood_NAmes_SWISU_Sawyer                       -0.259900
# Foundation_CBlock                                     -0.331782
# MSZoning_RM                                           -0.370536
# GarageType_Detchd                                     -0.397753
# Neighborhood_BrkSide_Edwards_Blueste_OldTown_IDOTRR   -0.417469
# years_since_remodeled_                                -0.564930
# house_age_                                            -0.594880
# Name: log_price, dtype: float64

# %%
drops =[ 'OverallCond',
'BldgType_TwnhsE',
'3SsnPorch',
'MSSubClass_70',
'has_finsished_basement'
'BsmtHalfBath',
'MoSold_7',
'LowQualFinSF',
'HouseStyle_1Story',
'Exterior2nd_Plywood',
'MoSold_3',
'MoSold_6',
'MoSold_9',
'Exterior1st_Plywood']
