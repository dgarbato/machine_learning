# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd
from scipy import stats
# %matplotlib inline

#x_train is being read in as housing

housing = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\x_train.csv',index_col=0)

x_test = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\x_text.csv',index_col=0)

y_train = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\y_train.csv',index_col=0)

df_dummies = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\df_dummies.csv',index_col=0)
# y_test.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\y_test.csv',index_col=0)

# %%
housing.shape
# Out:
# (1784, 109)

# %%
# list(df_dummies.columns)
# dummy_set = set(df_dummies.columns)
# dummy_set

# %%
keeps = ['BldgType_2fmCon', 'BldgType_Duplex', 'BldgType_Twnhs', 'BldgType_TwnhsE','HouseStyle_1.5Unf', \
         'HouseStyle_1Story', 'HouseStyle_2.5Fin', 'HouseStyle_2.5Unf',  'HouseStyle_2Story', \
         'HouseStyle_SFoyer', 'HouseStyle_SLvl','PavedDrive_P', 'PavedDrive_Y','MoSold_10', 'MoSold_11', \
         'MoSold_12', 'MoSold_2', 'MoSold_3', 'MoSold_4', 'MoSold_5', 'MoSold_6', 'MoSold_7', 'MoSold_8',\
         'MoSold_9','MSSubClass_60', 'MSSubClass_50',  'MSSubClass_30']
keeps_set = set(keeps)

# %%
# drops_set = dummy_set - keeps_set
# drops_set
# drops_list = list(drops_set)

# %%
housing_copy = housing.copy()
housing2 = housing.copy()

# %%
housing2.SalePrice.mean() #mean before
# Out:
# 178893.34360986546

# %%
# housing = housing.drop(drops_list, axis= 1)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1784 entries, 1232 to 1679
# Columns: 109 entries, GrLivArea to MSSubClass_30
# dtypes: bool(3), float64(13), int64(68), object(25)
# memory usage: 1.5+ MB

# %%
pd.set_option('display.max_columns', None)


housing.head()
# Out:
#       GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 1232       1664     162900          60       RL         78.0    10140   Pave
# 2381       1268     133000          40       RL         60.0    12144   Pave
# 810        1628     189000          80       RL         60.0     8400   Pave
# 863        2270     290000          60       RL         92.0    11764   Pave
# 1346       1482     143000          70       RM         50.0     9000   Pave
#
#       LotShape LandContour Utilities LotConfig  LandSlope Neighborhood  \
# 1232         4         Lvl    AllPub    Inside          3       NWAmes
# 2381         4         Lvl    AllPub    Inside          3        NAmes
# 810          4         Lvl    AllPub    Inside          3      Gilbert
# 863          3         Lvl    AllPub   CulDSac          3      NoRidge
# 1346         4         Lvl    AllPub    Inside          3      OldTown
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# ...

# %%
housing.SalePrice.head()
# housing.drop({'SalePrice'})
# Out:
# 1232    162900
# 2381    133000
# 810     189000
# 863     290000
# 1346    143000
# Name: SalePrice, dtype: int64

# %%
housing.shape
# Out:
# (1784, 109)

# %%
# x_test.drop({'SalePrice'})
x_test.SalePrice.head()
# Out:
# 1140    175900
# 398     147500
# 894     192000
# 2422    197900
# 2548    110000
# Name: SalePrice, dtype: int64

# %%
x_test.shape
# Out:
# (765, 109)

# %%
y_train.shape
type(y_train)
y_train.head()
SalePrice = y_train.SalePrice
price = y_train.SalePrice
type(SalePrice)
# Out:
# pandas.core.series.Series

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(housing.SalePrice, bins=20)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
log_price = np.log(SalePrice)

# %%
sns.histplot(log_price, bins=20);

# %%
def proc_freq(df,variable_):  #Note variable_ must be given in quotes example: variable_ = 'xyz'
    datax = df[variable_].value_counts().sort_index()
    
    datay = pd.DataFrame({
        variable_: datax.index,
        'Frequency': datax.values,
        'Percent': ((datax.values/datax.values.sum())*100).round(2),
        'Cumulative_Frequency': datax.values.cumsum(),
        'Cumulative_Percent': ((datax.values.cumsum()/datax.values.sum())*100).round(2)   })
    
    #datay.set_index(variable_)
    #return(datay.set_index(variable_))
    return(datay)

# %%
def miss_cols(df):
    missing = np.sum(df.isnull(),axis=0)
    
    miss_ind = np.sum(df.isnull(),axis=0) > 0
    
    vals = pd.Series(filter(lambda x: x != 0,missing))
     
    cols_miss = df.columns[miss_ind]

    L=list(zip(cols_miss,vals, round(vals/df.shape[0],4)))
    
    return sorted(L,reverse=True,key=lambda x: x[2])

# %%
def categ_check(
df_name = None,
target_median = None,
categ_feature = None,
target = None):

    df1 = df_name.groupby([categ_feature])[target].median().reset_index()
    df1 = df1.rename(columns={target:'median_of_target'})

    df1['index'] = (df1['median_of_target']/target_median*100).astype(int)

    df2= df_name[[categ_feature,target]]
    df2 = df2.groupby([categ_feature]).count().reset_index()
    df2 = df2.rename(columns={target:'category_freq'})

    df2['pct_total'] = df2['category_freq']/df_name.shape[0]*100

    df3 = pd.merge(df2,df1)

    df4 = df3.sort_values(by=['index'], ascending=False).reset_index()
    df4 = df4.drop(columns=['level_0'])
    return df4

# %%
def categ_mean(
df_name = None,
target_mean = None,
categ_feature = None,
target = None):

    df1 = df_name.groupby([categ_feature])[target].mean().reset_index()
    df1 = df1.rename(columns={target:'mean_of_target'})

    df1['index'] = (df1['mean_of_target']/target_mean*100).astype(int)

    df2= df_name[[categ_feature,target]]
    df2 = df2.groupby([categ_feature]).count().reset_index()
    df2 = df2.rename(columns={target:'category_freq'})

    df2['pct_total'] = df2['category_freq']/df_name.shape[0]*100

    df3 = pd.merge(df2,df1)

    df4 = df3.sort_values(by=['index'], ascending=False).reset_index()
    df4 = df4.drop(columns=['level_0'])
    return df4

# %%
missing = np.sum(housing.isnull(),axis=0)
missing.head()
# Out:
# GrLivArea        0
# SalePrice        0
# MSSubClass       0
# MSZoning         0
# LotFrontage    310
# dtype: int64

# %%
miss_cols(housing) #list of columns with missing values and the quantity of missing values for housing df
# Out:
# [('LotFrontage', 310, 0.1738),
#  ('GarageYrBlt', 94, 0.0527),
#  ('MasVnrArea', 9, 0.005),
#  ('BsmtFullBath', 1, 0.0006),
#  ('BsmtHalfBath', 1, 0.0006),
#  ('GarageCars', 1, 0.0006),
#  ('GarageArea', 1, 0.0006)]

# %%
proc_freq(housing,'MSZoning')
# Out:
#   MSZoning  Frequency  Percent  Cumulative_Frequency  Cumulative_Percent
# 0       FV         78     4.37                    78                4.37
# 1       RH         13     0.73                    91                5.10
# 2       RL       1397    78.31                  1488               83.41
# 3       RM        296    16.59                  1784              100.00

# %%
list(housing.columns)
# Out:
# ['GrLivArea',
#  'SalePrice',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
housing.LotFrontage.corr(housing['1stFlrSF'])
# Out:
# 0.436130149401068

# %%
housing.LotFrontage.corr(housing.GrLivArea)
# Out:
# 0.3516585830315819

# %%
size_related = housing.filter(regex='SF$|Area$')#filter out columns that end with SF or that end with Area
size_related.columns
# Out:
# Index(['GrLivArea', 'LotArea', 'MasVnrArea', 'BsmtUnfSF', 'TotalBsmtSF',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'PoolArea', 'bc_GrLivArea'],
#       dtype='object')

# %%
# proc_freq(housing,'Neighborhood')

# %% [markdown]
# ### impute LotFrontage

# %%
list_sub = ['Neighborhood','LotFrontage']
housing_sub = housing[list_sub]
housing_sub
# Out:
#      Neighborhood  LotFrontage
# 1232       NWAmes         78.0
# 2381        NAmes         60.0
# 810       Gilbert         60.0
# 863       NoRidge         92.0
# 1346      OldTown         50.0
# ...           ...          ...
# 1051      OldTown          NaN
# 1758       Timber         88.0
# 778       Gilbert         96.0
# 851         NAmes          NaN
# 1679        NAmes         75.0
#
# [1784 rows x 2 columns]

# %% [markdown]
# #### imputation dictionary

# %%
imputation_dict = housing_sub.groupby(["Neighborhood"]).median().to_dict()
imputation_dict['LotFrontage']
# Out:
# {'Blmngtn': 43.0,
#  'Blueste': 24.0,
#  'BrDale': 21.0,
#  'BrkSide': 52.0,
#  'ClearCr': 81.0,
#  'CollgCr': 70.0,
#  'Crawfor': 70.0,
#  'Edwards': 64.0,
#  'Gilbert': 64.5,
#  'Greens': 40.0,
#  'IDOTRR': 59.5,
#  'MeadowV': 21.0,
#  'Mitchel': 74.0,
#  'NAmes': 73.0,
#  'NPkVill': 24.0,
#  'NWAmes': 80.0,
#  'NoRidge': 85.0,
#  'NridgHt': 94.5,
#  'OldTown': 60.0,
#  'SWISU': 60.0,
#  'Sawyer': 72.0,
#  'SawyerW': 70.0,
#  'Somerst': 73.0,
#  'StoneBr': 47.0,
#  'Timber': 82.0,
#  'Veenker': 80.0}

# %%
# imputation_dict
type(housing_sub)
# Out:
# pandas.core.frame.DataFrame

# %%
impute_index = housing_sub.LotFrontage.isnull()

housing_sub.loc[impute_index,'LotFrontage'] = housing_sub.loc[impute_index].apply(lambda current_row:imputation_dict['LotFrontage'][(current_row[0])], axis=1)
# Out:
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
miss_cols(housing_sub)
# Out:
# []

# %%
housing_sub.shape
# Out:
# (1784, 2)

# %% [markdown]
# #### Make a copy of housing

# %%
housing_copy= housing.copy()

# %% [markdown]
# ####  do actual imputation of LotFrontage in housing

# %%
housing['LotFrontage'] =  housing_sub['LotFrontage']

# %%
miss_cols(housing)
# Out:
# [('GarageYrBlt', 94, 0.0527),
#  ('MasVnrArea', 9, 0.005),
#  ('BsmtFullBath', 1, 0.0006),
#  ('BsmtHalfBath', 1, 0.0006),
#  ('GarageCars', 1, 0.0006),
#  ('GarageArea', 1, 0.0006)]

# %%
list_sub = ['Neighborhood','LotFrontage']
df1 = housing[list_sub]
df1 = df1.groupby(["Neighborhood"]).median().reset_index()


print(type(df1))
# df1 = df1.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### LotFrontage median bar graph by neighborhood

# %%
sns.set_theme(style='darkgrid')
sns.set(rc = {'figure.figsize':(15,8)})



ax = sns.barplot(x=df1["Neighborhood"], y='LotFrontage', data =df1,  color='skyblue', ci=None)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# Out:
# [Text(0, 0, 'Blmngtn'),
#  Text(1, 0, 'Blueste'),
#  Text(2, 0, 'BrDale'),
#  Text(3, 0, 'BrkSide'),
#  Text(4, 0, 'ClearCr'),
#  Text(5, 0, 'CollgCr'),
#  Text(6, 0, 'Crawfor'),
#  Text(7, 0, 'Edwards'),
#  Text(8, 0, 'Gilbert'),
#  Text(9, 0, 'Greens'),
#  Text(10, 0, 'IDOTRR'),
#  Text(11, 0, 'MeadowV'),
#  Text(12, 0, 'Mitchel'),
#  Text(13, 0, 'NAmes'),
#  Text(14, 0, 'NPkVill'),
#  Text(15, 0, 'NWAmes'),
#  Text(16, 0, 'NoRidge'),
#  Text(17, 0, 'NridgHt'),
#  Text(18, 0, 'OldTown'),
#  Text(19, 0, 'SWISU'),
#  Text(20, 0, 'Sawyer'),
#  Text(21, 0, 'SawyerW'),
#  Text(22, 0, 'Somerst'),
#  Text(23, 0, 'StoneBr'),
#  Text(24, 0, 'Timber'),
#  Text(25, 0, 'Veenker')]

# %%
housing.MasVnrArea = housing.MasVnrArea.fillna(0)



housing.BsmtFullBath = housing.BsmtFullBath.fillna(0)

housing.BsmtHalfBath = housing.BsmtHalfBath.fillna(0)

housing.BsmtFinSF1 = housing.BsmtFinSF1.fillna(0)

housing.BsmtFinSF2 = housing.BsmtFinSF2.fillna(0)

housing.BsmtUnfSF = housing.BsmtUnfSF.fillna(0)

housing.TotalBsmtSF = housing.TotalBsmtSF.fillna(0)

housing.GarageCars = housing.GarageCars.fillna(0)

housing.GarageArea = housing.GarageArea.fillna(0)

housing.loc[housing['GarageYrBlt'].isnull(),'GarageYrBlt'] = housing['YearBuilt']

# %%
miss_cols(housing)
# Out:
# []

# %%
housing2 = housing.copy()

# %%
 price        = housing['SalePrice']
size_related = housing.filter(regex='SF$|Area$')#filter out columns that end with SF or that end with Area
size_related.head()
# Out:
#       GrLivArea  LotArea  MasVnrArea  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 1232       1664    10140         0.0      638.0        832.0       832
# 2381       1268    12144         0.0      457.0        832.0      1036
# 810        1628     8400        32.0      100.0        384.0       958
# 863        2270    11764       348.0      628.0       1152.0      1164
# 1346       1482     9000         0.0       26.0        650.0       832
#
#       2ndFlrSF  LowQualFinSF  GarageArea  WoodDeckSF  OpenPorchSF  PoolArea  \
# 1232       832             0       528.0           0           28         0
# 2381         0           232       288.0           0           28         0
# 810        670             0       390.0          48           72         0
# 863       1106             0       671.0         132           57         0
# 1346       650             0       324.0           0            0         0
#
#       bc_GrLivArea
# 1232      9.303792
# 2381      8.886250
# 810       9.269942
# ...

# %%
size_related.describe()
# Out:
#          GrLivArea       LotArea   MasVnrArea    BsmtUnfSF  TotalBsmtSF  \
# count  1784.000000   1784.000000  1784.000000  1784.000000  1784.000000
# mean   1488.602578   9804.981502    97.079596   535.695628  1034.843049
# std     487.818064   5009.083106   173.793191   423.857932   414.467452
# min     334.000000   1300.000000     0.000000     0.000000     0.000000
# 25%    1111.750000   7432.000000     0.000000   212.000000   791.750000
# 50%    1436.000000   9378.500000     0.000000   442.000000   971.500000
# 75%    1733.250000  11428.250000   156.500000   779.250000  1256.250000
# max    3820.000000  70761.000000  1600.000000  2153.000000  3206.000000
#
#           1stFlrSF     2ndFlrSF  LowQualFinSF   GarageArea   WoodDeckSF  \
# count  1784.000000  1784.000000   1784.000000  1784.000000  1784.000000
# mean   1139.994395   343.841928      4.766256   465.214686    96.244395
# std     372.301600   425.356854     48.213441   208.328657   126.945317
# ...

# %% [markdown]
# # GrLivArea

# %%
housing['log_GrLivArea'] =np.log(housing.GrLivArea)

# %%
housing[['GrLivArea', 'SalePrice']].plot(kind='scatter', x='GrLivArea', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
housing['log_price'] = np.log(housing.SalePrice)

# %%
log_price = np.log(housing.SalePrice)
log_price.corr(housing['log_GrLivArea'])
# Out:
# 0.7311657099486206

# %%
housing['bc_GrLivArea'],_ = stats.boxcox(housing.GrLivArea)

# %%
log_price.corr((housing['bc_GrLivArea']))
# Out:
# 0.7314670802822264

# %%
# housing[['bc_GrLivArea', 'log_price']].plot(kind='scatter', x='bc_GrLivArea', y='log_price' ) #logx=True, logy=True

# %%
sns.histplot(data=housing, x='log_GrLivArea', bins=20);

# %%
sns.histplot(data=housing, x='bc_GrLivArea', bins=20);

# %% [markdown]
# # 'LotArea'

# %%
housing[['LotArea', 'SalePrice']].plot(kind='scatter', x='LotArea', y='SalePrice',logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
# sns.histplot(data=housing, x='LotArea', bins=20);

# %%
housing['log_LotArea'] = np.log(housing['LotArea'])

# %%
log_price.corr(housing['log_LotArea'])
# Out:
# 0.398168479490573

# %%
# sns.histplot(data=housing, x='log_LotArea', bins=20);

# %%
log_price.corr(housing['LotArea'])
# Out:
# 0.37215484872036986

# %%
housing['bc_LotArea'],_ = stats.boxcox(housing['LotArea'])

# %%
log_price.corr(housing['bc_LotArea'])
# Out:
# 0.40638169167489485

# %%
# sns.histplot(housing.bc_LotArea, bins=20);

# %% [markdown]
# # MasVnrArea

# %%
housing[['MasVnrArea', 'SalePrice']].plot(kind='scatter', x='MasVnrArea', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='MasVnrArea', ylabel='SalePrice'>

# %%
housing['yeo_MasVnrArea'],_ = stats.yeojohnson(housing['MasVnrArea'])

# %%
housing['log_MasVnrArea'] = np.log(housing['MasVnrArea'] + 1)

# %%
log_price.corr(housing['yeo_MasVnrArea'])
# Out:
# 0.4022418776868633

# %%
log_price.corr(np.log(housing['MasVnrArea'] + 1))
# Out:
# 0.41764489461512283

# %%
# sns.histplot(data=housing, x='log_MasVnrArea', bins=20);

# %% [markdown]
# # BsmtUnfSF

# %%
housing[['BsmtUnfSF', 'SalePrice']].plot(kind='scatter', x='BsmtUnfSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtUnfSF', ylabel='SalePrice'>

# %%
log_price.corr(np.log(housing['BsmtUnfSF']+1)) #correlation
# Out:
# 0.1780290201769859

# %%
log_price.corr(housing['BsmtUnfSF']) #correlation
# Out:
# 0.1902297317063011

# %%
housing['yeo_BsmtUnfSF'],_= stats.yeojohnson(housing['BsmtUnfSF'])

# %%
log_price.corr(np.log(housing['yeo_BsmtUnfSF']+1)) #correlation
# Out:
# 0.17688182455361703

# %%
# housing[['BsmtUnfSF', 'SalePrice']].plot(kind='scatter', x='BsmtUnfSF', y='SalePrice', logx=True, logy=True)

# %% [markdown]
# # TotalBsmtSF

# %%
# TotalBsmtSF 
housing[['TotalBsmtSF', 'SalePrice']].plot(kind='scatter', x='TotalBsmtSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
housing['yeo_TotalBsmtSF'],_ = stats.yeojohnson(housing['TotalBsmtSF'])

# %%
log_TotalBsmtSF = np.log(housing['TotalBsmtSF'] + 1)
log_price = housing['log_price']

log_price.corr(log_TotalBsmtSF) #correlation
# Out:
# 0.3767731935750898

# %%
log_price.corr(housing['yeo_TotalBsmtSF']) #correlation
# Out:
# 0.6415234734620474

# %%
# sns.histplot(data=housing, x='TotalBsmtSF', bins=20);

# %%
# sns.histplot(data=housing, x='yeo_TotalBsmtSF', bins=20);

# %% [markdown]
# # 1stFlrSF

# %%
# 1stFlrSF

housing[['1stFlrSF', 'SalePrice']].plot(kind='scatter', x='1stFlrSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %%
first_FlrSF = housing[['1stFlrSF']]
log_first_FlrSF = np.log(housing['1stFlrSF'])

# %%
# log_price.corr(log_TotalBsmtSF) #correlation
log_price.corr(log_first_FlrSF)
# Out:
# 0.6383392553634412

# %%
housing['log_first_FlrSF'] = np.log(housing['1stFlrSF'])

# %%
housing['bc_first_FlrSF'],_ = stats.boxcox(housing['1stFlrSF'])

# %%
log_price.corr(housing['bc_first_FlrSF'])
# Out:
# 0.6374746531087248

# %% [markdown]
# #  2ndFlrSF

# %%
# 2ndFlrSF

housing[['2ndFlrSF', 'SalePrice']].plot(kind='scatter', x='2ndFlrSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='2ndFlrSF', ylabel='SalePrice'>

# %%
log_price.corr(np.log(housing['2ndFlrSF'] + 1))
# Out:
# 0.1192714622033411

# %%
log_price.corr(housing['2ndFlrSF'])
# Out:
# 0.2693833571504791

# %%
housing['log_2ndFlrSF'] =np.log(housing['2ndFlrSF']+1)

# %%
housing['yeo_2ndFlrSF'],_ = stats.yeojohnson(housing['2ndFlrSF'])

# %%
log_price.corr(housing['yeo_2ndFlrSF'])  #very low correlation
# Out:
# 0.10935394035398902

# %% [markdown]
# # LowQualFinSF: Low quality finished square feet (all floors)

# %%
#LowQualFinSF: Low quality finished square feet (all floors)
housing[['LowQualFinSF', 'SalePrice']].plot(kind='scatter', x='LowQualFinSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LowQualFinSF', ylabel='SalePrice'>

# %% [markdown]
# # GarageArea

# %%
# GarageArea 

housing[['GarageArea', 'SalePrice']].plot(kind='scatter', x='GarageArea', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %%
log_price.corr(np.log(housing['GarageArea'] + 1))
# Out:
# 0.42854785247843596

# %%
housing['yeo_GarageArea'],_  = stats.yeojohnson(housing['GarageArea'] )

# %%
log_price.corr(housing['yeo_GarageArea'])
# Out:
# 0.6518804606863746

# %% [markdown]
# # Correlation WoodDeckSF is 0.347 still could be taken into consideration for the model.  It may be important for the more expnsive homes.

# %%
# WoodDeckSF 
housing[['WoodDeckSF', 'SalePrice']].plot(kind='scatter', x='WoodDeckSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='WoodDeckSF', ylabel='SalePrice'>

# %%
log_price.corr(np.log(housing['WoodDeckSF'] + 1))
# Out:
# 0.33374218051691723

# %%
log_price.corr(housing['WoodDeckSF'])
# Out:
# 0.32520086718540625

# %%
housing['log_WoodDeckSF'] = np.log(housing['WoodDeckSF'] + 1)

# %%
housing['yeo_WoodDeckSF'],_ = stats.yeojohnson(housing['WoodDeckSF'])

# %%
log_price.corr(housing['yeo_WoodDeckSF'])
# Out:
# 0.3315252703362067

# %%
housing['log_WoodDeckSF'] = np.log(housing['WoodDeckSF'] + 1)

# %% [markdown]
# #  OpenPorchSF

# %%
# OpenPorchSF 
housing[['OpenPorchSF', 'SalePrice']].plot(kind='scatter', x='OpenPorchSF', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='OpenPorchSF', ylabel='SalePrice'>

# %%
log_price.corr(np.log(housing['OpenPorchSF'] + 1))
# Out:
# 0.4660993488224769

# %%
housing['log_OpenPorchSF'] = np.log(housing['OpenPorchSF'] + 1)

# %%
housing['yeo_OpenPorchSF'],_ = stats.yeojohnson(housing['OpenPorchSF'])

# %%
log_price.corr(housing['yeo_OpenPorchSF'])
# Out:
# 0.46592370339042405

# %% [markdown]
# # Pool

# %%
housing['has_pool'] = housing['PoolArea'] != 0

# %% [markdown]
# # 'LotFrontage'

# %%
housing[['LotFrontage', 'SalePrice']].plot(kind='scatter', x='LotFrontage', y='SalePrice', logx=True, logy=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %%
housing['yeo_LotFrontage'],_ = stats.yeojohnson(housing['LotFrontage'])

# %%
log_price.corr(housing['yeo_LotFrontage'])
# Out:
# 0.3821738004287051

# %%
log_price.corr(np.log(housing['LotFrontage'] + 1))
# Out:
# 0.36265343329195593

# %%
housing['log_LotFrontage']=np.log(housing['LotFrontage'] + 1)

# %%
housing['yeo_LotFrontage'],_ = stats.yeojohnson(housing['LotFrontage'])

# %%
log_price.corr(housing['yeo_LotFrontage'] )
# Out:
# 0.3821738004287051

# %%
# seaborn scatter with reg line

# %%
# sns.lmplot(data=housing, x='log_LotFrontage', y='log_price', fit_reg= True)

# %%
# size_related.columns
# df_num.columns

# other_numerics = list(filter(lambda x: x not in size_related.columns, df_num.columns ))

# %%
# other_numerics = housing[other_numerics]

# %%
# housing.info()

# %% [markdown]
# x="OverallQual", y="SalePrice"

# %% [markdown]
# # OverallQual

# %%
sns.set_theme(style='darkgrid')

# tips = sns.load_dataset("tips")
ax = sns.barplot(x="OverallQual", y="SalePrice", data=housing, color='skyblue', ci=None)

# %% [markdown]
# x="OverallQual", y="log_price"

# %% [markdown]
# # OverallCond

# %%
ax = sns.barplot(x="OverallCond", y="SalePrice", data=housing, color='skyblue' ,ci=None)

# %%
sns.set_theme(style='darkgrid')

# tips = sns.load_dataset("tips")
ax = sns.barplot(x="OverallCond", y="log_price", data=housing, color='skyblue' ,ci=None)

# %% [markdown]
# # YearBuilt  correation 0.5866

# %%
housing[['YearBuilt', 'SalePrice']].plot(kind='scatter', x='YearBuilt', y='SalePrice',  logy=True) #logx=True,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
log_price.corr(housing['YearBuilt'])
# Out:
# 0.5958495060907166

# %%
housing['YearBuilt'].corr(housing['YearRemodAdd'])
# Out:
# 0.5653412228386129

# %% [markdown]
# # YearRemodAdd

# %%
# YearRemodAdd

housing[['YearRemodAdd', 'SalePrice']].plot(kind='scatter', x='YearRemodAdd', y='SalePrice',  logy=True) #logx=True,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='SalePrice'>

# %%
# sns.heatmap(other_numerics.corr(), cmap="Blues", center=0); #cmap="Blues", cmap='RdBu',
log_price.corr(housing['YearRemodAdd'])
# Out:
# 0.5641195945542202

# %% [markdown]
# # BsmtFinSF1: Type 1 finished square feet

# %%
# BsmtFinSF1

# sns.set_theme(style='darkgrid')

# ax = sns.barplot(x="BsmtFinSF1", y="SalePrice", data=other_numerics, color='skyblue' ,ci=None)

housing[['BsmtFinSF1', 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtFinSF1', ylabel='SalePrice'>

# %%
housing['yeo_BsmtFinSF1'],_  = stats.yeojohnson(housing['BsmtFinSF1'])

# %%
housing['log_BsmtFinSF1'] = np.log(housing['BsmtFinSF1']+1)

# %%
log_price.corr(housing['BsmtFinSF1'])
# Out:
# 0.441399960064673

# %%
log_price.corr(housing['yeo_BsmtFinSF1'])
# Out:
# 0.2925749861878254

# %%
log_price.corr(housing['log_BsmtFinSF1'])
# Out:
# 0.23332528008307393

# %%
housing[['BsmtFinSF2', 'SalePrice']].plot(kind='scatter', x='BsmtFinSF2', y='SalePrice', logx=True, logy=True) #,, 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtFinSF2', ylabel='SalePrice'>

# %%
# BsmtUnfSF  
housing[['BsmtUnfSF', 'SalePrice']].plot(kind='scatter', x='BsmtUnfSF', y='SalePrice', logx=True, logy=True) #,, 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtUnfSF', ylabel='SalePrice'>

# %%
log_price.corr(np.log(housing['BsmtUnfSF']+1))
# Out:
# 0.1780290201769859

# %%
housing['log_BsmtUnfSF'] = np.log(housing['BsmtUnfSF']+1)

# %%
log_price.corr(housing['BsmtUnfSF'])
# Out:
# 0.1902297317063011

# %%
log_price.corr(np.log(housing['BsmtUnfSF']+1))
# Out:
# 0.1780290201769859

# %%
yeo_BsmtUnfSF,_ = pd.Series(stats.yeojohnson(housing['BsmtUnfSF']))
# log_price.corr(yeo_BsmtUnfSF)
yeo_BsmtUnfSF = pd.Series(yeo_BsmtUnfSF)
type(yeo_BsmtUnfSF)
log_price.corr(yeo_BsmtUnfSF)
# Out:
# 0.06004277234424995

# %%
# EnclosedPorch 

housing[['EnclosedPorch', 'SalePrice']].plot(kind='scatter', x='EnclosedPorch', y='SalePrice', logx=True, logy=True) #logx=True,    ,, 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='EnclosedPorch', ylabel='SalePrice'>

# %%
log_price.corr(np.log(housing['EnclosedPorch']+1))
# Out:
# -0.22682247472091344

# %%
housing['log_EnclosedPorch'] = np.log(housing['EnclosedPorch']+1)

# %%
log_price.corr(housing['EnclosedPorch'])
# Out:
# -0.1657224564556693

# %%
yeo_EnclosedPorch,_ = pd.Series(stats.yeojohnson(housing['EnclosedPorch']))
yeo_EnclosedPorch =pd.Series(yeo_EnclosedPorch)
log_price.corr(yeo_EnclosedPorch)
# Out:
# 0.008708588182985626

# %%
# BsmtFullBath 
housing[['BsmtFullBath', 'SalePrice']].plot(kind='scatter', x='BsmtFullBath', y='SalePrice',  logy=True) #logx=True,    ,, 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtFullBath', ylabel='SalePrice'>

# %%
# BsmtHalfBath 
housing[['BsmtHalfBath', 'SalePrice']].plot(kind='scatter', x='BsmtHalfBath', y='SalePrice',  logy=True) #logx=True,    ,, 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='BsmtHalfBath', ylabel='SalePrice'>

# %%
# FullBath

housing[['FullBath', 'SalePrice']].plot(kind='scatter', x='FullBath', y='SalePrice',  logy=True) #logx=True,    ,, 'SalePrice']].plot(kind='scatter', x='BsmtFinSF1', y='SalePrice', logx=True, logy=True) #,
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='FullBath', ylabel='SalePrice'>

# %% [markdown]
# # create dummies from categoricals

# %%
categ = ['MSSubClass','MSZoning','Street', 'LandContour', 'Utilities', 'LotConfig', 'Neighborhood', \
           'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', \
           'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', \
           'GarageFinish', 'PavedDrive', 'Fence', 'MoSold', 'SaleCondition' ]

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Neighborhood',
target = 'SalePrice')
# Out:
#    Neighborhood  category_freq  pct_total  median_of_target  index
# 0       NoRidge             43   2.410314          315750.0    197
# 1       NridgHt             86   4.820628          312545.0    195
# 2       Veenker             17   0.952915          255000.0    159
# 3       StoneBr             34   1.905830          255500.0    159
# 4       Somerst             98   5.493274          233250.0    145
# 5        Timber             32   1.793722          216750.0    135
# 6       ClearCr             27   1.513453          200000.0    125
# 7       CollgCr            170   9.529148          200000.0    125
# 8       Crawfor             74   4.147982          198750.0    124
# 9        Greens              6   0.336323          189000.0    118
# 10      SawyerW             77   4.316143          187000.0    116
# 11      Blmngtn             13   0.728700          185485.0    116
# 12      Gilbert             93   5.213004          183200.0    114
# ...

# %%
MSSubClass = categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'MSSubClass',
target = 'SalePrice')

MSSubClass
# Out:
#     MSSubClass  category_freq  pct_total  median_of_target  index
# 0           60            347  19.450673          214000.0    133
# 1          120            118   6.614350          196000.0    122
# 2           75             13   0.728700          179500.0    112
# 3           80             78   4.372197          166250.0    103
# 4           20            632  35.426009          155000.0     96
# 5           70             86   4.820628          150000.0     93
# 6           85             34   1.905830          148000.0     92
# 7          150              1   0.056054          148400.0     92
# 8           90             60   3.363229          139500.0     87
# 9           40              5   0.280269          133000.0     83
# 10          50            196  10.986547          133000.0     83
# 11         160             76   4.260090          127500.0     79
# 12         190             35   1.961883          118000.0     73
# ...

# %%
# housing['MSSubClass_60'] = housing.MSSubClass == '60'
# housing['MSSubClass_120'] = housing.MSSubClass.isin(['120'])
# housing['MSSubClass_50'] = housing.MSSubClass.isin(['50'])
# housing['MSSubClass_30'] = housing.MSSubClass.isin(['30'])
# housing['MSSubClass_30'].head(3)

# %%
# housing['MSSubClass_60'].head(3)

# %%
# housing['MSSubClass_120'].head(3)

# %%
# housing['MSSubClass_50'].head(3)

# %%
# housing['MSSubClass_30'].head(3)

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'MSZoning',
target = 'SalePrice')
# Out:
#   MSZoning  category_freq  pct_total  median_of_target  index
# 0       FV             78   4.372197          221500.0    138
# 1       RL           1397  78.307175          169900.0    106
# 2       RH             13   0.728700          145000.0     90
# 3       RM            296  16.591928          123000.0     76

# %%
housing['MSZoning_RM'] = housing.MSZoning.isin(['RM'])
housing['MSZoning_RM'].head(3)
# Out:
# 1232    False
# 2381    False
# 810     False
# Name: MSZoning_RM, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Street',
target = 'SalePrice')
# Out:
#   Street  category_freq  pct_total  median_of_target  index
# 0   Pave           1779  99.719731          159900.0    100
# 1   Grvl              5   0.280269          118500.0     74

# %%
housing['paved_street'] = housing.Street == 'Pave'
housing['paved_street'].head(3)
# Out:
# 1232    True
# 2381    True
# 810     True
# Name: paved_street, dtype: bool

# %%
categ = ['MSSubClass','MSZoning','Street', 'LandContour', 'Utilities', 'LotConfig', 'Neighborhood', \
           'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', \
           'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', \
           'GarageFinish', 'PavedDrive', 'Fence', 'MoSold', 'SaleCondition' ]

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'LandContour',
target = 'SalePrice')
# Out:
#   LandContour  category_freq  pct_total  median_of_target  index
# 0         Low             32   1.793722          198500.0    124
# 1         HLS             76   4.260090          196000.0    122
# 2         Lvl           1614  90.470852          158750.0     99
# 3         Bnk             62   3.475336          139700.0     87

# %%
housing['LandContour_Lvl'] = housing.LandContour == 'Lvl'
housing['LandContour_Lvl'].head(3)
# Out:
# 1232    True
# 2381    True
# 810     True
# Name: LandContour_Lvl, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Utilities',
target = 'SalePrice')
# Out:
#   Utilities  category_freq  pct_total  median_of_target  index
# 0    AllPub           1784      100.0          159897.5    100

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'LotConfig',
target = 'SalePrice')

# LotConfig: Lot configuration

#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
# Out:
#   LotConfig  category_freq  pct_total  median_of_target  index
# 0       FR3              7   0.392377          207000.0    129
# 1   CulDSac            101   5.661435          191000.0    119
# 2    Corner            312  17.488789          159750.0     99
# 3    Inside           1313  73.598655          157000.0     98
# 4       FR2             51   2.858744          153500.0     95

# %%
housing['LotConfig_CulDSac'] = housing.LotConfig.isin(['CulDSac'])

housing['LotConfig_corner_inside_FR2'] = housing.LotConfig.isin(['Corner','Inside','FR2'])
housing['LotConfig_corner_inside_FR2'].mean()
# Out:
# 0.9394618834080718

# %%
housing['LotConfig_CulDSac'].head(3)
# Out:
# 1232    False
# 2381    False
# 810     False
# Name: LotConfig_CulDSac, dtype: bool

# %%
df = categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Neighborhood',
target = 'SalePrice')
df
# Out:
#    Neighborhood  category_freq  pct_total  median_of_target  index
# 0       NoRidge             43   2.410314          315750.0    197
# 1       NridgHt             86   4.820628          312545.0    195
# 2       Veenker             17   0.952915          255000.0    159
# 3       StoneBr             34   1.905830          255500.0    159
# 4       Somerst             98   5.493274          233250.0    145
# 5        Timber             32   1.793722          216750.0    135
# 6       ClearCr             27   1.513453          200000.0    125
# 7       CollgCr            170   9.529148          200000.0    125
# 8       Crawfor             74   4.147982          198750.0    124
# 9        Greens              6   0.336323          189000.0    118
# 10      SawyerW             77   4.316143          187000.0    116
# 11      Blmngtn             13   0.728700          185485.0    116
# 12      Gilbert             93   5.213004          183200.0    114
# ...

# %%
type(df['median_of_target'].describe())
df['median_of_target'].describe()
# df.shape
# Out:
# count        26.000000
# mean     178461.730769
# std       59949.595427
# min       87000.000000
# 25%      130050.000000
# 50%      182100.000000
# 75%      200000.000000
# max      315750.000000
# Name: median_of_target, dtype: float64

# %%
def categ_check(
df_name = None,
target_median = None,
categ_feature = None,
target = None):

    df1 = df_name.groupby([categ_feature])[target].median().reset_index()
    df1 = df1.rename(columns={target:'median_of_target'})

    df1['index'] = (df1['median_of_target']/target_median*100).astype(int)

    df2= df_name[[categ_feature,target]]
    df2 = df2.groupby([categ_feature]).count().reset_index()
    df2 = df2.rename(columns={target:'category_freq'})

    df2['pct_total'] = df2['category_freq']/df_name.shape[0]*100

    df3 = pd.merge(df2,df1)

    df4 = df3.sort_values(by=['index'], ascending=False).reset_index()
    df4 = df4.drop(columns=['level_0'])
    return df4

# %%
df['median_of_target'].describe()
# Out:
# count        26.000000
# mean     178461.730769
# std       59949.595427
# min       87000.000000
# 25%      130050.000000
# 50%      182100.000000
# 75%      200000.000000
# max      315750.000000
# Name: median_of_target, dtype: float64

# %%
df = categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Neighborhood',
target = 'SalePrice')

def func(row):
    if row['median_of_target'] >= 87000.0 and row['median_of_target'] < 130050.0:
        return 1
    elif row['median_of_target'] >= 130050.0 and row['median_of_target'] < 182100.0:
        return 2
    elif row['median_of_target'] >= 182100.0 and row['median_of_target'] < 200000.0:
        return 3
    else:
        return 4

df['neighborhood_group'] = df.apply(func, axis=1)

neighborhood_group = df[['Neighborhood', 'neighborhood_group']]
neighborhood_group
# Out:
#    Neighborhood  neighborhood_group
# 0       NoRidge                   4
# 1       NridgHt                   4
# 2       Veenker                   4
# 3       StoneBr                   4
# 4       Somerst                   4
# 5        Timber                   4
# 6       ClearCr                   4
# 7       CollgCr                   4
# 8       Crawfor                   3
# 9        Greens                   3
# 10      SawyerW                   3
# 11      Blmngtn                   3
# 12      Gilbert                   3
# 13       NWAmes                   2
# 14      Mitchel                   2
# 15      NPkVill                   2
# 16        NAmes                   2
# 17        SWISU                   2
# 18       Sawyer                   2
# 19      BrkSide                   1
# 20      Edwards                   1
# 21      Blueste                   1
# 22      OldTown                   1
# 23       IDOTRR                   1
# 24       BrDale                   1
# ...

# %%
housing.shape
# Out:
# (1784, 136)

# %%
housing
# Out:
#       GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 1232       1664     162900          60       RL         78.0    10140   Pave
# 2381       1268     133000          40       RL         60.0    12144   Pave
# 810        1628     189000          80       RL         60.0     8400   Pave
# 863        2270     290000          60       RL         92.0    11764   Pave
# 1346       1482     143000          70       RM         50.0     9000   Pave
# ...         ...        ...         ...      ...          ...      ...    ...
# 1051       1224     115000          50       RM         60.0     3950   Pave
# 1758       2482     281213          60       RL         88.0    12665   Pave
# 778        2373     258000          60       RL         96.0    11631   Pave
# 851        1008     137000          20       RL         73.0    11425   Pave
# 1679       1080     136000          20       RL         75.0     9464   Pave
#
# ...

# %%
housing_test = pd.merge(housing, neighborhood_group, how='inner', on ='Neighborhood')
housing_test.shape
# Out:
# (1784, 137)

# %%
housing['Neighborhood_NoRidge_NridgHt_Veenker_StoneBr']= housing.Neighborhood.isin(['NoRidge','NridgHt','Veenker','StoneBr'])

housing['Neighborhood_Somerst_Timber'] = housing.Neighborhood.isin(['Somerst','Timber'])

housing['Neighborhood_ClearCr_CollgCr_Crawfor'] = housing.Neighborhood.isin(['ClearCr','CollgCr','Crawfor'])

housing['Neighborhood_Greens_SawyerW_Blmngtn'] = housing.Neighborhood.isin(['Greens','SawyerW','Blmngtn'])

housing['Neighborhood_Gilbert_NWAmes'] = housing.Neighborhood.isin(['Gilbert','NWAmes'])

housing['Neighborhood_Mitchel_NPkVill'] = housing.Neighborhood.isin(['Mitchel','NPkVill'])

housing['Neighborhood_NAmes_SWISU_Sawyer'] = housing.Neighborhood.isin(['NAmes','SWISU','Sawyer'])

housing['Neighborhood_BrkSide_Edwards_Blueste_OldTown_IDOTRR'] = housing.Neighborhood.isin(['BrkSide','Edwards','Blueste','OldTown','IDOTRR'])




# housing['Neighborhood']

# %%
neigh = ['Neighborhood_NoRidge_NridgHt_Veenker_StoneBr','Neighborhood_Somerst_Timber', 'Neighborhood_ClearCr_CollgCr_Crawfor', 'Neighborhood_Greens_SawyerW_Blmngtn','Neighborhood_Gilbert_NWAmes', 'Neighborhood_Mitchel_NPkVill', 'Neighborhood_NAmes_SWISU_Sawyer','Neighborhood_BrkSide_Edwards_Blueste_OldTown_IDOTRR']

# %%
sns.set_theme(style='darkgrid')
sns.set(rc = {'figure.figsize':(15,8)})

# medians = housing.groupby('Neighborhood')['SalePrice'].median().reset_index()
# medians = medians.sort_values(by=['SalePrice'], ascending=False).reset_index()

ax = sns.barplot(x=df1["Neighborhood"], y='index', data = df,  color='skyblue', ci=None)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)

ax.set_xlabel("Neighborhood",fontsize=15)
ax.set_ylabel("Index to Median Sale Price",fontsize=15)  
ax.set_title('Ames Iowa Neighborhoods',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Ames Iowa Neighborhoods')

# %%
# df = housing.groupby('Neighborhood')['SalePrice'].median().reset_index()
# df = df.sort_values(by=['SalePrice'], ascending=False)
# type(df)
# df
# medians

# %%
sns.set_theme(style='darkgrid')
sns.set(rc = {'figure.figsize':(15,8)})

medians = housing.groupby('Neighborhood')['SalePrice'].median().reset_index()
medians = medians.sort_values(by=['SalePrice'], ascending=False).reset_index()

ax = sns.barplot(x=df1["Neighborhood"], y='SalePrice', data = medians,  color='skyblue', ci=None)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)

ax.set_xlabel("Neighborhood",fontsize=15)
ax.set_ylabel("Median Sale Price",fontsize=15)  
ax.set_title('Ames Iowa Neighborhoods',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Ames Iowa Neighborhoods')

# %%
# combined= compare_percent('num_images')
medians = housing.groupby('Neighborhood')['SalePrice'].median()
features = ['Neighborhood','SalePrice' ]
df = housing[features].sort_values(by=['SalePrice'], ascending=False).reset_index()

sns.set(rc = {'figure.figsize':(15,8)})
box = sns.boxplot(x='Neighborhood', y='SalePrice', data=df, palette='Blues')
# for i in range(len(medians)):
#     box.annotate(str(medians[i]), xy=(i,medians[i]),horizontalalignment = 'center',fontsize=20);

#hue="smoker", palette=["m", "g"],
#sns.despine(offset=10, trim=True)

box.set_xlabel("Neighborhood",fontsize=15)
#box.set_xlabel("",fontsize=15)
box.set_ylabel("Sale Price",fontsize=15)
box.set_title('Neighborhoods',fontsize=20)
box.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# Out:
# [Text(0, 0, 'Blmngtn'),
#  Text(1, 0, 'Blueste'),
#  Text(2, 0, 'BrDale'),
#  Text(3, 0, 'BrkSide'),
#  Text(4, 0, 'ClearCr'),
#  Text(5, 0, 'CollgCr'),
#  Text(6, 0, 'Crawfor'),
#  Text(7, 0, 'Edwards'),
#  Text(8, 0, 'Gilbert'),
#  Text(9, 0, 'Greens'),
#  Text(10, 0, 'IDOTRR'),
#  Text(11, 0, 'MeadowV'),
#  Text(12, 0, 'Mitchel'),
#  Text(13, 0, 'NAmes'),
#  Text(14, 0, 'NPkVill'),
#  Text(15, 0, 'NWAmes'),
#  Text(16, 0, 'NoRidge'),
#  Text(17, 0, 'NridgHt'),
#  Text(18, 0, 'OldTown'),
#  Text(19, 0, 'SWISU'),
#  Text(20, 0, 'Sawyer'),
#  Text(21, 0, 'SawyerW'),
#  Text(22, 0, 'Somerst'),
#  Text(23, 0, 'StoneBr'),
#  Text(24, 0, 'Timber'),
#  Text(25, 0, 'Veenker')]

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Condition1',
target = 'SalePrice')

# Condition1: Proximity to various conditions

#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street	
#        Norm	Normal	
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
# Out:
#   Condition1  category_freq  pct_total  median_of_target  index
# 0       RRNn              5   0.280269          220000.0    137
# 1       PosN             22   1.233184          210000.0    131
# 2       PosA             11   0.616592          190000.0    118
# 3       RRNe              3   0.168161          187000.0    116
# 4       RRAn             24   1.345291          169302.5    105
# 5       Norm           1552  86.995516          161875.0    101
# 6       RRAe             17   0.952915          142500.0     89
# 7      Feedr             94   5.269058          139000.0     86
# 8     Artery             56   3.139013          121125.0     75

# %%
housing['Condition1_near_RR'] = housing.Condition1.isin(['RRNn','RRNe','RRAn','RRAe'])

housing['Condition1z_Feedr_Artery'] = housing.Condition1.isin(['Feedr','Artery'])

housing['Condition1_PosN_PosA'] = housing.Condition1.isin(['PosN','PosA'])

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Condition2',
target = 'SalePrice')
# Out:
#   Condition2  category_freq  pct_total  median_of_target  index
# 0       PosA              2   0.112108          467500.0    292
# 1       PosN              2   0.112108          401000.0    250
# 2       Norm           1769  99.159193          159900.0    100
# 3     Artery              2   0.112108          137125.0     85
# 4       RRAn              1   0.056054          136905.0     85
# 5      Feedr              6   0.336323          117700.0     73
# 6       RRNn              2   0.112108           96750.0     60

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'BldgType',
target = 'SalePrice')

# ldgType: Type of dwelling

#        1Fam	Single-family Detached	
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
# Out:
#   BldgType  category_freq  pct_total  median_of_target  index
# 0   TwnhsE            140   7.847534          178970.0    111
# 1     1Fam           1486  83.295964          161875.0    101
# 2   Duplex             60   3.363229          139500.0     87
# 3    Twnhs             62   3.475336          126950.0     79
# 4   2fmCon             36   2.017937          117000.0     73

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'HouseStyle',
target = 'SalePrice')


# HouseStyle: Style of dwelling

#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
# Out:
#   HouseStyle  category_freq  pct_total  median_of_target  index
# 0     2.5Fin              5   0.280269          191000.0    119
# 1     2Story            533  29.876682          189000.0    118
# 2       SLvl             84   4.708520          165500.0    103
# 3     2.5Unf             13   0.728700          164000.0    102
# 4     1Story            865  48.486547          153500.0     95
# 5     SFoyer             55   3.082960          140000.0     87
# 6     1.5Fin            218  12.219731          132000.0     82
# 7     1.5Unf             11   0.616592          113000.0     70

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'RoofStyle',
target = 'SalePrice')
# Out:
#   RoofStyle  category_freq  pct_total  median_of_target  index
# 0      Shed              2   0.112108          208500.0    130
# 1       Hip            319  17.881166          172500.0    107
# 2      Flat              9   0.504484          164000.0    102
# 3     Gable           1433  80.325112          157000.0     98
# 4   Mansard              9   0.504484          152000.0     95
# 5   Gambrel             12   0.672646          138000.0     86

# %%
housing['RoofStyle_Gable'] = housing.RoofStyle.isin(['Gable'])

housing['RoofStyle_Hip'] = housing.RoofStyle.isin(['Hip'])

housing['RoofStyle_other'] = housing.RoofStyle.isin(['Shed','Flat','Mansard','Gambrel'])

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'RoofMatl',
target = 'SalePrice')
# Out:
#   RoofMatl  category_freq  pct_total  median_of_target  index
# 0  WdShngl              4   0.224215          332500.0    207
# 1  WdShake              6   0.336323          251000.0    156
# 2  Membran              1   0.056054          241500.0    151
# 3  Tar&Grv             10   0.560538          162000.0    101
# 4  CompShg           1762  98.766816          159000.0     99
# 5     Roll              1   0.056054          137000.0     85

# %%
housing['RoofMatl_CompShg'] = housing.RoofMatl.isin(['CompShg'])

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Exterior1st',
target = 'SalePrice')
# Out:
#    Exterior1st  category_freq  pct_total  median_of_target  index
# 0      PreCast              1   0.056054          260000.0    162
# 1      VinylSd            603  33.800448          201000.0    125
# 2      CemntBd             72   4.035874          193000.0    120
# 3      BrkFace             51   2.858744          161500.0    101
# 4      BrkComm              2   0.112108          161250.0    100
# 5      Plywood            132   7.399103          156750.0     98
# 6      HdBoard            295  16.535874          154204.0     96
# 7      Wd Sdng            271  15.190583          140000.0     87
# 8      MetalSd            276  15.470852          139000.0     86
# 9      WdShing             32   1.793722          132950.0     83
# 10      Stucco             26   1.457399          120000.0     75
# 11     AsbShng             21   1.177130          111000.0     69
# 12      CBlock              1   0.056054          105000.0     65
# ...

# %%
housing['Exterior1st_VinylSd'] = housing.Exterior1st.isin(['VinylSd'])

housing['Exterior1st_HdBoard'] = housing.Exterior1st.isin(['HdBoard'])

housing['Exterior1st_MetalSd'] = housing.Exterior1st.isin(['MetalSd'])

housing['Exterior1st_Wd_Sdng'] = housing.Exterior1st.isin(['Wd Sdng'])

housing['Exterior1st_Plywood'] = housing.Exterior1st.isin(['Plywood'])

housing['Exterior1st_CemntBd'] = housing.Exterior1st.isin(['CemntBd'])

housing['Exterior1st_BrkFace_BrkComm'] = housing.Exterior1st.isin(['BrkFace','BrkComm'])

housing['Exterior1st_WdShing_Stucco_AsbShng'] = housing.Exterior1st.isin(['WdShing','Stucco','AsbShng'])

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Exterior2nd',
target = 'SalePrice')
# Out:
#    Exterior2nd  category_freq  pct_total  median_of_target  index
# 0      PreCast              1   0.056054          260000.0    162
# 1      VinylSd            593  33.239910          202500.0    126
# 2      CmentBd             72   4.035874          196000.0    122
# 3      ImStucc              9   0.504484          192000.0    120
# 4      BrkFace             27   1.513453          160000.0    100
# 5      HdBoard            271  15.190583          157000.0     98
# 6      Plywood            155   8.688341          154000.0     96
# 7      Brk Cmn             14   0.784753          146500.0     91
# 8      MetalSd            275  15.414798          140000.0     87
# 9      Wd Sdng            263  14.742152          139600.0     87
# 10     AsphShn              3   0.168161          139000.0     86
# 11     Wd Shng             50   2.802691          139000.0     86
# 12       Stone              2   0.112108          133500.0     83
# ...

# %%
housing['Exterior2nd_VinylSd'] = housing.Exterior2nd.isin(['VinylSd'])

housing['Exterior2nd_HdBoard'] = housing.Exterior2nd.isin(['HdBoard'])

housing['Exterior2nd_MetalSd'] = housing.Exterior2nd.isin(['MetalSd'])

housing['Exterior2nd_Wd_Sdng'] = housing.Exterior2nd.isin(['Wd Sdng'])

housing['Exterior2nd_Plywood'] = housing.Exterior2nd.isin(['Plywood'])

housing['Exterior2nd_CemntBd'] = housing.Exterior2nd.isin(['CemntBd'])

housing['Exterior2nd_BrkFace_BrkComm'] = housing.Exterior2nd.isin(['BrkFace','BrkComm'])

housing['Exterior2nd_WdShing_Stucco_AsbShng'] = housing.Exterior2nd.isin(['WdShing','Stucco','AsbShng'])

housing['Exterior2nd_WdShing_Stucco_AsbShng'].head(3)
# Out:
# 1232    False
# 2381    False
# 810     False
# Name: Exterior2nd_WdShing_Stucco_AsbShng, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'MasVnrType',
target = 'SalePrice')
# Out:
#   MasVnrType  category_freq  pct_total  median_of_target  index
# 0      Stone            129   7.230942          224000.0    140
# 1    BrkFace            550  30.829596          185000.0    115
# 2       None           1092  61.210762          144050.0     90
# 3     BrkCmn             13   0.728700          139000.0     86

# %%
housing['MasVnrType_Stone'] = housing.MasVnrType.isin(['Stone'])

housing['MasVnrType_BrkFace'] = housing.MasVnrType.isin(['BrkFace'])

housing['MasVnrType_None'] = housing.MasVnrType.isin(['None'])

housing['MasVnrType_None'].head(3)
# Out:
# 1232     True
# 2381     True
# 810     False
# Name: MasVnrType_None, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Foundation',
target = 'SalePrice')
# Out:
#   Foundation  category_freq  pct_total  median_of_target  index
# 0       Wood              2   0.112108          207000.0    129
# 1      PConc            769  43.105381          206000.0    128
# 2     CBlock            782  43.834081          141250.0     88
# 3      Stone              5   0.280269          139900.0     87
# 4     BrkTil            198  11.098655          123000.0     76
# 5       Slab             28   1.569507          102350.0     64

# %%
housing['Foundation_PConc'] = housing.Foundation.isin(['PConc'])

housing['Foundation_CBlock'] = housing.Foundation.isin(['CBlock'])

housing['Foundation_BrkTil'] = housing.Foundation.isin(['BrkTil'])

housing['Foundation_BrkTil'].head(3)
# Out:
# 1232    False
# 2381    False
# 810     False
# Name: Foundation_BrkTil, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Heating',
target = 'SalePrice')
# Out:
#   Heating  category_freq  pct_total  median_of_target  index
# 0    GasA           1760  98.654709          160000.0    100
# 1    GasW             15   0.840807          144000.0     90
# 2    OthW              2   0.112108          125750.0     78
# 3    Wall              4   0.224215           91450.0     57
# 4    Grav              3   0.168161           80000.0     50

# %%
housing['Heating_GasA'] = housing.Heating.isin(['GasA'])
housing['Heating_GasA'].head(3)
# Out:
# 1232    True
# 2381    True
# 810     True
# Name: Heating_GasA, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'CentralAir',
target = 'SalePrice')
# Out:
#   CentralAir  category_freq  pct_total  median_of_target  index
# 0          Y           1680  94.170404          163000.0    101
# 1          N            104   5.829596          101500.0     63

# %%
housing['CentralAir_Y'] =  housing.CentralAir.isin(['Y'])

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Electrical',
target = 'SalePrice')
# Out:
#   Electrical  category_freq  pct_total  median_of_target  index
# 0      SBrkr           1648  92.376682          164500.0    102
# 1      FuseA            109   6.109865          127000.0     79
# 2      FuseF             26   1.457399          103750.0     64
# 3      FuseP              1   0.056054           68000.0     42

# %%
housing['Electrical_SBrkr'] =  housing.Electrical.isin(['SBrkr'])
housing['Electrical_Fuse'] =  housing.Electrical.isin(['FuseA','FuseF','FuseP'])

housing['Electrical_Fuse'].head(3)
# Out:
# 1232    False
# 2381    False
# 810     False
# Name: Electrical_Fuse, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'GarageType',
target = 'SalePrice')
# Out:
#   GarageType  category_freq  pct_total  median_of_target  index
# 0    BuiltIn            110   6.165919          215750.0    134
# 1     Attchd           1043  58.464126          183200.0    114
# 2     2Types              9   0.504484          170000.0    106
# 3    Basment             22   1.233184          149150.0     93
# 4     Detchd            504  28.251121          132000.0     82
# 5         No             92   5.156951          107750.0     67
# 6    CarPort              4   0.224215          105900.0     66

# %%
housing['GarageType_BuiltIn'] =  housing.GarageType.isin(['BuiltIn'])
housing['GarageType_Attchd'] =  housing.GarageType.isin(['Attchd'])
housing['GarageType_Detchd'] =  housing.GarageType.isin(['Detchd'])
housing['No_Garage'] =  housing.GarageType.isin(['No'])

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'GarageFinish',
target = 'SalePrice')
# Out:
#   GarageFinish  category_freq  pct_total  median_of_target  index
# 0          Fin            439  24.607623          213490.0    133
# 1          RFn            481  26.961883          190000.0    118
# 2          Unf            770  43.161435          136500.0     85
# 3           No             94   5.269058          108750.0     68

# %%
housing['GarageFinish_Fin'] =  housing.GarageFinish.isin(['Fin'])
housing['GarageFinish_RFn'] =  housing.GarageFinish.isin(['RFn'])
housing['GarageFinish_Unf'] =  housing.GarageFinish.isin(['Unf'])

housing['GarageFinish_Unf'].head(3)
# Out:
# 1232    False
# 2381     True
# 810     False
# Name: GarageFinish_Unf, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'PavedDrive',
target = 'SalePrice')
# Out:
#   PavedDrive  category_freq  pct_total  median_of_target  index
# 0          Y           1624   91.03139          165000.0    103
# 1          P             42    2.35426          127700.0     79
# 2          N            118    6.61435          110700.0     69

# %%
# PavedDrive: Paved driveway

#        Y	Paved 
#        P	Partial Pavement
#        N	Dirt/Gravel

# use dummify

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Fence',
target = 'SalePrice')
# Out:
#    Fence  category_freq  pct_total  median_of_target  index
# 0     No           1405  78.755605          169000.0    105
# 1  GdPrv             72   4.035874          162950.0    101
# 2  MnPrv            224  12.556054          140000.0     87
# 3   GdWo             76   4.260090          138250.0     86
# 4   MnWw              7   0.392377          123000.0     76

# %%
housing['no_fence'] =  housing.Fence.isin(['No'])
housing['Fence_GdPrv'] = housing.Fence.isin(['GdPrv'])
housing['Fence_GdWo'] = housing.Fence.isin(['GdWo'])

housing['Fence_GdWo'].head(2)
# Out:
# 1232     True
# 2381    False
# Name: Fence_GdWo, dtype: bool

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'MoSold',
target = 'SalePrice')
# Out:
#     MoSold  category_freq  pct_total  median_of_target  index
# 0        1             76   4.260090          178000.0    111
# 1       11             79   4.428251          173000.0    108
# 2        8            135   7.567265          169000.0    105
# 3        2             89   4.988789          165000.0    103
# 4       12             63   3.531390          165000.0    103
# 5        9             89   4.988789          161500.0    101
# 6        7            275  15.414798          159900.0    100
# 7        6            302  16.928251          159250.0     99
# 8        3            151   8.464126          156932.0     98
# 9        5            245  13.733184          155000.0     96
# 10       4            184  10.313901          149050.0     93
# 11      10             96   5.381166          150000.0     93

# %%
# MoSold dummify

# %%
categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'SaleCondition',
target = 'SalePrice')
# Out:
#   SaleCondition  category_freq  pct_total  median_of_target  index
# 0       Partial             59   3.307175          252678.0    158
# 1        Normal           1672  93.721973          158750.0     99
# 2        Alloca              2   0.112108          152556.5     95
# 3        Family             12   0.672646          147000.0     91
# 4       Abnorml             37   2.073991          145000.0     90
# 5       AdjLand              2   0.112108          138750.0     86

# %%
housing['SaleCondition_Normal'] = housing.SaleCondition.isin(['Normal'])

housing['SaleCondition_Partial'] = housing.SaleCondition.isin(['Partial'])

housing['SaleCondition_Partial'].head(3)
# Out:
# 1232    False
# 2381    False
# 810     False
# Name: SaleCondition_Partial, dtype: bool

# %%
categ = ['MSSubClass','MSZoning','Street', 'LandContour', 'Utilities', 'LotConfig', 'Neighborhood', \
           'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', \
           'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', \
           'GarageFinish', 'PavedDrive', 'Fence', 'MoSold', 'SaleCondition' ]

# %%
list(housing.columns)
# Out:
# ['GrLivArea',
#  'SalePrice',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
new_dummies = ['MSSubClass_60', 'MSSubClass_50',  'MSSubClass_30', 'LandContour_Lvl',\
               'LotConfig_CulDSac', 'LotConfig_corner_inside_FR2', 'Condition1_near_RR',\
               'Condition1z_Feedr_Artery',  'Condition1_PosN_PosA', 'RoofStyle_Gable', 'RoofStyle_Hip',\
               'RoofStyle_other', 'RoofMatl_CompShg', 'Exterior1st_VinylSd', 'Exterior1st_HdBoard', \
               'Exterior1st_MetalSd',  'Exterior1st_Wd_Sdng', 'Exterior1st_Plywood',  'Exterior1st_CemntBd',\
               'Exterior1st_BrkFace_BrkComm', 'Exterior1st_WdShing_Stucco_AsbShng', 'Exterior2nd_VinylSd', \
               'Exterior2nd_HdBoard', 'Exterior2nd_MetalSd', 'Exterior2nd_Wd_Sdng', 'Exterior2nd_Plywood',\
                'Exterior2nd_CemntBd', 'Exterior2nd_BrkFace_BrkComm', 'Exterior2nd_WdShing_Stucco_AsbShng',\
               'MasVnrType_Stone', 'MasVnrType_BrkFace', 'MasVnrType_None',  'Foundation_PConc',\
               'Foundation_CBlock', 'Foundation_BrkTil', 'Heating_GasA', 'CentralAir_Y', 'Electrical_SBrkr',\
               'Electrical_Fuse', 'GarageType_BuiltIn', 'GarageType_Attchd', 'GarageType_Detchd', 'No_Garage',\
               'GarageFinish_Fin', 'GarageFinish_RFn', 'GarageFinish_Unf', 'no_fence', 'Fence_GdPrv',\
                'Fence_GdWo', 'SaleCondition_Normal', 'SaleCondition_Partial'] + keeps

# %%
df2 = categ_check(
df_name = housing,
target_median = housing.SalePrice.median(),
categ_feature = 'Heating',
target = 'SalePrice')
print(df2)
# Out:
#   Heating  category_freq  pct_total  median_of_target  index
# 0    GasA           1760  98.654709          160000.0    100
# 1    GasW             15   0.840807          144000.0     90
# 2    OthW              2   0.112108          125750.0     78
# 3    Wall              4   0.224215           91450.0     57
# 4    Grav              3   0.168161           80000.0     50

# %%
# for feature in new_dummies:
#     print(feature,' ', housing[feature].mean()*100)

# %%
for feature in new_dummies:    
    df = categ_mean(
    df_name = housing,
    target_mean = housing.SalePrice.mean(),
    categ_feature = feature,
    target = 'SalePrice')
    print(df)
    print(' ')
    
    df2 = categ_check(
    df_name = housing,
    target_median = housing.SalePrice.median(),
    categ_feature = feature,
    target = 'SalePrice')
    print(df2)
    print(' ')
# Out:
#    MSSubClass_60  category_freq  pct_total  mean_of_target  index
# 0              1            347  19.450673   230418.772334    128
# 1              0           1437  80.549327   166451.225470     93
#
#    MSSubClass_60  category_freq  pct_total  median_of_target  index
# 0              1            347  19.450673          214000.0    133
# 1              0           1437  80.549327          147500.0     92
#
#    MSSubClass_50  category_freq  pct_total  mean_of_target  index
# 0              0           1588  89.013453   183395.659320    102
# 1              1            196  10.986547   142415.397959     79
#
#    MSSubClass_50  category_freq  pct_total  median_of_target  index
# 0              0           1588  89.013453          165000.0    103
# 1              1            196  10.986547          133000.0     83
#
#    MSSubClass_30  category_freq  pct_total  mean_of_target  index
# 0              0           1704  95.515695   182599.574531    102
# ...

# %%
neigh

for feature in neigh:    
    df = categ_mean(
    df_name = housing,
    target_mean = housing.SalePrice.mean(),
    categ_feature = feature,
    target = 'SalePrice')
    print(df)
    print(' ')
    
    df2 = categ_check(
    df_name = housing,
    target_median = housing.SalePrice.median(),
    categ_feature = feature,
    target = 'SalePrice')
    print(df2)
    print(' ')
# Out:
#    Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  category_freq  pct_total  \
# 0                                          True            180  10.089686
# 1                                         False           1604  89.910314
#
#    mean_of_target  index
# 0   310814.588889    173
# 1   164089.213840     91
#
#    Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  category_freq  pct_total  \
# 0                                          True            180  10.089686
# 1                                         False           1604  89.910314
#
#    median_of_target  index
# 0          292000.0    182
# 1          153000.0     95
#
#    Neighborhood_Somerst_Timber  category_freq  pct_total  mean_of_target  \
# 0                         True            130   7.286996   234326.376923
# 1                        False           1654  92.713004   174536.454655
#
#    index
# 0    130
# 1     97
#
#    Neighborhood_Somerst_Timber  category_freq  pct_total  median_of_target  \
# ...

# %%
# housing['bc_GrLivArea'],_ = stats.boxcox(housing.GrLivArea)

# housing['bc_LotArea'],_ = stats.boxcox(housing['LotArea'])

# housing['log_MasVnrArea'] = np.log(housing['MasVnrArea'] + 1)

# housing['yeo_TotalBsmtSF'],_ = stats.yeojohnson(housing['TotalBsmtSF'])

# housing['log_first_FlrSF'] = np.log(housing['1stFlrSF'])

# housing['yeo_GarageArea'],_  = stats.yeojohnson(housing['GarageArea'] )

# housing['log_WoodDeckSF'] = np.log(housing['WoodDeckSF'] + 1)

# housing['log_OpenPorchSF'] = np.log(housing['OpenPorchSF'] + 1)


# housing['yeo_LotFrontage'],_ = stats.yeojohnson(housing['LotFrontage'])

# housing['log_EnclosedPorch'] = np.log(housing['EnclosedPorch']+1)

# %%
# housing2.head()

# %% [markdown]
# ## Imputations

# %% [markdown]
# ### impute training data
# ### housing2 is a copy of the unaltered training data

# %%
#Imputations

list_sub = ['Neighborhood','LotFrontage']
housing2_sub = housing2[list_sub]
housing2_sub

imputation_dict = housing2_sub.groupby(["Neighborhood"]).median().to_dict()
imputation_dict['LotFrontage']

impute_index = housing2_sub.LotFrontage.isnull()

housing2_sub.loc[impute_index,'LotFrontage'] = housing2_sub.loc[impute_index].apply(lambda current_row:imputation_dict['LotFrontage'][(current_row[0])], axis=1)

####  do actual imputation of LotFrontage in housing2

housing2['LotFrontage'] =  housing2_sub['LotFrontage']


######################################################################
# Other imputations

housing2.MasVnrArea = housing2.MasVnrArea.fillna(0)

housing2.BsmtFullBath = housing2.BsmtFullBath.fillna(0)

housing2.BsmtHalfBath = housing2.BsmtHalfBath.fillna(0)

housing2.BsmtFinSF1 = housing2.BsmtFinSF1.fillna(0)

housing2.BsmtFinSF2 = housing2.BsmtFinSF2.fillna(0)

housing2.BsmtUnfSF = housing2.BsmtUnfSF.fillna(0)

housing2.TotalBsmtSF = housing2.TotalBsmtSF.fillna(0)

housing2.GarageCars = housing2.GarageCars.fillna(0)

housing2.GarageArea = housing2.GarageArea.fillna(0)

housing2.loc[housing2['GarageYrBlt'].isnull(),'GarageYrBlt'] = housing2['YearBuilt']
# Out:
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\pandas\core\indexing.py:1884: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %% [markdown]
# ### impute test data

# %%
#Imputations

list_sub = ['Neighborhood','LotFrontage']
x_test_sub = x_test[list_sub]
x_test_sub

imputation_dict = x_test_sub.groupby(["Neighborhood"]).median().to_dict()
imputation_dict['LotFrontage']

impute_index = x_test_sub.LotFrontage.isnull()

x_test_sub.loc[impute_index,'LotFrontage'] = x_test_sub.loc[impute_index].apply(lambda current_row:imputation_dict['LotFrontage'][(current_row[0])], axis=1)

####  do actual imputation of LotFrontage in x_test

x_test['LotFrontage'] =  x_test_sub['LotFrontage']


######################################################################
# Other imputations

x_test.MasVnrArea = x_test.MasVnrArea.fillna(0)

x_test.BsmtFullBath = x_test.BsmtFullBath.fillna(0)

x_test.BsmtHalfBath = x_test.BsmtHalfBath.fillna(0)

x_test.BsmtFinSF1 = x_test.BsmtFinSF1.fillna(0)

x_test.BsmtFinSF2 = x_test.BsmtFinSF2.fillna(0)

x_test.BsmtUnfSF = x_test.BsmtUnfSF.fillna(0)

x_test.TotalBsmtSF = x_test.TotalBsmtSF.fillna(0)

x_test.GarageCars = x_test.GarageCars.fillna(0)

x_test.GarageArea = x_test.GarageArea.fillna(0)

x_test.loc[x_test['GarageYrBlt'].isnull(),'GarageYrBlt'] = x_test['YearBuilt']
# Out:
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# ## transformations and dummy creation

# %%
housing2['bc_GrLivArea'],_ = stats.boxcox(housing2.GrLivArea)

housing2['bc_LotArea'],_ = stats.boxcox(housing2['LotArea'])

housing2['log_MasVnrArea'] = np.log(housing2['MasVnrArea'] + 1)

housing2['yeo_TotalBsmtSF'],_ = stats.yeojohnson(housing2['TotalBsmtSF'])

housing2['log_first_FlrSF'] = np.log(housing2['1stFlrSF'])

housing2['yeo_GarageArea'],_  = stats.yeojohnson(housing2['GarageArea'] )

housing2['log_WoodDeckSF'] = np.log(housing2['WoodDeckSF'] + 1)

housing2['log_OpenPorchSF'] = np.log(housing2['OpenPorchSF'] + 1)


housing2['yeo_LotFrontage'],_ = stats.yeojohnson(housing2['LotFrontage'])

housing2['log_EnclosedPorch'] = np.log(housing2['EnclosedPorch']+1)

######################################################################

# drop 'Utilities','Condition2'

#########################################################################
#dummify BldgType HouseStyle PavedDrive MoSold


###########################################################################

housing2['MSZoning_RM'] = housing2.MSZoning.isin(['RM'])

housing2['paved_street'] = housing2.Street == 'Pave'

housing2['LandContour_Lvl'] = housing2.LandContour == 'Lvl'


housing2['LotConfig_CulDSac'] = housing2.LotConfig.isin(['CulDSac'])

housing2['LotConfig_corner_inside_FR2'] = housing2.LotConfig.isin(['Corner','Inside','FR2'])

housing2['Neighborhood_NoRidge_NridgHt_Veenker_StoneBr']= housing2.Neighborhood.isin(['NoRidge','NridgHt','Veenker','StoneBr'])

housing2['Neighborhood_Somerst_Timber'] = housing2.Neighborhood.isin(['Somerst','Timber'])

housing2['Neighborhood_ClearCr_CollgCr_Crawfor'] = housing2.Neighborhood.isin(['ClearCr','CollgCr','Crawfor'])

housing2['Neighborhood_Greens_SawyerW_Blmngtn'] = housing2.Neighborhood.isin(['Greens','SawyerW','Blmngtn'])

housing2['Neighborhood_Gilbert_NWAmes'] = housing2.Neighborhood.isin(['Gilbert','NWAmes'])

housing2['Neighborhood_Mitchel_NPkVill'] = housing2.Neighborhood.isin(['Mitchel','NPkVill'])

housing2['Neighborhood_NAmes_SWISU_Sawyer'] = housing2.Neighborhood.isin(['NAmes','SWISU','Sawyer'])

housing2['Neighborhood_BrkSide_Edwards_Blueste_OldTown_IDOTRR'] = housing2.Neighborhood.isin(['BrkSide','Edwards','Blueste','OldTown','IDOTRR'])


housing2['Condition1_near_RR'] = housing2.Condition1.isin(['RRNn','RRNe','RRAn','RRAe'])

housing2['Condition1z_Feedr_Artery'] = housing2.Condition1.isin(['Feedr','Artery'])

housing2['Condition1_PosN_PosA'] = housing2.Condition1.isin(['PosN','PosA'])

housing2['RoofStyle_Gable'] = housing2.RoofStyle.isin(['Gable'])

housing2['RoofStyle_Hip'] = housing2.RoofStyle.isin(['Hip'])

housing2['RoofStyle_other'] = housing2.RoofStyle.isin(['Shed','Flat','Mansard','Gambrel'])


housing2['RoofMatl_CompShg'] = housing2.RoofMatl.isin(['CompShg'])


housing2['Exterior1st_VinylSd'] = housing2.Exterior1st.isin(['VinylSd'])

housing2['Exterior1st_HdBoard'] = housing2.Exterior1st.isin(['HdBoard'])

housing2['Exterior1st_MetalSd'] = housing2.Exterior1st.isin(['MetalSd'])

housing2['Exterior1st_Wd_Sdng'] = housing2.Exterior1st.isin(['Wd Sdng'])

housing2['Exterior1st_Plywood'] = housing2.Exterior1st.isin(['Plywood'])

housing2['Exterior1st_CemntBd'] = housing2.Exterior1st.isin(['CemntBd'])

housing2['Exterior1st_BrkFace_BrkComm'] = housing2.Exterior1st.isin(['BrkFace','BrkComm'])

housing2['Exterior1st_WdShing_Stucco_AsbShng'] = housing2.Exterior1st.isin(['WdShing','Stucco','AsbShng'])



housing2['Exterior2nd_VinylSd'] = housing2.Exterior2nd.isin(['VinylSd'])

housing2['Exterior2nd_HdBoard'] = housing2.Exterior2nd.isin(['HdBoard'])

housing2['Exterior2nd_MetalSd'] = housing2.Exterior2nd.isin(['MetalSd'])

housing2['Exterior2nd_Wd_Sdng'] = housing2.Exterior2nd.isin(['Wd Sdng'])

housing2['Exterior2nd_Plywood'] = housing2.Exterior2nd.isin(['Plywood'])

housing2['Exterior2nd_CemntBd'] = housing2.Exterior2nd.isin(['CemntBd'])

housing2['Exterior2nd_BrkFace_BrkComm'] = housing2.Exterior2nd.isin(['BrkFace','BrkComm'])

housing2['Exterior2nd_WdShing_Stucco_AsbShng'] = housing2.Exterior2nd.isin(['WdShing','Stucco','AsbShng'])


housing2['MasVnrType_Stone'] = housing2.MasVnrType.isin(['Stone'])
housing2['MasVnrType_BrkFace'] = housing2.MasVnrType.isin(['BrkFace'])


housing2['Foundation_PConc'] = housing2.Foundation.isin(['PConc'])
housing2['Foundation_CBlock'] = housing2.Foundation.isin(['CBlock'])
housing2['Foundation_BrkTil'] = housing2.Foundation.isin(['BrkTil'])


housing2['Heating_GasA'] = housing2.Heating.isin(['GasA'])

housing2['CentralAir_Y'] =  housing2.CentralAir.isin(['Y'])

housing2['Electrical_SBrkr'] =  housing2.Electrical.isin(['SBrkr'])
housing2['Electrical_Fuse'] =  housing2.Electrical.isin(['FuseA','FuseF','FuseP'])

housing2['GarageType_BuiltIn'] =  housing2.GarageType.isin(['BuiltIn'])
housing2['GarageType_Attchd'] =  housing2.GarageType.isin(['Attchd'])
housing2['GarageType_Detchd'] =  housing2.GarageType.isin(['Detchd'])
housing2['No_Garage'] =  housing2.GarageType.isin(['No'])

housing2['GarageFinish_Fin'] =  housing2.GarageFinish.isin(['Fin'])
housing2['GarageFinish_RFn'] =  housing2.GarageFinish.isin(['RFn'])
housing2['GarageFinish_Unf'] =  housing2.GarageFinish.isin(['Unf'])


housing2['no_fence'] =  housing2.Fence.isin(['No'])
housing2['Fence_GdPrv'] = housing2.Fence.isin(['GdPrv'])
housing2['Fence_MnPrv'] = housing2.Fence.isin(['MnPrv'])
housing2['Fence_GdWo'] = housing2.Fence.isin(['GdWo'])


housing2['SaleCondition_Normal'] = housing2.SaleCondition.isin(['Normal'])

housing2['SaleCondition_Partial'] = housing2.SaleCondition.isin(['Partial'])

##############################################################################
housing2['Neighborhood_NoRidge_NridgHt_Veenker_StoneBr']= housing2.Neighborhood.isin(['NoRidge','NridgHt','Veenker','StoneBr'])

housing2['Neighborhood_Somerst_Timber'] = housing2.Neighborhood.isin(['Somerst','Timber'])

housing2['Neighborhood_ClearCr_CollgCr_Crawfor'] = housing2.Neighborhood.isin(['ClearCr','CollgCr','Crawfor'])

housing2['Neighborhood_Greens_SawyerW_Blmngtn'] = housing2.Neighborhood.isin(['Greens','SawyerW','Blmngtn'])

housing2['Neighborhood_Gilbert_NWAmes'] = housing2.Neighborhood.isin(['Gilbert','NWAmes'])

housing2['Neighborhood_Mitchel_NPkVill'] = housing2.Neighborhood.isin(['Mitchel','NPkVill'])

housing2['Neighborhood_NAmes_SWISU_Sawyer'] = housing2.Neighborhood.isin(['NAmes','SWISU','Sawyer'])

housing2['Neighborhood_BrkSide_Edwards_Blueste_OldTown_IDOTRR'] = housing2.Neighborhood.isin(['BrkSide','Edwards','Blueste','OldTown','IDOTRR'])

########################################################################################
housing2['has_wood_deck '] = housing2.WoodDeckSF != 0
housing2['has_openporch'] = housing2.OpenPorchSF != 0
housing2['has_EnclosedPorch'] = housing2.EnclosedPorch !=0

housing2['house_age_'] = housing2.YrSold - housing2.YearBuilt #not dummy
housing2['years_since_remodeled_'] = housing2.YrSold - housing2.YearRemodAdd # not dummy

housing2['has_basement'] = housing2.TotalBsmtSF != 0
housing2['has_finsished_basement'] = housing2.BsmtFinSF2 !=0

# %%
x_test['bc_GrLivArea'],_ = stats.boxcox(x_test.GrLivArea)

x_test['bc_LotArea'],_ = stats.boxcox(x_test['LotArea'])

x_test['log_MasVnrArea'] = np.log(x_test['MasVnrArea'] + 1)

x_test['yeo_TotalBsmtSF'],_ = stats.yeojohnson(x_test['TotalBsmtSF'])

x_test['log_first_FlrSF'] = np.log(x_test['1stFlrSF'])

x_test['yeo_GarageArea'],_  = stats.yeojohnson(x_test['GarageArea'] )

x_test['log_WoodDeckSF'] = np.log(x_test['WoodDeckSF'] + 1)

x_test['log_OpenPorchSF'] = np.log(x_test['OpenPorchSF'] + 1)


x_test['yeo_LotFrontage'],_ = stats.yeojohnson(x_test['LotFrontage'])

x_test['log_EnclosedPorch'] = np.log(x_test['EnclosedPorch']+1)

######################################################################

# drop 'Utilities','Condition2'

#########################################################################
#dummify BldgType HouseStyle PavedDrive MoSold


###########################################################################

x_test['MSZoning_RM'] = x_test.MSZoning.isin(['RM'])

x_test['paved_street'] = x_test.Street == 'Pave'

x_test['LandContour_Lvl'] = x_test.LandContour == 'Lvl'


x_test['LotConfig_CulDSac'] = x_test.LotConfig.isin(['CulDSac'])

x_test['LotConfig_corner_inside_FR2'] = x_test.LotConfig.isin(['Corner','Inside','FR2'])

x_test['Neighborhood_NoRidge_NridgHt_Veenker_StoneBr']= x_test.Neighborhood.isin(['NoRidge','NridgHt','Veenker','StoneBr'])

x_test['Neighborhood_Somerst_Timber'] = x_test.Neighborhood.isin(['Somerst','Timber'])

x_test['Neighborhood_ClearCr_CollgCr_Crawfor'] = x_test.Neighborhood.isin(['ClearCr','CollgCr','Crawfor'])

x_test['Neighborhood_Greens_SawyerW_Blmngtn'] = x_test.Neighborhood.isin(['Greens','SawyerW','Blmngtn'])

x_test['Neighborhood_Gilbert_NWAmes'] = x_test.Neighborhood.isin(['Gilbert','NWAmes'])

x_test['Neighborhood_Mitchel_NPkVill'] = x_test.Neighborhood.isin(['Mitchel','NPkVill'])

x_test['Neighborhood_NAmes_SWISU_Sawyer'] = x_test.Neighborhood.isin(['NAmes','SWISU','Sawyer'])

x_test['Neighborhood_BrkSide_Edwards_Blueste_OldTown_IDOTRR'] = x_test.Neighborhood.isin(['BrkSide','Edwards','Blueste','OldTown','IDOTRR'])


x_test['Condition1_near_RR'] = x_test.Condition1.isin(['RRNn','RRNe','RRAn','RRAe'])

x_test['Condition1z_Feedr_Artery'] = x_test.Condition1.isin(['Feedr','Artery'])

x_test['Condition1_PosN_PosA'] = x_test.Condition1.isin(['PosN','PosA'])

x_test['RoofStyle_Gable'] = x_test.RoofStyle.isin(['Gable'])

x_test['RoofStyle_Hip'] = x_test.RoofStyle.isin(['Hip'])

x_test['RoofStyle_other'] = x_test.RoofStyle.isin(['Shed','Flat','Mansard','Gambrel'])


x_test['RoofMatl_CompShg'] = x_test.RoofMatl.isin(['CompShg'])


x_test['Exterior1st_VinylSd'] = x_test.Exterior1st.isin(['VinylSd'])

x_test['Exterior1st_HdBoard'] = x_test.Exterior1st.isin(['HdBoard'])

x_test['Exterior1st_MetalSd'] = x_test.Exterior1st.isin(['MetalSd'])

x_test['Exterior1st_Wd_Sdng'] = x_test.Exterior1st.isin(['Wd Sdng'])

x_test['Exterior1st_Plywood'] = x_test.Exterior1st.isin(['Plywood'])

x_test['Exterior1st_CemntBd'] = x_test.Exterior1st.isin(['CemntBd'])

x_test['Exterior1st_BrkFace_BrkComm'] = x_test.Exterior1st.isin(['BrkFace','BrkComm'])

x_test['Exterior1st_WdShing_Stucco_AsbShng'] = x_test.Exterior1st.isin(['WdShing','Stucco','AsbShng'])



x_test['Exterior2nd_VinylSd'] = x_test.Exterior2nd.isin(['VinylSd'])

x_test['Exterior2nd_HdBoard'] = x_test.Exterior2nd.isin(['HdBoard'])

x_test['Exterior2nd_MetalSd'] = x_test.Exterior2nd.isin(['MetalSd'])

x_test['Exterior2nd_Wd_Sdng'] = x_test.Exterior2nd.isin(['Wd Sdng'])

x_test['Exterior2nd_Plywood'] = x_test.Exterior2nd.isin(['Plywood'])

x_test['Exterior2nd_CemntBd'] = x_test.Exterior2nd.isin(['CemntBd'])

x_test['Exterior2nd_BrkFace_BrkComm'] = x_test.Exterior2nd.isin(['BrkFace','BrkComm'])

x_test['Exterior2nd_WdShing_Stucco_AsbShng'] = x_test.Exterior2nd.isin(['WdShing','Stucco','AsbShng'])


x_test['MasVnrType_Stone'] = x_test.MasVnrType.isin(['Stone'])
x_test['MasVnrType_BrkFace'] = x_test.MasVnrType.isin(['BrkFace'])


x_test['Foundation_PConc'] = x_test.Foundation.isin(['PConc'])
x_test['Foundation_CBlock'] = x_test.Foundation.isin(['CBlock'])
x_test['Foundation_BrkTil'] = x_test.Foundation.isin(['BrkTil'])


x_test['Heating_GasA'] = x_test.Heating.isin(['GasA'])

x_test['CentralAir_Y'] =  x_test.CentralAir.isin(['Y'])

x_test['Electrical_SBrkr'] =  x_test.Electrical.isin(['SBrkr'])
x_test['Electrical_Fuse'] =  x_test.Electrical.isin(['FuseA','FuseF','FuseP'])

x_test['GarageType_BuiltIn'] =  x_test.GarageType.isin(['BuiltIn'])
x_test['GarageType_Attchd'] =  x_test.GarageType.isin(['Attchd'])
x_test['GarageType_Detchd'] =  x_test.GarageType.isin(['Detchd'])
x_test['No_Garage'] =  x_test.GarageType.isin(['No'])

x_test['GarageFinish_Fin'] =  x_test.GarageFinish.isin(['Fin'])
x_test['GarageFinish_RFn'] =  x_test.GarageFinish.isin(['RFn'])
x_test['GarageFinish_Unf'] =  x_test.GarageFinish.isin(['Unf'])


x_test['no_fence'] =  x_test.Fence.isin(['No'])
x_test['Fence_GdPrv'] = x_test.Fence.isin(['GdPrv'])
x_test['Fence_MnPrv'] = x_test.Fence.isin(['MnPrv'])
x_test['Fence_GdWo'] = x_test.Fence.isin(['GdWo'])


x_test['SaleCondition_Normal'] = x_test.SaleCondition.isin(['Normal'])

x_test['SaleCondition_Partial'] = x_test.SaleCondition.isin(['Partial'])

##############################################################################
x_test['Neighborhood_NoRidge_NridgHt_Veenker_StoneBr']= x_test.Neighborhood.isin(['NoRidge','NridgHt','Veenker','StoneBr'])

x_test['Neighborhood_Somerst_Timber'] = x_test.Neighborhood.isin(['Somerst','Timber'])

x_test['Neighborhood_ClearCr_CollgCr_Crawfor'] = x_test.Neighborhood.isin(['ClearCr','CollgCr','Crawfor'])

x_test['Neighborhood_Greens_SawyerW_Blmngtn'] = x_test.Neighborhood.isin(['Greens','SawyerW','Blmngtn'])

x_test['Neighborhood_Gilbert_NWAmes'] = x_test.Neighborhood.isin(['Gilbert','NWAmes'])

x_test['Neighborhood_Mitchel_NPkVill'] = x_test.Neighborhood.isin(['Mitchel','NPkVill'])

x_test['Neighborhood_NAmes_SWISU_Sawyer'] = x_test.Neighborhood.isin(['NAmes','SWISU','Sawyer'])

x_test['Neighborhood_BrkSide_Edwards_Blueste_OldTown_IDOTRR'] = x_test.Neighborhood.isin(['BrkSide','Edwards','Blueste','OldTown','IDOTRR'])

########################################################################################
x_test['has_wood_deck '] = x_test.WoodDeckSF != 0
x_test['has_openporch'] = x_test.OpenPorchSF != 0
x_test['has_EnclosedPorch'] = x_test.EnclosedPorch !=0

x_test['house_age_'] = x_test.YrSold - x_test.YearBuilt #not dummy
x_test['years_since_remodeled_'] = x_test.YrSold - x_test.YearRemodAdd # not dummy

x_test['has_basement'] = x_test.TotalBsmtSF != 0
x_test['has_finsished_basement'] = x_test.BsmtFinSF2 !=0

# %% [markdown]
# ## drop dummies

# %%
dummy_drops =['Condition1_PosN_PosA', 'RoofStyle_other', 'RoofStyle_other' ,  'Exterior1st_HdBoard', 'Exterior1st_Plywood',\
              'Exterior1st_BrkFace_BrkComm', 'Exterior2nd_HdBoard', 'Exterior2nd_Plywood',  'Exterior2nd_CemntBd', \
              'Exterior2nd_BrkFace_BrkComm', 'Exterior2nd_WdShing_Stucco_AsbShng',  'Exterior2nd_WdShing_Stucco_AsbShng',\
              'Heating_GasA', 'SaleCondition_Partial', 'BldgType_2fmCon',  'BldgType_2fmCon',  'BldgType_Duplex', \
              'BldgType_Twnhs', 'HouseStyle_1.5Unf', 'HouseStyle_1Story','HouseStyle_2.5Fin',\
              'HouseStyle_2.5Unf',  'HouseStyle_SLvl', 'PavedDrive_P' ,'MoSold_10','MoSold_11', \
              'MoSold_12', 'MoSold_2', 'MoSold_3', 'MoSold_4', 'MoSold_5', 'MoSold_6', 'MoSold_7', 'MoSold_8', \
              'MoSold_9', 'Neighborhood_Greens_SawyerW_Blmngtn','Neighborhood_Gilbert_NWAmes']       

housing2 = housing2.drop(dummy_drops, axis=1)

x_test= x_test.drop(dummy_drops, axis=1)

# %%
housing2.shape
# Out:
# (1784, 149)

# %%
x_test.shape
# Out:
# (765, 149)

# %%
nums = housing2.select_dtypes(include=['int64','float64'])
# list(nums.columns)

# %%
nums['log_price'] = np.log(nums['SalePrice'])
# Out:
# C:\Users\dgarb\AppData\Local\Temp/ipykernel_9200/1377982762.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nums['log_price'] = np.log(nums['SalePrice'])

# %% [markdown]
# dropped features exclusing dummies with correlation less than 0.15

# %%
# housing2.head(3)
pd.set_option('display.max_rows', None)

print("look at correlations with target")
corr = nums.corr()
corr.sort_values(["log_price"], ascending = False, inplace = True)


# print(corr.log_price)

#dropped features exclusing dummies with correlation less than 0.15
# Out:
# look at correlations with target

# %%
numes = nums.drop(['log_price'], axis=1)

# %%
num_drops = ['SalePrice','MasVnrArea', 'TotalBsmtSF', '1stFlrSF', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'LotFrontage', \
             'EnclosedPorch','YearBuilt', 'YearRemodAdd', 'YrSold', 'KitchenAbvGr', 'GarageCond', \
             'OverallCond', 'ScreenPorch', 'LowQualFinSF', 'BsmtExposure', 'BsmtHalfBath', 'Functional', \
             'log_EnclosedPorch', 'MoSold', 'PoolArea','YrSold', '3SsnPorch']

# housing2 = housing2.drop(num_drops, axis=1)
# nums = 
nums.drop(num_drops, axis=1)
# nums = nums.drop(num_drops, axis=1)

nums_cols = set(nums.columns)

keeps = nums_cols - set(num_drops)

keep_features = list(keeps)
# keeps

# %%
model_vars_data = housing2[keep_features]
test_vars_data = x_test[keep_features]

# %%
miss_cols(model_vars_data)
# Out:
# []

# %%
to_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\model_vars_data.csv')

test_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\test_vars_data.csv')

# %%
# # housing2.head(3)
# pd.set_option('display.max_rows', None)

# print("look at correlations with target")
# corr = nums.corr()
# corr.sort_values(["log_price"], ascending = False, inplace = True)


# # type(corr.SalePrice)
# # # type(corr)
# print(corr.log_price)

# %% [markdown]
# # here

# %%
# corr.to_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\output\corr1.csv')
