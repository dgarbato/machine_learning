# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import GridSearchCV

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
from scipy import stats

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
from regression_function_fix import regx3

# %%
model_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\model_vars_data.csv',index_col=0)

test_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\test_vars_data.csv',index_col=0)

price_train = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\y_train.csv',index_col=0)

price_test = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\y_test.csv',index_col=0)

# %%
def miss_cols(df):
    missing = np.sum(df.isnull(),axis=0)
    
    miss_ind = np.sum(df.isnull(),axis=0) > 0
    
    vals = pd.Series(filter(lambda x: x != 0,missing))
     
    cols_miss = df.columns[miss_ind]

    L=list(zip(cols_miss,vals, round(vals/df.shape[0],4)))
    
    return sorted(L,reverse=True,key=lambda x: x[2])

# %%
model_vars_data.drop(['GarageYrBlt'],axis=1, inplace = True)
miss_cols(model_vars_data)
# Out:
# []

# %%
test_vars_data.drop(['GarageYrBlt'],axis=1, inplace = True)
miss_cols(test_vars_data)
# Out:
# []

# %%
def to_keep(mod, amt):
    keeps1 = mod.loc[mod['abs_val'] > amt,['features']]
    list_keeps1 = list(keeps1.features)
    return list_keeps1

# %%
# def regx2(model= None,
# x_train = None,
# x_test = None,
# y_train = None,
# y_test = None,
# params = None, #put dictionary of params
# cv_ = 5,
# linear_reg = True,
# tree_based = False) :
# ######################################
# #########################################

#     features = list(x_train.columns)

#     ss = StandardScaler()
#     x_train = pd.DataFrame(ss.fit_transform(x_train), columns = features)
#     x_test = pd.DataFrame(ss.fit_transform(x_test), columns = features)
    
# #     print('train ',x_train.head())
# #     print(' ')
# #     print('test ', x_test.head())
    
    
#     gs = GridSearchCV(model, params, cv=cv_, return_train_score=True, refit=True)
#     gs.fit(x_train,y_train)
#     gs.best_params_

#     model= gs.best_estimator_
#     ###################################    

#     print('best params: ',gs.best_params_)
#     print('score: ',gs.score(x_train,y_train))
#     print('  ')
#     print('test score: ',gs.score(x_test,y_test))


#     if linear_reg:
#         adj_r2 = 1-(1-gs.score(x_train,y_train))*(x_train.shape[0] - 1) / (x_train.shape[0] - x_train.shape[1] - 1)
#         print('adj_r2: ', adj_r2)
#         adj_r2_test = 1-(1-gs.score(x_test,y_test))*(x_test.shape[0] - 1) / (x_test.shape[0] - x_test.shape[1] - 1)
#         print('  ')
#         print('adj_r2_test: ',adj_r2_test)
#         print(' ')


#     train_pred = gs.best_estimator_.predict(x_train)
#     print('train RMSE: ' + str(mean_squared_error(train_pred,y_train)**0.5))
#     print('  ')

#     test_pred = gs.best_estimator_.predict(x_test)
#     print('test RMSE: ' + str(mean_squared_error(test_pred,y_test)**0.5))

#     if linear_reg:

#         coefs = pd.Series(gs.best_estimator_.coef_, name = 'coef' )

#         varnames = pd.Series(features, name = 'features')

#         pd.set_option('display.max_rows', None) # or 1000.

#         abs_coefs = pd.Series(np.abs(coefs),name = 'abs_val')

#         coefs_ = pd.concat([varnames,coefs, abs_coefs], axis=1)

#         #return:
#         model_importances = coefs_.sort_values(by=['abs_val'], ascending=False)

#         print(model_importances)
#         print(' ')

#     elif tree_based:
#         pd.set_option('display.max_rows', None) # or 1000.

#         #return
#         varnames = pd.Series(features, name = 'features')

#         importances_ = pd.Series(model.feature_importances_, name = 'importances')

#         df = pd.concat([varnames,importances_], axis=1)

#         model_importances = df.sort_values(by=['importances'], ascending=False)



#     #         model_importances = pd.Series(model.feature_importances_, index = features).sort_values(ascending=False)

#         print(model_importances)


#     if linear_reg:
#         residuals = y_train - train_pred
#         print('skewness: ',stats.skew(residuals))
#         print(' ')
#         sns.set_theme(style='darkgrid')
#         sns.histplot(residuals, bins=20);
    
#     print('model_importances.shape: ',model_importances.shape)
#     return model_importances

# %%
# def regx3(model= None,
# x_train = None,
# x_test = None,
# y_train = None,
# y_test = None,
# params = None, #put dictionary of params
# cv_ = 5,
# linear_reg = True,
# tree_based = False) :
# ######################################
# #########################################

#     features = list(x_train.columns)

#     ss = StandardScaler()
#     x_train = pd.DataFrame(ss.fit_transform(x_train), columns = features)
#     x_test = pd.DataFrame(ss.fit_transform(x_test), columns = features)
    
# #     print('train ',x_train.head())
# #     print(' ')
# #     print('test ', x_test.head())
    
    
#     gs = GridSearchCV(model, params, cv=cv_, return_train_score=True, refit=True)
#     gs.fit(x_train,y_train)
#     gs.best_params_

#     model= gs.best_estimator_
#     ###################################    

#     print('best params: ',gs.best_params_)
#     print('score: ',gs.score(x_train,y_train))
#     print('  ')
#     print('test score: ',gs.score(x_test,y_test))


#     if linear_reg:
#         adj_r2 = 1-(1-gs.score(x_train,y_train))*(x_train.shape[0] - 1) / (x_train.shape[0] - x_train.shape[1] - 1)
#         print('adj_r2: ', adj_r2)
#         adj_r2_test = 1-(1-gs.score(x_test,y_test))*(x_test.shape[0] - 1) / (x_test.shape[0] - x_test.shape[1] - 1)
#         print('  ')
#         print('adj_r2_test: ',adj_r2_test)
#         print(' ')


#     train_pred = gs.best_estimator_.predict(x_train)
#     print('train RMSE: ' + str(mean_squared_error(train_pred,y_train)**0.5))
#     print('  ')

#     test_pred = gs.best_estimator_.predict(x_test)
#     print('test RMSE: ' + str(mean_squared_error(test_pred,y_test)**0.5))

#     if linear_reg:

#         coefs = pd.Series(gs.best_estimator_.coef_, name = 'coef' )

#         varnames = pd.Series(features, name = 'features')

#         pd.set_option('display.max_rows', None) # or 1000.

#         abs_coefs = pd.Series(np.abs(coefs),name = 'abs_val')

#         coefs_ = pd.concat([varnames,coefs, abs_coefs], axis=1)

#         #return:
#         model_importances = coefs_.sort_values(by=['abs_val'], ascending=False)

#         print(model_importances)
#         print(' ')

#     elif tree_based:
#         pd.set_option('display.max_rows', None) # or 1000.

#         #return
#         varnames = pd.Series(features, name = 'features')

#         importances_ = pd.Series(model.feature_importances_, name = 'importances')

#         df = pd.concat([varnames,importances_], axis=1)

#         model_importances = df.sort_values(by=['importances'], ascending=False)



#     #         model_importances = pd.Series(model.feature_importances_, index = features).sort_values(ascending=False)

#         print(model_importances)


#     if linear_reg:
#         residuals = y_train - train_pred
#         print('skewness: ',stats.skew(residuals))
#         print(' ')
#         sns.set_theme(style='darkgrid')
#         sns.histplot(residuals, bins=20);
    
#     print('model_importances.shape: ',model_importances.shape)
#     return model_importances

# %%
# Fucntion returns dictionary

def regx4(
model=  None,
x_train = None,
x_test = None,
y_train = None,
y_test =  None,
params = None,
cv_ = 5,
linear_reg = True,
tree_based = False):
######################################
#########################################

    features = list(x_train.columns)

    ss = StandardScaler()
    x_train = pd.DataFrame(ss.fit_transform(x_train), columns = features)
    x_test = pd.DataFrame(ss.fit_transform(x_test), columns = features)

    #     print('train ',x_train.head())
    #     print(' ')
    #     print('test ', x_test.head())


    gs = GridSearchCV(model, params, cv=cv_, return_train_score=True, refit=True)
    gs.fit(x_train,y_train)
    gs.best_params_

    reg_dict = {}
    model= gs.best_estimator_
    reg_dict['mod'] = model
    ###################################    

    print('best params: ',gs.best_params_)
    reg_dict['best params'] = gs.best_params_

    print('score: ',gs.score(x_train,y_train))
    reg_dict['score'] = gs.score(x_train,y_train)

    print('  ')
    print('test score: ',gs.score(x_test,y_test))
    reg_dict['test score'] = gs.score(x_test,y_test)

    if linear_reg:
        adj_r2 = 1-(1-gs.score(x_train,y_train))*(x_train.shape[0] - 1) / (x_train.shape[0] - x_train.shape[1] - 1)
        print('adj_r2: ', adj_r2)
        reg_dict['adj_r2'] = adj_r2

        adj_r2_test = 1-(1-gs.score(x_test,y_test))*(x_test.shape[0] - 1) / (x_test.shape[0] - x_test.shape[1] - 1)
        print('  ')
        print('adj_r2_test: ',adj_r2_test)
        reg_dict['adj_r2_test'] = adj_r2_test

        print(' ')

    train_pred = gs.best_estimator_.predict(x_train)
    print('train RMSE: ' + str(mean_squared_error(train_pred,y_train)**0.5))
    print('  ')
    reg_dict['train RMSE'] = mean_squared_error(train_pred,y_train)**0.5

    test_pred = gs.best_estimator_.predict(x_test)
    print('test RMSE: ' + str(mean_squared_error(test_pred,y_test)**0.5))
    ###
    reg_dict['test RMSE'] = mean_squared_error(test_pred,y_test)**0.5

    if linear_reg:

        coefs = pd.Series(gs.best_estimator_.coef_, name = 'coef' )

        varnames = pd.Series(features, name = 'features')

        pd.set_option('display.max_rows', None) # or 1000.

        abs_coefs = pd.Series(np.abs(coefs),name = 'abs_val')

        coefs_ = pd.concat([varnames,coefs, abs_coefs], axis=1)

        #return:
        model_importances = coefs_.sort_values(by=['abs_val'], ascending=False)
        model_importances.index=(range(model_importances.shape[0]))
        model_importances
        reg_dict['model_importances'] = model_importances

        print(model_importances)
        print(' ')

    elif tree_based:
        pd.set_option('display.max_rows', None) # or 1000.

        #return
        varnames = pd.Series(features, name = 'features')

        importances_ = pd.Series(model.feature_importances_, name = 'importances')

        df = pd.concat([varnames,importances_], axis=1)

        model_importances = df.sort_values(by=['importances'], ascending=False)

        model_importances.index=(range(model_importances.shape[0]))

        reg_dict['model_importances'] = model_importances



    #         model_importances = pd.Series(model.feature_importances_, index = features).sort_values(ascending=False)

        print(model_importances)


    if linear_reg:
        residuals = y_train - train_pred
        print('skewness: ',stats.skew(residuals))
        print(' ')
        sns.set_theme(style='darkgrid')
        sns.histplot(residuals, bins=20);

    print('model_importances.shape: ',model_importances.shape)
    
    return reg_dict

# %%
ridge1 = regx2(model= Ridge(max_iter=3000),
x_train = model_vars_data,
x_test = test_vars_data,
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 100}
# score:  0.9475439740410747
#
# test score:  0.9110335424027615
# adj_r2:  0.9401875383096272
#
# adj_r2_test:  0.8751886175632207
#
# train RMSE: 0.08782408752870607
#
# test RMSE: 0.1181073294802005
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.074199  0.074199
# 24             OverallQual  0.058131  0.058131
# 46             OverallCond  0.041115  0.041115
# 4          log_first_FlrSF  0.038897  0.038897
# 22               YearBuilt  0.034947  0.034947
# 29              BsmtFinSF1  0.032828  0.032828
# 1              log_LotArea  0.028387  0.028387
# 3          yeo_TotalBsmtSF  0.021118  0.021118
# 108        Condition1_Norm  0.020300  0.020300
# 10            log_2ndFlrSF  0.019164  0.019164
# 42              Functional  0.017872  0.017872
# 103   Neighborhood_Somerst  0.017746  0.017746
# 118        Condition2_PosN -0.017535  0.017535
# 5           yeo_GarageArea  0.017200  0.017200
# 40            TotRmsAbvGrd  0.017049  0.017049
# 21              Fireplaces  0.016347  0.016347
# 104   Neighborhood_StoneBr  0.016189  0.016189
# 39             KitchenQual  0.016052  0.016052
# 146    Exterior1st_BrkFace  0.015965  0.015965
# 44              GarageCars  0.015485  0.015485
# 89    Neighborhood_GrnHill  0.015194  0.015194
# 85    Neighborhood_Crawfor  0.015135  0.015135
# 28              GarageCond  0.014463  0.014463
# 34                FullBath  0.014455  0.014455
# 98    Neighborhood_NridgHt  0.014429  0.014429
# 35                BsmtQual  0.014197  0.014197
# 221  SaleCondition_Partial  0.014109  0.014109
# 86    Neighborhood_Edwards -0.013730  0.013730
# 63        MSZoning_C (all) -0.013269  0.013269
# 45               ExterQual  0.013214  0.013214
# 15            YearRemodAdd  0.013180  0.013180
# 17            BsmtExposure  0.013083  0.013083
# 97    Neighborhood_NoRidge  0.012731  0.012731
# 30                HalfBath  0.011708  0.011708
# 14            BsmtFinType1  0.011138  0.011138
# 49          MSSubClass_160 -0.010972  0.010972
# 37               HeatingQC  0.010620  0.010620
# 143       RoofMatl_WdShngl  0.010086  0.010086
# 19           EnclosedPorch  0.009929  0.009929
# 186           CentralAir_Y  0.009774  0.009774
# 196          GarageType_No  0.009544  0.009544
# 177       Foundation_PConc  0.009411  0.009411
# 197        GarageFinish_No  0.009324  0.009324
# 27            BsmtFullBath  0.009125  0.009125
# 18              BsmtFinSF2  0.008479  0.008479
# 220   SaleCondition_Normal  0.008460  0.008460
# 92    Neighborhood_MeadowV -0.008436  0.008436
# 201           PavedDrive_Y  0.008191  0.008191
# 151    Exterior1st_MetalSd  0.008184  0.008184
# 99    Neighborhood_OldTown -0.008165  0.008165
# 170    Exterior2nd_VinylSd  0.007972  0.007972
# 110        Condition1_PosN  0.007945  0.007945
# 219   SaleCondition_Family -0.007677  0.007677
# 9           log_BsmtFinSF1 -0.007453  0.007453
# 11         log_LotFrontage  0.007281  0.007281
# 218   SaleCondition_Alloca  0.007150  0.007150
# 67             MSZoning_RL  0.007136  0.007136
# 136      RoofStyle_Mansard -0.007077  0.007077
# 94      Neighborhood_NAmes -0.006877  0.006877
# 210               MoSold_3 -0.006815  0.006815
# 25             ScreenPorch  0.006802  0.006802
# 134      RoofStyle_Gambrel -0.006669  0.006669
# 156    Exterior1st_Wd Sdng -0.006635  0.006635
# 117        Condition2_PosA  0.006443  0.006443
# 59           MSSubClass_75  0.006414  0.006414
# 102   Neighborhood_SawyerW -0.006315  0.006315
# 198       GarageFinish_RFn -0.006272  0.006272
# 68             MSZoning_RM -0.005979  0.005979
# 109        Condition1_PosA  0.005866  0.005866
# 171    Exterior2nd_Wd Sdng  0.005863  0.005863
# 31               LandSlope -0.005667  0.005667
# 206              MoSold_10 -0.005549  0.005549
# 32             FireplaceQu  0.005174  0.005174
# 205               Fence_No -0.005163  0.005163
# 83    Neighborhood_ClearCr  0.005131  0.005131
# 145    Exterior1st_BrkComm  0.005080  0.005080
# 75        Utilities_NoSewr -0.005033  0.005033
# 96     Neighborhood_NWAmes -0.005030  0.005030
# 199       GarageFinish_Unf -0.004993  0.004993
# 82    Neighborhood_BrkSide  0.004938  0.004938
# 191      GarageType_Attchd  0.004897  0.004897
# 41            KitchenAbvGr -0.004865  0.004865
# 52           MSSubClass_20  0.004844  0.004844
# 182           Heating_GasW  0.004792  0.004792
# 95    Neighborhood_NPkVill  0.004779  0.004779
# 88     Neighborhood_Greens  0.004712  0.004712
# 162    Exterior2nd_CmentBd  0.004710  0.004710
# 8                 has_pool  0.004645  0.004645
# 81     Neighborhood_BrDale  0.004639  0.004639
# 93    Neighborhood_Mitchel -0.004613  0.004613
# 193     GarageType_BuiltIn  0.004512  0.004512
# 155    Exterior1st_VinylSd  0.004495  0.004495
# 72         LandContour_HLS  0.004493  0.004493
# 174        MasVnrType_None  0.004469  0.004469
# 204             Fence_MnWw -0.004401  0.004401
# 74         LandContour_Lvl  0.004333  0.004333
# 130      HouseStyle_2Story  0.004312  0.004312
# 6           log_WoodDeckSF  0.004293  0.004293
# 13       log_EnclosedPorch -0.004244  0.004244
# 178        Foundation_Slab  0.004219  0.004219
# 207              MoSold_11 -0.004170  0.004170
# 158    Exterior2nd_AsphShn  0.004127  0.004127
# 161     Exterior2nd_CBlock  0.004086  0.004086
# 60           MSSubClass_80 -0.004069  0.004069
# 188       Electrical_FuseP  0.004029  0.004029
# 80    Neighborhood_Blueste  0.004024  0.004024
# 116        Condition2_Norm  0.004011  0.004011
# 71              Alley_Pave  0.003924  0.003924
# 62           MSSubClass_90 -0.003898  0.003898
# 123        BldgType_Duplex -0.003898  0.003898
# 58           MSSubClass_70  0.003857  0.003857
# 70              Alley_None  0.003825  0.003825
# 48          MSSubClass_150 -0.003790  0.003790
# 173     MasVnrType_BrkFace  0.003784  0.003784
# 148    Exterior1st_CemntBd -0.003727  0.003727
# 61           MSSubClass_85  0.003710  0.003710
# 56           MSSubClass_50  0.003701  0.003701
# 203            Fence_MnPrv -0.003691  0.003691
# 84    Neighborhood_CollgCr -0.003646  0.003646
# 26              GarageQual  0.003531  0.003531
# 90     Neighborhood_IDOTRR -0.003530  0.003530
# 176      Foundation_CBlock  0.003526  0.003526
# 209               MoSold_2 -0.003461  0.003461
# 183           Heating_Grav -0.003445  0.003445
# 124         BldgType_Twnhs -0.003422  0.003422
# 53           MSSubClass_30 -0.003403  0.003403
# 132        HouseStyle_SLvl  0.003062  0.003062
# 190       Electrical_SBrkr  0.003020  0.003020
# 217  SaleCondition_AdjLand  0.003013  0.003013
# 215               MoSold_8 -0.002984  0.002984
# 57           MSSubClass_60 -0.002945  0.002945
# 169     Exterior2nd_Stucco  0.002874  0.002874
# 78           LotConfig_FR3 -0.002773  0.002773
# 138       RoofMatl_Membran  0.002723  0.002723
# 192     GarageType_Basment -0.002679  0.002679
# 43            BedroomAbvGr -0.002648  0.002648
# 160    Exterior2nd_BrkFace -0.002640  0.002640
# 211               MoSold_4 -0.002631  0.002631
# 184           Heating_OthW -0.002624  0.002624
# 51          MSSubClass_190 -0.002519  0.002519
# 172    Exterior2nd_Wd Shng  0.002508  0.002508
# 128      HouseStyle_2.5Fin -0.002492  0.002492
# 121        Condition2_RRNn  0.002469  0.002469
# 111        Condition1_RRAe -0.002455  0.002455
# 175       MasVnrType_Stone  0.002433  0.002433
# 79        LotConfig_Inside  0.002423  0.002423
# 76       LotConfig_CulDSac  0.002382  0.002382
# 38                  YrSold -0.002361  0.002361
# 64             MSZoning_FV  0.002359  0.002359
# 114        Condition1_RRNn  0.002325  0.002325
# 77           LotConfig_FR2 -0.002306  0.002306
# 149    Exterior1st_HdBoard  0.002283  0.002283
# 144    Exterior1st_AsphShn -0.002257  0.002257
# 87    Neighborhood_Gilbert -0.002195  0.002195
# 33             LotFrontage  0.002147  0.002147
# 115       Condition2_Feedr -0.002087  0.002087
# 7          log_OpenPorchSF  0.002064  0.002064
# 195      GarageType_Detchd  0.001985  0.001985
# 36                LotShape -0.001944  0.001944
# 16               ExterCond -0.001880  0.001880
# 131      HouseStyle_SFoyer  0.001812  0.001812
# 216               MoSold_9 -0.001773  0.001773
# 20            BsmtHalfBath  0.001759  0.001759
# 113        Condition1_RRNe  0.001651  0.001651
# 47                BsmtCond  0.001639  0.001639
# 166    Exterior2nd_Plywood -0.001585  0.001585
# 157    Exterior1st_WdShing  0.001568  0.001568
# 2           log_MasVnrArea  0.001554  0.001554
# 179       Foundation_Stone -0.001542  0.001542
# 212               MoSold_5 -0.001539  0.001539
# 112        Condition1_RRAn  0.001514  0.001514
# 66             MSZoning_RH -0.001509  0.001509
# 65        MSZoning_I (all)  0.001463  0.001463
# 187       Electrical_FuseF -0.001446  0.001446
# 140          RoofMatl_Roll  0.001431  0.001431
# 150    Exterior1st_ImStucc -0.001403  0.001403
# 125        BldgType_TwnhsE  0.001395  0.001395
# 202             Fence_GdWo -0.001263  0.001263
# 154     Exterior1st_Stucco -0.001250  0.001250
# 163    Exterior2nd_HdBoard -0.001129  0.001129
# 185           Heating_Wall  0.001057  0.001057
# 194     GarageType_CarPort -0.001003  0.001003
# 100     Neighborhood_SWISU -0.001001  0.001001
# 181           Heating_GasA  0.000956  0.000956
# 200           PavedDrive_P  0.000954  0.000954
# 69             Street_Pave  0.000950  0.000950
# 133        RoofStyle_Gable -0.000947  0.000947
# 12           log_BsmtUnfSF -0.000933  0.000933
# 147     Exterior1st_CBlock -0.000918  0.000918
# 168      Exterior2nd_Stone  0.000861  0.000861
# 213               MoSold_6 -0.000746  0.000746
# 137         RoofStyle_Shed  0.000720  0.000720
# 50          MSSubClass_180  0.000705  0.000705
# 208              MoSold_12 -0.000684  0.000684
# 23            BsmtFinType2  0.000622  0.000622
# 55           MSSubClass_45 -0.000610  0.000610
# 101    Neighborhood_Sawyer  0.000599  0.000599
# 119        Condition2_RRAe -0.000596  0.000596
# 73         LandContour_Low -0.000590  0.000590
# 164    Exterior2nd_ImStucc  0.000578  0.000578
# 54           MSSubClass_40 -0.000574  0.000574
# 122        BldgType_2fmCon -0.000466  0.000466
# 159    Exterior2nd_Brk Cmn  0.000447  0.000447
# 214               MoSold_7 -0.000434  0.000434
# 142       RoofMatl_WdShake  0.000424  0.000424
# 152    Exterior1st_Plywood -0.000415  0.000415
# 107       Condition1_Feedr -0.000403  0.000403
# 126      HouseStyle_1.5Unf  0.000373  0.000373
# 106   Neighborhood_Veenker  0.000257  0.000257
# 165    Exterior2nd_MetalSd -0.000249  0.000249
# 105    Neighborhood_Timber  0.000223  0.000223
# 91    Neighborhood_Landmrk  0.000218  0.000218
# 135          RoofStyle_Hip  0.000185  0.000185
# 180        Foundation_Wood -0.000184  0.000184
# 127      HouseStyle_1Story -0.000126  0.000126
# 141       RoofMatl_Tar&Grv  0.000087  0.000087
# 120        Condition2_RRAn -0.000070  0.000070
# 129      HouseStyle_2.5Unf -0.000010  0.000010
# 153    Exterior1st_PreCast  0.000000  0.000000
# 167    Exterior2nd_PreCast  0.000000  0.000000
# 139         RoofMatl_Metal  0.000000  0.000000
# 189       Electrical_Mixed  0.000000  0.000000
#
# skewness:  -0.5410040045268689
#
# model_importances.shape:  (222, 3)

# %%
lasso1 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data,
x_test = test_vars_data,
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001}
# score:  0.9470479866992151
#
# test score:  0.9140827558257063
# adj_r2:  0.9396219936778795
#
# adj_r2_test:  0.8794663706955916
#
# train RMSE: 0.08823831212478267
#
# test RMSE: 0.1160656932586015
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.129839  0.129839
# 24             OverallQual  0.067738  0.067738
# 22               YearBuilt  0.058440  0.058440
# 46             OverallCond  0.046351  0.046351
# 29              BsmtFinSF1  0.034191  0.034191
# 1              log_LotArea  0.031153  0.031153
# 103   Neighborhood_Somerst  0.023179  0.023179
# 108        Condition1_Norm  0.020334  0.020334
# 118        Condition2_PosN -0.019452  0.019452
# 42              Functional  0.017831  0.017831
# 21              Fireplaces  0.017801  0.017801
# 85    Neighborhood_Crawfor  0.017074  0.017074
# 98    Neighborhood_NridgHt  0.016328  0.016328
# 104   Neighborhood_StoneBr  0.016123  0.016123
# 3          yeo_TotalBsmtSF  0.015802  0.015802
# 146    Exterior1st_BrkFace  0.015118  0.015118
# 89    Neighborhood_GrnHill  0.014610  0.014610
# 44              GarageCars  0.014421  0.014421
# 5           yeo_GarageArea  0.014316  0.014316
# 39             KitchenQual  0.013791  0.013791
# 17            BsmtExposure  0.013309  0.013309
# 97    Neighborhood_NoRidge  0.012707  0.012707
# 221  SaleCondition_Partial  0.012381  0.012381
# 4          log_first_FlrSF  0.012174  0.012174
# 49          MSSubClass_160 -0.012089  0.012089
# 15            YearRemodAdd  0.011776  0.011776
# 35                BsmtQual  0.011768  0.011768
# 67             MSZoning_RL  0.011650  0.011650
# 63        MSZoning_C (all) -0.011593  0.011593
# 45               ExterQual  0.010904  0.010904
# 86    Neighborhood_Edwards -0.009931  0.009931
# 37               HeatingQC  0.009139  0.009139
# 143       RoofMatl_WdShngl  0.009010  0.009010
# 18              BsmtFinSF2  0.008855  0.008855
# 82    Neighborhood_BrkSide  0.008797  0.008797
# 27            BsmtFullBath  0.008123  0.008123
# 186           CentralAir_Y  0.007863  0.007863
# 219   SaleCondition_Family -0.007560  0.007560
# 196          GarageType_No  0.007560  0.007560
# 110        Condition1_PosN  0.007453  0.007453
# 40            TotRmsAbvGrd  0.007221  0.007221
# 41            KitchenAbvGr -0.007094  0.007094
# 170    Exterior2nd_VinylSd  0.007089  0.007089
# 28              GarageCond  0.006991  0.006991
# 201           PavedDrive_Y  0.005972  0.005972
# 220   SaleCondition_Normal  0.005822  0.005822
# 136      RoofStyle_Mansard -0.005724  0.005724
# 62           MSSubClass_90 -0.005689  0.005689
# 25             ScreenPorch  0.005487  0.005487
# 218   SaleCondition_Alloca  0.005338  0.005338
# 92    Neighborhood_MeadowV -0.005226  0.005226
# 34                FullBath  0.005213  0.005213
# 14            BsmtFinType1  0.005020  0.005020
# 117        Condition2_PosA  0.004996  0.004996
# 11         log_LotFrontage  0.004916  0.004916
# 83    Neighborhood_ClearCr  0.004903  0.004903
# 19           EnclosedPorch  0.004886  0.004886
# 134      RoofStyle_Gambrel -0.004682  0.004682
# 198       GarageFinish_RFn -0.004664  0.004664
# 210               MoSold_3 -0.004649  0.004649
# 57           MSSubClass_60 -0.004624  0.004624
# 95    Neighborhood_NPkVill  0.004573  0.004573
# 177       Foundation_PConc  0.004543  0.004543
# 102   Neighborhood_SawyerW -0.004452  0.004452
# 30                HalfBath  0.004111  0.004111
# 61           MSSubClass_85  0.004066  0.004066
# 109        Condition1_PosA  0.003980  0.003980
# 68             MSZoning_RM -0.003877  0.003877
# 145    Exterior1st_BrkComm  0.003858  0.003858
# 8                 has_pool  0.003783  0.003783
# 31               LandSlope -0.003777  0.003777
# 206              MoSold_10 -0.003773  0.003773
# 75        Utilities_NoSewr -0.003578  0.003578
# 101    Neighborhood_Sawyer  0.003542  0.003542
# 80    Neighborhood_Blueste  0.003408  0.003408
# 6           log_WoodDeckSF  0.003370  0.003370
# 192     GarageType_Basment -0.003370  0.003370
# 183           Heating_Grav -0.003310  0.003310
# 182           Heating_GasW  0.003299  0.003299
# 151    Exterior1st_MetalSd  0.003274  0.003274
# 52           MSSubClass_20  0.003098  0.003098
# 115       Condition2_Feedr -0.003033  0.003033
# 88     Neighborhood_Greens  0.002972  0.002972
# 48          MSSubClass_150 -0.002933  0.002933
# 43            BedroomAbvGr -0.002884  0.002884
# 184           Heating_OthW -0.002835  0.002835
# 204             Fence_MnWw -0.002796  0.002796
# 166    Exterior2nd_Plywood -0.002731  0.002731
# 72         LandContour_HLS  0.002680  0.002680
# 81     Neighborhood_BrDale  0.002643  0.002643
# 51          MSSubClass_190 -0.002462  0.002462
# 77           LotConfig_FR2 -0.002282  0.002282
# 207              MoSold_11 -0.002282  0.002282
# 59           MSSubClass_75  0.002228  0.002228
# 156    Exterior1st_Wd Sdng -0.002224  0.002224
# 160    Exterior2nd_BrkFace -0.002195  0.002195
# 33             LotFrontage  0.002010  0.002010
# 96     Neighborhood_NWAmes -0.002008  0.002008
# 188       Electrical_FuseP  0.001955  0.001955
# 199       GarageFinish_Unf -0.001934  0.001934
# 138       RoofMatl_Membran  0.001667  0.001667
# 190       Electrical_SBrkr  0.001643  0.001643
# 217  SaleCondition_AdjLand  0.001582  0.001582
# 74         LandContour_Lvl  0.001576  0.001576
# 215               MoSold_8 -0.001546  0.001546
# 99    Neighborhood_OldTown -0.001515  0.001515
# 93    Neighborhood_Mitchel -0.001503  0.001503
# 158    Exterior2nd_AsphShn  0.001490  0.001490
# 161     Exterior2nd_CBlock  0.001489  0.001489
# 78           LotConfig_FR3 -0.001450  0.001450
# 111        Condition1_RRAe -0.001431  0.001431
# 125        BldgType_TwnhsE  0.001415  0.001415
# 124         BldgType_Twnhs -0.001268  0.001268
# 38                  YrSold -0.001145  0.001145
# 70              Alley_None  0.001042  0.001042
# 211               MoSold_4 -0.001015  0.001015
# 121        Condition2_RRNn  0.001005  0.001005
# 209               MoSold_2 -0.001003  0.001003
# 79        LotConfig_Inside  0.000992  0.000992
# 123        BldgType_Duplex -0.000981  0.000981
# 169     Exterior2nd_Stucco  0.000951  0.000951
# 157    Exterior1st_WdShing  0.000940  0.000940
# 20            BsmtHalfBath  0.000933  0.000933
# 155    Exterior1st_VinylSd  0.000901  0.000901
# 32             FireplaceQu  0.000828  0.000828
# 60           MSSubClass_80 -0.000818  0.000818
# 213               MoSold_6  0.000758  0.000758
# 9           log_BsmtFinSF1 -0.000756  0.000756
# 185           Heating_Wall  0.000724  0.000724
# 71              Alley_Pave  0.000552  0.000552
# 205               Fence_No -0.000526  0.000526
# 84    Neighborhood_CollgCr -0.000486  0.000486
# 114        Condition1_RRNn  0.000453  0.000453
# 216               MoSold_9 -0.000451  0.000451
# 76       LotConfig_CulDSac  0.000402  0.000402
# 16               ExterCond -0.000396  0.000396
# 105    Neighborhood_Timber  0.000388  0.000388
# 113        Condition1_RRNe  0.000385  0.000385
# 150    Exterior1st_ImStucc -0.000344  0.000344
# 66             MSZoning_RH -0.000279  0.000279
# 147     Exterior1st_CBlock -0.000254  0.000254
# 179       Foundation_Stone -0.000254  0.000254
# 120        Condition2_RRAn -0.000228  0.000228
# 142       RoofMatl_WdShake  0.000147  0.000147
# 172    Exterior2nd_Wd Shng  0.000144  0.000144
# 214               MoSold_7  0.000081  0.000081
# 187       Electrical_FuseF -0.000073  0.000073
# 212               MoSold_5  0.000064  0.000064
# 171    Exterior2nd_Wd Sdng  0.000000  0.000000
# 174        MasVnrType_None  0.000000  0.000000
# 173     MasVnrType_BrkFace  0.000000  0.000000
# 175       MasVnrType_Stone -0.000000  0.000000
# 202             Fence_GdWo  0.000000  0.000000
# 176      Foundation_CBlock  0.000000  0.000000
# 178        Foundation_Slab  0.000000  0.000000
# 180        Foundation_Wood -0.000000  0.000000
# 181           Heating_GasA -0.000000  0.000000
# 168      Exterior2nd_Stone  0.000000  0.000000
# 191      GarageType_Attchd  0.000000  0.000000
# 193     GarageType_BuiltIn  0.000000  0.000000
# 194     GarageType_CarPort -0.000000  0.000000
# 195      GarageType_Detchd -0.000000  0.000000
# 203            Fence_MnPrv -0.000000  0.000000
# 197        GarageFinish_No  0.000000  0.000000
# 208              MoSold_12  0.000000  0.000000
# 200           PavedDrive_P  0.000000  0.000000
# 189       Electrical_Mixed  0.000000  0.000000
# 23            BsmtFinType2  0.000000  0.000000
# 167    Exterior2nd_PreCast  0.000000  0.000000
# 73         LandContour_Low -0.000000  0.000000
# 7          log_OpenPorchSF  0.000000  0.000000
# 107       Condition1_Feedr  0.000000  0.000000
# 106   Neighborhood_Veenker -0.000000  0.000000
# 100     Neighborhood_SWISU  0.000000  0.000000
# 10            log_2ndFlrSF  0.000000  0.000000
# 94      Neighborhood_NAmes -0.000000  0.000000
# 91    Neighborhood_Landmrk  0.000000  0.000000
# 90     Neighborhood_IDOTRR -0.000000  0.000000
# 12           log_BsmtUnfSF  0.000000  0.000000
# 87    Neighborhood_Gilbert  0.000000  0.000000
# 13       log_EnclosedPorch -0.000000  0.000000
# 69             Street_Pave  0.000000  0.000000
# 165    Exterior2nd_MetalSd  0.000000  0.000000
# 65        MSZoning_I (all)  0.000000  0.000000
# 64             MSZoning_FV  0.000000  0.000000
# 58           MSSubClass_70  0.000000  0.000000
# 56           MSSubClass_50  0.000000  0.000000
# 55           MSSubClass_45  0.000000  0.000000
# 54           MSSubClass_40 -0.000000  0.000000
# 53           MSSubClass_30 -0.000000  0.000000
# 50          MSSubClass_180  0.000000  0.000000
# 47                BsmtCond  0.000000  0.000000
# 36                LotShape -0.000000  0.000000
# 26              GarageQual  0.000000  0.000000
# 112        Condition1_RRAn  0.000000  0.000000
# 116        Condition2_Norm  0.000000  0.000000
# 119        Condition2_RRAe -0.000000  0.000000
# 126      HouseStyle_1.5Unf  0.000000  0.000000
# 164    Exterior2nd_ImStucc -0.000000  0.000000
# 163    Exterior2nd_HdBoard -0.000000  0.000000
# 162    Exterior2nd_CmentBd -0.000000  0.000000
# 159    Exterior2nd_Brk Cmn  0.000000  0.000000
# 154     Exterior1st_Stucco  0.000000  0.000000
# 153    Exterior1st_PreCast  0.000000  0.000000
# 152    Exterior1st_Plywood -0.000000  0.000000
# 149    Exterior1st_HdBoard -0.000000  0.000000
# 148    Exterior1st_CemntBd -0.000000  0.000000
# 2           log_MasVnrArea -0.000000  0.000000
# 144    Exterior1st_AsphShn -0.000000  0.000000
# 141       RoofMatl_Tar&Grv  0.000000  0.000000
# 140          RoofMatl_Roll  0.000000  0.000000
# 139         RoofMatl_Metal  0.000000  0.000000
# 137         RoofStyle_Shed -0.000000  0.000000
# 135          RoofStyle_Hip  0.000000  0.000000
# 133        RoofStyle_Gable -0.000000  0.000000
# 132        HouseStyle_SLvl -0.000000  0.000000
# 131      HouseStyle_SFoyer  0.000000  0.000000
# 130      HouseStyle_2Story -0.000000  0.000000
# 129      HouseStyle_2.5Unf  0.000000  0.000000
# 128      HouseStyle_2.5Fin -0.000000  0.000000
# 127      HouseStyle_1Story  0.000000  0.000000
# 122        BldgType_2fmCon -0.000000  0.000000
#
# skewness:  -0.6260191324878509
#
# model_importances.shape:  (222, 3)

# %%
keeps = to_keep(lasso1,0.000064)

# %%
lasso2 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0001}
# score:  0.9488518555619613
#
# test score:  0.9131907127139526
# adj_r2:  0.9442834033128185
#
# adj_r2_test:  0.8926342734846165
#
# train RMSE: 0.08672232146231737
#
# test RMSE: 0.11666666834515338
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.135930  0.135930
# 1              OverallQual  0.062989  0.062989
# 2                YearBuilt  0.060393  0.060393
# 3              OverallCond  0.048582  0.048582
# 4               BsmtFinSF1  0.041899  0.041899
# 5              log_LotArea  0.033470  0.033470
# 6     Neighborhood_Somerst  0.025461  0.025461
# 38           GarageType_No  0.024513  0.024513
# 43              GarageCond  0.024263  0.024263
# 7          Condition1_Norm  0.021704  0.021704
# 8          Condition2_PosN -0.021317  0.021317
# 9               Functional  0.018991  0.018991
# 15     Exterior1st_BrkFace  0.018740  0.018740
# 24          MSSubClass_160 -0.018319  0.018319
# 13    Neighborhood_StoneBr  0.017427  0.017427
# 11    Neighborhood_Crawfor  0.017361  0.017361
# 12    Neighborhood_NridgHt  0.017262  0.017262
# 127         log_BsmtFinSF1 -0.017243  0.017243
# 10              Fireplaces  0.016612  0.016612
# 14         yeo_TotalBsmtSF  0.015897  0.015897
# 52            BsmtFinType1  0.015841  0.015841
# 17              GarageCars  0.015425  0.015425
# 16    Neighborhood_GrnHill  0.015324  0.015324
# 22   SaleCondition_Partial  0.015030  0.015030
# 21    Neighborhood_NoRidge  0.013888  0.013888
# 27             MSZoning_RL  0.013454  0.013454
# 20            BsmtExposure  0.013285  0.013285
# 18          yeo_GarageArea  0.013156  0.013156
# 60           MSSubClass_60 -0.012902  0.012902
# 19             KitchenQual  0.012827  0.012827
# 28        MSZoning_C (all) -0.012360  0.012360
# 33              BsmtFinSF2  0.012033  0.012033
# 26                BsmtQual  0.011976  0.011976
# 40            TotRmsAbvGrd  0.011335  0.011335
# 34    Neighborhood_BrkSide  0.010896  0.010896
# 29               ExterQual  0.010405  0.010405
# 30    Neighborhood_Edwards -0.010007  0.010007
# 25            YearRemodAdd  0.009921  0.009921
# 45    SaleCondition_Normal  0.009488  0.009488
# 39         Condition1_PosN  0.009320  0.009320
# 54         log_LotFrontage  0.009263  0.009263
# 32        RoofMatl_WdShngl  0.009192  0.009192
# 47           MSSubClass_90 -0.009140  0.009140
# 31               HeatingQC  0.008910  0.008910
# 89     Neighborhood_BrDale  0.008727  0.008727
# 61    Neighborhood_NPkVill  0.008201  0.008201
# 42     Exterior2nd_VinylSd  0.008180  0.008180
# 35            BsmtFullBath  0.008033  0.008033
# 49    SaleCondition_Alloca  0.007968  0.007968
# 36            CentralAir_Y  0.007518  0.007518
# 51                FullBath  0.007443  0.007443
# 57       RoofStyle_Gambrel -0.007252  0.007252
# 64                HalfBath  0.007108  0.007108
# 37    SaleCondition_Family -0.007066  0.007066
# 79     Exterior1st_MetalSd  0.006918  0.006918
# 46       RoofStyle_Mansard -0.006891  0.006891
# 48             ScreenPorch  0.006716  0.006716
# 59                MoSold_3 -0.006698  0.006698
# 56           EnclosedPorch  0.006341  0.006341
# 41            KitchenAbvGr -0.006271  0.006271
# 58        GarageFinish_RFn -0.006255  0.006255
# 44            PavedDrive_Y  0.006249  0.006249
# 55    Neighborhood_ClearCr  0.006125  0.006125
# 84            BedroomAbvGr -0.005931  0.005931
# 74    Neighborhood_Blueste  0.005899  0.005899
# 66         Condition1_PosA  0.005600  0.005600
# 73     Neighborhood_Sawyer  0.005396  0.005396
# 71               MoSold_10 -0.005384  0.005384
# 103        LandContour_Lvl  0.005323  0.005323
# 68     Exterior1st_BrkComm  0.005224  0.005224
# 70               LandSlope -0.005175  0.005175
# 63    Neighborhood_SawyerW -0.005089  0.005089
# 53         Condition2_PosA  0.005087  0.005087
# 23         log_first_FlrSF  0.004986  0.004986
# 62        Foundation_PConc  0.004935  0.004935
# 88         LandContour_HLS  0.004916  0.004916
# 95     Exterior2nd_BrkFace -0.004863  0.004863
# 77            Heating_Grav -0.004712  0.004712
# 65           MSSubClass_85  0.004694  0.004694
# 81        Condition2_Feedr -0.004615  0.004615
# 82     Neighborhood_Greens  0.004586  0.004586
# 67             MSZoning_RM -0.004570  0.004570
# 83          MSSubClass_150 -0.004370  0.004370
# 90          MSSubClass_190 -0.004109  0.004109
# 104               MoSold_8 -0.004085  0.004085
# 72        Utilities_NoSewr -0.004082  0.004082
# 98        Electrical_FuseP  0.004022  0.004022
# 86              Fence_MnWw -0.003993  0.003993
# 76      GarageType_Basment -0.003783  0.003783
# 129             Alley_Pave  0.003697  0.003697
# 102  SaleCondition_AdjLand  0.003696  0.003696
# 117               MoSold_2 -0.003670  0.003670
# 69                has_pool  0.003630  0.003630
# 80           MSSubClass_20  0.003607  0.003607
# 92               MoSold_11 -0.003532  0.003532
# 114             Alley_None  0.003510  0.003510
# 50    Neighborhood_MeadowV -0.003347  0.003347
# 85            Heating_OthW -0.003294  0.003294
# 78            Heating_GasW  0.003286  0.003286
# 111        BldgType_TwnhsE  0.003181  0.003181
# 75          log_WoodDeckSF  0.003050  0.003050
# 130               Fence_No -0.003020  0.003020
# 87     Exterior2nd_Plywood -0.003020  0.003020
# 93           MSSubClass_75  0.003013  0.003013
# 113                 YrSold -0.002957  0.002957
# 115               MoSold_4 -0.002930  0.002930
# 109          LotConfig_FR3 -0.002903  0.002903
# 123    Exterior1st_VinylSd  0.002854  0.002854
# 107    Exterior2nd_AsphShn  0.002831  0.002831
# 91           LotConfig_FR2 -0.002813  0.002813
# 100       RoofMatl_Membran  0.002691  0.002691
# 121    Exterior1st_WdShing  0.002651  0.002651
# 135              ExterCond -0.002625  0.002625
# 97     Neighborhood_NWAmes -0.002595  0.002595
# 108     Exterior2nd_CBlock  0.002574  0.002574
# 132        Condition1_RRNn  0.002574  0.002574
# 120     Exterior2nd_Stucco  0.002469  0.002469
# 133               MoSold_9 -0.002463  0.002463
# 125          MSSubClass_80 -0.002452  0.002452
# 99        GarageFinish_Unf -0.002374  0.002374
# 101       Electrical_SBrkr  0.002266  0.002266
# 112         BldgType_Twnhs -0.002140  0.002140
# 110        Condition1_RRAe -0.002118  0.002118
# 137        Condition1_RRNe  0.002056  0.002056
# 106   Neighborhood_Mitchel -0.001991  0.001991
# 118       LotConfig_Inside  0.001973  0.001973
# 122           BsmtHalfBath  0.001825  0.001825
# 116        Condition2_RRNn  0.001688  0.001688
# 138    Exterior1st_ImStucc -0.001680  0.001680
# 140     Exterior1st_CBlock -0.001505  0.001505
# 128           Heating_Wall  0.001368  0.001368
# 94     Exterior1st_Wd Sdng -0.001348  0.001348
# 141       Foundation_Stone -0.001221  0.001221
# 134      LotConfig_CulDSac  0.001186  0.001186
# 145               MoSold_7 -0.001173  0.001173
# 131   Neighborhood_CollgCr -0.001087  0.001087
# 146       Electrical_FuseF -0.001036  0.001036
# 142        Condition2_RRAn -0.000966  0.000966
# 136    Neighborhood_Timber  0.000820  0.000820
# 119        BldgType_Duplex -0.000789  0.000789
# 143       RoofMatl_WdShake  0.000648  0.000648
# 147               MoSold_5 -0.000456  0.000456
# 144    Exterior2nd_Wd Shng  0.000425  0.000425
# 105   Neighborhood_OldTown -0.000423  0.000423
# 126               MoSold_6 -0.000252  0.000252
# 139            MSZoning_RH -0.000056  0.000056
# 96             LotFrontage -0.000000  0.000000
# 124            FireplaceQu  0.000000  0.000000
#
# skewness:  -0.485176800971822
#
# model_importances.shape:  (148, 3)

# %%
keeps = to_keep(lasso2,0.0006)

# %%
lasso3 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0001}
# score:  0.9488478228480296
#
# test score:  0.9132193006777082
# adj_r2:  0.9445134136061859
#
# adj_r2_test:  0.8938584168099184
#
# train RMSE: 0.08672574015349989
#
# test RMSE: 0.11664745647723508
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.136053  0.136053
# 1              OverallQual  0.063007  0.063007
# 2                YearBuilt  0.060689  0.060689
# 3              OverallCond  0.048600  0.048600
# 4               BsmtFinSF1  0.041933  0.041933
# 5              log_LotArea  0.033514  0.033514
# 6     Neighborhood_Somerst  0.025526  0.025526
# 7            GarageType_No  0.024543  0.024543
# 8               GarageCond  0.024270  0.024270
# 9          Condition1_Norm  0.021728  0.021728
# 10         Condition2_PosN -0.021332  0.021332
# 11              Functional  0.018963  0.018963
# 12     Exterior1st_BrkFace  0.018744  0.018744
# 13          MSSubClass_160 -0.018353  0.018353
# 14    Neighborhood_StoneBr  0.017445  0.017445
# 15    Neighborhood_Crawfor  0.017394  0.017394
# 17          log_BsmtFinSF1 -0.017308  0.017308
# 16    Neighborhood_NridgHt  0.017296  0.017296
# 18              Fireplaces  0.016604  0.016604
# 19         yeo_TotalBsmtSF  0.015912  0.015912
# 20            BsmtFinType1  0.015880  0.015880
# 21              GarageCars  0.015446  0.015446
# 22    Neighborhood_GrnHill  0.015334  0.015334
# 23   SaleCondition_Partial  0.015023  0.015023
# 24    Neighborhood_NoRidge  0.013917  0.013917
# 25             MSZoning_RL  0.013570  0.013570
# 26            BsmtExposure  0.013308  0.013308
# 27          yeo_GarageArea  0.013072  0.013072
# 28           MSSubClass_60 -0.013008  0.013008
# 29             KitchenQual  0.012802  0.012802
# 30        MSZoning_C (all) -0.012306  0.012306
# 31              BsmtFinSF2  0.012041  0.012041
# 32                BsmtQual  0.011953  0.011953
# 33            TotRmsAbvGrd  0.011330  0.011330
# 34    Neighborhood_BrkSide  0.011032  0.011032
# 35               ExterQual  0.010394  0.010394
# 36    Neighborhood_Edwards -0.009966  0.009966
# 37            YearRemodAdd  0.009880  0.009880
# 42           MSSubClass_90 -0.009725  0.009725
# 38    SaleCondition_Normal  0.009474  0.009474
# 39         Condition1_PosN  0.009344  0.009344
# 40         log_LotFrontage  0.009265  0.009265
# 41        RoofMatl_WdShngl  0.009199  0.009199
# 43               HeatingQC  0.008886  0.008886
# 44     Neighborhood_BrDale  0.008773  0.008773
# 45    Neighborhood_NPkVill  0.008198  0.008198
# 47            BsmtFullBath  0.008033  0.008033
# 48    SaleCondition_Alloca  0.007969  0.007969
# 46     Exterior2nd_VinylSd  0.007717  0.007717
# 49            CentralAir_Y  0.007545  0.007545
# 50                FullBath  0.007410  0.007410
# 51       RoofStyle_Gambrel -0.007270  0.007270
# 52                HalfBath  0.007088  0.007088
# 53    SaleCondition_Family -0.007065  0.007065
# 55       RoofStyle_Mansard -0.006896  0.006896
# 54     Exterior1st_MetalSd  0.006884  0.006884
# 56             ScreenPorch  0.006717  0.006717
# 57                MoSold_3 -0.006455  0.006455
# 58           EnclosedPorch  0.006329  0.006329
# 59            KitchenAbvGr -0.006271  0.006271
# 61            PavedDrive_Y  0.006270  0.006270
# 60        GarageFinish_RFn -0.006238  0.006238
# 62    Neighborhood_ClearCr  0.006120  0.006120
# 64    Neighborhood_Blueste  0.005928  0.005928
# 63            BedroomAbvGr -0.005913  0.005913
# 65         Condition1_PosA  0.005628  0.005628
# 66     Neighborhood_Sawyer  0.005409  0.005409
# 68         LandContour_Lvl  0.005280  0.005280
# 69     Exterior1st_BrkComm  0.005212  0.005212
# 67               MoSold_10 -0.005203  0.005203
# 70               LandSlope -0.005175  0.005175
# 71    Neighborhood_SawyerW -0.005078  0.005078
# 72         Condition2_PosA  0.005070  0.005070
# 74        Foundation_PConc  0.004927  0.004927
# 75         LandContour_HLS  0.004914  0.004914
# 76     Exterior2nd_BrkFace -0.004876  0.004876
# 73         log_first_FlrSF  0.004852  0.004852
# 77            Heating_Grav -0.004734  0.004734
# 78           MSSubClass_85  0.004719  0.004719
# 81             MSZoning_RM -0.004664  0.004664
# 79        Condition2_Feedr -0.004622  0.004622
# 80     Neighborhood_Greens  0.004583  0.004583
# 82          MSSubClass_150 -0.004370  0.004370
# 83          MSSubClass_190 -0.004121  0.004121
# 85        Utilities_NoSewr -0.004076  0.004076
# 86        Electrical_FuseP  0.004014  0.004014
# 87              Fence_MnWw -0.003994  0.003994
# 84                MoSold_8 -0.003891  0.003891
# 88      GarageType_Basment -0.003786  0.003786
# 90   SaleCondition_AdjLand  0.003750  0.003750
# 89              Alley_Pave  0.003746  0.003746
# 92                has_pool  0.003609  0.003609
# 95              Alley_None  0.003593  0.003593
# 93           MSSubClass_20  0.003587  0.003587
# 91                MoSold_2 -0.003496  0.003496
# 94               MoSold_11 -0.003378  0.003378
# 96    Neighborhood_MeadowV -0.003313  0.003313
# 97            Heating_OthW -0.003290  0.003290
# 98            Heating_GasW  0.003281  0.003281
# 107    Exterior1st_VinylSd  0.003262  0.003262
# 99         BldgType_TwnhsE  0.003204  0.003204
# 101               Fence_No -0.003058  0.003058
# 102    Exterior2nd_Plywood -0.003054  0.003054
# 100         log_WoodDeckSF  0.003036  0.003036
# 103          MSSubClass_75  0.003021  0.003021
# 104                 YrSold -0.002962  0.002962
# 111    Exterior1st_WdShing  0.002940  0.002940
# 106          LotConfig_FR3 -0.002892  0.002892
# 108    Exterior2nd_AsphShn  0.002858  0.002858
# 109          LotConfig_FR2 -0.002824  0.002824
# 105               MoSold_4 -0.002693  0.002693
# 110       RoofMatl_Membran  0.002690  0.002690
# 112              ExterCond -0.002640  0.002640
# 113    Neighborhood_NWAmes -0.002595  0.002595
# 115        Condition1_RRNn  0.002581  0.002581
# 114     Exterior2nd_CBlock  0.002556  0.002556
# 118          MSSubClass_80 -0.002475  0.002475
# 116     Exterior2nd_Stucco  0.002429  0.002429
# 119       GarageFinish_Unf -0.002359  0.002359
# 117               MoSold_9 -0.002289  0.002289
# 120       Electrical_SBrkr  0.002284  0.002284
# 121         BldgType_Twnhs -0.002116  0.002116
# 122        Condition1_RRAe -0.002113  0.002113
# 123        Condition1_RRNe  0.002059  0.002059
# 124   Neighborhood_Mitchel -0.001970  0.001970
# 125       LotConfig_Inside  0.001966  0.001966
# 126           BsmtHalfBath  0.001822  0.001822
# 128    Exterior1st_ImStucc -0.001686  0.001686
# 127        Condition2_RRNn  0.001676  0.001676
# 129     Exterior1st_CBlock -0.001486  0.001486
# 130           Heating_Wall  0.001377  0.001377
# 131    Exterior1st_Wd Sdng -0.001309  0.001309
# 132       Foundation_Stone -0.001229  0.001229
# 133      LotConfig_CulDSac  0.001190  0.001190
# 135   Neighborhood_CollgCr -0.001064  0.001064
# 136       Electrical_FuseF -0.000999  0.000999
# 137        Condition2_RRAn -0.000961  0.000961
# 134               MoSold_7 -0.000890  0.000890
# 138    Neighborhood_Timber  0.000827  0.000827
# 140       RoofMatl_WdShake  0.000655  0.000655
# 139        BldgType_Duplex -0.000206  0.000206
#
# skewness:  -0.4844508958202612
#
# model_importances.shape:  (141, 3)

# %%
keeps = to_keep(lasso3,0.001)

# %%
lasso4 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0001}
# score:  0.948820534312494
#
# test score:  0.9133328990670797
# adj_r2:  0.9446832721161986
#
# adj_r2_test:  0.8949942491831546
#
# train RMSE: 0.0867488701845515
#
# test RMSE: 0.11657108406611372
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.135899  0.135899
# 1              OverallQual  0.063203  0.063203
# 2                YearBuilt  0.060734  0.060734
# 3              OverallCond  0.048553  0.048553
# 4               BsmtFinSF1  0.041817  0.041817
# 5              log_LotArea  0.033650  0.033650
# 6     Neighborhood_Somerst  0.025291  0.025291
# 7            GarageType_No  0.024548  0.024548
# 8               GarageCond  0.024161  0.024161
# 9          Condition1_Norm  0.021843  0.021843
# 10         Condition2_PosN -0.021371  0.021371
# 11              Functional  0.018955  0.018955
# 12     Exterior1st_BrkFace  0.018712  0.018712
# 13          MSSubClass_160 -0.018234  0.018234
# 14    Neighborhood_StoneBr  0.017263  0.017263
# 15    Neighborhood_Crawfor  0.017169  0.017169
# 16          log_BsmtFinSF1 -0.017134  0.017134
# 17    Neighborhood_NridgHt  0.016938  0.016938
# 18              Fireplaces  0.016625  0.016625
# 20            BsmtFinType1  0.015815  0.015815
# 19         yeo_TotalBsmtSF  0.015684  0.015684
# 21              GarageCars  0.015480  0.015480
# 22    Neighborhood_GrnHill  0.015313  0.015313
# 23   SaleCondition_Partial  0.014899  0.014899
# 24    Neighborhood_NoRidge  0.013746  0.013746
# 25             MSZoning_RL  0.013532  0.013532
# 26            BsmtExposure  0.013392  0.013392
# 28           MSSubClass_60 -0.013232  0.013232
# 27          yeo_GarageArea  0.013206  0.013206
# 29             KitchenQual  0.012848  0.012848
# 30        MSZoning_C (all) -0.012285  0.012285
# 32                BsmtQual  0.012164  0.012164
# 31              BsmtFinSF2  0.012012  0.012012
# 33            TotRmsAbvGrd  0.011408  0.011408
# 34    Neighborhood_BrkSide  0.010919  0.010919
# 35               ExterQual  0.010403  0.010403
# 38           MSSubClass_90 -0.010219  0.010219
# 36    Neighborhood_Edwards -0.010111  0.010111
# 37            YearRemodAdd  0.009925  0.009925
# 40         Condition1_PosN  0.009410  0.009410
# 39    SaleCondition_Normal  0.009390  0.009390
# 41         log_LotFrontage  0.009330  0.009330
# 42        RoofMatl_WdShngl  0.009182  0.009182
# 43               HeatingQC  0.008953  0.008953
# 44     Neighborhood_BrDale  0.008756  0.008756
# 45    Neighborhood_NPkVill  0.008136  0.008136
# 46            BsmtFullBath  0.008095  0.008095
# 47    SaleCondition_Alloca  0.007990  0.007990
# 48     Exterior2nd_VinylSd  0.007748  0.007748
# 49            CentralAir_Y  0.007654  0.007654
# 50                FullBath  0.007388  0.007388
# 51       RoofStyle_Gambrel -0.007226  0.007226
# 52                HalfBath  0.007162  0.007162
# 53    SaleCondition_Family -0.007112  0.007112
# 55     Exterior1st_MetalSd  0.006936  0.006936
# 54       RoofStyle_Mansard -0.006819  0.006819
# 56             ScreenPorch  0.006720  0.006720
# 58           EnclosedPorch  0.006300  0.006300
# 60            PavedDrive_Y  0.006280  0.006280
# 61        GarageFinish_RFn -0.006252  0.006252
# 57                MoSold_3 -0.006238  0.006238
# 59            KitchenAbvGr -0.006220  0.006220
# 62    Neighborhood_ClearCr  0.006088  0.006088
# 64            BedroomAbvGr -0.006001  0.006001
# 63    Neighborhood_Blueste  0.005833  0.005833
# 65         Condition1_PosA  0.005763  0.005763
# 67         LandContour_Lvl  0.005440  0.005440
# 70               LandSlope -0.005374  0.005374
# 66     Neighborhood_Sawyer  0.005336  0.005336
# 71    Neighborhood_SawyerW -0.005237  0.005237
# 68     Exterior1st_BrkComm  0.005172  0.005172
# 76         log_first_FlrSF  0.005101  0.005101
# 74         LandContour_HLS  0.005040  0.005040
# 72         Condition2_PosA  0.004980  0.004980
# 69               MoSold_10 -0.004980  0.004980
# 73        Foundation_PConc  0.004939  0.004939
# 75     Exterior2nd_BrkFace -0.004880  0.004880
# 77            Heating_Grav -0.004762  0.004762
# 79             MSZoning_RM -0.004654  0.004654
# 78           MSSubClass_85  0.004597  0.004597
# 80        Condition2_Feedr -0.004595  0.004595
# 81     Neighborhood_Greens  0.004504  0.004504
# 82          MSSubClass_150 -0.004389  0.004389
# 83          MSSubClass_190 -0.004176  0.004176
# 85        Electrical_FuseP  0.004138  0.004138
# 86              Fence_MnWw -0.004015  0.004015
# 84        Utilities_NoSewr -0.004008  0.004008
# 89   SaleCondition_AdjLand  0.003828  0.003828
# 90              Alley_Pave  0.003777  0.003777
# 88      GarageType_Basment -0.003774  0.003774
# 87                MoSold_8 -0.003692  0.003692
# 92              Alley_None  0.003641  0.003641
# 91                has_pool  0.003566  0.003566
# 93           MSSubClass_20  0.003492  0.003492
# 94                MoSold_2 -0.003359  0.003359
# 96    Neighborhood_MeadowV -0.003295  0.003295
# 97            Heating_OthW -0.003285  0.003285
# 98            Heating_GasW  0.003237  0.003237
# 99     Exterior1st_VinylSd  0.003232  0.003232
# 95               MoSold_11 -0.003201  0.003201
# 100        BldgType_TwnhsE  0.003093  0.003093
# 101               Fence_No -0.003045  0.003045
# 103         log_WoodDeckSF  0.003035  0.003035
# 104          MSSubClass_75  0.002991  0.002991
# 102    Exterior2nd_Plywood -0.002962  0.002962
# 105                 YrSold -0.002900  0.002900
# 107          LotConfig_FR3 -0.002895  0.002895
# 106    Exterior1st_WdShing  0.002892  0.002892
# 113    Neighborhood_NWAmes -0.002821  0.002821
# 109          LotConfig_FR2 -0.002808  0.002808
# 108    Exterior2nd_AsphShn  0.002782  0.002782
# 112              ExterCond -0.002652  0.002652
# 120       Electrical_SBrkr  0.002651  0.002651
# 111       RoofMatl_Membran  0.002622  0.002622
# 114        Condition1_RRNn  0.002619  0.002619
# 115     Exterior2nd_CBlock  0.002619  0.002619
# 116          MSSubClass_80 -0.002602  0.002602
# 117     Exterior2nd_Stucco  0.002471  0.002471
# 110               MoSold_4 -0.002456  0.002456
# 118       GarageFinish_Unf -0.002374  0.002374
# 121         BldgType_Twnhs -0.002171  0.002171
# 119               MoSold_9 -0.002165  0.002165
# 124   Neighborhood_Mitchel -0.002124  0.002124
# 123        Condition1_RRNe  0.002087  0.002087
# 122        Condition1_RRAe -0.002073  0.002073
# 125       LotConfig_Inside  0.001999  0.001999
# 126           BsmtHalfBath  0.001843  0.001843
# 127    Exterior1st_ImStucc -0.001730  0.001730
# 128        Condition2_RRNn  0.001713  0.001713
# 129     Exterior1st_CBlock -0.001418  0.001418
# 131    Exterior1st_Wd Sdng -0.001346  0.001346
# 134   Neighborhood_CollgCr -0.001339  0.001339
# 130           Heating_Wall  0.001299  0.001299
# 133      LotConfig_CulDSac  0.001202  0.001202
# 132       Foundation_Stone -0.001185  0.001185
#
# skewness:  -0.4833571221976291
#
# model_importances.shape:  (135, 3)

# %%
keeps = to_keep(lasso4,0.002)

# %%
lasso5 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0001}
# score:  0.9486895480861707
#
# test score:  0.9137620967988711
# adj_r2:  0.9448718061282965
#
# adj_r2_test:  0.8971266988048262
#
# train RMSE: 0.08685980965863739
#
# test RMSE: 0.11628208085110048
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.135180  0.135180
# 1              OverallQual  0.063086  0.063086
# 2                YearBuilt  0.060944  0.060944
# 3              OverallCond  0.048811  0.048811
# 4               BsmtFinSF1  0.042340  0.042340
# 5              log_LotArea  0.033451  0.033451
# 6     Neighborhood_Somerst  0.026324  0.026324
# 7            GarageType_No  0.024569  0.024569
# 8               GarageCond  0.024533  0.024533
# 9          Condition1_Norm  0.021829  0.021829
# 10         Condition2_PosN -0.021427  0.021427
# 12     Exterior1st_BrkFace  0.019184  0.019184
# 11              Functional  0.019103  0.019103
# 13          MSSubClass_160 -0.018349  0.018349
# 14    Neighborhood_StoneBr  0.017473  0.017473
# 17    Neighborhood_NridgHt  0.017364  0.017364
# 16          log_BsmtFinSF1 -0.017278  0.017278
# 15    Neighborhood_Crawfor  0.017192  0.017192
# 18              Fireplaces  0.016885  0.016885
# 19            BsmtFinType1  0.016117  0.016117
# 20         yeo_TotalBsmtSF  0.015805  0.015805
# 22    Neighborhood_GrnHill  0.015339  0.015339
# 21              GarageCars  0.015339  0.015339
# 23   SaleCondition_Partial  0.015147  0.015147
# 25             MSZoning_RL  0.014892  0.014892
# 24    Neighborhood_NoRidge  0.013969  0.013969
# 26            BsmtExposure  0.013350  0.013350
# 28          yeo_GarageArea  0.013313  0.013313
# 27           MSSubClass_60 -0.012743  0.012743
# 29             KitchenQual  0.012652  0.012652
# 32              BsmtFinSF2  0.012538  0.012538
# 31                BsmtQual  0.012063  0.012063
# 30        MSZoning_C (all) -0.011999  0.011999
# 33            TotRmsAbvGrd  0.011867  0.011867
# 34    Neighborhood_BrkSide  0.011110  0.011110
# 35               ExterQual  0.010006  0.010006
# 38            YearRemodAdd  0.009834  0.009834
# 37    Neighborhood_Edwards -0.009705  0.009705
# 36           MSSubClass_90 -0.009647  0.009647
# 40    SaleCondition_Normal  0.009559  0.009559
# 39         Condition1_PosN  0.009341  0.009341
# 42        RoofMatl_WdShngl  0.009288  0.009288
# 44     Neighborhood_BrDale  0.008900  0.008900
# 43               HeatingQC  0.008742  0.008742
# 41         log_LotFrontage  0.008523  0.008523
# 45    Neighborhood_NPkVill  0.008188  0.008188
# 47    SaleCondition_Alloca  0.008020  0.008020
# 54     Exterior1st_MetalSd  0.007871  0.007871
# 50                FullBath  0.007629  0.007629
# 51       RoofStyle_Gambrel -0.007243  0.007243
# 46            BsmtFullBath  0.007181  0.007181
# 49            CentralAir_Y  0.007154  0.007154
# 52                HalfBath  0.007132  0.007132
# 53    SaleCondition_Family -0.007003  0.007003
# 55       RoofStyle_Mansard -0.006882  0.006882
# 61            KitchenAbvGr -0.006833  0.006833
# 56             ScreenPorch  0.006770  0.006770
# 59        GarageFinish_RFn -0.006581  0.006581
# 58            PavedDrive_Y  0.006387  0.006387
# 62    Neighborhood_ClearCr  0.006269  0.006269
# 60                MoSold_3 -0.006269  0.006269
# 57           EnclosedPorch  0.006097  0.006097
# 63            BedroomAbvGr -0.006085  0.006085
# 98     Exterior1st_VinylSd  0.005781  0.005781
# 65         Condition1_PosA  0.005763  0.005763
# 68     Neighborhood_Sawyer  0.005762  0.005762
# 48     Exterior2nd_VinylSd  0.005760  0.005760
# 64    Neighborhood_Blueste  0.005714  0.005714
# 66         LandContour_Lvl  0.005617  0.005617
# 72         LandContour_HLS  0.005599  0.005599
# 67               LandSlope -0.005527  0.005527
# 71         log_first_FlrSF  0.005350  0.005350
# 70     Exterior1st_BrkComm  0.005257  0.005257
# 73         Condition2_PosA  0.005033  0.005033
# 77            Heating_Grav -0.004982  0.004982
# 76     Exterior2nd_BrkFace -0.004865  0.004865
# 74               MoSold_10 -0.004819  0.004819
# 79           MSSubClass_85  0.004818  0.004818
# 80        Condition2_Feedr -0.004686  0.004686
# 75        Foundation_PConc  0.004676  0.004676
# 69    Neighborhood_SawyerW -0.004661  0.004661
# 82          MSSubClass_150 -0.004395  0.004395
# 81     Neighborhood_Greens  0.004373  0.004373
# 83          MSSubClass_190 -0.004159  0.004159
# 87   SaleCondition_AdjLand  0.004099  0.004099
# 85              Fence_MnWw -0.003987  0.003987
# 86        Utilities_NoSewr -0.003937  0.003937
# 84        Electrical_FuseP  0.003812  0.003812
# 89      GarageType_Basment -0.003782  0.003782
# 88              Alley_Pave  0.003765  0.003765
# 90                MoSold_8 -0.003691  0.003691
# 92                has_pool  0.003591  0.003591
# 93           MSSubClass_20  0.003531  0.003531
# 91              Alley_None  0.003462  0.003462
# 109          LotConfig_FR2 -0.003426  0.003426
# 78             MSZoning_RM -0.003352  0.003352
# 94                MoSold_2 -0.003280  0.003280
# 102         log_WoodDeckSF  0.003278  0.003278
# 96            Heating_OthW -0.003255  0.003255
# 107    Exterior1st_WdShing  0.003223  0.003223
# 100        BldgType_TwnhsE  0.003195  0.003195
# 99               MoSold_11 -0.003187  0.003187
# 95    Neighborhood_MeadowV -0.003122  0.003122
# 106          LotConfig_FR3 -0.003114  0.003114
# 110    Exterior2nd_AsphShn  0.003073  0.003073
# 97            Heating_GasW  0.003046  0.003046
# 103          MSSubClass_75  0.002932  0.002932
# 101               Fence_No -0.002853  0.002853
# 117     Exterior2nd_Stucco  0.002833  0.002833
# 119       GarageFinish_Unf -0.002806  0.002806
# 105                 YrSold -0.002793  0.002793
# 104    Exterior2nd_Plywood -0.002755  0.002755
# 115     Exterior2nd_CBlock  0.002728  0.002728
# 112       Electrical_SBrkr  0.002683  0.002683
# 113       RoofMatl_Membran  0.002638  0.002638
# 111              ExterCond -0.002549  0.002549
# 114        Condition1_RRNn  0.002519  0.002519
# 108    Neighborhood_NWAmes -0.002482  0.002482
# 118               MoSold_4 -0.002465  0.002465
# 120         BldgType_Twnhs -0.002227  0.002227
# 116          MSSubClass_80 -0.002227  0.002227
# 121               MoSold_9 -0.002177  0.002177
# 124        Condition1_RRAe -0.002040  0.002040
# 123        Condition1_RRNe  0.002033  0.002033
# 122   Neighborhood_Mitchel -0.001800  0.001800
#
# skewness:  -0.47972708096065086
#
# model_importances.shape:  (125, 3)

# %%
lasso6 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0001}
# score:  0.9486895480861707
#
# test score:  0.9137620967988711
# adj_r2:  0.9448718061282965
#
# adj_r2_test:  0.8971266988048262
#
# train RMSE: 0.08685980965863739
#
# test RMSE: 0.11628208085110048
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.135180  0.135180
# 1              OverallQual  0.063086  0.063086
# 2                YearBuilt  0.060944  0.060944
# 3              OverallCond  0.048811  0.048811
# 4               BsmtFinSF1  0.042340  0.042340
# 5              log_LotArea  0.033451  0.033451
# 6     Neighborhood_Somerst  0.026324  0.026324
# 7            GarageType_No  0.024569  0.024569
# 8               GarageCond  0.024533  0.024533
# 9          Condition1_Norm  0.021829  0.021829
# 10         Condition2_PosN -0.021427  0.021427
# 12     Exterior1st_BrkFace  0.019184  0.019184
# 11              Functional  0.019103  0.019103
# 13          MSSubClass_160 -0.018349  0.018349
# 14    Neighborhood_StoneBr  0.017473  0.017473
# 17    Neighborhood_NridgHt  0.017364  0.017364
# 16          log_BsmtFinSF1 -0.017278  0.017278
# 15    Neighborhood_Crawfor  0.017192  0.017192
# 18              Fireplaces  0.016885  0.016885
# 19            BsmtFinType1  0.016117  0.016117
# 20         yeo_TotalBsmtSF  0.015805  0.015805
# 22    Neighborhood_GrnHill  0.015339  0.015339
# 21              GarageCars  0.015339  0.015339
# 23   SaleCondition_Partial  0.015147  0.015147
# 25             MSZoning_RL  0.014892  0.014892
# 24    Neighborhood_NoRidge  0.013969  0.013969
# 26            BsmtExposure  0.013350  0.013350
# 28          yeo_GarageArea  0.013313  0.013313
# 27           MSSubClass_60 -0.012743  0.012743
# 29             KitchenQual  0.012652  0.012652
# 32              BsmtFinSF2  0.012538  0.012538
# 31                BsmtQual  0.012063  0.012063
# 30        MSZoning_C (all) -0.011999  0.011999
# 33            TotRmsAbvGrd  0.011867  0.011867
# 34    Neighborhood_BrkSide  0.011110  0.011110
# 35               ExterQual  0.010006  0.010006
# 38            YearRemodAdd  0.009834  0.009834
# 37    Neighborhood_Edwards -0.009705  0.009705
# 36           MSSubClass_90 -0.009647  0.009647
# 40    SaleCondition_Normal  0.009559  0.009559
# 39         Condition1_PosN  0.009341  0.009341
# 42        RoofMatl_WdShngl  0.009288  0.009288
# 44     Neighborhood_BrDale  0.008900  0.008900
# 43               HeatingQC  0.008742  0.008742
# 41         log_LotFrontage  0.008523  0.008523
# 45    Neighborhood_NPkVill  0.008188  0.008188
# 47    SaleCondition_Alloca  0.008020  0.008020
# 54     Exterior1st_MetalSd  0.007871  0.007871
# 50                FullBath  0.007629  0.007629
# 51       RoofStyle_Gambrel -0.007243  0.007243
# 46            BsmtFullBath  0.007181  0.007181
# 49            CentralAir_Y  0.007154  0.007154
# 52                HalfBath  0.007132  0.007132
# 53    SaleCondition_Family -0.007003  0.007003
# 55       RoofStyle_Mansard -0.006882  0.006882
# 61            KitchenAbvGr -0.006833  0.006833
# 56             ScreenPorch  0.006770  0.006770
# 59        GarageFinish_RFn -0.006581  0.006581
# 58            PavedDrive_Y  0.006387  0.006387
# 62    Neighborhood_ClearCr  0.006269  0.006269
# 60                MoSold_3 -0.006269  0.006269
# 57           EnclosedPorch  0.006097  0.006097
# 63            BedroomAbvGr -0.006085  0.006085
# 98     Exterior1st_VinylSd  0.005781  0.005781
# 65         Condition1_PosA  0.005763  0.005763
# 68     Neighborhood_Sawyer  0.005762  0.005762
# 48     Exterior2nd_VinylSd  0.005760  0.005760
# 64    Neighborhood_Blueste  0.005714  0.005714
# 66         LandContour_Lvl  0.005617  0.005617
# 72         LandContour_HLS  0.005599  0.005599
# 67               LandSlope -0.005527  0.005527
# 71         log_first_FlrSF  0.005350  0.005350
# 70     Exterior1st_BrkComm  0.005257  0.005257
# 73         Condition2_PosA  0.005033  0.005033
# 77            Heating_Grav -0.004982  0.004982
# 76     Exterior2nd_BrkFace -0.004865  0.004865
# 74               MoSold_10 -0.004819  0.004819
# 79           MSSubClass_85  0.004818  0.004818
# 80        Condition2_Feedr -0.004686  0.004686
# 75        Foundation_PConc  0.004676  0.004676
# 69    Neighborhood_SawyerW -0.004661  0.004661
# 82          MSSubClass_150 -0.004395  0.004395
# 81     Neighborhood_Greens  0.004373  0.004373
# 83          MSSubClass_190 -0.004159  0.004159
# 87   SaleCondition_AdjLand  0.004099  0.004099
# 85              Fence_MnWw -0.003987  0.003987
# 86        Utilities_NoSewr -0.003937  0.003937
# 84        Electrical_FuseP  0.003812  0.003812
# 89      GarageType_Basment -0.003782  0.003782
# 88              Alley_Pave  0.003765  0.003765
# 90                MoSold_8 -0.003691  0.003691
# 92                has_pool  0.003591  0.003591
# 93           MSSubClass_20  0.003531  0.003531
# 91              Alley_None  0.003462  0.003462
# 109          LotConfig_FR2 -0.003426  0.003426
# 78             MSZoning_RM -0.003352  0.003352
# 94                MoSold_2 -0.003280  0.003280
# 102         log_WoodDeckSF  0.003278  0.003278
# 96            Heating_OthW -0.003255  0.003255
# 107    Exterior1st_WdShing  0.003223  0.003223
# 100        BldgType_TwnhsE  0.003195  0.003195
# 99               MoSold_11 -0.003187  0.003187
# 95    Neighborhood_MeadowV -0.003122  0.003122
# 106          LotConfig_FR3 -0.003114  0.003114
# 110    Exterior2nd_AsphShn  0.003073  0.003073
# 97            Heating_GasW  0.003046  0.003046
# 103          MSSubClass_75  0.002932  0.002932
# 101               Fence_No -0.002853  0.002853
# 117     Exterior2nd_Stucco  0.002833  0.002833
# 119       GarageFinish_Unf -0.002806  0.002806
# 105                 YrSold -0.002793  0.002793
# 104    Exterior2nd_Plywood -0.002755  0.002755
# 115     Exterior2nd_CBlock  0.002728  0.002728
# 112       Electrical_SBrkr  0.002683  0.002683
# 113       RoofMatl_Membran  0.002638  0.002638
# 111              ExterCond -0.002549  0.002549
# 114        Condition1_RRNn  0.002519  0.002519
# 108    Neighborhood_NWAmes -0.002482  0.002482
# 118               MoSold_4 -0.002465  0.002465
# 120         BldgType_Twnhs -0.002227  0.002227
# 116          MSSubClass_80 -0.002227  0.002227
# 121               MoSold_9 -0.002177  0.002177
# 124        Condition1_RRAe -0.002040  0.002040
# 123        Condition1_RRNe  0.002033  0.002033
# 122   Neighborhood_Mitchel -0.001800  0.001800
#
# skewness:  -0.47972708096065086
#
# model_importances.shape:  (125, 3)

# %%
lasso7 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.0002,   0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0002}
# score:  0.9486381692329872
#
# test score:  0.9139917224345513
# adj_r2:  0.9448166044437749
#
# adj_r2_test:  0.8974006195091175
#
# train RMSE: 0.08690328657828926
#
# test RMSE: 0.11612716553044679
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.134586  0.134586
# 1              OverallQual  0.063573  0.063573
# 2                YearBuilt  0.060865  0.060865
# 3              OverallCond  0.048557  0.048557
# 4               BsmtFinSF1  0.041469  0.041469
# 5              log_LotArea  0.033208  0.033208
# 6     Neighborhood_Somerst  0.026024  0.026024
# 7            GarageType_No  0.022704  0.022704
# 8               GarageCond  0.022630  0.022630
# 9          Condition1_Norm  0.021654  0.021654
# 10         Condition2_PosN -0.021211  0.021211
# 11              Functional  0.018969  0.018969
# 12     Exterior1st_BrkFace  0.018799  0.018799
# 13          MSSubClass_160 -0.017675  0.017675
# 14    Neighborhood_StoneBr  0.017341  0.017341
# 17    Neighborhood_NridgHt  0.017269  0.017269
# 15    Neighborhood_Crawfor  0.017188  0.017188
# 18              Fireplaces  0.017061  0.017061
# 20         yeo_TotalBsmtSF  0.015814  0.015814
# 16          log_BsmtFinSF1 -0.015472  0.015472
# 21              GarageCars  0.015268  0.015268
# 22    Neighborhood_GrnHill  0.015251  0.015251
# 19            BsmtFinType1  0.014918  0.014918
# 23   SaleCondition_Partial  0.014846  0.014846
# 25             MSZoning_RL  0.014615  0.014615
# 24    Neighborhood_NoRidge  0.013853  0.013853
# 28          yeo_GarageArea  0.013398  0.013398
# 26            BsmtExposure  0.013352  0.013352
# 29             KitchenQual  0.012766  0.012766
# 32              BsmtFinSF2  0.012154  0.012154
# 31                BsmtQual  0.012012  0.012012
# 30        MSZoning_C (all) -0.011915  0.011915
# 27           MSSubClass_60 -0.011834  0.011834
# 33            TotRmsAbvGrd  0.011388  0.011388
# 34    Neighborhood_BrkSide  0.010915  0.010915
# 35               ExterQual  0.010102  0.010102
# 38            YearRemodAdd  0.010039  0.010039
# 37    Neighborhood_Edwards -0.009693  0.009693
# 36           MSSubClass_90 -0.009309  0.009309
# 42        RoofMatl_WdShngl  0.009261  0.009261
# 40    SaleCondition_Normal  0.009151  0.009151
# 39         Condition1_PosN  0.009126  0.009126
# 43               HeatingQC  0.008776  0.008776
# 41         log_LotFrontage  0.008357  0.008357
# 44     Neighborhood_BrDale  0.008289  0.008289
# 45    Neighborhood_NPkVill  0.007829  0.007829
# 47    SaleCondition_Alloca  0.007728  0.007728
# 54     Exterior1st_MetalSd  0.007491  0.007491
# 50                FullBath  0.007366  0.007366
# 46            BsmtFullBath  0.007236  0.007236
# 49            CentralAir_Y  0.007203  0.007203
# 53    SaleCondition_Family -0.007055  0.007055
# 51       RoofStyle_Gambrel -0.006976  0.006976
# 61            KitchenAbvGr -0.006894  0.006894
# 52                HalfBath  0.006794  0.006794
# 55       RoofStyle_Mansard -0.006764  0.006764
# 56             ScreenPorch  0.006630  0.006630
# 59        GarageFinish_RFn -0.006393  0.006393
# 58            PavedDrive_Y  0.006343  0.006343
# 62    Neighborhood_ClearCr  0.006122  0.006122
# 60                MoSold_3 -0.006109  0.006109
# 71         log_first_FlrSF  0.006086  0.006086
# 57           EnclosedPorch  0.005956  0.005956
# 63            BedroomAbvGr -0.005735  0.005735
# 48     Exterior2nd_VinylSd  0.005673  0.005673
# 65         Condition1_PosA  0.005578  0.005578
# 98     Exterior1st_VinylSd  0.005557  0.005557
# 68     Neighborhood_Sawyer  0.005555  0.005555
# 64    Neighborhood_Blueste  0.005476  0.005476
# 67               LandSlope -0.005346  0.005346
# 72         LandContour_HLS  0.005313  0.005313
# 66         LandContour_Lvl  0.005173  0.005173
# 70     Exterior1st_BrkComm  0.005113  0.005113
# 73         Condition2_PosA  0.005024  0.005024
# 77            Heating_Grav -0.004821  0.004821
# 79           MSSubClass_85  0.004748  0.004748
# 74               MoSold_10 -0.004716  0.004716
# 75        Foundation_PConc  0.004620  0.004620
# 69    Neighborhood_SawyerW -0.004617  0.004617
# 76     Exterior2nd_BrkFace -0.004575  0.004575
# 80        Condition2_Feedr -0.004504  0.004504
# 82          MSSubClass_150 -0.004237  0.004237
# 81     Neighborhood_Greens  0.004181  0.004181
# 83          MSSubClass_190 -0.003975  0.003975
# 86        Utilities_NoSewr -0.003894  0.003894
# 85              Fence_MnWw -0.003857  0.003857
# 87   SaleCondition_AdjLand  0.003843  0.003843
# 89      GarageType_Basment -0.003733  0.003733
# 92                has_pool  0.003601  0.003601
# 84        Electrical_FuseP  0.003589  0.003589
# 93           MSSubClass_20  0.003493  0.003493
# 90                MoSold_8 -0.003481  0.003481
# 88              Alley_Pave  0.003425  0.003425
# 78             MSZoning_RM -0.003396  0.003396
# 109          LotConfig_FR2 -0.003326  0.003326
# 102         log_WoodDeckSF  0.003287  0.003287
# 95    Neighborhood_MeadowV -0.003275  0.003275
# 91              Alley_None  0.003209  0.003209
# 96            Heating_OthW -0.003200  0.003200
# 99               MoSold_11 -0.003100  0.003100
# 97            Heating_GasW  0.003064  0.003064
# 94                MoSold_2 -0.003043  0.003043
# 100        BldgType_TwnhsE  0.003035  0.003035
# 107    Exterior1st_WdShing  0.003031  0.003031
# 106          LotConfig_FR3 -0.002933  0.002933
# 110    Exterior2nd_AsphShn  0.002927  0.002927
# 103          MSSubClass_75  0.002840  0.002840
# 119       GarageFinish_Unf -0.002746  0.002746
# 104    Exterior2nd_Plywood -0.002714  0.002714
# 117     Exterior2nd_Stucco  0.002673  0.002673
# 105                 YrSold -0.002606  0.002606
# 101               Fence_No -0.002598  0.002598
# 115     Exterior2nd_CBlock  0.002591  0.002591
# 112       Electrical_SBrkr  0.002572  0.002572
# 113       RoofMatl_Membran  0.002531  0.002531
# 108    Neighborhood_NWAmes -0.002401  0.002401
# 118               MoSold_4 -0.002327  0.002327
# 111              ExterCond -0.002316  0.002316
# 114        Condition1_RRNn  0.002282  0.002282
# 120         BldgType_Twnhs -0.002085  0.002085
# 116          MSSubClass_80 -0.002044  0.002044
# 121               MoSold_9 -0.001999  0.001999
# 124        Condition1_RRAe -0.001973  0.001973
# 123        Condition1_RRNe  0.001852  0.001852
# 122   Neighborhood_Mitchel -0.001725  0.001725
#
# skewness:  -0.4982913798866462
#
# model_importances.shape:  (125, 3)

# %%
lasso8 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.0002, 0.0003, 0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0003}
# score:  0.9485523072583057
#
# test score:  0.9141815722304867
# adj_r2:  0.9447243539293106
#
# adj_r2_test:  0.8976270915650713
#
# train RMSE: 0.08697589469840394
#
# test RMSE: 0.11599892846467738
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.133966  0.133966
# 1              OverallQual  0.064063  0.064063
# 2                YearBuilt  0.060748  0.060748
# 3              OverallCond  0.048303  0.048303
# 4               BsmtFinSF1  0.040599  0.040599
# 5              log_LotArea  0.032957  0.032957
# 6     Neighborhood_Somerst  0.025742  0.025742
# 9          Condition1_Norm  0.021479  0.021479
# 10         Condition2_PosN -0.020996  0.020996
# 7            GarageType_No  0.020838  0.020838
# 8               GarageCond  0.020727  0.020727
# 11              Functional  0.018835  0.018835
# 12     Exterior1st_BrkFace  0.018412  0.018412
# 18              Fireplaces  0.017236  0.017236
# 14    Neighborhood_StoneBr  0.017209  0.017209
# 15    Neighborhood_Crawfor  0.017183  0.017183
# 17    Neighborhood_NridgHt  0.017173  0.017173
# 13          MSSubClass_160 -0.016989  0.016989
# 20         yeo_TotalBsmtSF  0.015804  0.015804
# 21              GarageCars  0.015172  0.015172
# 22    Neighborhood_GrnHill  0.015163  0.015163
# 23   SaleCondition_Partial  0.014544  0.014544
# 25             MSZoning_RL  0.014380  0.014380
# 24    Neighborhood_NoRidge  0.013734  0.013734
# 19            BsmtFinType1  0.013712  0.013712
# 16          log_BsmtFinSF1 -0.013661  0.013661
# 28          yeo_GarageArea  0.013502  0.013502
# 26            BsmtExposure  0.013356  0.013356
# 29             KitchenQual  0.012880  0.012880
# 31                BsmtQual  0.011973  0.011973
# 30        MSZoning_C (all) -0.011822  0.011822
# 32              BsmtFinSF2  0.011769  0.011769
# 33            TotRmsAbvGrd  0.010909  0.010909
# 27           MSSubClass_60 -0.010908  0.010908
# 34    Neighborhood_BrkSide  0.010719  0.010719
# 38            YearRemodAdd  0.010243  0.010243
# 35               ExterQual  0.010201  0.010201
# 37    Neighborhood_Edwards -0.009681  0.009681
# 42        RoofMatl_WdShngl  0.009235  0.009235
# 36           MSSubClass_90 -0.008963  0.008963
# 39         Condition1_PosN  0.008910  0.008910
# 43               HeatingQC  0.008810  0.008810
# 40    SaleCondition_Normal  0.008742  0.008742
# 41         log_LotFrontage  0.008197  0.008197
# 44     Neighborhood_BrDale  0.007670  0.007670
# 45    Neighborhood_NPkVill  0.007465  0.007465
# 47    SaleCondition_Alloca  0.007436  0.007436
# 46            BsmtFullBath  0.007294  0.007294
# 49            CentralAir_Y  0.007253  0.007253
# 50                FullBath  0.007116  0.007116
# 54     Exterior1st_MetalSd  0.007109  0.007109
# 53    SaleCondition_Family -0.007108  0.007108
# 61            KitchenAbvGr -0.006958  0.006958
# 71         log_first_FlrSF  0.006851  0.006851
# 51       RoofStyle_Gambrel -0.006707  0.006707
# 55       RoofStyle_Mansard -0.006647  0.006647
# 56             ScreenPorch  0.006489  0.006489
# 52                HalfBath  0.006464  0.006464
# 58            PavedDrive_Y  0.006303  0.006303
# 59        GarageFinish_RFn -0.006204  0.006204
# 62    Neighborhood_ClearCr  0.005975  0.005975
# 60                MoSold_3 -0.005948  0.005948
# 57           EnclosedPorch  0.005813  0.005813
# 48     Exterior2nd_VinylSd  0.005639  0.005639
# 65         Condition1_PosA  0.005392  0.005392
# 63            BedroomAbvGr -0.005381  0.005381
# 68     Neighborhood_Sawyer  0.005348  0.005348
# 98     Exterior1st_VinylSd  0.005285  0.005285
# 64    Neighborhood_Blueste  0.005235  0.005235
# 67               LandSlope -0.005166  0.005166
# 72         LandContour_HLS  0.005028  0.005028
# 73         Condition2_PosA  0.005014  0.005014
# 70     Exterior1st_BrkComm  0.004970  0.004970
# 66         LandContour_Lvl  0.004728  0.004728
# 79           MSSubClass_85  0.004681  0.004681
# 77            Heating_Grav -0.004659  0.004659
# 74               MoSold_10 -0.004612  0.004612
# 75        Foundation_PConc  0.004575  0.004575
# 69    Neighborhood_SawyerW -0.004573  0.004573
# 80        Condition2_Feedr -0.004322  0.004322
# 76     Exterior2nd_BrkFace -0.004283  0.004283
# 82          MSSubClass_150 -0.004081  0.004081
# 81     Neighborhood_Greens  0.003988  0.003988
# 86        Utilities_NoSewr -0.003850  0.003850
# 83          MSSubClass_190 -0.003788  0.003788
# 85              Fence_MnWw -0.003727  0.003727
# 89      GarageType_Basment -0.003686  0.003686
# 92                has_pool  0.003612  0.003612
# 87   SaleCondition_AdjLand  0.003584  0.003584
# 93           MSSubClass_20  0.003465  0.003465
# 95    Neighborhood_MeadowV -0.003434  0.003434
# 78             MSZoning_RM -0.003403  0.003403
# 84        Electrical_FuseP  0.003367  0.003367
# 102         log_WoodDeckSF  0.003298  0.003298
# 90                MoSold_8 -0.003271  0.003271
# 109          LotConfig_FR2 -0.003226  0.003226
# 96            Heating_OthW -0.003146  0.003146
# 88              Alley_Pave  0.003087  0.003087
# 97            Heating_GasW  0.003081  0.003081
# 99               MoSold_11 -0.003012  0.003012
# 91              Alley_None  0.002959  0.002959
# 100        BldgType_TwnhsE  0.002884  0.002884
# 107    Exterior1st_WdShing  0.002837  0.002837
# 94                MoSold_2 -0.002806  0.002806
# 110    Exterior2nd_AsphShn  0.002782  0.002782
# 106          LotConfig_FR3 -0.002752  0.002752
# 103          MSSubClass_75  0.002747  0.002747
# 119       GarageFinish_Unf -0.002685  0.002685
# 104    Exterior2nd_Plywood -0.002674  0.002674
# 117     Exterior2nd_Stucco  0.002511  0.002511
# 112       Electrical_SBrkr  0.002462  0.002462
# 115     Exterior2nd_CBlock  0.002456  0.002456
# 113       RoofMatl_Membran  0.002425  0.002425
# 105                 YrSold -0.002418  0.002418
# 101               Fence_No -0.002341  0.002341
# 108    Neighborhood_NWAmes -0.002318  0.002318
# 118               MoSold_4 -0.002189  0.002189
# 111              ExterCond -0.002086  0.002086
# 114        Condition1_RRNn  0.002045  0.002045
# 120         BldgType_Twnhs -0.001932  0.001932
# 124        Condition1_RRAe -0.001905  0.001905
# 116          MSSubClass_80 -0.001860  0.001860
# 121               MoSold_9 -0.001823  0.001823
# 123        Condition1_RRNe  0.001670  0.001670
# 122   Neighborhood_Mitchel -0.001649  0.001649
#
# skewness:  -0.5163023732830053
#
# model_importances.shape:  (125, 3)

# %%
lasso9 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0003}
# score:  0.9485523072583057
#
# test score:  0.9141815722304867
# adj_r2:  0.9447243539293106
#
# adj_r2_test:  0.8976270915650713
#
# train RMSE: 0.08697589469840394
#
# test RMSE: 0.11599892846467738
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.133966  0.133966
# 1              OverallQual  0.064063  0.064063
# 2                YearBuilt  0.060748  0.060748
# 3              OverallCond  0.048303  0.048303
# 4               BsmtFinSF1  0.040599  0.040599
# 5              log_LotArea  0.032957  0.032957
# 6     Neighborhood_Somerst  0.025742  0.025742
# 9          Condition1_Norm  0.021479  0.021479
# 10         Condition2_PosN -0.020996  0.020996
# 7            GarageType_No  0.020838  0.020838
# 8               GarageCond  0.020727  0.020727
# 11              Functional  0.018835  0.018835
# 12     Exterior1st_BrkFace  0.018412  0.018412
# 18              Fireplaces  0.017236  0.017236
# 14    Neighborhood_StoneBr  0.017209  0.017209
# 15    Neighborhood_Crawfor  0.017183  0.017183
# 17    Neighborhood_NridgHt  0.017173  0.017173
# 13          MSSubClass_160 -0.016989  0.016989
# 20         yeo_TotalBsmtSF  0.015804  0.015804
# 21              GarageCars  0.015172  0.015172
# 22    Neighborhood_GrnHill  0.015163  0.015163
# 23   SaleCondition_Partial  0.014544  0.014544
# 25             MSZoning_RL  0.014380  0.014380
# 24    Neighborhood_NoRidge  0.013734  0.013734
# 19            BsmtFinType1  0.013712  0.013712
# 16          log_BsmtFinSF1 -0.013661  0.013661
# 28          yeo_GarageArea  0.013502  0.013502
# 26            BsmtExposure  0.013356  0.013356
# 29             KitchenQual  0.012880  0.012880
# 31                BsmtQual  0.011973  0.011973
# 30        MSZoning_C (all) -0.011822  0.011822
# 32              BsmtFinSF2  0.011769  0.011769
# 33            TotRmsAbvGrd  0.010909  0.010909
# 27           MSSubClass_60 -0.010908  0.010908
# 34    Neighborhood_BrkSide  0.010719  0.010719
# 38            YearRemodAdd  0.010243  0.010243
# 35               ExterQual  0.010201  0.010201
# 37    Neighborhood_Edwards -0.009681  0.009681
# 42        RoofMatl_WdShngl  0.009235  0.009235
# 36           MSSubClass_90 -0.008963  0.008963
# 39         Condition1_PosN  0.008910  0.008910
# 43               HeatingQC  0.008810  0.008810
# 40    SaleCondition_Normal  0.008742  0.008742
# 41         log_LotFrontage  0.008197  0.008197
# 44     Neighborhood_BrDale  0.007670  0.007670
# 45    Neighborhood_NPkVill  0.007465  0.007465
# 47    SaleCondition_Alloca  0.007436  0.007436
# 46            BsmtFullBath  0.007294  0.007294
# 49            CentralAir_Y  0.007253  0.007253
# 50                FullBath  0.007116  0.007116
# 54     Exterior1st_MetalSd  0.007109  0.007109
# 53    SaleCondition_Family -0.007108  0.007108
# 61            KitchenAbvGr -0.006958  0.006958
# 71         log_first_FlrSF  0.006851  0.006851
# 51       RoofStyle_Gambrel -0.006707  0.006707
# 55       RoofStyle_Mansard -0.006647  0.006647
# 56             ScreenPorch  0.006489  0.006489
# 52                HalfBath  0.006464  0.006464
# 58            PavedDrive_Y  0.006303  0.006303
# 59        GarageFinish_RFn -0.006204  0.006204
# 62    Neighborhood_ClearCr  0.005975  0.005975
# 60                MoSold_3 -0.005948  0.005948
# 57           EnclosedPorch  0.005813  0.005813
# 48     Exterior2nd_VinylSd  0.005639  0.005639
# 65         Condition1_PosA  0.005392  0.005392
# 63            BedroomAbvGr -0.005381  0.005381
# 68     Neighborhood_Sawyer  0.005348  0.005348
# 98     Exterior1st_VinylSd  0.005285  0.005285
# 64    Neighborhood_Blueste  0.005235  0.005235
# 67               LandSlope -0.005166  0.005166
# 72         LandContour_HLS  0.005028  0.005028
# 73         Condition2_PosA  0.005014  0.005014
# 70     Exterior1st_BrkComm  0.004970  0.004970
# 66         LandContour_Lvl  0.004728  0.004728
# 79           MSSubClass_85  0.004681  0.004681
# 77            Heating_Grav -0.004659  0.004659
# 74               MoSold_10 -0.004612  0.004612
# 75        Foundation_PConc  0.004575  0.004575
# 69    Neighborhood_SawyerW -0.004573  0.004573
# 80        Condition2_Feedr -0.004322  0.004322
# 76     Exterior2nd_BrkFace -0.004283  0.004283
# 82          MSSubClass_150 -0.004081  0.004081
# 81     Neighborhood_Greens  0.003988  0.003988
# 86        Utilities_NoSewr -0.003850  0.003850
# 83          MSSubClass_190 -0.003788  0.003788
# 85              Fence_MnWw -0.003727  0.003727
# 89      GarageType_Basment -0.003686  0.003686
# 92                has_pool  0.003612  0.003612
# 87   SaleCondition_AdjLand  0.003584  0.003584
# 93           MSSubClass_20  0.003465  0.003465
# 95    Neighborhood_MeadowV -0.003434  0.003434
# 78             MSZoning_RM -0.003403  0.003403
# 84        Electrical_FuseP  0.003367  0.003367
# 102         log_WoodDeckSF  0.003298  0.003298
# 90                MoSold_8 -0.003271  0.003271
# 109          LotConfig_FR2 -0.003226  0.003226
# 96            Heating_OthW -0.003146  0.003146
# 88              Alley_Pave  0.003087  0.003087
# 97            Heating_GasW  0.003081  0.003081
# 99               MoSold_11 -0.003012  0.003012
# 91              Alley_None  0.002959  0.002959
# 100        BldgType_TwnhsE  0.002884  0.002884
# 107    Exterior1st_WdShing  0.002837  0.002837
# 94                MoSold_2 -0.002806  0.002806
# 110    Exterior2nd_AsphShn  0.002782  0.002782
# 106          LotConfig_FR3 -0.002752  0.002752
# 103          MSSubClass_75  0.002747  0.002747
# 119       GarageFinish_Unf -0.002685  0.002685
# 104    Exterior2nd_Plywood -0.002674  0.002674
# 117     Exterior2nd_Stucco  0.002511  0.002511
# 112       Electrical_SBrkr  0.002462  0.002462
# 115     Exterior2nd_CBlock  0.002456  0.002456
# 113       RoofMatl_Membran  0.002425  0.002425
# 105                 YrSold -0.002418  0.002418
# 101               Fence_No -0.002341  0.002341
# 108    Neighborhood_NWAmes -0.002318  0.002318
# 118               MoSold_4 -0.002189  0.002189
# 111              ExterCond -0.002086  0.002086
# 114        Condition1_RRNn  0.002045  0.002045
# 120         BldgType_Twnhs -0.001932  0.001932
# 124        Condition1_RRAe -0.001905  0.001905
# 116          MSSubClass_80 -0.001860  0.001860
# 121               MoSold_9 -0.001823  0.001823
# 123        Condition1_RRNe  0.001670  0.001670
# 122   Neighborhood_Mitchel -0.001649  0.001649
#
# skewness:  -0.5163023732830053
#
# model_importances.shape:  (125, 3)

# %%
keeps= to_keep(lasso9,0.002)

# %%
lasso10 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0003}
# score:  0.9484250090093628
#
# test score:  0.9143057404334923
# adj_r2:  0.944784781294128
#
# adj_r2_test:  0.89871305405977
#
# train RMSE: 0.08708343148103063
#
# test RMSE: 0.11591498033953086
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.135061  0.135061
# 1              OverallQual  0.063980  0.063980
# 2                YearBuilt  0.058735  0.058735
# 3              OverallCond  0.048146  0.048146
# 4               BsmtFinSF1  0.040422  0.040422
# 5              log_LotArea  0.032817  0.032817
# 6     Neighborhood_Somerst  0.025843  0.025843
# 7          Condition1_Norm  0.021699  0.021699
# 10              GarageCond  0.021157  0.021157
# 9            GarageType_No  0.021136  0.021136
# 8          Condition2_PosN -0.021018  0.021018
# 11              Functional  0.018922  0.018922
# 12     Exterior1st_BrkFace  0.018539  0.018539
# 17          MSSubClass_160 -0.017482  0.017482
# 15    Neighborhood_Crawfor  0.017431  0.017431
# 14    Neighborhood_StoneBr  0.017240  0.017240
# 16    Neighborhood_NridgHt  0.017219  0.017219
# 13              Fireplaces  0.017142  0.017142
# 18         yeo_TotalBsmtSF  0.016561  0.016561
# 19              GarageCars  0.015577  0.015577
# 20    Neighborhood_GrnHill  0.014998  0.014998
# 21   SaleCondition_Partial  0.014658  0.014658
# 22             MSZoning_RL  0.014467  0.014467
# 23    Neighborhood_NoRidge  0.013758  0.013758
# 24            BsmtFinType1  0.013455  0.013455
# 25          log_BsmtFinSF1 -0.013447  0.013447
# 27            BsmtExposure  0.013189  0.013189
# 26          yeo_GarageArea  0.013183  0.013183
# 28             KitchenQual  0.012963  0.012963
# 30        MSZoning_C (all) -0.011720  0.011720
# 29                BsmtQual  0.011688  0.011688
# 31              BsmtFinSF2  0.011639  0.011639
# 34    Neighborhood_BrkSide  0.011083  0.011083
# 32            TotRmsAbvGrd  0.010905  0.010905
# 36               ExterQual  0.010734  0.010734
# 35            YearRemodAdd  0.010035  0.010035
# 37    Neighborhood_Edwards -0.009399  0.009399
# 38        RoofMatl_WdShngl  0.009166  0.009166
# 41               HeatingQC  0.009066  0.009066
# 33           MSSubClass_60 -0.008952  0.008952
# 40         Condition1_PosN  0.008927  0.008927
# 42    SaleCondition_Normal  0.008915  0.008915
# 43         log_LotFrontage  0.008604  0.008604
# 39           MSSubClass_90 -0.008088  0.008088
# 46    SaleCondition_Alloca  0.007650  0.007650
# 52            KitchenAbvGr -0.007474  0.007474
# 44     Neighborhood_BrDale  0.007353  0.007353
# 45    Neighborhood_NPkVill  0.007335  0.007335
# 47            BsmtFullBath  0.007226  0.007226
# 49                FullBath  0.007065  0.007065
# 50     Exterior1st_MetalSd  0.007055  0.007055
# 48            CentralAir_Y  0.007032  0.007032
# 51    SaleCondition_Family -0.007024  0.007024
# 55       RoofStyle_Mansard -0.006853  0.006853
# 54       RoofStyle_Gambrel -0.006686  0.006686
# 56             ScreenPorch  0.006395  0.006395
# 57                HalfBath  0.006382  0.006382
# 58            PavedDrive_Y  0.006249  0.006249
# 59        GarageFinish_RFn -0.006109  0.006109
# 60    Neighborhood_ClearCr  0.006094  0.006094
# 63     Exterior2nd_VinylSd  0.005828  0.005828
# 89           MSSubClass_20  0.005750  0.005750
# 62           EnclosedPorch  0.005745  0.005745
# 61                MoSold_3 -0.005744  0.005744
# 53         log_first_FlrSF  0.005708  0.005708
# 65            BedroomAbvGr -0.005625  0.005625
# 64         Condition1_PosA  0.005544  0.005544
# 74           MSSubClass_85  0.005278  0.005278
# 68    Neighborhood_Blueste  0.005222  0.005222
# 66     Neighborhood_Sawyer  0.005210  0.005210
# 70         LandContour_HLS  0.005054  0.005054
# 67     Exterior1st_VinylSd  0.004990  0.004990
# 71         Condition2_PosA  0.004970  0.004970
# 69               LandSlope -0.004925  0.004925
# 72     Exterior1st_BrkComm  0.004897  0.004897
# 101        BldgType_TwnhsE  0.004797  0.004797
# 73         LandContour_Lvl  0.004682  0.004682
# 75            Heating_Grav -0.004638  0.004638
# 77        Foundation_PConc  0.004576  0.004576
# 76               MoSold_10 -0.004482  0.004482
# 78    Neighborhood_SawyerW -0.004419  0.004419
# 80     Exterior2nd_BrkFace -0.004386  0.004386
# 79        Condition2_Feedr -0.004299  0.004299
# 81          MSSubClass_150 -0.004188  0.004188
# 82     Neighborhood_Greens  0.003864  0.003864
# 83        Utilities_NoSewr -0.003841  0.003841
# 86      GarageType_Basment -0.003834  0.003834
# 85              Fence_MnWw -0.003748  0.003748
# 88   SaleCondition_AdjLand  0.003626  0.003626
# 90    Neighborhood_MeadowV -0.003554  0.003554
# 87                has_pool  0.003528  0.003528
# 93          log_WoodDeckSF  0.003432  0.003432
# 92        Electrical_FuseP  0.003407  0.003407
# 84          MSSubClass_190 -0.003335  0.003335
# 95           LotConfig_FR2 -0.003332  0.003332
# 91             MSZoning_RM -0.003242  0.003242
# 96            Heating_OthW -0.003184  0.003184
# 108    Exterior2nd_Plywood -0.003118  0.003118
# 98            Heating_GasW  0.003090  0.003090
# 97              Alley_Pave  0.003079  0.003079
# 102    Exterior1st_WdShing  0.003033  0.003033
# 100             Alley_None  0.003009  0.003009
# 94                MoSold_8 -0.003000  0.003000
# 99               MoSold_11 -0.002983  0.002983
# 105          LotConfig_FR3 -0.002832  0.002832
# 106          MSSubClass_75  0.002785  0.002785
# 104    Exterior2nd_AsphShn  0.002769  0.002769
# 109     Exterior2nd_Stucco  0.002607  0.002607
# 103               MoSold_2 -0.002570  0.002570
# 107       GarageFinish_Unf -0.002565  0.002565
# 112       RoofMatl_Membran  0.002496  0.002496
# 111     Exterior2nd_CBlock  0.002483  0.002483
# 110       Electrical_SBrkr  0.002411  0.002411
# 113                 YrSold -0.002310  0.002310
# 114               Fence_No -0.002230  0.002230
# 115    Neighborhood_NWAmes -0.002163  0.002163
# 118        Condition1_RRNn  0.002110  0.002110
# 117              ExterCond -0.002104  0.002104
# 116               MoSold_4 -0.001994  0.001994
#
# skewness:  -0.514130562003141
#
# model_importances.shape:  (119, 3)

# %%
leeps=to_keep(lasso10, 0.003)

# %%
lasso11 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0003}
# score:  0.9484250090093628
#
# test score:  0.9143057404334923
# adj_r2:  0.944784781294128
#
# adj_r2_test:  0.89871305405977
#
# train RMSE: 0.08708343148103063
#
# test RMSE: 0.11591498033953086
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.135061  0.135061
# 1              OverallQual  0.063980  0.063980
# 2                YearBuilt  0.058735  0.058735
# 3              OverallCond  0.048146  0.048146
# 4               BsmtFinSF1  0.040422  0.040422
# 5              log_LotArea  0.032817  0.032817
# 6     Neighborhood_Somerst  0.025843  0.025843
# 7          Condition1_Norm  0.021699  0.021699
# 10              GarageCond  0.021157  0.021157
# 9            GarageType_No  0.021136  0.021136
# 8          Condition2_PosN -0.021018  0.021018
# 11              Functional  0.018922  0.018922
# 12     Exterior1st_BrkFace  0.018539  0.018539
# 17          MSSubClass_160 -0.017482  0.017482
# 15    Neighborhood_Crawfor  0.017431  0.017431
# 14    Neighborhood_StoneBr  0.017240  0.017240
# 16    Neighborhood_NridgHt  0.017219  0.017219
# 13              Fireplaces  0.017142  0.017142
# 18         yeo_TotalBsmtSF  0.016561  0.016561
# 19              GarageCars  0.015577  0.015577
# 20    Neighborhood_GrnHill  0.014998  0.014998
# 21   SaleCondition_Partial  0.014658  0.014658
# 22             MSZoning_RL  0.014467  0.014467
# 23    Neighborhood_NoRidge  0.013758  0.013758
# 24            BsmtFinType1  0.013455  0.013455
# 25          log_BsmtFinSF1 -0.013447  0.013447
# 27            BsmtExposure  0.013189  0.013189
# 26          yeo_GarageArea  0.013183  0.013183
# 28             KitchenQual  0.012963  0.012963
# 30        MSZoning_C (all) -0.011720  0.011720
# 29                BsmtQual  0.011688  0.011688
# 31              BsmtFinSF2  0.011639  0.011639
# 34    Neighborhood_BrkSide  0.011083  0.011083
# 32            TotRmsAbvGrd  0.010905  0.010905
# 36               ExterQual  0.010734  0.010734
# 35            YearRemodAdd  0.010035  0.010035
# 37    Neighborhood_Edwards -0.009399  0.009399
# 38        RoofMatl_WdShngl  0.009166  0.009166
# 41               HeatingQC  0.009066  0.009066
# 33           MSSubClass_60 -0.008952  0.008952
# 40         Condition1_PosN  0.008927  0.008927
# 42    SaleCondition_Normal  0.008915  0.008915
# 43         log_LotFrontage  0.008604  0.008604
# 39           MSSubClass_90 -0.008088  0.008088
# 46    SaleCondition_Alloca  0.007650  0.007650
# 52            KitchenAbvGr -0.007474  0.007474
# 44     Neighborhood_BrDale  0.007353  0.007353
# 45    Neighborhood_NPkVill  0.007335  0.007335
# 47            BsmtFullBath  0.007226  0.007226
# 49                FullBath  0.007065  0.007065
# 50     Exterior1st_MetalSd  0.007055  0.007055
# 48            CentralAir_Y  0.007032  0.007032
# 51    SaleCondition_Family -0.007024  0.007024
# 55       RoofStyle_Mansard -0.006853  0.006853
# 54       RoofStyle_Gambrel -0.006686  0.006686
# 56             ScreenPorch  0.006395  0.006395
# 57                HalfBath  0.006382  0.006382
# 58            PavedDrive_Y  0.006249  0.006249
# 59        GarageFinish_RFn -0.006109  0.006109
# 60    Neighborhood_ClearCr  0.006094  0.006094
# 63     Exterior2nd_VinylSd  0.005828  0.005828
# 89           MSSubClass_20  0.005750  0.005750
# 62           EnclosedPorch  0.005745  0.005745
# 61                MoSold_3 -0.005744  0.005744
# 53         log_first_FlrSF  0.005708  0.005708
# 65            BedroomAbvGr -0.005625  0.005625
# 64         Condition1_PosA  0.005544  0.005544
# 74           MSSubClass_85  0.005278  0.005278
# 68    Neighborhood_Blueste  0.005222  0.005222
# 66     Neighborhood_Sawyer  0.005210  0.005210
# 70         LandContour_HLS  0.005054  0.005054
# 67     Exterior1st_VinylSd  0.004990  0.004990
# 71         Condition2_PosA  0.004970  0.004970
# 69               LandSlope -0.004925  0.004925
# 72     Exterior1st_BrkComm  0.004897  0.004897
# 101        BldgType_TwnhsE  0.004797  0.004797
# 73         LandContour_Lvl  0.004682  0.004682
# 75            Heating_Grav -0.004638  0.004638
# 77        Foundation_PConc  0.004576  0.004576
# 76               MoSold_10 -0.004482  0.004482
# 78    Neighborhood_SawyerW -0.004419  0.004419
# 80     Exterior2nd_BrkFace -0.004386  0.004386
# 79        Condition2_Feedr -0.004299  0.004299
# 81          MSSubClass_150 -0.004188  0.004188
# 82     Neighborhood_Greens  0.003864  0.003864
# 83        Utilities_NoSewr -0.003841  0.003841
# 86      GarageType_Basment -0.003834  0.003834
# 85              Fence_MnWw -0.003748  0.003748
# 88   SaleCondition_AdjLand  0.003626  0.003626
# 90    Neighborhood_MeadowV -0.003554  0.003554
# 87                has_pool  0.003528  0.003528
# 93          log_WoodDeckSF  0.003432  0.003432
# 92        Electrical_FuseP  0.003407  0.003407
# 84          MSSubClass_190 -0.003335  0.003335
# 95           LotConfig_FR2 -0.003332  0.003332
# 91             MSZoning_RM -0.003242  0.003242
# 96            Heating_OthW -0.003184  0.003184
# 108    Exterior2nd_Plywood -0.003118  0.003118
# 98            Heating_GasW  0.003090  0.003090
# 97              Alley_Pave  0.003079  0.003079
# 102    Exterior1st_WdShing  0.003033  0.003033
# 100             Alley_None  0.003009  0.003009
# 94                MoSold_8 -0.003000  0.003000
# 99               MoSold_11 -0.002983  0.002983
# 105          LotConfig_FR3 -0.002832  0.002832
# 106          MSSubClass_75  0.002785  0.002785
# 104    Exterior2nd_AsphShn  0.002769  0.002769
# 109     Exterior2nd_Stucco  0.002607  0.002607
# 103               MoSold_2 -0.002570  0.002570
# 107       GarageFinish_Unf -0.002565  0.002565
# 112       RoofMatl_Membran  0.002496  0.002496
# 111     Exterior2nd_CBlock  0.002483  0.002483
# 110       Electrical_SBrkr  0.002411  0.002411
# 113                 YrSold -0.002310  0.002310
# 114               Fence_No -0.002230  0.002230
# 115    Neighborhood_NWAmes -0.002163  0.002163
# 118        Condition1_RRNn  0.002110  0.002110
# 117              ExterCond -0.002104  0.002104
# 116               MoSold_4 -0.001994  0.001994
#
# skewness:  -0.514130562003141
#
# model_importances.shape:  (119, 3)

# %%
keeps = to_keep(lasso11,0.004)

# %%
lasso12 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.0001}
# score:  0.9465640785390124
#
# test score:  0.9133443081261284
# adj_r2:  0.9439559336216835
#
# adj_r2_test:  0.9027796083911426
#
# train RMSE: 0.08864058322693057
#
# test RMSE: 0.11656341096905602
#                  features      coef   abs_val
# 0            bc_GrLivArea  0.137613  0.137613
# 1             OverallQual  0.065622  0.065622
# 2               YearBuilt  0.059305  0.059305
# 3             OverallCond  0.048585  0.048585
# 4              BsmtFinSF1  0.041660  0.041660
# 5             log_LotArea  0.030967  0.030967
# 6    Neighborhood_Somerst  0.028700  0.028700
# 9           GarageType_No  0.025928  0.025928
# 8              GarageCond  0.025601  0.025601
# 7         Condition1_Norm  0.022120  0.022120
# 10        Condition2_PosN -0.021335  0.021335
# 22            MSZoning_RL  0.020041  0.020041
# 13         MSSubClass_160 -0.019974  0.019974
# 12    Exterior1st_BrkFace  0.019301  0.019301
# 11             Functional  0.018359  0.018359
# 17             Fireplaces  0.017920  0.017920
# 14   Neighborhood_Crawfor  0.017615  0.017615
# 15   Neighborhood_StoneBr  0.017603  0.017603
# 16   Neighborhood_NridgHt  0.016993  0.016993
# 25         log_BsmtFinSF1 -0.016655  0.016655
# 18        yeo_TotalBsmtSF  0.016338  0.016338
# 19             GarageCars  0.015332  0.015332
# 20   Neighborhood_GrnHill  0.015105  0.015105
# 24           BsmtFinType1  0.014387  0.014387
# 23   Neighborhood_NoRidge  0.013951  0.013951
# 21  SaleCondition_Partial  0.013860  0.013860
# 26           BsmtExposure  0.013843  0.013843
# 28            KitchenQual  0.013062  0.013062
# 27         yeo_GarageArea  0.012999  0.012999
# 31             BsmtFinSF2  0.012401  0.012401
# 32   Neighborhood_BrkSide  0.012396  0.012396
# 30               BsmtQual  0.011350  0.011350
# 34              ExterQual  0.011220  0.011220
# 33           TotRmsAbvGrd  0.010911  0.010911
# 45           KitchenAbvGr -0.010586  0.010586
# 37       RoofMatl_WdShngl  0.010241  0.010241
# 42        log_LotFrontage  0.010010  0.010010
# 39          MSSubClass_60 -0.009980  0.009980
# 38              HeatingQC  0.009938  0.009938
# 35           YearRemodAdd  0.009846  0.009846
# 29       MSZoning_C (all) -0.009752  0.009752
# 46    Neighborhood_BrDale  0.009279  0.009279
# 36   Neighborhood_Edwards -0.009026  0.009026
# 40        Condition1_PosN  0.008800  0.008800
# 41   SaleCondition_Normal  0.008328  0.008328
# 48           BsmtFullBath  0.007937  0.007937
# 44   SaleCondition_Alloca  0.007887  0.007887
# 47   Neighborhood_NPkVill  0.007850  0.007850
# 49               FullBath  0.007739  0.007739
# 52   SaleCondition_Family -0.007542  0.007542
# 50    Exterior1st_MetalSd  0.006981  0.006981
# 59   Neighborhood_ClearCr  0.006925  0.006925
# 61          MSSubClass_20  0.006847  0.006847
# 65           BedroomAbvGr -0.006787  0.006787
# 56               HalfBath  0.006771  0.006771
# 62          EnclosedPorch  0.006674  0.006674
# 76        LandContour_Lvl  0.006663  0.006663
# 68   Neighborhood_Blueste  0.006531  0.006531
# 55            ScreenPorch  0.006500  0.006500
# 74    Exterior1st_BrkComm  0.006470  0.006470
# 70        LandContour_HLS  0.006087  0.006087
# 73              LandSlope -0.006057  0.006057
# 51           CentralAir_Y  0.006046  0.006046
# 53      RoofStyle_Mansard -0.006003  0.006003
# 57           PavedDrive_Y  0.005947  0.005947
# 69    Neighborhood_Sawyer  0.005890  0.005890
# 58       GarageFinish_RFn -0.005869  0.005869
# 71    Exterior1st_VinylSd  0.005775  0.005775
# 54      RoofStyle_Gambrel -0.005689  0.005689
# 78       Foundation_PConc  0.005666  0.005666
# 63               MoSold_3 -0.005634  0.005634
# 43          MSSubClass_90 -0.005588  0.005588
# 72        Condition2_PosA  0.005587  0.005587
# 83         MSSubClass_150 -0.005567  0.005567
# 67          MSSubClass_85  0.005236  0.005236
# 81    Exterior2nd_BrkFace -0.005133  0.005133
# 82       Condition2_Feedr -0.005062  0.005062
# 60    Exterior2nd_VinylSd  0.005008  0.005008
# 75        BldgType_TwnhsE  0.004908  0.004908
# 66        Condition1_PosA  0.004812  0.004812
# 80   Neighborhood_SawyerW -0.004502  0.004502
# 77           Heating_Grav -0.004438  0.004438
# 64        log_first_FlrSF  0.003698  0.003698
# 79              MoSold_10 -0.003645  0.003645
#
# skewness:  -0.4926978382892749
#
# model_importances.shape:  (84, 3)

# %%
keeps = to_keep(lasso12,0.005)

# %%
lasso13 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.00001,  0.0001,  0.00015, 0.0002, 0.0003, 0.0004, 0.0005, 0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.00015}
# score:  0.9459594886715644
#
# test score:  0.9144542491229921
# adj_r2:  0.9435187475692958
#
# adj_r2_test:  0.9048534310389538
#
# train RMSE: 0.0891406257250764
#
# test RMSE: 0.11581449609158834
#                  features      coef   abs_val
# 0            bc_GrLivArea  0.140215  0.140215
# 1             OverallQual  0.066070  0.066070
# 2               YearBuilt  0.061599  0.061599
# 3             OverallCond  0.048383  0.048383
# 4              BsmtFinSF1  0.041793  0.041793
# 5             log_LotArea  0.030595  0.030595
# 6    Neighborhood_Somerst  0.028934  0.028934
# 8              GarageCond  0.024710  0.024710
# 7           GarageType_No  0.024389  0.024389
# 10        Condition2_PosN -0.021900  0.021900
# 9         Condition1_Norm  0.021764  0.021764
# 13    Exterior1st_BrkFace  0.019490  0.019490
# 12         MSSubClass_160 -0.019489  0.019489
# 11            MSZoning_RL  0.019050  0.019050
# 20        yeo_TotalBsmtSF  0.019009  0.019009
# 15             Fireplaces  0.018497  0.018497
# 14             Functional  0.018321  0.018321
# 16   Neighborhood_Crawfor  0.018125  0.018125
# 17   Neighborhood_StoneBr  0.018090  0.018090
# 18   Neighborhood_NridgHt  0.017803  0.017803
# 19         log_BsmtFinSF1 -0.015668  0.015668
# 22   Neighborhood_GrnHill  0.015491  0.015491
# 21             GarageCars  0.015094  0.015094
# 26           BsmtExposure  0.014581  0.014581
# 25  SaleCondition_Partial  0.014570  0.014570
# 24   Neighborhood_NoRidge  0.014390  0.014390
# 27            KitchenQual  0.013205  0.013205
# 23           BsmtFinType1  0.013184  0.013184
# 28         yeo_GarageArea  0.012896  0.012896
# 29             BsmtFinSF2  0.011976  0.011976
# 30   Neighborhood_BrkSide  0.011968  0.011968
# 37          MSSubClass_60 -0.011526  0.011526
# 33           TotRmsAbvGrd  0.010748  0.010748
# 39           YearRemodAdd  0.010456  0.010456
# 34           KitchenAbvGr -0.010423  0.010423
# 32              ExterQual  0.010269  0.010269
# 35       RoofMatl_WdShngl  0.010159  0.010159
# 40       MSZoning_C (all) -0.009804  0.009804
# 38              HeatingQC  0.009562  0.009562
# 44   SaleCondition_Normal  0.009419  0.009419
# 36        log_LotFrontage  0.009332  0.009332
# 31               BsmtQual  0.009116  0.009116
# 42   Neighborhood_Edwards -0.008805  0.008805
# 43        Condition1_PosN  0.008799  0.008799
# 53           BedroomAbvGr -0.008398  0.008398
# 47   Neighborhood_NPkVill  0.008101  0.008101
# 41    Neighborhood_BrDale  0.008001  0.008001
# 45           BsmtFullBath  0.007781  0.007781
# 46   SaleCondition_Alloca  0.007727  0.007727
# 48               FullBath  0.007394  0.007394
# 62           CentralAir_Y  0.007244  0.007244
# 49   SaleCondition_Family -0.007190  0.007190
# 50    Exterior1st_MetalSd  0.007054  0.007054
# 51   Neighborhood_ClearCr  0.006873  0.006873
# 58            ScreenPorch  0.006772  0.006772
# 72        Condition2_PosA  0.006764  0.006764
# 56        LandContour_Lvl  0.006527  0.006527
# 65    Neighborhood_Sawyer  0.006446  0.006446
# 59    Exterior1st_BrkComm  0.006355  0.006355
# 71          MSSubClass_90 -0.006307  0.006307
# 57   Neighborhood_Blueste  0.006305  0.006305
# 55          EnclosedPorch  0.006162  0.006162
# 61              LandSlope -0.006105  0.006105
# 60        LandContour_HLS  0.006056  0.006056
# 64           PavedDrive_Y  0.006023  0.006023
# 52          MSSubClass_20  0.006014  0.006014
# 66       GarageFinish_RFn -0.005968  0.005968
# 68      RoofStyle_Gambrel -0.005866  0.005866
# 54               HalfBath  0.005774  0.005774
# 77    Exterior2nd_VinylSd  0.005610  0.005610
# 63      RoofStyle_Mansard -0.005606  0.005606
# 73         MSSubClass_150 -0.005516  0.005516
# 69       Foundation_PConc  0.005269  0.005269
# 76       Condition2_Feedr -0.005218  0.005218
# 70               MoSold_3 -0.005110  0.005110
# 67    Exterior1st_VinylSd  0.004935  0.004935
# 74          MSSubClass_85  0.004858  0.004858
# 75    Exterior2nd_BrkFace -0.004610  0.004610
#
# skewness:  -0.47053678554472494
#
# model_importances.shape:  (78, 3)

# %%
keeps = to_keep(lasso13,0.006)

# %%
lasso14 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.00001,  0.0001,  0.00015, 0.0002, 0.0003, 0.0004, 0.0005, 0.001, 0.002, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-05}
# score:  0.943966893434885
#
# test score:  0.9139764204349907
# adj_r2:  0.9418402775445471
#
# adj_r2_test:  0.9059459306877622
#
# train RMSE: 0.09076915741756164
#
# test RMSE: 0.1161374953432063
#                  features      coef   abs_val
# 0            bc_GrLivArea  0.139989  0.139989
# 2               YearBuilt  0.068085  0.068085
# 1             OverallQual  0.064230  0.064230
# 3             OverallCond  0.048111  0.048111
# 4              BsmtFinSF1  0.043873  0.043873
# 5             log_LotArea  0.031706  0.031706
# 6    Neighborhood_Somerst  0.029251  0.029251
# 8           GarageType_No  0.026855  0.026855
# 7              GarageCond  0.024814  0.024814
# 10        Condition1_Norm  0.023243  0.023243
# 9         Condition2_PosN -0.022150  0.022150
# 12         MSSubClass_160 -0.019934  0.019934
# 22             GarageCars  0.018928  0.018928
# 15             Fireplaces  0.018820  0.018820
# 20         log_BsmtFinSF1 -0.018713  0.018713
# 13            MSZoning_RL  0.018575  0.018575
# 17   Neighborhood_Crawfor  0.018275  0.018275
# 16             Functional  0.018019  0.018019
# 19   Neighborhood_NridgHt  0.017976  0.017976
# 18   Neighborhood_StoneBr  0.017609  0.017609
# 14        yeo_TotalBsmtSF  0.016090  0.016090
# 11    Exterior1st_BrkFace  0.015744  0.015744
# 21   Neighborhood_GrnHill  0.015672  0.015672
# 24  SaleCondition_Partial  0.015088  0.015088
# 25   Neighborhood_NoRidge  0.014619  0.014619
# 23           BsmtExposure  0.014345  0.014345
# 27           BsmtFinType1  0.013466  0.013466
# 26            KitchenQual  0.012946  0.012946
# 33           YearRemodAdd  0.012461  0.012461
# 28         yeo_GarageArea  0.012080  0.012080
# 38              HeatingQC  0.012037  0.012037
# 41               BsmtQual  0.012002  0.012002
# 29             BsmtFinSF2  0.011735  0.011735
# 30   Neighborhood_BrkSide  0.011035  0.011035
# 35              ExterQual  0.011007  0.011007
# 32           TotRmsAbvGrd  0.011001  0.011001
# 36       RoofMatl_WdShngl  0.010381  0.010381
# 37       MSZoning_C (all) -0.010316  0.010316
# 40        log_LotFrontage  0.010107  0.010107
# 31          MSSubClass_60 -0.010038  0.010038
# 43        Condition1_PosN  0.009770  0.009770
# 34           KitchenAbvGr -0.009434  0.009434
# 39   SaleCondition_Normal  0.009255  0.009255
# 46    Neighborhood_BrDale  0.008959  0.008959
# 42   Neighborhood_Edwards -0.008789  0.008789
# 45   Neighborhood_NPkVill  0.008272  0.008272
# 47           BsmtFullBath  0.008073  0.008073
# 51   SaleCondition_Family -0.007935  0.007935
# 59          MSSubClass_90 -0.007711  0.007711
# 56        LandContour_Lvl  0.007387  0.007387
# 55        Condition2_PosA  0.007325  0.007325
# 48   SaleCondition_Alloca  0.007112  0.007112
# 50           CentralAir_Y  0.007081  0.007081
# 44           BedroomAbvGr -0.007055  0.007055
# 61          EnclosedPorch  0.006715  0.006715
# 63        LandContour_HLS  0.006401  0.006401
# 57    Neighborhood_Sawyer  0.006231  0.006231
# 60   Neighborhood_Blueste  0.006108  0.006108
# 53   Neighborhood_ClearCr  0.006040  0.006040
# 62              LandSlope -0.005977  0.005977
# 54            ScreenPorch  0.005915  0.005915
# 64           PavedDrive_Y  0.005805  0.005805
# 58    Exterior1st_BrkComm  0.005721  0.005721
# 49               FullBath  0.005108  0.005108
# 52    Exterior1st_MetalSd  0.004983  0.004983
# 65          MSSubClass_20  0.003532  0.003532
#
# skewness:  -0.5633637968777693
#
# model_importances.shape:  (66, 3)

# %%
keeps = to_keep(lasso13,0.006) #change alpha

# %%
lasso15 = regx3(model= Lasso(max_iter=3000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45.50,55,100]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08}
# score:  0.9369069428797295
#
# test score:  0.9066950505410085
# adj_r2:  0.9355136080962128
#
# adj_r2_test:  0.9017374306106262
#
# train RMSE: 0.09631784099408222
#
# test RMSE: 0.12095283203368772
#                  features      coef   abs_val
# 0            bc_GrLivArea  0.136992  0.136992
# 1             OverallQual  0.069634  0.069634
# 2               YearBuilt  0.068179  0.068179
# 3             OverallCond  0.051533  0.051533
# 4              BsmtFinSF1  0.049166  0.049166
# 5             log_LotArea  0.031937  0.031937
# 6              GarageCond  0.028148  0.028148
# 7    Neighborhood_Somerst  0.028047  0.028047
# 8              Fireplaces  0.025168  0.025168
# 9           GarageType_No  0.022775  0.022775
# 10        Condition2_PosN -0.020712  0.020712
# 11            MSZoning_RL  0.019366  0.019366
# 12        Condition1_Norm  0.019229  0.019229
# 13        yeo_TotalBsmtSF  0.018829  0.018829
# 14   Neighborhood_StoneBr  0.018605  0.018605
# 15   Neighborhood_Crawfor  0.018285  0.018285
# 16         log_BsmtFinSF1 -0.018110  0.018110
# 17   Neighborhood_NridgHt  0.017991  0.017991
# 19   Neighborhood_GrnHill  0.015997  0.015997
# 20           BsmtFinType1  0.015910  0.015910
# 18         yeo_GarageArea  0.015901  0.015901
# 22             Functional  0.015481  0.015481
# 21               BsmtQual  0.015462  0.015462
# 23             BsmtFinSF2  0.015124  0.015124
# 24   Neighborhood_NoRidge  0.014504  0.014504
# 25    Exterior1st_BrkFace  0.014342  0.014342
# 26            KitchenQual  0.014141  0.014141
# 27           BsmtExposure  0.013836  0.013836
# 28             GarageCars  0.013742  0.013742
# 29           YearRemodAdd  0.012936  0.012936
# 30              HeatingQC  0.012461  0.012461
# 31         MSSubClass_160 -0.012257  0.012257
# 32       MSZoning_C (all) -0.011368  0.011368
# 33              ExterQual  0.011270  0.011270
# 34   Neighborhood_BrkSide  0.010592  0.010592
# 35       RoofMatl_WdShngl  0.009925  0.009925
# 36  SaleCondition_Partial  0.009001  0.009001
# 37        log_LotFrontage  0.008651  0.008651
# 38          MSSubClass_60 -0.007109  0.007109
#
# skewness:  -0.7785741053272799
#
# model_importances.shape:  (39, 3)

# %%
keeps = to_keep(lasso15,0.007) #change alpha

# %%
lasso15 = regx3(model= Lasso(max_iter=12000),
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-19,1e-18,1e-17,1e-16,1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45.50,55,100]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.534595204893608, tolerance: 0.021744675357153697
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.405422153700214, tolerance: 0.020419507984612877
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.487749560288627, tolerance: 0.021333050454127863
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.802217601687525, tolerance: 0.022045323125517734
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.115483030952172, tolerance: 0.020669068498055863
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.030412896619238, tolerance: 0.021744675357153697
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.858984334118098, tolerance: 0.020419507984612877
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.077422985206511, tolerance: 0.021333050454127863
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.124767133865487, tolerance: 0.022045323125517734
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.014165307189431, tolerance: 0.020669068498055863
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2962247700568073, tolerance: 0.021744675357153697
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.07318488737343, tolerance: 0.020419507984612877
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.1270251168732273, tolerance: 0.021333050454127863
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3437677401555908, tolerance: 0.022045323125517734
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\dgarb\anaconda3_reinstall\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3953875918138388, tolerance: 0.020669068498055863
#   model = cd_fast.enet_coordinate_descent(
# best params:  {'alpha': 1e-08}
# score:  0.9369069428797295
#
# test score:  0.9066950505410085
# adj_r2:  0.9355136080962128
#
# adj_r2_test:  0.9017374306106262
#
# train RMSE: 0.09631784099408222
#
# test RMSE: 0.12095283203368772
#                  features      coef   abs_val
# 0            bc_GrLivArea  0.136992  0.136992
# 1             OverallQual  0.069634  0.069634
# 2               YearBuilt  0.068179  0.068179
# 3             OverallCond  0.051533  0.051533
# 4              BsmtFinSF1  0.049166  0.049166
# 5             log_LotArea  0.031937  0.031937
# 6              GarageCond  0.028148  0.028148
# 7    Neighborhood_Somerst  0.028047  0.028047
# 8              Fireplaces  0.025168  0.025168
# 9           GarageType_No  0.022775  0.022775
# 10        Condition2_PosN -0.020712  0.020712
# 11            MSZoning_RL  0.019366  0.019366
# 12        Condition1_Norm  0.019229  0.019229
# 13        yeo_TotalBsmtSF  0.018829  0.018829
# 14   Neighborhood_StoneBr  0.018605  0.018605
# 15   Neighborhood_Crawfor  0.018285  0.018285
# 16         log_BsmtFinSF1 -0.018110  0.018110
# 17   Neighborhood_NridgHt  0.017991  0.017991
# 19   Neighborhood_GrnHill  0.015997  0.015997
# 20           BsmtFinType1  0.015910  0.015910
# 18         yeo_GarageArea  0.015901  0.015901
# 22             Functional  0.015481  0.015481
# 21               BsmtQual  0.015462  0.015462
# 23             BsmtFinSF2  0.015124  0.015124
# 24   Neighborhood_NoRidge  0.014504  0.014504
# 25    Exterior1st_BrkFace  0.014342  0.014342
# 26            KitchenQual  0.014141  0.014141
# 27           BsmtExposure  0.013836  0.013836
# 28             GarageCars  0.013742  0.013742
# 29           YearRemodAdd  0.012936  0.012936
# 30              HeatingQC  0.012461  0.012461
# 31         MSSubClass_160 -0.012257  0.012257
# 32       MSZoning_C (all) -0.011368  0.011368
# 33              ExterQual  0.011270  0.011270
# 34   Neighborhood_BrkSide  0.010592  0.010592
# 35       RoofMatl_WdShngl  0.009925  0.009925
# 36  SaleCondition_Partial  0.009001  0.009001
# 37        log_LotFrontage  0.008651  0.008651
# 38          MSSubClass_60 -0.007109  0.007109
#
# skewness:  -0.7785741053272799
#
# model_importances.shape:  (39, 3)
