# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
model_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\model_vars_data_n.csv',index_col=0)

test_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\test_vars_data_n.csv',index_col=0)

price_train = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\ny_train.csv',index_col=0)

price_test = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\ny_test.csv',index_col=0)

# %%
model_vars_data = model_vars_data.drop(['MoSold','MSSubClass','LotArea'], axis = 1)
test_vars_data = test_vars_data.drop(['MoSold','MSSubClass','LotArea'], axis = 1) 
#there is a transformed version of LotArea

# %%
combine = pd.concat([price_train, model_vars_data], axis=1)

combine.head()
# Out:
#       SalePrice  LotShape  LandSlope  OverallQual  OverallCond  ExterQual  \
# 1232     162900         4          3            7            5          3
# 2381     133000         4          3            5            7          4
# 810      189000         4          3            7            5          3
# 863      290000         3          3            8            7          4
# 1346     143000         4          3            7            9          3
#
#       ExterCond  BsmtQual  BsmtCond  BsmtExposure  ...  \
# 1232          3         4         3             0  ...
# 2381          3         3         3             0  ...
# 810           3         4         3             0  ...
# 863           3         4         3             0  ...
# 1346          4         3         3             0  ...
#
#       Neighborhood_Mitchel_NPkVill  Neighborhood_NAmes_SWISU_Sawyer  \
# 1232                         False                            False
# 2381                         False                             True
# 810                          False                            False
# 863                          False                            False
# 1346                         False                            False
#
#       Neighborhood_BrkSide_Edwards_Blueste_OldTown_IDOTRR  has_wood_deck   \
# 1232                                              False             False
# 2381                                              False             False
# 810                                               False              True
# 863                                               False              True
# 1346                                               True             False
#
#       has_openporch  has_EnclosedPorch  house_age_  years_since_remodeled_  \
# 1232           True              False          30                      30
# 2381           True              False          60                      59
# 810            True              False          13                      12
# 863            True              False          11                       3
# 1346          False              False          89                      21
#
#       has_basement  has_finsished_basement
# 1232          True                   False
# 2381          True                   False
# 810           True                   False
# 863           True                   False
# 1346          True                   False
#
# [5 rows x 208 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(dataset):
    vif=pd.DataFrame()
    vif['features'] = dataset.columns
    vif['VIF_Value'] = [variance_inflation_factor(dataset.values,i) for i in range(dataset.shape[1])]
    return vif

# %%
df_float = combine.select_dtypes(include=['float64'])
df_vif = calculate_vif(df_float)
df_vif.loc[df_vif['VIF_Value'] >=5,:]
# Out:
#            features    VIF_Value
# 0        BsmtFinSF1   239.505860
# 1        BsmtFinSF2    24.412837
# 2         BsmtUnfSF   303.141997
# 5       GarageYrBlt  1394.160818
# 6        GarageCars    36.588610
# 7      bc_GrLivArea   660.989498
# 8        bc_LotArea    79.880097
# 10  yeo_TotalBsmtSF  1030.022461
# 11  log_first_FlrSF  1688.468711
# 12   yeo_GarageArea    41.322696
# 15  yeo_LotFrontage    35.645838

# %%
pd.set_option('display.max_rows', None)
df = combine[['log_first_FlrSF','BsmtFinSF1', 'BsmtUnfSF',
'BsmtFinSF2','GarageCars','bc_GrLivArea','bc_LotArea','yeo_TotalBsmtSF', 'yeo_GarageArea', 'yeo_LotFrontage' ]]

df_corrs = df.corr() 

print(df_corrs)
# Out:
#                  log_first_FlrSF  BsmtFinSF1  BsmtUnfSF  BsmtFinSF2  \
# log_first_FlrSF         1.000000    0.400854   0.313563    0.092694
# BsmtFinSF1              0.400854    1.000000  -0.475230   -0.064983
# BsmtUnfSF               0.313563   -0.475230   1.000000   -0.259080
# BsmtFinSF2              0.092694   -0.064983  -0.259080    1.000000
# GarageCars              0.444919    0.261327   0.152550   -0.002819
# bc_GrLivArea            0.528854    0.134775   0.271938   -0.031670
# bc_LotArea              0.455276    0.182496   0.070659    0.072624
# yeo_TotalBsmtSF         0.737931    0.501543   0.424382    0.106655
# yeo_GarageArea          0.469515    0.290110   0.128749    0.022924
# yeo_LotFrontage         0.442383    0.188072   0.100447    0.047318
#
#                  GarageCars  bc_GrLivArea  bc_LotArea  yeo_TotalBsmtSF  \
# log_first_FlrSF    0.444919      0.528854    0.455276         0.737931
# BsmtFinSF1         0.261327      0.134775    0.182496         0.501543
# BsmtUnfSF          0.152550      0.271938    0.070659         0.424382
# BsmtFinSF2        -0.002819     -0.031670    0.072624         0.106655
# GarageCars         1.000000      0.493118    0.280202         0.410251
# bc_GrLivArea       0.493118      1.000000    0.369188         0.388146
# bc_LotArea         0.280202      0.369188    1.000000         0.274727
# yeo_TotalBsmtSF    0.410251      0.388146    0.274727         1.000000
# yeo_GarageArea     0.898421      0.458847    0.313090         0.426808
# yeo_LotFrontage    0.300827      0.321635    0.643457         0.299915
#
#                  yeo_GarageArea  yeo_LotFrontage
# log_first_FlrSF        0.469515         0.442383
# BsmtFinSF1             0.290110         0.188072
# BsmtUnfSF              0.128749         0.100447
# BsmtFinSF2             0.022924         0.047318
# GarageCars             0.898421         0.300827
# bc_GrLivArea           0.458847         0.321635
# bc_LotArea             0.313090         0.643457
# yeo_TotalBsmtSF        0.426808         0.299915
# yeo_GarageArea         1.000000         0.326408
# yeo_LotFrontage        0.326408         1.000000

# %%
combine["log_price"] = np.log(combine.SalePrice)

# %%
pd.set_option('display.max_rows', None)

print("look at correlations with target")
df4a = combine[['log_price',
'log_first_FlrSF','BsmtFinSF1', 'BsmtUnfSF',
'BsmtFinSF2','GarageCars','bc_GrLivArea','bc_LotArea','yeo_TotalBsmtSF', 'yeo_GarageArea', 'yeo_LotFrontage'  ]]

corr = df4a.corr()
corr.sort_values(["log_price"], ascending = False, inplace = True)


# type(corr.SalePrice)
# # type(corr)
print(corr.log_price)
# Out:
# look at correlations with target
# log_price          1.000000
# bc_GrLivArea       0.731467
# GarageCars         0.670287
# yeo_GarageArea     0.651880
# yeo_TotalBsmtSF    0.641523
# log_first_FlrSF    0.638339
# BsmtFinSF1         0.441400
# bc_LotArea         0.406382
# yeo_LotFrontage    0.382174
# BsmtUnfSF          0.190230
# BsmtFinSF2         0.016467
# Name: log_price, dtype: float64

# %%
#removed yeo_LotFrontage  BsmtFinSF2           
pd.set_option('display.max_rows', None)
df = combine[[
'GarageCars','bc_GrLivArea','bc_LotArea','yeo_TotalBsmtSF', 'yeo_GarageArea',
    'log_first_FlrSF','BsmtFinSF1', 'BsmtUnfSF'  ]]

df_corrs = df.corr() 

print(df_corrs)
# Out:
#                  GarageCars  bc_GrLivArea  bc_LotArea  yeo_TotalBsmtSF  \
# GarageCars         1.000000      0.493118    0.280202         0.410251
# bc_GrLivArea       0.493118      1.000000    0.369188         0.388146
# bc_LotArea         0.280202      0.369188    1.000000         0.274727
# yeo_TotalBsmtSF    0.410251      0.388146    0.274727         1.000000
# yeo_GarageArea     0.898421      0.458847    0.313090         0.426808
# log_first_FlrSF    0.444919      0.528854    0.455276         0.737931
# BsmtFinSF1         0.261327      0.134775    0.182496         0.501543
# BsmtUnfSF          0.152550      0.271938    0.070659         0.424382
#
#                  yeo_GarageArea  log_first_FlrSF  BsmtFinSF1  BsmtUnfSF
# GarageCars             0.898421         0.444919    0.261327   0.152550
# bc_GrLivArea           0.458847         0.528854    0.134775   0.271938
# bc_LotArea             0.313090         0.455276    0.182496   0.070659
# yeo_TotalBsmtSF        0.426808         0.737931    0.501543   0.424382
# yeo_GarageArea         1.000000         0.469515    0.290110   0.128749
# log_first_FlrSF        0.469515         1.000000    0.400854   0.313563
# BsmtFinSF1             0.290110         0.400854    1.000000  -0.475230
# BsmtUnfSF              0.128749         0.313563   -0.475230   1.000000

# %%
multicollinear = ['GarageCars','bc_GrLivArea','bc_LotArea','yeo_TotalBsmtSF', 'yeo_GarageArea',
    'log_first_FlrSF','BsmtFinSF1', 'BsmtUnfSF','yeo_LotFrontage', 'BsmtFinSF2']

# %%
remove = ['log_first_FlrSF','BsmtFinSF1', 'BsmtUnfSF','yeo_GarageArea','GarageCars','yeo_LotFrontage', 'BsmtFinSF2' ] #remove due to mulicollinearity #drop GarageYrBlt

# %%
remain_set = set(multicollinear) - set(remove)
remain_lst = list(remain_set)

# %%
pd.set_option('display.max_rows', None)
df = combine[remain_lst]

df_corrs = df.corr() 

print(df_corrs)
# Out:
#                  yeo_TotalBsmtSF  bc_GrLivArea  bc_LotArea
# yeo_TotalBsmtSF         1.000000      0.388146    0.274727
# bc_GrLivArea            0.388146      1.000000    0.369188
# bc_LotArea              0.274727      0.369188    1.000000
