# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import GridSearchCV

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
from scipy import stats

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
from regression_function import regx2

# %%
model_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\model_vars_data.csv',index_col=0)

test_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\test_vars_data.csv',index_col=0)

price_train = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\y_train.csv',index_col=0)

price_test = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\y_test.csv',index_col=0)

# %%
def miss_cols(df):
    missing = np.sum(df.isnull(),axis=0)
    
    miss_ind = np.sum(df.isnull(),axis=0) > 0
    
    vals = pd.Series(filter(lambda x: x != 0,missing))
     
    cols_miss = df.columns[miss_ind]

    L=list(zip(cols_miss,vals, round(vals/df.shape[0],4)))
    
    return sorted(L,reverse=True,key=lambda x: x[2])

# %%
model_vars_data.drop(['GarageYrBlt'],axis=1, inplace = True)
miss_cols(model_vars_data)
# Out:
# []

# %%
test_vars_data.drop(['GarageYrBlt'],axis=1, inplace = True)
miss_cols(test_vars_data)
# Out:
# []

# %%
def to_keep(it_lasso, amt):
    keeps1 = it_lasso.loc[it_lasso['abs_val'] > amt,['features']]
    list_keeps1 = list(keeps1.features)
    return list_keeps1

# %%
def regx2(model= None,
x_train = None,
x_test = None,
y_train = None,
y_test = None,
params = None, #put dictionary of params
cv_ = 5,
linear_reg = True,
tree_based = False) :
######################################
#########################################

    features = list(x_train.columns)

    ss = StandardScaler()
    x_train = pd.DataFrame(ss.fit_transform(x_train), columns = features)
    x_test = pd.DataFrame(ss.fit_transform(x_test), columns = features)
    
#     print('train ',x_train.head())
#     print(' ')
#     print('test ', x_test.head())
    
    
    gs = GridSearchCV(model, params, cv=cv_, return_train_score=True, refit=True)
    gs.fit(x_train,y_train)
    gs.best_params_

    model= gs.best_estimator_
    ###################################    

    print('best params: ',gs.best_params_)
    print('score: ',gs.score(x_train,y_train))
    print('  ')
    print('test score: ',gs.score(x_test,y_test))


    if linear_reg:
        adj_r2 = 1-(1-gs.score(x_train,y_train))*(x_train.shape[0] - 1) / (x_train.shape[0] - x_train.shape[1] - 1)
        print('adj_r2: ', adj_r2)
        adj_r2_test = 1-(1-gs.score(x_test,y_test))*(x_test.shape[0] - 1) / (x_test.shape[0] - x_test.shape[1] - 1)
        print('  ')
        print('adj_r2_test: ',adj_r2_test)
        print(' ')


    train_pred = gs.best_estimator_.predict(x_train)
    print('train RMSE: ' + str(mean_squared_error(train_pred,y_train)**0.5))
    print('  ')

    test_pred = gs.best_estimator_.predict(x_test)
    print('test RMSE: ' + str(mean_squared_error(test_pred,y_test)**0.5))

    if linear_reg:

        coefs = pd.Series(gs.best_estimator_.coef_, name = 'coef' )

        varnames = pd.Series(features, name = 'features')

        pd.set_option('display.max_rows', None) # or 1000.

        abs_coefs = pd.Series(np.abs(coefs),name = 'abs_val')

        coefs_ = pd.concat([varnames,coefs, abs_coefs], axis=1)

        #return:
        model_importances = coefs_.sort_values(by=['abs_val'], ascending=False)

        print(model_importances)
        print(' ')

    elif tree_based:
        pd.set_option('display.max_rows', None) # or 1000.

        #return
        varnames = pd.Series(features, name = 'features')

        importances_ = pd.Series(model.feature_importances_, name = 'importances')

        df = pd.concat([varnames,importances_], axis=1)

        model_importances = df.sort_values(by=['importances'], ascending=False)



    #         model_importances = pd.Series(model.feature_importances_, index = features).sort_values(ascending=False)

        print(model_importances)


    if linear_reg:
        residuals = y_train - train_pred
        print('skewness: ',stats.skew(residuals))
        print(' ')
        sns.set_theme(style='darkgrid')
        sns.histplot(residuals, bins=20);
    
    print('model_importances.shape: ',model_importances.shape)
    return model_importances

# %%
ridge1 = regx2(model= Ridge(max_iter=3000),
x_train = model_vars_data,
x_test = test_vars_data,
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# train     bc_GrLivArea  log_LotArea  log_MasVnrArea  yeo_TotalBsmtSF  \
# 0     -0.215765     0.375963       -0.769027        -0.971596
# 1      0.452296     0.124408       -0.769027        -0.622710
# 2      0.044942     0.412749       -0.769027        -0.273138
# 3      1.140404     0.586631        1.590873         2.202585
# 4      0.827245     1.178625        1.512299         1.774612
#
#    log_first_FlrSF  yeo_GarageArea  log_WoodDeckSF  log_OpenPorchSF  has_pool  \
# 0         0.616724       -0.883247        0.651807        -1.075755 -0.057735
# 1        -0.600836       -1.037603       -0.966649         0.752575 -0.057735
# 2         0.459424        4.194637       -0.966649        -1.075755 -0.057735
# 3         1.983224        1.654404        1.257266         0.979041 -0.057735
# 4         1.669775        1.397108        1.440554         1.122517 -0.057735
#
#    log_BsmtFinSF1  ...  MoSold_5  MoSold_6  MoSold_7  MoSold_8  MoSold_9  \
# 0        0.567835  ... -0.411933 -0.453440 -0.427447 -0.285372 -0.229014
# 1        0.490766  ... -0.411933 -0.453440  2.339470 -0.285372 -0.229014
# 2       -1.520197  ... -0.411933  2.205365 -0.427447 -0.285372 -0.229014
# 3       -1.520197  ... -0.411933 -0.453440  2.339470 -0.285372 -0.229014
# 4        0.939524  ... -0.411933 -0.453440 -0.427447 -0.285372 -0.229014
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0              -0.033296             -0.040791             -0.085149
# 1              -0.033296             -0.040791             -0.085149
# 2              -0.033296             -0.040791             -0.085149
# 3              -0.033296             -0.040791             -0.085149
# 4              -0.033296             -0.040791             -0.085149
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0              0.263195              -0.183772
# 1              0.263195              -0.183772
# 2              0.263195              -0.183772
# 3             -3.799460               5.441523
# 4              0.263195              -0.183772
#
# [5 rows x 222 columns]
#
# test     bc_GrLivArea  log_LotArea  log_MasVnrArea  yeo_TotalBsmtSF  \
# 0     -0.921689    -0.156089       -0.827407         0.051203
# 1     -0.713344    -0.605628        0.869084         0.227353
# 2     -0.710612    -0.335802       -0.827407        -0.831047
# 3      0.113578     0.132024        0.810968         1.013158
# 4     -0.306130    -0.168241        1.083423        -0.929996
#
#    log_first_FlrSF  yeo_GarageArea  log_WoodDeckSF  log_OpenPorchSF  has_pool  \
# 0        -0.147351        1.038696        1.188286        -1.041609 -0.062378
# 1         0.069896        0.085040       -0.921267        -1.041609 -0.062378
# 2        -1.462614        0.306927        0.399507        -1.041609 -0.062378
# 3         0.915462        1.913065        1.137155         1.289282 -0.062378
# 4         0.489572        0.306927        0.976622        -1.041609 -0.062378
#
#    log_BsmtFinSF1  ...  MoSold_5  MoSold_6  MoSold_7  MoSold_8  MoSold_9  \
# 0        0.502900  ... -0.387394 -0.492317  2.323079 -0.281954 -0.236505
# 1        0.928932  ...  2.581350 -0.492317 -0.430463 -0.281954 -0.236505
# 2       -1.390843  ... -0.387394 -0.492317 -0.430463 -0.281954 -0.236505
# 3       -1.390843  ... -0.387394 -0.492317 -0.430463 -0.281954 -0.236505
# 4       -1.390843  ... -0.387394 -0.492317 -0.430463 -0.281954 -0.236505
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                    0.0             -0.035968             -0.072075
# 1                    0.0             -0.035968             -0.072075
# 2                    0.0             -0.035968             -0.072075
# 3                    0.0             -0.035968             -0.072075
# 4                    0.0             -0.035968             -0.072075
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0              0.259973              -0.175002
# 1              0.259973              -0.175002
# 2             -3.846546              -0.175002
# 3             -3.846546               5.714208
# 4              0.259973              -0.175002
#
# [5 rows x 222 columns]
# best params:  {'alpha': 100}
# score:  0.9475439740410747
#
# test score:  0.9110335424027615
# adj_r2:  0.9401875383096272
#
# adj_r2_test:  0.8751886175632207
#
# train RMSE: 0.08782408752870607
#
# test RMSE: 0.1181073294802005
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.074199  0.074199
# 24             OverallQual  0.058131  0.058131
# 46             OverallCond  0.041115  0.041115
# 4          log_first_FlrSF  0.038897  0.038897
# 22               YearBuilt  0.034947  0.034947
# 29              BsmtFinSF1  0.032828  0.032828
# 1              log_LotArea  0.028387  0.028387
# 3          yeo_TotalBsmtSF  0.021118  0.021118
# 108        Condition1_Norm  0.020300  0.020300
# 10            log_2ndFlrSF  0.019164  0.019164
# 42              Functional  0.017872  0.017872
# 103   Neighborhood_Somerst  0.017746  0.017746
# 118        Condition2_PosN -0.017535  0.017535
# 5           yeo_GarageArea  0.017200  0.017200
# 40            TotRmsAbvGrd  0.017049  0.017049
# 21              Fireplaces  0.016347  0.016347
# 104   Neighborhood_StoneBr  0.016189  0.016189
# 39             KitchenQual  0.016052  0.016052
# 146    Exterior1st_BrkFace  0.015965  0.015965
# 44              GarageCars  0.015485  0.015485
# 89    Neighborhood_GrnHill  0.015194  0.015194
# 85    Neighborhood_Crawfor  0.015135  0.015135
# 28              GarageCond  0.014463  0.014463
# 34                FullBath  0.014455  0.014455
# 98    Neighborhood_NridgHt  0.014429  0.014429
# 35                BsmtQual  0.014197  0.014197
# 221  SaleCondition_Partial  0.014109  0.014109
# 86    Neighborhood_Edwards -0.013730  0.013730
# 63        MSZoning_C (all) -0.013269  0.013269
# 45               ExterQual  0.013214  0.013214
# 15            YearRemodAdd  0.013180  0.013180
# 17            BsmtExposure  0.013083  0.013083
# 97    Neighborhood_NoRidge  0.012731  0.012731
# 30                HalfBath  0.011708  0.011708
# 14            BsmtFinType1  0.011138  0.011138
# 49          MSSubClass_160 -0.010972  0.010972
# 37               HeatingQC  0.010620  0.010620
# 143       RoofMatl_WdShngl  0.010086  0.010086
# 19           EnclosedPorch  0.009929  0.009929
# 186           CentralAir_Y  0.009774  0.009774
# 196          GarageType_No  0.009544  0.009544
# 177       Foundation_PConc  0.009411  0.009411
# 197        GarageFinish_No  0.009324  0.009324
# 27            BsmtFullBath  0.009125  0.009125
# 18              BsmtFinSF2  0.008479  0.008479
# 220   SaleCondition_Normal  0.008460  0.008460
# 92    Neighborhood_MeadowV -0.008436  0.008436
# 201           PavedDrive_Y  0.008191  0.008191
# 151    Exterior1st_MetalSd  0.008184  0.008184
# 99    Neighborhood_OldTown -0.008165  0.008165
# 170    Exterior2nd_VinylSd  0.007972  0.007972
# 110        Condition1_PosN  0.007945  0.007945
# 219   SaleCondition_Family -0.007677  0.007677
# 9           log_BsmtFinSF1 -0.007453  0.007453
# 11         log_LotFrontage  0.007281  0.007281
# 218   SaleCondition_Alloca  0.007150  0.007150
# 67             MSZoning_RL  0.007136  0.007136
# 136      RoofStyle_Mansard -0.007077  0.007077
# 94      Neighborhood_NAmes -0.006877  0.006877
# 210               MoSold_3 -0.006815  0.006815
# 25             ScreenPorch  0.006802  0.006802
# 134      RoofStyle_Gambrel -0.006669  0.006669
# 156    Exterior1st_Wd Sdng -0.006635  0.006635
# 117        Condition2_PosA  0.006443  0.006443
# 59           MSSubClass_75  0.006414  0.006414
# 102   Neighborhood_SawyerW -0.006315  0.006315
# 198       GarageFinish_RFn -0.006272  0.006272
# 68             MSZoning_RM -0.005979  0.005979
# 109        Condition1_PosA  0.005866  0.005866
# 171    Exterior2nd_Wd Sdng  0.005863  0.005863
# 31               LandSlope -0.005667  0.005667
# 206              MoSold_10 -0.005549  0.005549
# 32             FireplaceQu  0.005174  0.005174
# 205               Fence_No -0.005163  0.005163
# 83    Neighborhood_ClearCr  0.005131  0.005131
# 145    Exterior1st_BrkComm  0.005080  0.005080
# 75        Utilities_NoSewr -0.005033  0.005033
# 96     Neighborhood_NWAmes -0.005030  0.005030
# 199       GarageFinish_Unf -0.004993  0.004993
# 82    Neighborhood_BrkSide  0.004938  0.004938
# 191      GarageType_Attchd  0.004897  0.004897
# 41            KitchenAbvGr -0.004865  0.004865
# 52           MSSubClass_20  0.004844  0.004844
# 182           Heating_GasW  0.004792  0.004792
# 95    Neighborhood_NPkVill  0.004779  0.004779
# 88     Neighborhood_Greens  0.004712  0.004712
# 162    Exterior2nd_CmentBd  0.004710  0.004710
# 8                 has_pool  0.004645  0.004645
# 81     Neighborhood_BrDale  0.004639  0.004639
# 93    Neighborhood_Mitchel -0.004613  0.004613
# 193     GarageType_BuiltIn  0.004512  0.004512
# 155    Exterior1st_VinylSd  0.004495  0.004495
# 72         LandContour_HLS  0.004493  0.004493
# 174        MasVnrType_None  0.004469  0.004469
# 204             Fence_MnWw -0.004401  0.004401
# 74         LandContour_Lvl  0.004333  0.004333
# 130      HouseStyle_2Story  0.004312  0.004312
# 6           log_WoodDeckSF  0.004293  0.004293
# 13       log_EnclosedPorch -0.004244  0.004244
# 178        Foundation_Slab  0.004219  0.004219
# 207              MoSold_11 -0.004170  0.004170
# 158    Exterior2nd_AsphShn  0.004127  0.004127
# 161     Exterior2nd_CBlock  0.004086  0.004086
# 60           MSSubClass_80 -0.004069  0.004069
# 188       Electrical_FuseP  0.004029  0.004029
# 80    Neighborhood_Blueste  0.004024  0.004024
# 116        Condition2_Norm  0.004011  0.004011
# 71              Alley_Pave  0.003924  0.003924
# 62           MSSubClass_90 -0.003898  0.003898
# 123        BldgType_Duplex -0.003898  0.003898
# 58           MSSubClass_70  0.003857  0.003857
# 70              Alley_None  0.003825  0.003825
# 48          MSSubClass_150 -0.003790  0.003790
# 173     MasVnrType_BrkFace  0.003784  0.003784
# 148    Exterior1st_CemntBd -0.003727  0.003727
# 61           MSSubClass_85  0.003710  0.003710
# 56           MSSubClass_50  0.003701  0.003701
# 203            Fence_MnPrv -0.003691  0.003691
# 84    Neighborhood_CollgCr -0.003646  0.003646
# 26              GarageQual  0.003531  0.003531
# 90     Neighborhood_IDOTRR -0.003530  0.003530
# 176      Foundation_CBlock  0.003526  0.003526
# 209               MoSold_2 -0.003461  0.003461
# 183           Heating_Grav -0.003445  0.003445
# 124         BldgType_Twnhs -0.003422  0.003422
# 53           MSSubClass_30 -0.003403  0.003403
# 132        HouseStyle_SLvl  0.003062  0.003062
# 190       Electrical_SBrkr  0.003020  0.003020
# 217  SaleCondition_AdjLand  0.003013  0.003013
# 215               MoSold_8 -0.002984  0.002984
# 57           MSSubClass_60 -0.002945  0.002945
# 169     Exterior2nd_Stucco  0.002874  0.002874
# 78           LotConfig_FR3 -0.002773  0.002773
# 138       RoofMatl_Membran  0.002723  0.002723
# 192     GarageType_Basment -0.002679  0.002679
# 43            BedroomAbvGr -0.002648  0.002648
# 160    Exterior2nd_BrkFace -0.002640  0.002640
# 211               MoSold_4 -0.002631  0.002631
# 184           Heating_OthW -0.002624  0.002624
# 51          MSSubClass_190 -0.002519  0.002519
# 172    Exterior2nd_Wd Shng  0.002508  0.002508
# 128      HouseStyle_2.5Fin -0.002492  0.002492
# 121        Condition2_RRNn  0.002469  0.002469
# 111        Condition1_RRAe -0.002455  0.002455
# 175       MasVnrType_Stone  0.002433  0.002433
# 79        LotConfig_Inside  0.002423  0.002423
# 76       LotConfig_CulDSac  0.002382  0.002382
# 38                  YrSold -0.002361  0.002361
# 64             MSZoning_FV  0.002359  0.002359
# 114        Condition1_RRNn  0.002325  0.002325
# 77           LotConfig_FR2 -0.002306  0.002306
# 149    Exterior1st_HdBoard  0.002283  0.002283
# 144    Exterior1st_AsphShn -0.002257  0.002257
# 87    Neighborhood_Gilbert -0.002195  0.002195
# 33             LotFrontage  0.002147  0.002147
# 115       Condition2_Feedr -0.002087  0.002087
# 7          log_OpenPorchSF  0.002064  0.002064
# 195      GarageType_Detchd  0.001985  0.001985
# 36                LotShape -0.001944  0.001944
# 16               ExterCond -0.001880  0.001880
# 131      HouseStyle_SFoyer  0.001812  0.001812
# 216               MoSold_9 -0.001773  0.001773
# 20            BsmtHalfBath  0.001759  0.001759
# 113        Condition1_RRNe  0.001651  0.001651
# 47                BsmtCond  0.001639  0.001639
# 166    Exterior2nd_Plywood -0.001585  0.001585
# 157    Exterior1st_WdShing  0.001568  0.001568
# 2           log_MasVnrArea  0.001554  0.001554
# 179       Foundation_Stone -0.001542  0.001542
# 212               MoSold_5 -0.001539  0.001539
# 112        Condition1_RRAn  0.001514  0.001514
# 66             MSZoning_RH -0.001509  0.001509
# 65        MSZoning_I (all)  0.001463  0.001463
# 187       Electrical_FuseF -0.001446  0.001446
# 140          RoofMatl_Roll  0.001431  0.001431
# 150    Exterior1st_ImStucc -0.001403  0.001403
# 125        BldgType_TwnhsE  0.001395  0.001395
# 202             Fence_GdWo -0.001263  0.001263
# 154     Exterior1st_Stucco -0.001250  0.001250
# 163    Exterior2nd_HdBoard -0.001129  0.001129
# 185           Heating_Wall  0.001057  0.001057
# 194     GarageType_CarPort -0.001003  0.001003
# 100     Neighborhood_SWISU -0.001001  0.001001
# 181           Heating_GasA  0.000956  0.000956
# 200           PavedDrive_P  0.000954  0.000954
# 69             Street_Pave  0.000950  0.000950
# 133        RoofStyle_Gable -0.000947  0.000947
# 12           log_BsmtUnfSF -0.000933  0.000933
# 147     Exterior1st_CBlock -0.000918  0.000918
# 168      Exterior2nd_Stone  0.000861  0.000861
# 213               MoSold_6 -0.000746  0.000746
# 137         RoofStyle_Shed  0.000720  0.000720
# 50          MSSubClass_180  0.000705  0.000705
# 208              MoSold_12 -0.000684  0.000684
# 23            BsmtFinType2  0.000622  0.000622
# 55           MSSubClass_45 -0.000610  0.000610
# 101    Neighborhood_Sawyer  0.000599  0.000599
# 119        Condition2_RRAe -0.000596  0.000596
# 73         LandContour_Low -0.000590  0.000590
# 164    Exterior2nd_ImStucc  0.000578  0.000578
# 54           MSSubClass_40 -0.000574  0.000574
# 122        BldgType_2fmCon -0.000466  0.000466
# 159    Exterior2nd_Brk Cmn  0.000447  0.000447
# 214               MoSold_7 -0.000434  0.000434
# 142       RoofMatl_WdShake  0.000424  0.000424
# 152    Exterior1st_Plywood -0.000415  0.000415
# 107       Condition1_Feedr -0.000403  0.000403
# 126      HouseStyle_1.5Unf  0.000373  0.000373
# 106   Neighborhood_Veenker  0.000257  0.000257
# 165    Exterior2nd_MetalSd -0.000249  0.000249
# 105    Neighborhood_Timber  0.000223  0.000223
# 91    Neighborhood_Landmrk  0.000218  0.000218
# 135          RoofStyle_Hip  0.000185  0.000185
# 180        Foundation_Wood -0.000184  0.000184
# 127      HouseStyle_1Story -0.000126  0.000126
# 141       RoofMatl_Tar&Grv  0.000087  0.000087
# 120        Condition2_RRAn -0.000070  0.000070
# 129      HouseStyle_2.5Unf -0.000010  0.000010
# 153    Exterior1st_PreCast  0.000000  0.000000
# 167    Exterior2nd_PreCast  0.000000  0.000000
# 139         RoofMatl_Metal  0.000000  0.000000
# 189       Electrical_Mixed  0.000000  0.000000
#
# skewness:  -0.5410040045268689
# model_importances.shape:  (222, 3)

# %%
it1_lasso = regx2(model= Lasso(max_iter=3000),
x_train = model_vars_data,
x_test = test_vars_data,
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# train     bc_GrLivArea  log_LotArea  log_MasVnrArea  yeo_TotalBsmtSF  \
# 0     -0.215765     0.375963       -0.769027        -0.971596
# 1      0.452296     0.124408       -0.769027        -0.622710
# 2      0.044942     0.412749       -0.769027        -0.273138
# 3      1.140404     0.586631        1.590873         2.202585
# 4      0.827245     1.178625        1.512299         1.774612
#
#    log_first_FlrSF  yeo_GarageArea  log_WoodDeckSF  log_OpenPorchSF  has_pool  \
# 0         0.616724       -0.883247        0.651807        -1.075755 -0.057735
# 1        -0.600836       -1.037603       -0.966649         0.752575 -0.057735
# 2         0.459424        4.194637       -0.966649        -1.075755 -0.057735
# 3         1.983224        1.654404        1.257266         0.979041 -0.057735
# 4         1.669775        1.397108        1.440554         1.122517 -0.057735
#
#    log_BsmtFinSF1  ...  MoSold_5  MoSold_6  MoSold_7  MoSold_8  MoSold_9  \
# 0        0.567835  ... -0.411933 -0.453440 -0.427447 -0.285372 -0.229014
# 1        0.490766  ... -0.411933 -0.453440  2.339470 -0.285372 -0.229014
# 2       -1.520197  ... -0.411933  2.205365 -0.427447 -0.285372 -0.229014
# 3       -1.520197  ... -0.411933 -0.453440  2.339470 -0.285372 -0.229014
# 4        0.939524  ... -0.411933 -0.453440 -0.427447 -0.285372 -0.229014
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0              -0.033296             -0.040791             -0.085149
# 1              -0.033296             -0.040791             -0.085149
# 2              -0.033296             -0.040791             -0.085149
# 3              -0.033296             -0.040791             -0.085149
# 4              -0.033296             -0.040791             -0.085149
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0              0.263195              -0.183772
# 1              0.263195              -0.183772
# 2              0.263195              -0.183772
# 3             -3.799460               5.441523
# 4              0.263195              -0.183772
#
# [5 rows x 222 columns]
#
# test     bc_GrLivArea  log_LotArea  log_MasVnrArea  yeo_TotalBsmtSF  \
# 0     -0.921689    -0.156089       -0.827407         0.051203
# 1     -0.713344    -0.605628        0.869084         0.227353
# 2     -0.710612    -0.335802       -0.827407        -0.831047
# 3      0.113578     0.132024        0.810968         1.013158
# 4     -0.306130    -0.168241        1.083423        -0.929996
#
#    log_first_FlrSF  yeo_GarageArea  log_WoodDeckSF  log_OpenPorchSF  has_pool  \
# 0        -0.147351        1.038696        1.188286        -1.041609 -0.062378
# 1         0.069896        0.085040       -0.921267        -1.041609 -0.062378
# 2        -1.462614        0.306927        0.399507        -1.041609 -0.062378
# 3         0.915462        1.913065        1.137155         1.289282 -0.062378
# 4         0.489572        0.306927        0.976622        -1.041609 -0.062378
#
#    log_BsmtFinSF1  ...  MoSold_5  MoSold_6  MoSold_7  MoSold_8  MoSold_9  \
# 0        0.502900  ... -0.387394 -0.492317  2.323079 -0.281954 -0.236505
# 1        0.928932  ...  2.581350 -0.492317 -0.430463 -0.281954 -0.236505
# 2       -1.390843  ... -0.387394 -0.492317 -0.430463 -0.281954 -0.236505
# 3       -1.390843  ... -0.387394 -0.492317 -0.430463 -0.281954 -0.236505
# 4       -1.390843  ... -0.387394 -0.492317 -0.430463 -0.281954 -0.236505
#
#    SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                    0.0             -0.035968             -0.072075
# 1                    0.0             -0.035968             -0.072075
# 2                    0.0             -0.035968             -0.072075
# 3                    0.0             -0.035968             -0.072075
# 4                    0.0             -0.035968             -0.072075
#
#    SaleCondition_Normal  SaleCondition_Partial
# 0              0.259973              -0.175002
# 1              0.259973              -0.175002
# 2             -3.846546              -0.175002
# 3             -3.846546               5.714208
# 4              0.259973              -0.175002
#
# [5 rows x 222 columns]
# best params:  {'alpha': 0.001}
# score:  0.9470479866992151
#
# test score:  0.9140827558257063
# adj_r2:  0.9396219936778795
#
# adj_r2_test:  0.8794663706955916
#
# train RMSE: 0.08823831212478267
#
# test RMSE: 0.1160656932586015
#                   features      coef   abs_val
# 0             bc_GrLivArea  0.129839  0.129839
# 24             OverallQual  0.067738  0.067738
# 22               YearBuilt  0.058440  0.058440
# 46             OverallCond  0.046351  0.046351
# 29              BsmtFinSF1  0.034191  0.034191
# 1              log_LotArea  0.031153  0.031153
# 103   Neighborhood_Somerst  0.023179  0.023179
# 108        Condition1_Norm  0.020334  0.020334
# 118        Condition2_PosN -0.019452  0.019452
# 42              Functional  0.017831  0.017831
# 21              Fireplaces  0.017801  0.017801
# 85    Neighborhood_Crawfor  0.017074  0.017074
# 98    Neighborhood_NridgHt  0.016328  0.016328
# 104   Neighborhood_StoneBr  0.016123  0.016123
# 3          yeo_TotalBsmtSF  0.015802  0.015802
# 146    Exterior1st_BrkFace  0.015118  0.015118
# 89    Neighborhood_GrnHill  0.014610  0.014610
# 44              GarageCars  0.014421  0.014421
# 5           yeo_GarageArea  0.014316  0.014316
# 39             KitchenQual  0.013791  0.013791
# 17            BsmtExposure  0.013309  0.013309
# 97    Neighborhood_NoRidge  0.012707  0.012707
# 221  SaleCondition_Partial  0.012381  0.012381
# 4          log_first_FlrSF  0.012174  0.012174
# 49          MSSubClass_160 -0.012089  0.012089
# 15            YearRemodAdd  0.011776  0.011776
# 35                BsmtQual  0.011768  0.011768
# 67             MSZoning_RL  0.011650  0.011650
# 63        MSZoning_C (all) -0.011593  0.011593
# 45               ExterQual  0.010904  0.010904
# 86    Neighborhood_Edwards -0.009931  0.009931
# 37               HeatingQC  0.009139  0.009139
# 143       RoofMatl_WdShngl  0.009010  0.009010
# 18              BsmtFinSF2  0.008855  0.008855
# 82    Neighborhood_BrkSide  0.008797  0.008797
# 27            BsmtFullBath  0.008123  0.008123
# 186           CentralAir_Y  0.007863  0.007863
# 219   SaleCondition_Family -0.007560  0.007560
# 196          GarageType_No  0.007560  0.007560
# 110        Condition1_PosN  0.007453  0.007453
# 40            TotRmsAbvGrd  0.007221  0.007221
# 41            KitchenAbvGr -0.007094  0.007094
# 170    Exterior2nd_VinylSd  0.007089  0.007089
# 28              GarageCond  0.006991  0.006991
# 201           PavedDrive_Y  0.005972  0.005972
# 220   SaleCondition_Normal  0.005822  0.005822
# 136      RoofStyle_Mansard -0.005724  0.005724
# 62           MSSubClass_90 -0.005689  0.005689
# 25             ScreenPorch  0.005487  0.005487
# 218   SaleCondition_Alloca  0.005338  0.005338
# 92    Neighborhood_MeadowV -0.005226  0.005226
# 34                FullBath  0.005213  0.005213
# 14            BsmtFinType1  0.005020  0.005020
# 117        Condition2_PosA  0.004996  0.004996
# 11         log_LotFrontage  0.004916  0.004916
# 83    Neighborhood_ClearCr  0.004903  0.004903
# 19           EnclosedPorch  0.004886  0.004886
# 134      RoofStyle_Gambrel -0.004682  0.004682
# 198       GarageFinish_RFn -0.004664  0.004664
# 210               MoSold_3 -0.004649  0.004649
# 57           MSSubClass_60 -0.004624  0.004624
# 95    Neighborhood_NPkVill  0.004573  0.004573
# 177       Foundation_PConc  0.004543  0.004543
# 102   Neighborhood_SawyerW -0.004452  0.004452
# 30                HalfBath  0.004111  0.004111
# 61           MSSubClass_85  0.004066  0.004066
# 109        Condition1_PosA  0.003980  0.003980
# 68             MSZoning_RM -0.003877  0.003877
# 145    Exterior1st_BrkComm  0.003858  0.003858
# 8                 has_pool  0.003783  0.003783
# 31               LandSlope -0.003777  0.003777
# 206              MoSold_10 -0.003773  0.003773
# 75        Utilities_NoSewr -0.003578  0.003578
# 101    Neighborhood_Sawyer  0.003542  0.003542
# 80    Neighborhood_Blueste  0.003408  0.003408
# 6           log_WoodDeckSF  0.003370  0.003370
# 192     GarageType_Basment -0.003370  0.003370
# 183           Heating_Grav -0.003310  0.003310
# 182           Heating_GasW  0.003299  0.003299
# 151    Exterior1st_MetalSd  0.003274  0.003274
# 52           MSSubClass_20  0.003098  0.003098
# 115       Condition2_Feedr -0.003033  0.003033
# 88     Neighborhood_Greens  0.002972  0.002972
# 48          MSSubClass_150 -0.002933  0.002933
# 43            BedroomAbvGr -0.002884  0.002884
# 184           Heating_OthW -0.002835  0.002835
# 204             Fence_MnWw -0.002796  0.002796
# 166    Exterior2nd_Plywood -0.002731  0.002731
# 72         LandContour_HLS  0.002680  0.002680
# 81     Neighborhood_BrDale  0.002643  0.002643
# 51          MSSubClass_190 -0.002462  0.002462
# 77           LotConfig_FR2 -0.002282  0.002282
# 207              MoSold_11 -0.002282  0.002282
# 59           MSSubClass_75  0.002228  0.002228
# 156    Exterior1st_Wd Sdng -0.002224  0.002224
# 160    Exterior2nd_BrkFace -0.002195  0.002195
# 33             LotFrontage  0.002010  0.002010
# 96     Neighborhood_NWAmes -0.002008  0.002008
# 188       Electrical_FuseP  0.001955  0.001955
# 199       GarageFinish_Unf -0.001934  0.001934
# 138       RoofMatl_Membran  0.001667  0.001667
# 190       Electrical_SBrkr  0.001643  0.001643
# 217  SaleCondition_AdjLand  0.001582  0.001582
# 74         LandContour_Lvl  0.001576  0.001576
# 215               MoSold_8 -0.001546  0.001546
# 99    Neighborhood_OldTown -0.001515  0.001515
# 93    Neighborhood_Mitchel -0.001503  0.001503
# 158    Exterior2nd_AsphShn  0.001490  0.001490
# 161     Exterior2nd_CBlock  0.001489  0.001489
# 78           LotConfig_FR3 -0.001450  0.001450
# 111        Condition1_RRAe -0.001431  0.001431
# 125        BldgType_TwnhsE  0.001415  0.001415
# 124         BldgType_Twnhs -0.001268  0.001268
# 38                  YrSold -0.001145  0.001145
# 70              Alley_None  0.001042  0.001042
# 211               MoSold_4 -0.001015  0.001015
# 121        Condition2_RRNn  0.001005  0.001005
# 209               MoSold_2 -0.001003  0.001003
# 79        LotConfig_Inside  0.000992  0.000992
# 123        BldgType_Duplex -0.000981  0.000981
# 169     Exterior2nd_Stucco  0.000951  0.000951
# 157    Exterior1st_WdShing  0.000940  0.000940
# 20            BsmtHalfBath  0.000933  0.000933
# 155    Exterior1st_VinylSd  0.000901  0.000901
# 32             FireplaceQu  0.000828  0.000828
# 60           MSSubClass_80 -0.000818  0.000818
# 213               MoSold_6  0.000758  0.000758
# 9           log_BsmtFinSF1 -0.000756  0.000756
# 185           Heating_Wall  0.000724  0.000724
# 71              Alley_Pave  0.000552  0.000552
# 205               Fence_No -0.000526  0.000526
# 84    Neighborhood_CollgCr -0.000486  0.000486
# 114        Condition1_RRNn  0.000453  0.000453
# 216               MoSold_9 -0.000451  0.000451
# 76       LotConfig_CulDSac  0.000402  0.000402
# 16               ExterCond -0.000396  0.000396
# 105    Neighborhood_Timber  0.000388  0.000388
# 113        Condition1_RRNe  0.000385  0.000385
# 150    Exterior1st_ImStucc -0.000344  0.000344
# 66             MSZoning_RH -0.000279  0.000279
# 147     Exterior1st_CBlock -0.000254  0.000254
# 179       Foundation_Stone -0.000254  0.000254
# 120        Condition2_RRAn -0.000228  0.000228
# 142       RoofMatl_WdShake  0.000147  0.000147
# 172    Exterior2nd_Wd Shng  0.000144  0.000144
# 214               MoSold_7  0.000081  0.000081
# 187       Electrical_FuseF -0.000073  0.000073
# 212               MoSold_5  0.000064  0.000064
# 171    Exterior2nd_Wd Sdng  0.000000  0.000000
# 174        MasVnrType_None  0.000000  0.000000
# 173     MasVnrType_BrkFace  0.000000  0.000000
# 175       MasVnrType_Stone -0.000000  0.000000
# 202             Fence_GdWo  0.000000  0.000000
# 176      Foundation_CBlock  0.000000  0.000000
# 178        Foundation_Slab  0.000000  0.000000
# 180        Foundation_Wood -0.000000  0.000000
# 181           Heating_GasA -0.000000  0.000000
# 168      Exterior2nd_Stone  0.000000  0.000000
# 191      GarageType_Attchd  0.000000  0.000000
# 193     GarageType_BuiltIn  0.000000  0.000000
# 194     GarageType_CarPort -0.000000  0.000000
# 195      GarageType_Detchd -0.000000  0.000000
# 203            Fence_MnPrv -0.000000  0.000000
# 197        GarageFinish_No  0.000000  0.000000
# 208              MoSold_12  0.000000  0.000000
# 200           PavedDrive_P  0.000000  0.000000
# 189       Electrical_Mixed  0.000000  0.000000
# 23            BsmtFinType2  0.000000  0.000000
# 167    Exterior2nd_PreCast  0.000000  0.000000
# 73         LandContour_Low -0.000000  0.000000
# 7          log_OpenPorchSF  0.000000  0.000000
# 107       Condition1_Feedr  0.000000  0.000000
# 106   Neighborhood_Veenker -0.000000  0.000000
# 100     Neighborhood_SWISU  0.000000  0.000000
# 10            log_2ndFlrSF  0.000000  0.000000
# 94      Neighborhood_NAmes -0.000000  0.000000
# 91    Neighborhood_Landmrk  0.000000  0.000000
# 90     Neighborhood_IDOTRR -0.000000  0.000000
# 12           log_BsmtUnfSF  0.000000  0.000000
# 87    Neighborhood_Gilbert  0.000000  0.000000
# 13       log_EnclosedPorch -0.000000  0.000000
# 69             Street_Pave  0.000000  0.000000
# 165    Exterior2nd_MetalSd  0.000000  0.000000
# 65        MSZoning_I (all)  0.000000  0.000000
# 64             MSZoning_FV  0.000000  0.000000
# 58           MSSubClass_70  0.000000  0.000000
# 56           MSSubClass_50  0.000000  0.000000
# 55           MSSubClass_45  0.000000  0.000000
# 54           MSSubClass_40 -0.000000  0.000000
# 53           MSSubClass_30 -0.000000  0.000000
# 50          MSSubClass_180  0.000000  0.000000
# 47                BsmtCond  0.000000  0.000000
# 36                LotShape -0.000000  0.000000
# 26              GarageQual  0.000000  0.000000
# 112        Condition1_RRAn  0.000000  0.000000
# 116        Condition2_Norm  0.000000  0.000000
# 119        Condition2_RRAe -0.000000  0.000000
# 126      HouseStyle_1.5Unf  0.000000  0.000000
# 164    Exterior2nd_ImStucc -0.000000  0.000000
# 163    Exterior2nd_HdBoard -0.000000  0.000000
# 162    Exterior2nd_CmentBd -0.000000  0.000000
# 159    Exterior2nd_Brk Cmn  0.000000  0.000000
# 154     Exterior1st_Stucco  0.000000  0.000000
# 153    Exterior1st_PreCast  0.000000  0.000000
# 152    Exterior1st_Plywood -0.000000  0.000000
# 149    Exterior1st_HdBoard -0.000000  0.000000
# 148    Exterior1st_CemntBd -0.000000  0.000000
# 2           log_MasVnrArea -0.000000  0.000000
# 144    Exterior1st_AsphShn -0.000000  0.000000
# 141       RoofMatl_Tar&Grv  0.000000  0.000000
# 140          RoofMatl_Roll  0.000000  0.000000
# 139         RoofMatl_Metal  0.000000  0.000000
# 137         RoofStyle_Shed -0.000000  0.000000
# 135          RoofStyle_Hip  0.000000  0.000000
# 133        RoofStyle_Gable -0.000000  0.000000
# 132        HouseStyle_SLvl -0.000000  0.000000
# 131      HouseStyle_SFoyer  0.000000  0.000000
# 130      HouseStyle_2Story -0.000000  0.000000
# 129      HouseStyle_2.5Unf  0.000000  0.000000
# 128      HouseStyle_2.5Fin -0.000000  0.000000
# 127      HouseStyle_1Story  0.000000  0.000000
# 122        BldgType_2fmCon -0.000000  0.000000
#
# skewness:  -0.6260191324878509
# model_importances.shape:  (222, 3)
