# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import GridSearchCV

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
from scipy import stats
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
model_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\model_vars_data_n.csv',index_col=0)

test_vars_data = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\test_vars_data_n.csv',index_col=0)

price_train = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\ny_train.csv',index_col=0)

price_test = pd.read_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\data\ny_test.csv',index_col=0)

# %%
# MSSubClass
# MoSold

# %%
model_vars_data['MoSold']
# Out:
# 1232     3
# 2381     9
# 810      6
# 863      4
# 1346     7
# 367     10
# 377      6
# 316      8
# 1212     7
# 1751     5
# 868      9
# 1250     4
# 1445    12
# 899      7
# 1912     7
# 88      10
# 1166     2
# 1924     6
# 1522     9
# 144      4
# 65       2
# 908     10
# 2540     4
# 2062     7
# 1086     4
# 530      7
# 1668     8
# 1201     5
# 2419     4
# 78       3
# 1515     9
# 401      7
# 1297     5
# 268      8
# 2082     8
# 1584     3
# 244      8
# 735      5
# 2154     1
# 2490     3
# 932      7
# 1263     9
# 814      9
# 1807     8
# 845      6
# 389     12
# 1768     2
# 1976     5
# 1446     7
# 898      3
# 2288     4
# 2296     9
# 1303     8
# 500      7
# 107      5
# 1647     5
# 86       7
# 206      8
# 16       1
# 483      5
# 1540    10
# 120      5
# 1928     7
# 1781     6
# 2233     3
# 511      3
# 1281     6
# 715      6
# 1841     6
# 2141     6
# 666      4
# 1799     5
# 2234     5
# 645      2
# 954      3
# 1165     5
# 1188     2
# 1100     4
# 611      6
# 2294     4
# 2374     2
# 994      8
# 1244     6
# 841      6
# 808      6
# 1553     3
# 806      7
# 940     11
# 1389     8
# 317      8
# 750      3
# 191      5
# 304      3
# 2095     4
# 1043    10
# 790      3
# 2460     1
# 1963     5
# 2555     7
# 423      7
# 525     12
# 1340    11
# 1964     4
# 1235     8
# 575      7
# 300      7
# 1730     4
# 1347     6
# 1344     7
# 1128     6
# 583      2
# 2572     7
# 2560     6
# 2058     7
# 2437     7
# 2398     6
# 147      9
# 2136     4
# 2320     6
# 266      5
# 821      2
# 796      8
# 848      9
# 1230     5
# 2173     7
# 2020     6
# 1592    12
# 2427     4
# 1283     7
# 2179    10
# 1295     6
# 2303     4
# 1021     6
# 2494     5
# 301      3
# 2053     7
# 1846     7
# 1020     6
# 555     11
# 2127     7
# 929      5
# 2407     6
# 2269     8
# 2006     2
# 1156     6
# 2425     7
# 1353     4
# 368      4
# 142      6
# 631      7
# 1803     5
# 35       5
# 1908     6
# 2121    10
# 1790     4
# 384      7
# 1787     4
# 1081     4
# 2054     9
# 2268     1
# 2230    10
# 1216     7
# 238      4
# 851      7
# 1679     6
# Name: MoSold, dtype: int64

# %%
# Fucntion returns dictionary

def regx3(
model=  None,
x_train = None,
x_test = None,
y_train = None,
y_test =  None,
params = None,
cv_ = 5,
linear_reg = True,
tree_based = False):
######################################
#########################################

    features = list(x_train.columns)

    ss = StandardScaler()
    x_train = pd.DataFrame(ss.fit_transform(x_train), columns = features)
    x_test = pd.DataFrame(ss.fit_transform(x_test), columns = features)

    #     print('train ',x_train.head())
    #     print(' ')
    #     print('test ', x_test.head())


    gs = GridSearchCV(model, params, cv=cv_, return_train_score=True, refit=True)
    gs.fit(x_train,y_train)
    gs.best_params_

    reg_dict = {}
    model= gs.best_estimator_
    reg_dict['mod'] = model
    ###################################    

    print('best params: ',gs.best_params_)
    reg_dict['best params'] = gs.best_params_

    print('score: ',gs.score(x_train,y_train))
    reg_dict['score'] = gs.score(x_train,y_train)

    print('  ')
    print('test score: ',gs.score(x_test,y_test))
    reg_dict['test score'] = gs.score(x_test,y_test)

    if linear_reg:
        adj_r2 = 1-(1-gs.score(x_train,y_train))*(x_train.shape[0] - 1) / (x_train.shape[0] - x_train.shape[1] - 1)
        print('adj_r2: ', adj_r2)
        reg_dict['adj_r2'] = adj_r2

        adj_r2_test = 1-(1-gs.score(x_test,y_test))*(x_test.shape[0] - 1) / (x_test.shape[0] - x_test.shape[1] - 1)
        print('  ')
        print('adj_r2_test: ',adj_r2_test)
        reg_dict['adj_r2_test'] = adj_r2_test

        print(' ')

    train_pred = gs.best_estimator_.predict(x_train)
    print('train RMSE: ' + str(mean_squared_error(train_pred,y_train)**0.5))
    print('  ')
    reg_dict['train RMSE'] = mean_squared_error(train_pred,y_train)**0.5

    test_pred = gs.best_estimator_.predict(x_test)
    print('test RMSE: ' + str(mean_squared_error(test_pred,y_test)**0.5))
    ###
    reg_dict['test RMSE'] = mean_squared_error(test_pred,y_test)**0.5

    if linear_reg:

        coefs = pd.Series(gs.best_estimator_.coef_, name = 'coef' )

        varnames = pd.Series(features, name = 'features')

        pd.set_option('display.max_rows', None) # or 1000.

        abs_coefs = pd.Series(np.abs(coefs),name = 'abs_val')

        coefs_ = pd.concat([varnames,coefs, abs_coefs], axis=1)

        #return:
        model_importances = coefs_.sort_values(by=['abs_val'], ascending=False)
        model_importances.index=(range(model_importances.shape[0]))
        model_importances
        reg_dict['model_importances'] = model_importances

        print(model_importances)
        print(' ')

    elif tree_based:
        pd.set_option('display.max_rows', None) # or 1000.

        #return
        varnames = pd.Series(features, name = 'features')

        importances_ = pd.Series(model.feature_importances_, name = 'importances')

        df = pd.concat([varnames,importances_], axis=1)

        model_importances = df.sort_values(by=['importances'], ascending=False)

        model_importances.index=(range(model_importances.shape[0]))

        reg_dict['model_importances'] = model_importances



    #         model_importances = pd.Series(model.feature_importances_, index = features).sort_values(ascending=False)

        print(model_importances)


    if linear_reg:
        residuals = y_train - train_pred
        print('skewness: ',stats.skew(residuals))
        print(' ')
        sns.set_theme(style='darkgrid')
        sns.histplot(residuals, bins=20);

    print('model_importances.shape: ',model_importances.shape)
    
    return reg_dict

# %%
def to_keep(mod, amt):
    mod = mod['model_importances']
    keeps1 = mod.loc[mod['abs_val'] > amt,['features']]
    list_keeps1 = list(keeps1.features)
    return list_keeps1

# %%
elas1 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data,
x_test = test_vars_data,
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.9515858667400429
#
# test score:  0.9261959575269095
# adj_r2:  0.9451224414478681
#
# adj_r2_test:  0.898219695939637
#
# train RMSE: 0.08305439467648044
#
# test RMSE: 0.10125008792633103
#                                               features      coef   abs_val
# 0                                         bc_GrLivArea  0.097538  0.097538
# 1                                           BsmtFinSF1  0.089108  0.089108
# 2                                          OverallQual  0.060374  0.060374
# 3                                            BsmtUnfSF  0.053855  0.053855
# 4                                          OverallCond  0.047998  0.047998
# 5                                           house_age_ -0.038773  0.038773
# 6                                             2ndFlrSF  0.038427  0.038427
# 7                                           BsmtFinSF2  0.035822  0.035822
# 8                                           bc_LotArea  0.032298  0.032298
# 9                                          MSZoning_RM -0.029576  0.029576
# 10                                          GarageCars  0.027730  0.027730
# 11        Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.026862  0.026862
# 12                                     Condition1_Norm  0.024672  0.024672
# 13                                     log_first_FlrSF  0.021824  0.021824
# 14                                          GarageCond  0.018422  0.018422
# 15                                          Functional  0.017615  0.017615
# 16                                         MSZoning_RL -0.017059  0.017059
# 17                               SaleCondition_Partial  0.016827  0.016827
# 18                         Neighborhood_Somerst_Timber  0.015892  0.015892
# 19                                 Exterior1st_BrkFace  0.015137  0.015137
# 20                Neighborhood_ClearCr_CollgCr_Crawfor  0.014909  0.014909
# 21                                   HouseStyle_1Story  0.014222  0.014222
# 22                                     yeo_TotalBsmtSF -0.013207  0.013207
# 23                                       GarageType_No  0.012949  0.012949
# 24                              has_finsished_basement -0.012536  0.012536
# 25                                         KitchenQual  0.012418  0.012418
# 26                                    Foundation_PConc  0.012179  0.012179
# 27                                SaleCondition_Family -0.012003  0.012003
# 28                                           HeatingQC  0.011718  0.011718
# 29                                     Condition1_PosN  0.011619  0.011619
# 30                                     LandContour_HLS  0.011136  0.011136
# 31                                        BsmtExposure  0.011006  0.011006
# 32                                          Fireplaces  0.010767  0.010767
# 33                                        KitchenAbvGr -0.010379  0.010379
# 34                                  Exterior2nd_CBlock  0.009698  0.009698
# 35                                         MSZoning_RH -0.009650  0.009650
# 36                                     log_OpenPorchSF  0.009331  0.009331
# 37                                         ScreenPorch  0.009061  0.009061
# 38                                        BsmtFullBath  0.008709  0.008709
# 39                                        BedroomAbvGr -0.008418  0.008418
# 40                                     GarageFinish_No  0.008354  0.008354
# 41                                     Condition1_PosA  0.008327  0.008327
# 100                                Exterior2nd_AsphShn  0.002775  0.002775
# 101                                    LandContour_Lvl  0.002771  0.002771
# 102                                    Condition1_RRNn  0.002650  0.002650
# 103                                     MSSubClass_180 -0.002603  0.002603
# 104                                    Condition2_PosA  0.002599  0.002599
# 105                                   LotConfig_Inside  0.002586  0.002586
# 106                               SaleCondition_Alloca  0.002561  0.002561
# 107                                  HouseStyle_2.5Fin -0.002408  0.002408
# 108                                Exterior2nd_Wd Sdng  0.002385  0.002385
# 109                                   RoofMatl_Membran  0.002297  0.002297
# 110                                      LotConfig_FR2 -0.002288  0.002288
# 111                                             MoSold -0.002173  0.002173
# 112                                Exterior2nd_BrkFace -0.002111  0.002111
# 113                                           MoSold_6  0.002032  0.002032
# 114                                        Street_Pave  0.001999  0.001999
# 115                                Exterior2nd_Plywood -0.001992  0.001992
# 116                                      LotConfig_FR3 -0.001950  0.001950
# 117                                    LandContour_Low  0.001926  0.001926
# 118                                    Condition2_Norm -0.001892  0.001892
# 119                                         MSSubClass -0.001831  0.001831
# 120                                           FullBath  0.001711  0.001711
# 121                              SaleCondition_AdjLand  0.001580  0.001580
# 122                                Exterior1st_Plywood -0.001562  0.001562
# 123                                  log_EnclosedPorch  0.001461  0.001461
# 124                                       BsmtHalfBath  0.001428  0.001428
# 125                                 GarageType_BuiltIn  0.001423  0.001423
# 126                                    Condition2_RRAn -0.001419  0.001419
# 127                                        GarageYrBlt  0.001379  0.001379
# 128                                      MSSubClass_40 -0.001363  0.001363
# 129                                Exterior1st_HdBoard  0.001319  0.001319
# 130                                  HouseStyle_2.5Unf  0.001296  0.001296
# 131                                         Fence_MnWw -0.001284  0.001284
# 132                                  RoofStyle_Gambrel -0.001276  0.001276
# 133                                     MSSubClass_190 -0.001253  0.001253
# 134                                    Condition1_RRNe  0.001246  0.001246
# 135                                  Exterior2nd_Stone -0.001243  0.001243
# 136                                     RoofStyle_Shed  0.001146  0.001146
# 137                                           Fence_No -0.001076  0.001076
# 138                                Exterior2nd_CmentBd  0.001073  0.001073
# 139                                   Electrical_FuseF -0.000980  0.000980
# 140                                Exterior1st_WdShing -0.000951  0.000951
# 141                                Exterior2nd_HdBoard  0.000951  0.000951
# 142                                           MoSold_8  0.000939  0.000939
# 143                                          MoSold_10 -0.000935  0.000935
# 144                                    Condition1_RRAe  0.000828  0.000828
# 145                                            MiscVal -0.000709  0.000709
# 146                                      MSSubClass_60 -0.000600  0.000600
# 147                                        Fence_MnPrv  0.000591  0.000591
# 148                                          MoSold_11 -0.000591  0.000591
# 149                                  GarageType_Detchd  0.000584  0.000584
# 150                                   RoofMatl_Tar&Grv  0.000488  0.000488
# 151                                 Exterior2nd_Stucco -0.000471  0.000471
# 152                                           MoSold_4 -0.000443  0.000443
# 153                                           LotShape  0.000385  0.000385
# 154                                  LotConfig_CulDSac  0.000376  0.000376
# 155                                          LandSlope -0.000351  0.000351
# 156                                       BsmtFinType1  0.000290  0.000290
# 157                                Exterior2nd_PreCast  0.000242  0.000242
# 158                                       PavedDrive_P -0.000211  0.000211
# 159                                           MoSold_5 -0.000205  0.000205
# 160                                 GarageType_Basment -0.000190  0.000190
# 161                                    has_miscfeature  0.000185  0.000185
# 162                                      MSSubClass_20  0.000158  0.000158
# 163                                    Condition2_RRNn  0.000135  0.000135
# 164                                Exterior1st_BrkComm  0.000130  0.000130
# 165                                   Electrical_FuseP -0.000062  0.000062
# 166                                      MSSubClass_45  0.000062  0.000062
# 167                                            LotArea -0.000051  0.000051
# 168                                Exterior1st_AsphShn  0.000027  0.000027
# 169                                    MasVnrType_None  0.000021  0.000021
# 170                                    BldgType_2fmCon -0.000000  0.000000
# 171                                Exterior2nd_ImStucc  0.000000  0.000000
# 172                                 MasVnrType_BrkFace -0.000000  0.000000
# 173                                    yeo_LotFrontage -0.000000  0.000000
# 174                                Exterior2nd_Wd Shng  0.000000  0.000000
# 175                                Exterior1st_CemntBd -0.000000  0.000000
# 176                                Exterior2nd_MetalSd -0.000000  0.000000
# 177                        Neighborhood_Gilbert_NWAmes -0.000000  0.000000
# 178                                       LowQualFinSF -0.000000  0.000000
# 179                    Neighborhood_NAmes_SWISU_Sawyer -0.000000  0.000000
# 180                                Exterior1st_ImStucc  0.000000  0.000000
# 181                                     has_wood_deck   0.000000  0.000000
# 182                                           BsmtCond -0.000000  0.000000
# 183                                  has_EnclosedPorch  0.000000  0.000000
# 184                                          ExterCond -0.000000  0.000000
# 185                                 Exterior1st_Stucco  0.000000  0.000000
# 186                                Exterior1st_VinylSd  0.000000  0.000000
# 187                                  Foundation_CBlock -0.000000  0.000000
# 188                                   RoofMatl_WdShake  0.000000  0.000000
# 189                                    BldgType_Duplex -0.000000  0.000000
# 190                                    RoofStyle_Gable  0.000000  0.000000
# 191                                         Fence_GdWo -0.000000  0.000000
# 192                                    BldgType_TwnhsE -0.000000  0.000000
# 193                                 GarageType_CarPort  0.000000  0.000000
# 194                                  GarageType_Attchd -0.000000  0.000000
# 195                                  HouseStyle_2Story -0.000000  0.000000
# 196                                   Electrical_Mixed  0.000000  0.000000
# 197                                          MoSold_12 -0.000000  0.000000
# 198                                           MoSold_2 -0.000000  0.000000
# 199                                      RoofStyle_Hip  0.000000  0.000000
# 200                                      MSSubClass_80 -0.000000  0.000000
# 201                                    Condition2_RRAe  0.000000  0.000000
# 202                                    Condition2_PosN -0.000000  0.000000
# 203                                       Heating_GasW  0.000000  0.000000
# 204                                           MoSold_9 -0.000000  0.000000
# 205                                       Heating_GasA  0.000000  0.000000
# 206                                     RoofMatl_Metal  0.000000  0.000000
# 207                                      RoofMatl_Roll  0.000000  0.000000
# 208                                   Utilities_NoSewr  0.000000  0.000000
# 209                                Exterior1st_Wd Sdng  0.000000  0.000000
#
# skewness:  -0.4365249566728759
#
# model_importances.shape:  (210, 3)

# %%
elas1['model_importances'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
elas1['model_importances'].plot.kde(y='abs_val',xlim=[0.0,0.025])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# based on graph below, drop features with coefficients less than 0.002

# %%
elas1['model_importances'].plot.kde(y='abs_val',xlim=[0.0,0.010])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
set(model_vars_data.columns) - set(to_keep(elas1, 0.002))
# Out:
# {'BldgType_2fmCon',
#  'BldgType_Duplex',
#  'BldgType_TwnhsE',
#  'BsmtCond',
#  'BsmtFinType1',
#  'BsmtHalfBath',
#  'Condition1_RRAe',
#  'Condition1_RRNe',
#  'Condition2_Norm',
#  'Condition2_PosN',
#  'Condition2_RRAe',
#  'Condition2_RRAn',
#  'Condition2_RRNn',
#  'Electrical_FuseF',
#  'Electrical_FuseP',
#  'Electrical_Mixed',
#  'ExterCond',
#  'Exterior1st_AsphShn',
#  'Exterior1st_BrkComm',
#  'Exterior1st_CemntBd',
#  'Exterior1st_HdBoard',
#  'Exterior1st_ImStucc',
#  'Exterior1st_Plywood',
#  'Exterior1st_Stucco',
#  'Exterior1st_VinylSd',
#  'Exterior1st_Wd Sdng',
#  'Exterior1st_WdShing',
#  'Exterior2nd_CmentBd',
#  'Exterior2nd_HdBoard',
#  'Exterior2nd_ImStucc',
#  'Exterior2nd_MetalSd',
#  'Exterior2nd_Plywood',
#  'Exterior2nd_PreCast',
#  'Exterior2nd_Stone',
#  'Exterior2nd_Stucco',
#  'Exterior2nd_Wd Shng',
#  'Fence_GdWo',
#  'Fence_MnPrv',
#  'Fence_MnWw',
#  'Fence_No',
#  'Foundation_CBlock',
#  'FullBath',
#  'GarageType_Attchd',
#  'GarageType_Basment',
#  'GarageType_BuiltIn',
#  'GarageType_CarPort',
#  'GarageType_Detchd',
#  'GarageYrBlt',
#  'Heating_GasA',
#  'Heating_GasW',
#  'HouseStyle_2.5Unf',
#  'HouseStyle_2Story',
#  'LandContour_Low',
#  'LandSlope',
#  'LotArea',
#  'LotConfig_CulDSac',
#  'LotConfig_FR3',
#  'LotShape',
#  'LowQualFinSF',
#  'MSSubClass',
#  'MSSubClass_190',
#  'MSSubClass_20',
#  'MSSubClass_40',
#  'MSSubClass_45',
#  'MSSubClass_60',
#  'MSSubClass_80',
#  'MasVnrType_BrkFace',
#  'MasVnrType_None',
#  'MiscVal',
#  'MoSold_10',
#  'MoSold_11',
#  'MoSold_12',
#  'MoSold_2',
#  'MoSold_4',
#  'MoSold_5',
#  'MoSold_8',
#  'MoSold_9',
#  'Neighborhood_Gilbert_NWAmes',
#  'Neighborhood_NAmes_SWISU_Sawyer',
#  'PavedDrive_P',
#  'RoofMatl_Metal',
#  'RoofMatl_Roll',
#  'RoofMatl_Tar&Grv',
#  'RoofMatl_WdShake',
#  'RoofStyle_Gable',
#  'RoofStyle_Gambrel',
#  'RoofStyle_Hip',
#  'RoofStyle_Shed',
#  'SaleCondition_AdjLand',
#  'Street_Pave',
#  'Utilities_NoSewr',
#  'has_EnclosedPorch',
#  'has_miscfeature',
#  'has_wood_deck ',
#  'log_EnclosedPorch',
#  'yeo_LotFrontage'}

# %%
keeps = to_keep(elas1, 0.002)

# %%
elas2 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.9507784591631792
#
# test score:  0.9263164903201547
# adj_r2:  0.9474164126350799
#
# adj_r2_test:  0.9133935363147665
#
# train RMSE: 0.08374408448338287
#
# test RMSE: 0.10116737604301809
#                                               features      coef   abs_val
# 0                                         bc_GrLivArea  0.132014  0.132014
# 1                                           BsmtFinSF1  0.073593  0.073593
# 2                                          OverallQual  0.065852  0.065852
# 3                                           house_age_ -0.057884  0.057884
# 4                                          OverallCond  0.049033  0.049033
# 5                                            BsmtUnfSF  0.038744  0.038744
# 6                                           bc_LotArea  0.035762  0.035762
# 7                                          MSZoning_RM -0.031994  0.031994
# 8                                           GarageCars  0.029243  0.029243
# 9                                    HouseStyle_1Story  0.028891  0.028891
# 10                                          BsmtFinSF2  0.027951  0.027951
# 11                                            2ndFlrSF  0.026949  0.026949
# 12        Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.025278  0.025278
# 13                                     Condition1_Norm  0.024439  0.024439
# 14                                         MSZoning_RL -0.019977  0.019977
# 15                                          Functional  0.018328  0.018328
# 16                                     log_OpenPorchSF  0.015515  0.015515
# 17                               SaleCondition_Partial  0.015490  0.015490
# 18                                     GarageFinish_No  0.014448  0.014448
# 19                                           HeatingQC  0.014192  0.014192
# 20                                 Exterior1st_BrkFace  0.014121  0.014121
# 21                                          GarageCond  0.013851  0.013851
# 22                                       has_openporch -0.013207  0.013207
# 23                Neighborhood_ClearCr_CollgCr_Crawfor  0.012865  0.012865
# 24                                       MSSubClass_50  0.012499  0.012499
# 25                                SaleCondition_Family -0.012057  0.012057
# 26                                     Condition1_PosN  0.011682  0.011682
# 27                         Neighborhood_Somerst_Timber  0.011656  0.011656
# 28                                        BsmtExposure  0.011583  0.011583
# 29                                          Fireplaces  0.011011  0.011011
# 30                                         MSZoning_RH -0.010849  0.010849
# 31                                     LandContour_HLS  0.010825  0.010825
# 32                                       MSSubClass_70  0.010488  0.010488
# 33                                        KitchenAbvGr -0.010011  0.010011
# 34                                         KitchenQual  0.009886  0.009886
# 35                              has_finsished_basement -0.009841  0.009841
# 36                                           ExterQual  0.009541  0.009541
# 37                                        BsmtFullBath  0.009447  0.009447
# 38                                  Exterior2nd_CBlock  0.009193  0.009193
# 39                                     HouseStyle_SLvl  0.009177  0.009177
# 40                                         ScreenPorch  0.009033  0.009033
# 41                                   HouseStyle_SFoyer  0.008506  0.008506
# 42                                     Condition1_PosA  0.007905  0.007905
# 43                                   HouseStyle_1.5Unf  0.007628  0.007628
# 44                                      yeo_GarageArea  0.007596  0.007596
# 45                                 Exterior1st_PreCast  0.007547  0.007547
# 46                                            BsmtQual  0.007528  0.007528
# 104                                       has_basement -0.001613  0.001613
# 105                                           PoolArea -0.001167  0.001167
# 106                                Exterior2nd_BrkFace -0.001116  0.001116
# 107                                Exterior2nd_VinylSd  0.001048  0.001048
# 108                                    Foundation_Slab -0.000768  0.000768
# 109                               SaleCondition_Alloca  0.000737  0.000737
# 110                                      MSSubClass_30  0.000000  0.000000
# 111                                         GarageQual  0.000000  0.000000
# 112                                   GarageFinish_Unf  0.000000  0.000000
# 113                                      GarageType_No  0.000000  0.000000
#
# skewness:  -0.4470957414872314
#
# model_importances.shape:  (114, 3)

# %%
keeps = to_keep(elas2,0.0007)

# %%
elas3 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.9500783003447315
#
# test score:  0.924292856277634
# adj_r2:  0.9467959411324903
#
# adj_r2_test:  0.9115592388319761
#
# train RMSE: 0.08433759614226514
#
# test RMSE: 0.10254719008821445
#                                               features      coef   abs_val
# 0                                         bc_GrLivArea  0.137661  0.137661
# 1                                           BsmtFinSF1  0.095936  0.095936
# 2                                            BsmtUnfSF  0.063117  0.063117
# 3                                          OverallQual  0.059294  0.059294
# 4                                          OverallCond  0.047901  0.047901
# 5                                           house_age_ -0.042167  0.042167
# 6                                           BsmtFinSF2  0.038246  0.038246
# 7                                           bc_LotArea  0.032356  0.032356
# 8                                      yeo_TotalBsmtSF -0.025158  0.025158
# 9         Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.024992  0.024992
# 10                                     Condition1_Norm  0.023556  0.023556
# 11                                   HouseStyle_1Story  0.023326  0.023326
# 12                                         MSZoning_RM -0.020423  0.020423
# 13                                          GarageCars  0.019763  0.019763
# 14                                      yeo_GarageArea  0.019606  0.019606
# 15                                            BsmtQual  0.018369  0.018369
# 16                                          Functional  0.017502  0.017502
# 17                         Neighborhood_Somerst_Timber  0.016430  0.016430
# 18                               SaleCondition_Partial  0.015617  0.015617
# 19                                          Fireplaces  0.015495  0.015495
# 20                                            2ndFlrSF  0.015260  0.015260
# 21                                 Exterior1st_BrkFace  0.014426  0.014426
# 22                                           HeatingQC  0.014412  0.014412
# 23                                           ExterQual  0.014102  0.014102
# 24                Neighborhood_ClearCr_CollgCr_Crawfor  0.012755  0.012755
# 25                                        KitchenAbvGr -0.012638  0.012638
# 26                                         KitchenQual  0.012334  0.012334
# 27                                        BsmtExposure  0.012083  0.012083
# 28                                     GarageFinish_No  0.011769  0.011769
# 29                                SaleCondition_Family -0.011764  0.011764
# 30                                        BsmtFullBath  0.011404  0.011404
# 31                                     Condition1_PosN  0.011130  0.011130
# 32                                          GarageCond  0.011023  0.011023
# 33                                     LandContour_HLS  0.010661  0.010661
# 92                                        Heating_Grav -0.002540  0.002540
# 93                                     LandContour_Lvl  0.002449  0.002449
# 94                                      MSSubClass_180 -0.002413  0.002413
# 95                                            has_pool  0.002400  0.002400
# 96                                            MoSold_6  0.002292  0.002292
# 97                                     Condition1_RRNn  0.002194  0.002194
# 98                                    Electrical_SBrkr  0.002004  0.002004
# 99                                    RoofMatl_Membran  0.001945  0.001945
# 100                                       TotRmsAbvGrd  0.001824  0.001824
# 101                                       BsmtFinType2  0.001722  0.001722
# 102                                     log_WoodDeckSF  0.001670  0.001670
# 103                                Exterior2nd_BrkFace -0.001604  0.001604
# 104                Neighborhood_Greens_SawyerW_Blmngtn  0.001345  0.001345
# 105                                           PoolArea -0.001087  0.001087
# 106                               SaleCondition_Alloca  0.000937  0.000937
# 107                                      MSSubClass_90 -0.000648  0.000648
# 108                                    Foundation_Slab -0.000557  0.000557
# 109                                Exterior2nd_VinylSd  0.000000  0.000000
#
# skewness:  -0.42336137951837044
#
# model_importances.shape:  (110, 3)

# %%
drop_dummy = ['has_pool',
 'has_miscfeature',
 'MSSubClass_150',
 'MSSubClass_160',
 'MSSubClass_180',
 'MSSubClass_190',
 'MSSubClass_30',
 'MSSubClass_40',
 'MSSubClass_45',
 'MSSubClass_75',
 'MSSubClass_80',
 'MSSubClass_85',
 'MSSubClass_90',
 'MSZoning_RH',
 'LandContour_HLS',
 'LandContour_Low',
 'LotConfig_FR2',
 'LotConfig_FR3',
 'Neighborhood_SawyerW',
 'Condition1_PosA',
 'Condition1_PosN',
 'Condition1_RRAe',
 'Condition1_RRAn',
 'Condition1_RRNe',
 'Condition1_RRNn',
 'Condition2_Feedr',
 'Condition2_PosA',
 'Condition2_PosN',
 'Condition2_RRAn',
 'Condition2_RRNn',
 'BldgType_2fmCon',
 'BldgType_Duplex',
 'BldgType_Twnhs',
 'HouseStyle_1.5Unf',
 'HouseStyle_2.5Fin',
 'HouseStyle_2.5Unf',
 'HouseStyle_SFoyer',
 'RoofStyle_Gambrel',
 'RoofStyle_Mansard',
 'RoofStyle_Shed',
 'RoofMatl_Membran',
 'RoofMatl_Roll',
 'RoofMatl_Tar&Grv',
 'RoofMatl_WdShake',
 'RoofMatl_WdShngl',
 'Exterior1st_AsphShn',
 'Exterior1st_BrkComm',
 'Exterior1st_BrkFace',
 'Exterior1st_CBlock',
 'Exterior1st_CemntBd',
 'Exterior1st_PreCast',
 'Exterior1st_Stucco',
 'Exterior1st_WdShing',
 'Exterior2nd_AsphShn',
 'Exterior2nd_Brk Cmn',
 'Exterior2nd_BrkFace',
 'Exterior2nd_CBlock',
 'Exterior2nd_CmentBd',
 'Exterior2nd_ImStucc',
 'Exterior2nd_PreCast',
 'Exterior2nd_Stone',
 'Exterior2nd_Stucco',
 'Exterior2nd_Wd Shng',
 'Foundation_Slab',
 'Foundation_Stone',
 'Foundation_Wood',
 'Heating_GasW',
 'Heating_Grav',
 'Heating_OthW',
 'Heating_Wall',
 'Electrical_FuseF',
 'Electrical_FuseP',
 'GarageType_Basment',
 'GarageType_CarPort',
 'PavedDrive_P',
 'Fence_GdWo',
 'Fence_MnWw',
 'MoSold_11',
 'MoSold_12',
 'SaleCondition_AdjLand',
 'SaleCondition_Alloca',
 'SaleCondition_Family',
 'SaleCondition_Partial']

# %%
keeps3 = set(to_keep(elas3,0.0))
keeps3_ = keeps3 - set(drop_dummy)
keeps3_
keeps = list(keeps3_)

# %%
elas4 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9423981375930874
#
# test score:  0.9242114322912053
# adj_r2:  0.9400792761543028
#
# adj_r2_test:  0.9166870996697566
#
# train RMSE: 0.09059303291581954
#
# test RMSE: 0.10260232066593188
#                                              features      coef   abs_val
# 0                                          BsmtFinSF1  0.207192  0.207192
# 1                                           BsmtUnfSF  0.175666  0.175666
# 2                                     yeo_TotalBsmtSF -0.137102  0.137102
# 3                                          BsmtFinSF2  0.087550  0.087550
# 4                                            2ndFlrSF  0.068448  0.068448
# 5                                         OverallQual  0.063641  0.063641
# 6                                        bc_GrLivArea  0.058275  0.058275
# 7                                     log_first_FlrSF  0.055462  0.055462
# 8                                          house_age_ -0.053149  0.053149
# 9                                         OverallCond  0.049874  0.049874
# 10                                         bc_LotArea  0.039111  0.039111
# 11                                    GarageFinish_No  0.024103  0.024103
# 12                                         GarageCond  0.023786  0.023786
# 13                                        MSZoning_RM -0.023417  0.023417
# 14                                         GarageCars  0.022773  0.022773
# 15                                    log_OpenPorchSF  0.021754  0.021754
# 16       Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.019894  0.019894
# 17                                         Functional  0.018812  0.018812
# 18                                      has_openporch -0.016570  0.016570
# 19                                         Fireplaces  0.014640  0.014640
# 20                                          HeatingQC  0.014376  0.014376
# 21                                    Condition1_Norm  0.014248  0.014248
# 22                                       BsmtExposure  0.014225  0.014225
# 23                                           BsmtQual  0.014167  0.014167
# 24                        Neighborhood_Somerst_Timber  0.013760  0.013760
# 25                                       BedroomAbvGr -0.013359  0.013359
# 26                                     yeo_GarageArea  0.013162  0.013162
# 27               Neighborhood_ClearCr_CollgCr_Crawfor  0.012342  0.012342
# 28                                      MSSubClass_50  0.012176  0.012176
# 29                                       KitchenAbvGr -0.012086  0.012086
# 30                                        KitchenQual  0.012076  0.012076
# 31                                          ExterQual  0.011625  0.011625
# 32                                  HouseStyle_1Story  0.010989  0.010989
# 33                                      MSSubClass_70  0.010404  0.010404
# 34                             has_finsished_basement -0.010233  0.010233
# 35                                       BsmtFullBath  0.010081  0.010081
# 36                                        ScreenPorch  0.010053  0.010053
# 37                                       TotRmsAbvGrd  0.009662  0.009662
# 38                                   Foundation_PConc  0.009639  0.009639
# 39                                        MSZoning_RL -0.009065  0.009065
# 40                                       CentralAir_Y  0.008767  0.008767
# 41                             years_since_remodeled_ -0.008125  0.008125
# 42                                        FireplaceQu  0.007662  0.007662
# 43                                       PavedDrive_Y  0.007443  0.007443
# 44                                           MoSold_7  0.007043  0.007043
# 45                                          3SsnPorch  0.005932  0.005932
# 46  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.005891  0.005891
# 47                                   LotConfig_Inside  0.005463  0.005463
# 48                                   MasVnrType_Stone  0.005379  0.005379
# 49                                   GarageFinish_RFn -0.004997  0.004997
# 50                Neighborhood_Greens_SawyerW_Blmngtn -0.003952  0.003952
# 51                                    HouseStyle_SLvl  0.003780  0.003780
# 52                                           HalfBath  0.003656  0.003656
# 53                                           MoSold_3 -0.003653  0.003653
# 54                                       has_basement  0.003493  0.003493
# 55                                Exterior1st_MetalSd  0.003454  0.003454
# 56                                             MoSold -0.003069  0.003069
# 57                       Neighborhood_Mitchel_NPkVill  0.003028  0.003028
# 58                                       BsmtFinType2  0.002978  0.002978
# 59                                    LandContour_Lvl -0.002903  0.002903
# 60                                           MoSold_6  0.002757  0.002757
# 61                                Exterior2nd_Wd Sdng  0.002193  0.002193
# 62                                   Electrical_SBrkr  0.002055  0.002055
# 63                                     log_MasVnrArea -0.001973  0.001973
# 64                               SaleCondition_Normal  0.001834  0.001834
# 65                                       alley_access -0.001688  0.001688
# 66                                     log_WoodDeckSF  0.001410  0.001410
# 67                                           PoolArea -0.000493  0.000493
# 68                                   Condition1_Feedr -0.000159  0.000159
#
# skewness:  -0.73230235460347
#
# model_importances.shape:  (69, 3)

# %%
keeps_set = set(to_keep(elas4,0)) - set(['MoSold'])
keeps = list(keeps_set)

# %%
elas5 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9423431599217835
#
# test score:  0.9240391969000622
# adj_r2:  0.9400570578078951
#
# adj_r2_test:  0.9166177391259304
#
# train RMSE: 0.0906362555298292
#
# test RMSE: 0.10271884036443411
#                                              features      coef   abs_val
# 0                                          BsmtFinSF1  0.206585  0.206585
# 1                                           BsmtUnfSF  0.175206  0.175206
# 2                                     yeo_TotalBsmtSF -0.136412  0.136412
# 3                                          BsmtFinSF2  0.087280  0.087280
# 4                                            2ndFlrSF  0.068739  0.068739
# 5                                         OverallQual  0.063552  0.063552
# 6                                        bc_GrLivArea  0.058076  0.058076
# 7                                     log_first_FlrSF  0.055528  0.055528
# 8                                          house_age_ -0.053341  0.053341
# 9                                         OverallCond  0.049974  0.049974
# 10                                         bc_LotArea  0.039266  0.039266
# 11                                    GarageFinish_No  0.024287  0.024287
# 12                                         GarageCond  0.023960  0.023960
# 13                                        MSZoning_RM -0.023282  0.023282
# 14                                         GarageCars  0.022636  0.022636
# 15                                    log_OpenPorchSF  0.021736  0.021736
# 16       Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.019712  0.019712
# 17                                         Functional  0.018900  0.018900
# 18                                      has_openporch -0.016644  0.016644
# 19                                         Fireplaces  0.014424  0.014424
# 20                                          HeatingQC  0.014387  0.014387
# 21                                       BsmtExposure  0.014299  0.014299
# 22                                    Condition1_Norm  0.014298  0.014298
# 23                                           BsmtQual  0.014161  0.014161
# 24                        Neighborhood_Somerst_Timber  0.013731  0.013731
# 25                                       BedroomAbvGr -0.013687  0.013687
# 26                                     yeo_GarageArea  0.013100  0.013100
# 27                                      MSSubClass_50  0.012272  0.012272
# 28               Neighborhood_ClearCr_CollgCr_Crawfor  0.012257  0.012257
# 29                                       KitchenAbvGr -0.012252  0.012252
# 30                                        KitchenQual  0.011898  0.011898
# 31                                          ExterQual  0.011808  0.011808
# 32                                  HouseStyle_1Story  0.011080  0.011080
# 33                                      MSSubClass_70  0.010379  0.010379
# 34                                       BsmtFullBath  0.010212  0.010212
# 35                             has_finsished_basement -0.010103  0.010103
# 36                                        ScreenPorch  0.009994  0.009994
# 37                                       TotRmsAbvGrd  0.009919  0.009919
# 38                                   Foundation_PConc  0.009707  0.009707
# 39                                        MSZoning_RL -0.009013  0.009013
# 40                                       CentralAir_Y  0.008685  0.008685
# 41                             years_since_remodeled_ -0.007973  0.007973
# 42                                        FireplaceQu  0.007726  0.007726
# 43                                       PavedDrive_Y  0.007517  0.007517
# 44                                           MoSold_7  0.006752  0.006752
# 45                                          3SsnPorch  0.005881  0.005881
# 46  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.005819  0.005819
# 47                                   MasVnrType_Stone  0.005571  0.005571
# 48                                   LotConfig_Inside  0.005428  0.005428
# 49                                   GarageFinish_RFn -0.004902  0.004902
# 50                Neighborhood_Greens_SawyerW_Blmngtn -0.003911  0.003911
# 51                                           HalfBath  0.003757  0.003757
# 52                                    HouseStyle_SLvl  0.003757  0.003757
# 53                                Exterior1st_MetalSd  0.003448  0.003448
# 54                                       has_basement  0.003319  0.003319
# 55                       Neighborhood_Mitchel_NPkVill  0.003088  0.003088
# 56                                       BsmtFinType2  0.002940  0.002940
# 57                                           MoSold_6  0.002887  0.002887
# 58                                    LandContour_Lvl -0.002829  0.002829
# 59                                           MoSold_3 -0.002618  0.002618
# 60                                   Electrical_SBrkr  0.002231  0.002231
# 61                                Exterior2nd_Wd Sdng  0.002195  0.002195
# 62                               SaleCondition_Normal  0.002040  0.002040
# 63                                     log_MasVnrArea -0.001868  0.001868
# 64                                       alley_access -0.001594  0.001594
# 65                                     log_WoodDeckSF  0.001317  0.001317
# 66                                           PoolArea -0.000411  0.000411
# 67                                   Condition1_Feedr -0.000067  0.000067
#
# skewness:  -0.7314843980943465
#
# model_importances.shape:  (68, 3)

# %%
keeps = to_keep(elas5,0.002)

# %%
elas6 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9423036935121968
#
# test score:  0.9239455796688099
# adj_r2:  0.9401903985652598
#
# adj_r2_test:  0.9171104463152222
#
# train RMSE: 0.09066727071948325
#
# test RMSE: 0.1027821183446387
#                                              features      coef   abs_val
# 0                                          BsmtFinSF1  0.207493  0.207493
# 1                                           BsmtUnfSF  0.176274  0.176274
# 2                                     yeo_TotalBsmtSF -0.137499  0.137499
# 3                                          BsmtFinSF2  0.087769  0.087769
# 4                                            2ndFlrSF  0.068973  0.068973
# 5                                         OverallQual  0.063298  0.063298
# 6                                        bc_GrLivArea  0.057762  0.057762
# 7                                     log_first_FlrSF  0.055495  0.055495
# 8                                          house_age_ -0.053651  0.053651
# 9                                         OverallCond  0.050203  0.050203
# 10                                         bc_LotArea  0.039474  0.039474
# 11                                    GarageFinish_No  0.024356  0.024356
# 12                                         GarageCond  0.024187  0.024187
# 13                                        MSZoning_RM -0.023245  0.023245
# 14                                         GarageCars  0.022319  0.022319
# 15                                    log_OpenPorchSF  0.021222  0.021222
# 16       Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.019650  0.019650
# 17                                         Functional  0.018790  0.018790
# 18                                      has_openporch -0.016295  0.016295
# 19                                       BsmtExposure  0.014528  0.014528
# 20                                           BsmtQual  0.014466  0.014466
# 21                                         Fireplaces  0.014388  0.014388
# 22                                          HeatingQC  0.014249  0.014249
# 23                                    Condition1_Norm  0.014175  0.014175
# 24                                       BedroomAbvGr -0.013854  0.013854
# 25                        Neighborhood_Somerst_Timber  0.013545  0.013545
# 26                                     yeo_GarageArea  0.013068  0.013068
# 27                                      MSSubClass_50  0.012432  0.012432
# 28               Neighborhood_ClearCr_CollgCr_Crawfor  0.012289  0.012289
# 29                                       KitchenAbvGr -0.012273  0.012273
# 30                                        KitchenQual  0.011958  0.011958
# 31                                          ExterQual  0.011781  0.011781
# 32                                  HouseStyle_1Story  0.011145  0.011145
# 33                                      MSSubClass_70  0.010437  0.010437
# 34                                       BsmtFullBath  0.010245  0.010245
# 35                             has_finsished_basement -0.010154  0.010154
# 36                                       TotRmsAbvGrd  0.009965  0.009965
# 37                                   Foundation_PConc  0.009882  0.009882
# 38                                        ScreenPorch  0.009685  0.009685
# 39                                        MSZoning_RL -0.008737  0.008737
# 40                                       CentralAir_Y  0.008719  0.008719
# 41                             years_since_remodeled_ -0.008015  0.008015
# 42                                        FireplaceQu  0.007957  0.007957
# 43                                       PavedDrive_Y  0.007687  0.007687
# 44                                           MoSold_7  0.006779  0.006779
# 45  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.005870  0.005870
# 46                                          3SsnPorch  0.005821  0.005821
# 47                                   LotConfig_Inside  0.005331  0.005331
# 48                                   MasVnrType_Stone  0.005130  0.005130
# 49                                   GarageFinish_RFn -0.004935  0.004935
# 50                Neighborhood_Greens_SawyerW_Blmngtn -0.003804  0.003804
# 51                                           HalfBath  0.003657  0.003657
# 52                                    HouseStyle_SLvl  0.003634  0.003634
# 53                       Neighborhood_Mitchel_NPkVill  0.003244  0.003244
# 54                                       has_basement  0.003237  0.003237
# 55                                Exterior1st_MetalSd  0.003192  0.003192
# 56                                       BsmtFinType2  0.003015  0.003015
# 57                                    LandContour_Lvl -0.002875  0.002875
# 58                                           MoSold_6  0.002779  0.002779
# 59                                           MoSold_3 -0.002630  0.002630
# 60                                   Electrical_SBrkr  0.002277  0.002277
# 61                                Exterior2nd_Wd Sdng  0.002177  0.002177
# 62                               SaleCondition_Normal  0.002079  0.002079
#
# skewness:  -0.7318039678403332
#
# model_importances.shape:  (63, 3)

# %%
keeps = to_keep(elas6, 0.003)

# %%
elas7 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9420536480494753
#
# test score:  0.9242282914506427
# adj_r2:  0.9401400083848288
#
# adj_r2_test:  0.91811939839928
#
# train RMSE: 0.09086352617475317
#
# test RMSE: 0.10259090809314161
#                                              features      coef   abs_val
# 0                                          BsmtFinSF1  0.202393  0.202393
# 1                                           BsmtUnfSF  0.170983  0.170983
# 2                                     yeo_TotalBsmtSF -0.133088  0.133088
# 3                                          BsmtFinSF2  0.085758  0.085758
# 4                                            2ndFlrSF  0.068246  0.068246
# 5                                         OverallQual  0.063482  0.063482
# 6                                        bc_GrLivArea  0.058730  0.058730
# 7                                     log_first_FlrSF  0.054902  0.054902
# 8                                          house_age_ -0.052381  0.052381
# 9                                         OverallCond  0.050729  0.050729
# 10                                         bc_LotArea  0.039735  0.039735
# 11                                         GarageCond  0.024902  0.024902
# 12                                    GarageFinish_No  0.024773  0.024773
# 13                                        MSZoning_RM -0.023463  0.023463
# 14                                         GarageCars  0.022616  0.022616
# 15                                    log_OpenPorchSF  0.020910  0.020910
# 16       Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.019814  0.019814
# 17                                         Functional  0.018290  0.018290
# 18                                      has_openporch -0.016038  0.016038
# 19                                       BsmtExposure  0.015120  0.015120
# 20                                           BsmtQual  0.014732  0.014732
# 21                                    Condition1_Norm  0.014313  0.014313
# 22                                         Fireplaces  0.014300  0.014300
# 23                                          HeatingQC  0.014161  0.014161
# 24                                       BedroomAbvGr -0.013658  0.013658
# 25                        Neighborhood_Somerst_Timber  0.013501  0.013501
# 26                                     yeo_GarageArea  0.012905  0.012905
# 27               Neighborhood_ClearCr_CollgCr_Crawfor  0.012712  0.012712
# 28                                      MSSubClass_50  0.012526  0.012526
# 29                                       KitchenAbvGr -0.012250  0.012250
# 30                                        KitchenQual  0.012057  0.012057
# 31                                          ExterQual  0.011805  0.011805
# 32                                  HouseStyle_1Story  0.011664  0.011664
# 33                                      MSSubClass_70  0.010407  0.010407
# 34                                       BsmtFullBath  0.010395  0.010395
# 35                             has_finsished_basement -0.010200  0.010200
# 36                                   Foundation_PConc  0.010167  0.010167
# 37                                        ScreenPorch  0.009947  0.009947
# 38                                       TotRmsAbvGrd  0.009671  0.009671
# 39                                       CentralAir_Y  0.009038  0.009038
# 40                                        MSZoning_RL -0.008668  0.008668
# 41                                        FireplaceQu  0.008413  0.008413
# 42                             years_since_remodeled_ -0.007897  0.007897
# 43                                       PavedDrive_Y  0.007326  0.007326
# 44                                           MoSold_7  0.006585  0.006585
# 45  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.006061  0.006061
# 46                                          3SsnPorch  0.005856  0.005856
# 47                                   LotConfig_Inside  0.005435  0.005435
# 48                                   GarageFinish_RFn -0.005065  0.005065
# 49                                   MasVnrType_Stone  0.004655  0.004655
# 50                                           HalfBath  0.003898  0.003898
# 51                Neighborhood_Greens_SawyerW_Blmngtn -0.003856  0.003856
# 52                                    HouseStyle_SLvl  0.003592  0.003592
# 53                       Neighborhood_Mitchel_NPkVill  0.003305  0.003305
# 54                                       BsmtFinType2  0.002995  0.002995
# 55                                       has_basement  0.002938  0.002938
# 56                                Exterior1st_MetalSd  0.002564  0.002564
#
# skewness:  -0.7390109429366981
#
# model_importances.shape:  (57, 3)

# %%
keeps = to_keep(elas7,0.004)

# %%
elas8 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9417289329119797
#
# test score:  0.9250673441607637
# adj_r2:  0.9400477134345411
#
# adj_r2_test:  0.9198199592980721
#
# train RMSE: 0.09111775739642804
#
# test RMSE: 0.10202131023363481
#                                              features      coef   abs_val
# 0                                          BsmtFinSF1  0.185054  0.185054
# 1                                           BsmtUnfSF  0.153511  0.153511
# 2                                     yeo_TotalBsmtSF -0.115111  0.115111
# 3                                          BsmtFinSF2  0.079050  0.079050
# 4                                            2ndFlrSF  0.065284  0.065284
# 5                                         OverallQual  0.063291  0.063291
# 6                                        bc_GrLivArea  0.061636  0.061636
# 7                                     log_first_FlrSF  0.052911  0.052911
# 8                                          house_age_ -0.052176  0.052176
# 9                                         OverallCond  0.051257  0.051257
# 10                                         bc_LotArea  0.040100  0.040100
# 11                                         GarageCond  0.024590  0.024590
# 12                                    GarageFinish_No  0.024331  0.024331
# 13                                        MSZoning_RM -0.023715  0.023715
# 14                                         GarageCars  0.022353  0.022353
# 15                                    log_OpenPorchSF  0.021541  0.021541
# 16       Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.021368  0.021368
# 17                                         Functional  0.018328  0.018328
# 18                                      has_openporch -0.016945  0.016945
# 19                                           BsmtQual  0.015973  0.015973
# 20                                       BsmtExposure  0.015070  0.015070
# 21                                    Condition1_Norm  0.014493  0.014493
# 22                        Neighborhood_Somerst_Timber  0.014403  0.014403
# 23                                         Fireplaces  0.014335  0.014335
# 24                                          HeatingQC  0.014084  0.014084
# 25                                       BedroomAbvGr -0.013381  0.013381
# 26                                     yeo_GarageArea  0.013279  0.013279
# 27               Neighborhood_ClearCr_CollgCr_Crawfor  0.013023  0.013023
# 28                                       KitchenAbvGr -0.012938  0.012938
# 29                                        KitchenQual  0.011533  0.011533
# 30                                      MSSubClass_50  0.010760  0.010760
# 31                                          ExterQual  0.010417  0.010417
# 32                                       BsmtFullBath  0.010279  0.010279
# 33                                        ScreenPorch  0.009954  0.009954
# 34                                       CentralAir_Y  0.009572  0.009572
# 35                                      MSSubClass_70  0.009454  0.009454
# 36                                       TotRmsAbvGrd  0.009420  0.009420
# 37                                   Foundation_PConc  0.009413  0.009413
# 38                                        MSZoning_RL -0.009049  0.009049
# 39                                        FireplaceQu  0.008385  0.008385
# 40                             has_finsished_basement -0.008229  0.008229
# 41                                  HouseStyle_1Story  0.007727  0.007727
# 42                             years_since_remodeled_ -0.007716  0.007716
# 43                                       PavedDrive_Y  0.007653  0.007653
# 44                                           MoSold_7  0.006486  0.006486
# 45  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.006216  0.006216
# 46                                          3SsnPorch  0.005595  0.005595
# 47                                   GarageFinish_RFn -0.005497  0.005497
# 48                                   LotConfig_Inside  0.005358  0.005358
# 49                                   MasVnrType_Stone  0.004637  0.004637
#
# skewness:  -0.7323542551998686
#
# model_importances.shape:  (50, 3)

# %%
keeps = to_keep(elas8,0.006)

# %%
elas9 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9410706743441998
#
# test score:  0.9255620631700984
# adj_r2:  0.939510081954927
#
# adj_r2_test:  0.9207930588606618
#
# train RMSE: 0.09163096754802139
#
# test RMSE: 0.1016839709038198
#                                              features      coef   abs_val
# 0                                          BsmtFinSF1  0.191020  0.191020
# 1                                           BsmtUnfSF  0.159172  0.159172
# 2                                     yeo_TotalBsmtSF -0.120061  0.120061
# 3                                          BsmtFinSF2  0.081209  0.081209
# 4                                            2ndFlrSF  0.064535  0.064535
# 5                                         OverallQual  0.063160  0.063160
# 6                                        bc_GrLivArea  0.062102  0.062102
# 7                                     log_first_FlrSF  0.051776  0.051776
# 8                                          house_age_ -0.051575  0.051575
# 9                                         OverallCond  0.051393  0.051393
# 10                                         bc_LotArea  0.039112  0.039112
# 11                                    GarageFinish_No  0.024642  0.024642
# 12                                         GarageCond  0.024558  0.024558
# 13                                        MSZoning_RM -0.023724  0.023724
# 14                                         GarageCars  0.023040  0.023040
# 15       Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.021265  0.021265
# 16                                    log_OpenPorchSF  0.019617  0.019617
# 17                                         Functional  0.018044  0.018044
# 18                                           BsmtQual  0.016962  0.016962
# 19                                      has_openporch -0.015702  0.015702
# 20                                       BsmtExposure  0.015368  0.015368
# 21                        Neighborhood_Somerst_Timber  0.014629  0.014629
# 22                                         Fireplaces  0.014573  0.014573
# 23                                    Condition1_Norm  0.014518  0.014518
# 24                                          HeatingQC  0.013947  0.013947
# 25                                       BedroomAbvGr -0.013633  0.013633
# 26                                       KitchenAbvGr -0.012891  0.012891
# 27               Neighborhood_ClearCr_CollgCr_Crawfor  0.012690  0.012690
# 28                                     yeo_GarageArea  0.012319  0.012319
# 29                                        KitchenQual  0.011994  0.011994
# 30                                      MSSubClass_50  0.011411  0.011411
# 31                                          ExterQual  0.011063  0.011063
# 32                                       TotRmsAbvGrd  0.010349  0.010349
# 33                                       BsmtFullBath  0.010272  0.010272
# 34                                       CentralAir_Y  0.009710  0.009710
# 35                                      MSSubClass_70  0.009642  0.009642
# 36                                        ScreenPorch  0.009419  0.009419
# 37                                        MSZoning_RL -0.009329  0.009329
# 38                                   Foundation_PConc  0.009159  0.009159
# 39                                        FireplaceQu  0.008782  0.008782
# 40                                  HouseStyle_1Story  0.008535  0.008535
# 41                             has_finsished_basement -0.008187  0.008187
# 42                                       PavedDrive_Y  0.007384  0.007384
# 43                             years_since_remodeled_ -0.007337  0.007337
# 44                                           MoSold_7  0.006194  0.006194
# 45  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.005382  0.005382
#
# skewness:  -0.7077080966004367
#
# model_importances.shape:  (46, 3)

# %%
df = model_vars_data[['BsmtFinSF1', 'BsmtUnfSF','yeo_TotalBsmtSF','BsmtFinSF2']]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(dataset):
    vif=pd.DataFrame()
    vif['features'] = dataset.columns
    vif['VIF_Value'] = [variance_inflation_factor(dataset.values,i) for i in range(dataset.shape[1])]
    return vif

# %%
calculate_vif(df)
# Out:
#           features   VIF_Value
# 0       BsmtFinSF1   54.950883
# 1        BsmtUnfSF   71.372852
# 2  yeo_TotalBsmtSF  184.152889
# 3       BsmtFinSF2    6.504593

# %%
df_corrbsmt = df.corr() 

print(df_corrbsmt)
# Out:
#                  BsmtFinSF1  BsmtUnfSF  yeo_TotalBsmtSF  BsmtFinSF2
# BsmtFinSF1         1.000000  -0.475230         0.501543   -0.064983
# BsmtUnfSF         -0.475230   1.000000         0.424382   -0.259080
# yeo_TotalBsmtSF    0.501543   0.424382         1.000000    0.106655
# BsmtFinSF2        -0.064983  -0.259080         0.106655    1.000000

# %%
keeps = to_keep(elas9,0.008)

# %%
elas10 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9403467281806294
#
# test score:  0.9245165839535319
# adj_r2:  0.9389076486766583
#
# adj_r2_test:  0.9201255819120475
#
# train RMSE: 0.09219209220597116
#
# test RMSE: 0.10239555565624932
#                                         features      coef   abs_val
# 0                                     BsmtFinSF1  0.183367  0.183367
# 1                                      BsmtUnfSF  0.151342  0.151342
# 2                                yeo_TotalBsmtSF -0.112886  0.112886
# 3                                     BsmtFinSF2  0.077874  0.077874
# 4                                   bc_GrLivArea  0.065334  0.065334
# 5                                    OverallQual  0.063159  0.063159
# 6                                       2ndFlrSF  0.063025  0.063025
# 7                                     house_age_ -0.060820  0.060820
# 8                                    OverallCond  0.054348  0.054348
# 9                                log_first_FlrSF  0.050800  0.050800
# 10                                    bc_LotArea  0.037847  0.037847
# 11                                    GarageCond  0.027316  0.027316
# 12                                   MSZoning_RM -0.026042  0.026042
# 13                               GarageFinish_No  0.026001  0.026001
# 14                                    GarageCars  0.023003  0.023003
# 15  Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.021539  0.021539
# 16                               log_OpenPorchSF  0.019524  0.019524
# 17                                    Functional  0.017833  0.017833
# 18                                      BsmtQual  0.017800  0.017800
# 19                                 has_openporch -0.015671  0.015671
# 20                                  BsmtExposure  0.015597  0.015597
# 21                   Neighborhood_Somerst_Timber  0.014864  0.014864
# 22                               Condition1_Norm  0.014673  0.014673
# 23                                     HeatingQC  0.014525  0.014525
# 24                                    Fireplaces  0.014120  0.014120
# 25          Neighborhood_ClearCr_CollgCr_Crawfor  0.013765  0.013765
# 26                                  BedroomAbvGr -0.013102  0.013102
# 27                                  KitchenAbvGr -0.013032  0.013032
# 28                                   KitchenQual  0.012887  0.012887
# 29                                yeo_GarageArea  0.011357  0.011357
# 30                                     ExterQual  0.011240  0.011240
# 31                                  CentralAir_Y  0.011040  0.011040
# 32                                  TotRmsAbvGrd  0.010730  0.010730
# 33                                  BsmtFullBath  0.010427  0.010427
# 34                                 MSSubClass_50  0.010296  0.010296
# 35                                 MSSubClass_70  0.009959  0.009959
# 36                                   FireplaceQu  0.009387  0.009387
# 37                                   ScreenPorch  0.009215  0.009215
# 38                                   MSZoning_RL -0.009191  0.009191
# 39                             HouseStyle_1Story  0.008790  0.008790
# 40                              Foundation_PConc  0.007870  0.007870
# 41                        has_finsished_basement -0.007568  0.007568
#
# skewness:  -0.6764759546085024
#
# model_importances.shape:  (42, 3)

# %%
keeps = to_keep(elas9,0.007)

# %%
elas11 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9407306908411254
#
# test score:  0.9254593053453163
# adj_r2:  0.9392310648474563
#
# adj_r2_test:  0.9209040406719745
#
# train RMSE: 0.09189491264692275
#
# test RMSE: 0.10175413150054077
#                                         features      coef   abs_val
# 0                                     BsmtFinSF1  0.189987  0.189987
# 1                                      BsmtUnfSF  0.158092  0.158092
# 2                                yeo_TotalBsmtSF -0.118731  0.118731
# 3                                     BsmtFinSF2  0.080436  0.080436
# 4                                       2ndFlrSF  0.064193  0.064193
# 5                                   bc_GrLivArea  0.063118  0.063118
# 6                                    OverallQual  0.062841  0.062841
# 7                                     house_age_ -0.054049  0.054049
# 8                                    OverallCond  0.051864  0.051864
# 9                                log_first_FlrSF  0.050827  0.050827
# 10                                    bc_LotArea  0.038648  0.038648
# 11                                   MSZoning_RM -0.026057  0.026057
# 12                                    GarageCond  0.024853  0.024853
# 13                               GarageFinish_No  0.024118  0.024118
# 14                                    GarageCars  0.023643  0.023643
# 15  Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.021871  0.021871
# 16                               log_OpenPorchSF  0.019408  0.019408
# 17                                    Functional  0.018210  0.018210
# 18                                      BsmtQual  0.017064  0.017064
# 19                                 has_openporch -0.015541  0.015541
# 20                                  BsmtExposure  0.015531  0.015531
# 21                   Neighborhood_Somerst_Timber  0.015024  0.015024
# 22                                    Fireplaces  0.014631  0.014631
# 23                               Condition1_Norm  0.014601  0.014601
# 24          Neighborhood_ClearCr_CollgCr_Crawfor  0.013590  0.013590
# 25                                     HeatingQC  0.013477  0.013477
# 26                                  BedroomAbvGr -0.013452  0.013452
# 27                                  KitchenAbvGr -0.012734  0.012734
# 28                                   KitchenQual  0.011834  0.011834
# 29                                yeo_GarageArea  0.011165  0.011165
# 30                                     ExterQual  0.010947  0.010947
# 31                                 MSSubClass_50  0.010705  0.010705
# 32                                  TotRmsAbvGrd  0.010474  0.010474
# 33                                  BsmtFullBath  0.010416  0.010416
# 34                                  CentralAir_Y  0.010246  0.010246
# 35                                 MSSubClass_70  0.009505  0.009505
# 36                                   MSZoning_RL -0.009376  0.009376
# 37                                   ScreenPorch  0.009297  0.009297
# 38                                   FireplaceQu  0.009160  0.009160
# 39                             HouseStyle_1Story  0.008563  0.008563
# 40                              Foundation_PConc  0.008375  0.008375
# 41                        has_finsished_basement -0.007701  0.007701
# 42                                  PavedDrive_Y  0.007494  0.007494
# 43                        years_since_remodeled_ -0.007099  0.007099
#
# skewness:  -0.7080518162035049
#
# model_importances.shape:  (44, 3)

# %%
# 'BsmtFinSF1', 'BsmtUnfSF','yeo_TotalBsmtSF','BsmtFinSF2'

elas9['model_importances'].to_csv(r'C:\Users\dgarb\OneDrive\Documents\Data Science Bootcamp August\Machine Learning Project\iterations\elas9.csv')

# %%
new_fea_set = set(to_keep(elas9,0)) - set(['BsmtFinSF1', 'BsmtUnfSF'])
keeps = list(new_fea_set)

# %%
elas12 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-15, 'tol': 0.02}
# score:  0.9369062706573109
#
# test score:  0.9225509308341397
# adj_r2:  0.9353098795756097
#
# adj_r2_test:  0.9178179321628928
#
# train RMSE: 0.09481338150780227
#
# test RMSE: 0.10372022141947793
#                                              features      coef   abs_val
# 0                                        bc_GrLivArea  0.085188  0.085188
# 1                                          house_age_ -0.061469  0.061469
# 2                                         OverallQual  0.061066  0.061066
# 3                                         OverallCond  0.053233  0.053233
# 4                                            2ndFlrSF  0.049288  0.049288
# 5                                     log_first_FlrSF  0.043563  0.043563
# 6                                          bc_LotArea  0.040036  0.040036
# 7                                     yeo_TotalBsmtSF  0.038470  0.038470
# 8                                     GarageFinish_No  0.028270  0.028270
# 9                                          GarageCond  0.026199  0.026199
# 10                                       BsmtFullBath  0.025461  0.025461
# 11       Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.024930  0.024930
# 12                                         GarageCars  0.023225  0.023225
# 13                                    log_OpenPorchSF  0.021899  0.021899
# 14                                       BsmtExposure  0.021828  0.021828
# 15                                        MSZoning_RM -0.021410  0.021410
# 16                                         Fireplaces  0.020741  0.020741
# 17                                      has_openporch -0.019672  0.019672
# 18                                         Functional  0.018609  0.018609
# 19                                       BedroomAbvGr -0.017613  0.017613
# 20                                     yeo_GarageArea  0.015123  0.015123
# 21                                    Condition1_Norm  0.014898  0.014898
# 22                        Neighborhood_Somerst_Timber  0.014137  0.014137
# 23                                       KitchenAbvGr -0.014021  0.014021
# 24                                        KitchenQual  0.013123  0.013123
# 25                                          HeatingQC  0.012677  0.012677
# 26                                          ExterQual  0.012346  0.012346
# 27                                  HouseStyle_1Story  0.012265  0.012265
# 28               Neighborhood_ClearCr_CollgCr_Crawfor  0.011580  0.011580
# 29                                      MSSubClass_50  0.011046  0.011046
# 30                                        ScreenPorch  0.010969  0.010969
# 31                                       TotRmsAbvGrd  0.010825  0.010825
# 32                                      MSSubClass_70  0.009279  0.009279
# 33                                        MSZoning_RL -0.007721  0.007721
# 34                                       CentralAir_Y  0.007625  0.007625
# 35                                       PavedDrive_Y  0.007242  0.007242
# 36                                   Foundation_PConc  0.007018  0.007018
# 37                             has_finsished_basement -0.006541  0.006541
# 38                                           BsmtQual  0.006133  0.006133
# 39  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.005995  0.005995
# 40                                           MoSold_7  0.005912  0.005912
# 41                             years_since_remodeled_ -0.005719  0.005719
# 42                                         BsmtFinSF2  0.004582  0.004582
# 43                                        FireplaceQu  0.004234  0.004234
#
# skewness:  -0.5360127661466293
#
# model_importances.shape:  (44, 3)

# %%
new_fea_set = set(to_keep(elas12,0)) - set(['log_first_FlrSF','has_openporch'])
keeps = list(new_fea_set)

# %%
elas13 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9359252937810482
#
# test score:  0.9205394380640528
# adj_r2:  0.9343795512990286
#
# adj_r2_test:  0.915917078505452
#
# train RMSE: 0.0955476144661318
#
# test RMSE: 0.10505848892601949
#                                              features      coef   abs_val
# 0                                        bc_GrLivArea  0.128777  0.128777
# 1                                         OverallQual  0.061802  0.061802
# 2                                          house_age_ -0.058256  0.058256
# 3                                         OverallCond  0.054021  0.054021
# 4                                     yeo_TotalBsmtSF  0.042439  0.042439
# 5                                          bc_LotArea  0.042345  0.042345
# 6                                     GarageFinish_No  0.027725  0.027725
# 7                                        BsmtFullBath  0.027131  0.027131
# 8        Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.026053  0.026053
# 9                                          GarageCond  0.024701  0.024701
# 10                                        MSZoning_RM -0.024033  0.024033
# 11                                       BsmtExposure  0.023278  0.023278
# 12                                         GarageCars  0.022783  0.022783
# 13                                         Fireplaces  0.021230  0.021230
# 14                                  HouseStyle_1Story  0.019134  0.019134
# 15                                         Functional  0.017879  0.017879
# 16                                     yeo_GarageArea  0.017836  0.017836
# 17                                       BedroomAbvGr -0.016814  0.016814
# 18                                           2ndFlrSF  0.016284  0.016284
# 19                                    Condition1_Norm  0.014892  0.014892
# 20                                       KitchenAbvGr -0.014481  0.014481
# 21                        Neighborhood_Somerst_Timber  0.014120  0.014120
# 22                                        KitchenQual  0.013428  0.013428
# 23                                          HeatingQC  0.012671  0.012671
# 24                                       TotRmsAbvGrd  0.012127  0.012127
# 25                                          ExterQual  0.011720  0.011720
# 26               Neighborhood_ClearCr_CollgCr_Crawfor  0.011496  0.011496
# 27                                        ScreenPorch  0.011075  0.011075
# 28                                        MSZoning_RL -0.008771  0.008771
# 29                                      MSSubClass_50  0.008771  0.008771
# 30                                       CentralAir_Y  0.007934  0.007934
# 31                                       PavedDrive_Y  0.007614  0.007614
# 32                                      MSSubClass_70  0.006603  0.006603
# 33                             has_finsished_basement -0.006603  0.006603
# 34                                   Foundation_PConc  0.006593  0.006593
# 35                                           MoSold_7  0.005846  0.005846
# 36                             years_since_remodeled_ -0.005353  0.005353
# 37  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.004896  0.004896
# 38                                         BsmtFinSF2  0.004667  0.004667
# 39                                           BsmtQual  0.004254  0.004254
# 40                                        FireplaceQu  0.003731  0.003731
# 41                                    log_OpenPorchSF  0.002393  0.002393
#
# skewness:  -0.5103662874190299
#
# model_importances.shape:  (42, 3)

# %%
keeps = to_keep(elas13,0.004)

# %%
elas14 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9358792288108468
#
# test score:  0.920382329430084
# adj_r2:  0.9344077251690992
#
# adj_r2_test:  0.9159835631002544
#
# train RMSE: 0.09558195412593883
#
# test RMSE: 0.10516229793932594
#                                              features      coef   abs_val
# 0                                        bc_GrLivArea  0.129933  0.129933
# 1                                         OverallQual  0.062107  0.062107
# 2                                          house_age_ -0.058245  0.058245
# 3                                         OverallCond  0.053784  0.053784
# 4                                          bc_LotArea  0.042282  0.042282
# 5                                     yeo_TotalBsmtSF  0.042186  0.042186
# 6                                     GarageFinish_No  0.027682  0.027682
# 7                                        BsmtFullBath  0.026992  0.026992
# 8        Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.026200  0.026200
# 9                                          GarageCond  0.024679  0.024679
# 10                                         Fireplaces  0.024200  0.024200
# 11                                        MSZoning_RM -0.024115  0.024115
# 12                                       BsmtExposure  0.023226  0.023226
# 13                                         GarageCars  0.022720  0.022720
# 14                                  HouseStyle_1Story  0.019326  0.019326
# 15                                         Functional  0.017982  0.017982
# 16                                     yeo_GarageArea  0.017802  0.017802
# 17                                       BedroomAbvGr -0.017297  0.017297
# 18                                           2ndFlrSF  0.016191  0.016191
# 19                                       KitchenAbvGr -0.014932  0.014932
# 20                                    Condition1_Norm  0.014857  0.014857
# 21                        Neighborhood_Somerst_Timber  0.014181  0.014181
# 22                                        KitchenQual  0.013583  0.013583
# 23                                          HeatingQC  0.012750  0.012750
# 24                                       TotRmsAbvGrd  0.012415  0.012415
# 25                                          ExterQual  0.011924  0.011924
# 26               Neighborhood_ClearCr_CollgCr_Crawfor  0.011282  0.011282
# 27                                        ScreenPorch  0.010936  0.010936
# 28                                        MSZoning_RL -0.008849  0.008849
# 29                                      MSSubClass_50  0.008617  0.008617
# 30                                       CentralAir_Y  0.007850  0.007850
# 31                                       PavedDrive_Y  0.007512  0.007512
# 32                                   Foundation_PConc  0.006998  0.006998
# 33                             has_finsished_basement -0.006860  0.006860
# 34                                      MSSubClass_70  0.006382  0.006382
# 35                                           MoSold_7  0.005898  0.005898
# 36                             years_since_remodeled_ -0.005626  0.005626
# 37  Neighborhood_BrkSide_Edwards_Blueste_OldTown_I... -0.004858  0.004858
# 38                                         BsmtFinSF2  0.004768  0.004768
# 39                                           BsmtQual  0.004393  0.004393
#
# skewness:  -0.5170404041950135
#
# model_importances.shape:  (40, 3)

# %%
remove = ['log_first_FlrSF','BsmtFinSF1', 'BsmtUnfSF' ]

# %%
keeps_set = set(model_vars_data.columns) - set(remove + drop_dummy)
keeps_set
keeps = list(keeps_set)

# %%
elas15 = regx3(model= ElasticNet(max_iter=80000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 0.001, 'tol': 0.02}
# score:  0.941445629746343
#
# test score:  0.9249745991360049
# adj_r2:  0.9370690523434175
#
# adj_r2_test:  0.9104384277186058
#
# train RMSE: 0.09133898768087034
#
# test RMSE: 0.10208442719412873
#                                               features      coef   abs_val
# 0                                         bc_GrLivArea  0.137111  0.137111
# 1                                           house_age_ -0.066528  0.066528
# 2                                           bc_LotArea  0.058182  0.058182
# 3                                          OverallQual  0.055308  0.055308
# 4                                          OverallCond  0.053025  0.053025
# 5                                      yeo_TotalBsmtSF  0.039774  0.039774
# 6         Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.026402  0.026402
# 7                                       yeo_GarageArea  0.023728  0.023728
# 8                                           Fireplaces  0.020581  0.020581
# 9                                             2ndFlrSF  0.020025  0.020025
# 10                                        BsmtFullBath  0.019777  0.019777
# 11                                          Functional  0.019200  0.019200
# 12                                     GarageFinish_No  0.018732  0.018732
# 13                                        BsmtExposure  0.018652  0.018652
# 14                                        BedroomAbvGr -0.017921  0.017921
# 15                                             LotArea -0.016970  0.016970
# 16                                        BsmtFinType1  0.016900  0.016900
# 17                                            BsmtQual  0.016776  0.016776
# 18                                     log_OpenPorchSF  0.016710  0.016710
# 19                         Neighborhood_Somerst_Timber  0.016573  0.016573
# 20                                        KitchenAbvGr -0.014949  0.014949
# 21                                           ExterQual  0.014475  0.014475
# 22                                     Condition1_Norm  0.014094  0.014094
# 23                                          GarageCars  0.013507  0.013507
# 24                                           HeatingQC  0.013383  0.013383
# 25                                          GarageQual  0.013341  0.013341
# 26                Neighborhood_ClearCr_CollgCr_Crawfor  0.012956  0.012956
# 27                                          GarageCond  0.012496  0.012496
# 28                                       has_openporch -0.012330  0.012330
# 29                                        has_basement -0.012254  0.012254
# 30                                       GarageType_No  0.012071  0.012071
# 31                                          MSSubClass -0.011649  0.011649
# 32                                         ScreenPorch  0.011596  0.011596
# 33                                         KitchenQual  0.011420  0.011420
# 34                                         MSZoning_RM -0.011348  0.011348
# 35                                       MSSubClass_60 -0.011087  0.011087
# 36                                   GarageType_Detchd  0.010113  0.010113
# 37                                        TotRmsAbvGrd  0.009127  0.009127
# 38                                   GarageType_Attchd  0.008922  0.008922
# 39                                   HouseStyle_2Story -0.008396  0.008396
# 40                              has_finsished_basement -0.008083  0.008083
# 41                                    GarageFinish_RFn -0.007951  0.007951
# 99                                     yeo_LotFrontage  0.000245  0.000245
# 100                                       alley_access -0.000237  0.000237
# 101                                        MSZoning_RL -0.000167  0.000167
# 102                                          LandSlope -0.000155  0.000155
# 103                                           MoSold_5 -0.000112  0.000112
# 104                                   Condition1_Feedr -0.000049  0.000049
# 105                                     RoofMatl_Metal  0.000000  0.000000
# 106                                Exterior2nd_HdBoard  0.000000  0.000000
# 107                                           MoSold_6  0.000000  0.000000
# 108                                   Electrical_Mixed  0.000000  0.000000
# 109                                       Heating_GasA -0.000000  0.000000
# 110                                Exterior1st_ImStucc  0.000000  0.000000
# 111                                           MoSold_8  0.000000  0.000000
# 112                                Exterior1st_MetalSd  0.000000  0.000000
# 113                                     has_wood_deck  -0.000000  0.000000
# 114                                    MasVnrType_None  0.000000  0.000000
# 115                                        Fence_MnPrv  0.000000  0.000000
# 116                                    Condition2_RRAe  0.000000  0.000000
# 117                                    RoofStyle_Gable  0.000000  0.000000
# 118                                     log_MasVnrArea  0.000000  0.000000
# 119                                Exterior2nd_MetalSd -0.000000  0.000000
# 120                                   Utilities_NoSewr  0.000000  0.000000
# 121                                      MSSubClass_50 -0.000000  0.000000
# 122                                       BsmtFinType2  0.000000  0.000000
# 123                                           PoolArea  0.000000  0.000000
#
# skewness:  -0.623581745142295
#
# model_importances.shape:  (124, 3)

# %%
elas15['model_importances'].plot.kde() #0.03
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
elas15['model_importances'].plot.kde(y='abs_val',xlim=[0.0,0.03])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
elas15['model_importances'].plot.kde(y='abs_val',xlim=[0.0,0.010]) #drop > 0.003
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
keeps = to_keep(elas15,0.003)

# %%
elas16 = regx3(model= ElasticNet(max_iter=80000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-15, 'tol': 0.02}
# score:  0.9414143677720281
#
# test score:  0.9227579322486792
# adj_r2:  0.9390914389140095
#
# adj_r2_test:  0.9152112934453892
#
# train RMSE: 0.09136336721094804
#
# test RMSE: 0.10358151996001669
#                                         features      coef   abs_val
# 0                                   bc_GrLivArea  0.125538  0.125538
# 1                                     house_age_ -0.061131  0.061131
# 2                                    OverallQual  0.058736  0.058736
# 3                                     bc_LotArea  0.057244  0.057244
# 4                                    OverallCond  0.053298  0.053298
# 5                                yeo_TotalBsmtSF  0.048903  0.048903
# 6                              log_EnclosedPorch  0.041930  0.041930
# 7                              has_EnclosedPorch -0.039504  0.039504
# 8                                GarageFinish_No  0.035675  0.035675
# 9                                       2ndFlrSF  0.027913  0.027913
# 10  Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.027611  0.027611
# 11                                    Fireplaces  0.022676  0.022676
# 12                               log_OpenPorchSF  0.021712  0.021712
# 13                                    GarageCars  0.020702  0.020702
# 14                                  BsmtFullBath  0.020635  0.020635
# 15                                  has_basement -0.020099  0.020099
# 16                                  BedroomAbvGr -0.019908  0.019908
# 17                   Neighborhood_Somerst_Timber  0.019859  0.019859
# 18                                    Functional  0.018972  0.018972
# 19                                    GarageCond  0.018963  0.018963
# 20                                  BsmtExposure  0.018357  0.018357
# 21                                       LotArea -0.018193  0.018193
# 22                                      BsmtQual  0.018035  0.018035
# 23                                 has_openporch -0.017711  0.017711
# 24                                yeo_GarageArea  0.016399  0.016399
# 25                                  BsmtFinType1  0.016160  0.016160
# 26                             HouseStyle_2Story -0.016094  0.016094
# 27                                  KitchenAbvGr -0.016029  0.016029
# 28          Neighborhood_ClearCr_CollgCr_Crawfor  0.015856  0.015856
# 29                             GarageType_Attchd  0.015824  0.015824
# 30                             GarageType_Detchd  0.015487  0.015487
# 31                               Condition1_Norm  0.014358  0.014358
# 32                                    GarageQual  0.014085  0.014085
# 33                                     HeatingQC  0.013848  0.013848
# 34                                   KitchenQual  0.013433  0.013433
# 35                                  TotRmsAbvGrd  0.012056  0.012056
# 36                                     ExterQual  0.011890  0.011890
# 37                                   ScreenPorch  0.011725  0.011725
# 38                                   MSZoning_RM -0.011533  0.011533
# 39                        has_finsished_basement -0.010349  0.010349
# 40                                    BsmtFinSF2  0.009987  0.009987
# 41                                    MSSubClass -0.009389  0.009389
# 42                                 MSSubClass_70  0.009100  0.009100
# 43               Neighborhood_NAmes_SWISU_Sawyer  0.008954  0.008954
# 44                            GarageType_BuiltIn  0.008624  0.008624
# 45                             HouseStyle_1Story  0.008525  0.008525
# 46                                      FullBath  0.007946  0.007946
# 47                  Neighborhood_Mitchel_NPkVill  0.007907  0.007907
# 48                              GarageFinish_RFn -0.007393  0.007393
# 49                                  CentralAir_Y  0.007312  0.007312
# 50                                      HalfBath  0.006523  0.006523
# 51                                  PavedDrive_Y  0.006398  0.006398
# 52                                 MSSubClass_60 -0.005829  0.005829
# 53                                 GarageType_No  0.005748  0.005748
# 54                                  LowQualFinSF -0.005598  0.005598
# 55                                     3SsnPorch  0.005298  0.005298
# 56                                  BsmtHalfBath  0.005235  0.005235
# 57                                 MSSubClass_20 -0.005035  0.005035
# 58                               LandContour_Lvl -0.004938  0.004938
# 59                           Exterior2nd_Plywood -0.004512  0.004512
# 60                              MasVnrType_Stone  0.004223  0.004223
# 61                                      MoSold_9 -0.004093  0.004093
# 62                                      MoSold_7  0.004061  0.004061
# 63                           Exterior1st_Plywood -0.004058  0.004058
# 64                              LotConfig_Inside  0.004032  0.004032
# 65                                      MoSold_3 -0.003887  0.003887
# 66                              Electrical_SBrkr  0.003845  0.003845
# 67                                      MoSold_4 -0.003139  0.003139
#
# skewness:  -0.5892387777532124
#
# model_importances.shape:  (68, 3)

# %%
# drp 'log_price','bc_GrLivArea' has_openporch, has_finsished_basement

# %%
keeps_set = set(to_keep(elas16,0.0040)) - set(['has_EnclosedPorch'])
keeps = list(keeps_set)

# %%
elas17 = regx3(model= ElasticNet(max_iter=80000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-15, 'tol': 0.02}
# score:  0.9409862966199367
#
# test score:  0.9228619186144145
# adj_r2:  0.938789160484786
#
# adj_r2_test:  0.9158092940305895
#
# train RMSE: 0.09169654480338245
#
# test RMSE: 0.10351177368260654
#                                         features      coef   abs_val
# 0                                   bc_GrLivArea  0.125901  0.125901
# 1                                     house_age_ -0.062703  0.062703
# 2                                    OverallQual  0.058880  0.058880
# 3                                     bc_LotArea  0.058412  0.058412
# 4                                    OverallCond  0.053518  0.053518
# 5                                yeo_TotalBsmtSF  0.049001  0.049001
# 6                                GarageFinish_No  0.037989  0.037989
# 7   Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.027390  0.027390
# 8                                       2ndFlrSF  0.027000  0.027000
# 9                                log_OpenPorchSF  0.023893  0.023893
# 10                                    Fireplaces  0.022597  0.022597
# 11                                    GarageCars  0.021161  0.021161
# 12                                  BsmtFullBath  0.020573  0.020573
# 13                                    GarageCond  0.020459  0.020459
# 14                                 has_openporch -0.019746  0.019746
# 15                                  has_basement -0.019583  0.019583
# 16                   Neighborhood_Somerst_Timber  0.019472  0.019472
# 17                                  BedroomAbvGr -0.019192  0.019192
# 18                                       LotArea -0.018774  0.018774
# 19                                  BsmtExposure  0.018573  0.018573
# 20                                    Functional  0.018272  0.018272
# 21                                      BsmtQual  0.017691  0.017691
# 22                             GarageType_Attchd  0.016369  0.016369
# 23                                  BsmtFinType1  0.016258  0.016258
# 24                                yeo_GarageArea  0.016243  0.016243
# 25                                  KitchenAbvGr -0.015962  0.015962
# 26          Neighborhood_ClearCr_CollgCr_Crawfor  0.015764  0.015764
# 27                             GarageType_Detchd  0.015667  0.015667
# 28                             HouseStyle_2Story -0.015363  0.015363
# 29                               Condition1_Norm  0.014615  0.014615
# 30                                   KitchenQual  0.014183  0.014183
# 31                                     HeatingQC  0.014166  0.014166
# 32                                    GarageQual  0.013682  0.013682
# 33                                   MSZoning_RM -0.011860  0.011860
# 34                                   ScreenPorch  0.011369  0.011369
# 35                                     ExterQual  0.011347  0.011347
# 36                                  TotRmsAbvGrd  0.011318  0.011318
# 37                        has_finsished_basement -0.010486  0.010486
# 38                                    BsmtFinSF2  0.010116  0.010116
# 39                                 MSSubClass_70  0.009609  0.009609
# 40               Neighborhood_NAmes_SWISU_Sawyer  0.009267  0.009267
# 41                            GarageType_BuiltIn  0.009129  0.009129
# 42                                  CentralAir_Y  0.008330  0.008330
# 43                             HouseStyle_1Story  0.008065  0.008065
# 44                  Neighborhood_Mitchel_NPkVill  0.007980  0.007980
# 45                                    MSSubClass -0.007889  0.007889
# 46                                      FullBath  0.007855  0.007855
# 47                              GarageFinish_RFn -0.007502  0.007502
# 48                                      HalfBath  0.006483  0.006483
# 49                                  PavedDrive_Y  0.005961  0.005961
# 50                                 MSSubClass_60 -0.005682  0.005682
# 51                                     3SsnPorch  0.005411  0.005411
# 52                                  BsmtHalfBath  0.005383  0.005383
# 53                                      MoSold_7  0.005142  0.005142
# 54                                  LowQualFinSF -0.005044  0.005044
# 55                               LandContour_Lvl -0.004839  0.004839
# 56                                 GarageType_No  0.004606  0.004606
# 57                           Exterior2nd_Plywood -0.004396  0.004396
# 58                           Exterior1st_Plywood -0.004164  0.004164
# 59                              LotConfig_Inside  0.004129  0.004129
# 60                                 MSSubClass_20 -0.003875  0.003875
# 61                              MasVnrType_Stone  0.003859  0.003859
# 62                                      MoSold_9 -0.003561  0.003561
# 63                             log_EnclosedPorch  0.003148  0.003148
#
# skewness:  -0.6154883353814395
#
# model_importances.shape:  (64, 3)

# %%
keeps = to_keep(elas17,0.004)

# %%
elas18 = regx3(model= ElasticNet(max_iter=80000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9407501648585493
#
# test score:  0.9234890335458654
# adj_r2:  0.9386869088466591
#
# adj_r2_test:  0.9169682125412517
#
# train RMSE: 0.0918798145280307
#
# test RMSE: 0.10309015150674815
#                                         features      coef   abs_val
# 0                                   bc_GrLivArea  0.125354  0.125354
# 1                                     house_age_ -0.060104  0.060104
# 2                                    OverallQual  0.059070  0.059070
# 3                                     bc_LotArea  0.058737  0.058737
# 4                                    OverallCond  0.052782  0.052782
# 5                                yeo_TotalBsmtSF  0.049121  0.049121
# 6                                GarageFinish_No  0.036790  0.036790
# 7   Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.028035  0.028035
# 8                                       2ndFlrSF  0.026739  0.026739
# 9                                log_OpenPorchSF  0.023398  0.023398
# 10                                    Fireplaces  0.023084  0.023084
# 11                                    GarageCars  0.021762  0.021762
# 12                                  BsmtFullBath  0.020685  0.020685
# 13                                    GarageCond  0.020278  0.020278
# 14                   Neighborhood_Somerst_Timber  0.019782  0.019782
# 15                                       LotArea -0.019607  0.019607
# 16                                  has_basement -0.019606  0.019606
# 17                                 has_openporch -0.019595  0.019595
# 18                                  BedroomAbvGr -0.019555  0.019555
# 19                                  BsmtExposure  0.018828  0.018828
# 20                                    Functional  0.018403  0.018403
# 21                                      BsmtQual  0.017539  0.017539
# 22                             GarageType_Attchd  0.016590  0.016590
# 23                             HouseStyle_2Story -0.016412  0.016412
# 24                                  KitchenAbvGr -0.016170  0.016170
# 25                                yeo_GarageArea  0.016010  0.016010
# 26                                  BsmtFinType1  0.015924  0.015924
# 27                             GarageType_Detchd  0.015775  0.015775
# 28          Neighborhood_ClearCr_CollgCr_Crawfor  0.015647  0.015647
# 29                                     HeatingQC  0.014568  0.014568
# 30                                   KitchenQual  0.014411  0.014411
# 31                               Condition1_Norm  0.014397  0.014397
# 32                                    GarageQual  0.013492  0.013492
# 33                                     ExterQual  0.012025  0.012025
# 34                                  TotRmsAbvGrd  0.011918  0.011918
# 35                                   MSZoning_RM -0.011349  0.011349
# 36                                   ScreenPorch  0.010956  0.010956
# 37                        has_finsished_basement -0.010592  0.010592
# 38                                    BsmtFinSF2  0.010111  0.010111
# 39                                 MSSubClass_70  0.009895  0.009895
# 40                            GarageType_BuiltIn  0.009161  0.009161
# 41               Neighborhood_NAmes_SWISU_Sawyer  0.008864  0.008864
# 42                                  CentralAir_Y  0.008281  0.008281
# 43                                      FullBath  0.008019  0.008019
# 44                  Neighborhood_Mitchel_NPkVill  0.007625  0.007625
# 45                              GarageFinish_RFn -0.007398  0.007398
# 46                             HouseStyle_1Story  0.006235  0.006235
# 47                                      HalfBath  0.006110  0.006110
# 48                                    MSSubClass -0.005969  0.005969
# 49                                  PavedDrive_Y  0.005905  0.005905
# 50                                      MoSold_7  0.005551  0.005551
# 51                                  BsmtHalfBath  0.005415  0.005415
# 52                                  LowQualFinSF -0.005381  0.005381
# 53                                     3SsnPorch  0.005213  0.005213
# 54                                 GarageType_No  0.005210  0.005210
# 55                               LandContour_Lvl -0.005125  0.005125
# 56                           Exterior2nd_Plywood -0.004431  0.004431
# 57                                 MSSubClass_60 -0.004294  0.004294
# 58                           Exterior1st_Plywood -0.004047  0.004047
# 59                              LotConfig_Inside  0.004018  0.004018
#
# skewness:  -0.6096683035434481
#
# model_importances.shape:  (60, 3)

# %%
keeps = to_keep(elas18,0.005)

# %%
elas19 = regx3(model= ElasticNet(max_iter=80000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-15, 'tol': 0.02}
# score:  0.9402588420983391
#
# test score:  0.9237153604934815
# adj_r2:  0.9383216650036703
#
# adj_r2_test:  0.9176815471991806
#
# train RMSE: 0.09225997967861982
#
# test RMSE: 0.10293756318761708
#                                         features      coef   abs_val
# 0                                   bc_GrLivArea  0.124481  0.124481
# 1                                     house_age_ -0.059373  0.059373
# 2                                    OverallQual  0.058723  0.058723
# 3                                     bc_LotArea  0.055735  0.055735
# 4                                    OverallCond  0.052148  0.052148
# 5                                yeo_TotalBsmtSF  0.049270  0.049270
# 6                                GarageFinish_No  0.034248  0.034248
# 7   Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.029012  0.029012
# 8                                       2ndFlrSF  0.027357  0.027357
# 9                                     Fireplaces  0.022712  0.022712
# 10                                    GarageCars  0.021620  0.021620
# 11                               log_OpenPorchSF  0.021131  0.021131
# 12                                  BsmtFullBath  0.020726  0.020726
# 13                   Neighborhood_Somerst_Timber  0.020698  0.020698
# 14                             HouseStyle_2Story -0.020087  0.020087
# 15                                    GarageCond  0.019653  0.019653
# 16                                  BedroomAbvGr -0.019604  0.019604
# 17                                  has_basement -0.019436  0.019436
# 18                                    Functional  0.018500  0.018500
# 19                                       LotArea -0.018448  0.018448
# 20                                  BsmtExposure  0.018418  0.018418
# 21                                 has_openporch -0.017689  0.017689
# 22                                      BsmtQual  0.017477  0.017477
# 23                             GarageType_Attchd  0.017337  0.017337
# 24                             GarageType_Detchd  0.017095  0.017095
# 25          Neighborhood_ClearCr_CollgCr_Crawfor  0.016133  0.016133
# 26                                yeo_GarageArea  0.016016  0.016016
# 27                                  KitchenAbvGr -0.015965  0.015965
# 28                                  BsmtFinType1  0.015889  0.015889
# 29                                     HeatingQC  0.015720  0.015720
# 30                               Condition1_Norm  0.014574  0.014574
# 31                                   KitchenQual  0.014407  0.014407
# 32                                    GarageQual  0.014108  0.014108
# 33                                     ExterQual  0.013089  0.013089
# 34                                  TotRmsAbvGrd  0.012578  0.012578
# 35                                 MSSubClass_70  0.011417  0.011417
# 36                                   ScreenPorch  0.010948  0.010948
# 37                        has_finsished_basement -0.010446  0.010446
# 38                                   MSZoning_RM -0.010341  0.010341
# 39                            GarageType_BuiltIn  0.009597  0.009597
# 40               Neighborhood_NAmes_SWISU_Sawyer  0.009472  0.009472
# 41                                    BsmtFinSF2  0.009345  0.009345
# 42                                 GarageType_No  0.008371  0.008371
# 43                                  CentralAir_Y  0.008322  0.008322
# 44                                      FullBath  0.007530  0.007530
# 45                              GarageFinish_RFn -0.006996  0.006996
# 46                  Neighborhood_Mitchel_NPkVill  0.006350  0.006350
# 47                                    MSSubClass -0.006223  0.006223
# 48                             HouseStyle_1Story  0.006210  0.006210
# 49                                      HalfBath  0.006192  0.006192
# 50                                  PavedDrive_Y  0.005590  0.005590
# 51                               LandContour_Lvl -0.005468  0.005468
# 52                                      MoSold_7  0.005226  0.005226
# 53                                     3SsnPorch  0.005159  0.005159
# 54                                  LowQualFinSF -0.005114  0.005114
# 55                                  BsmtHalfBath  0.005085  0.005085
#
# skewness:  -0.6156349464655716
#
# model_importances.shape:  (56, 3)

# %%
keeps_set = set(to_keep(elas19,0.0)) - set(['has_basement','LotArea','has_openporch','MSSubClass'])
keeps = list(keeps_set)

# %%
elas20 = regx3(model= ElasticNet(max_iter=80000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-08, 'tol': 0.02}
# score:  0.9388462787010644
#
# test score:  0.9229871074722187
# adj_r2:  0.9370091940635459
#
# adj_r2_test:  0.917362570377493
#
# train RMSE: 0.09334433832366625
#
# test RMSE: 0.10342774396335618
#                                         features      coef   abs_val
# 0                                   bc_GrLivArea  0.129834  0.129834
# 1                                     house_age_ -0.065293  0.065293
# 2                                    OverallQual  0.060218  0.060218
# 3                                    OverallCond  0.051855  0.051855
# 4                                     bc_LotArea  0.041418  0.041418
# 5                                yeo_TotalBsmtSF  0.038080  0.038080
# 6                                GarageFinish_No  0.036329  0.036329
# 7   Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.029569  0.029569
# 8                                       2ndFlrSF  0.025267  0.025267
# 9                              HouseStyle_2Story -0.023583  0.023583
# 10                             GarageType_Attchd  0.022615  0.022615
# 11                                    GarageCars  0.022406  0.022406
# 12                                    Fireplaces  0.022275  0.022275
# 13                                  BsmtFullBath  0.022035  0.022035
# 14                             GarageType_Detchd  0.021674  0.021674
# 15                   Neighborhood_Somerst_Timber  0.020577  0.020577
# 16                                    GarageCond  0.020365  0.020365
# 17                                  BedroomAbvGr -0.019456  0.019456
# 18                                  BsmtExposure  0.018517  0.018517
# 19                                    Functional  0.018036  0.018036
# 20                                yeo_GarageArea  0.017510  0.017510
# 21                                     HeatingQC  0.016206  0.016206
# 22          Neighborhood_ClearCr_CollgCr_Crawfor  0.016145  0.016145
# 23                                  KitchenAbvGr -0.015976  0.015976
# 24                                  TotRmsAbvGrd  0.015445  0.015445
# 25                                   KitchenQual  0.015096  0.015096
# 26                               Condition1_Norm  0.014703  0.014703
# 27                                     ExterQual  0.014407  0.014407
# 28                                  BsmtFinType1  0.014107  0.014107
# 29                                   MSZoning_RM -0.013158  0.013158
# 30                                 MSSubClass_70  0.012127  0.012127
# 31                                   ScreenPorch  0.011538  0.011538
# 32                             HouseStyle_1Story  0.011225  0.011225
# 33                            GarageType_BuiltIn  0.011092  0.011092
# 34                        has_finsished_basement -0.010632  0.010632
# 35                                    GarageQual  0.009473  0.009473
# 36                                    BsmtFinSF2  0.008988  0.008988
# 37               Neighborhood_NAmes_SWISU_Sawyer  0.008921  0.008921
# 38                                  CentralAir_Y  0.007035  0.007035
# 39                              GarageFinish_RFn -0.006899  0.006899
# 40                                      FullBath  0.006649  0.006649
# 41                  Neighborhood_Mitchel_NPkVill  0.006392  0.006392
# 42                                 GarageType_No  0.006003  0.006003
# 43                                      MoSold_7  0.005533  0.005533
# 44                                     3SsnPorch  0.005476  0.005476
# 45                                  LowQualFinSF -0.005419  0.005419
# 46                                  BsmtHalfBath  0.005246  0.005246
# 47                                  PavedDrive_Y  0.005069  0.005069
# 48                                      HalfBath  0.004737  0.004737
# 49                               LandContour_Lvl -0.004606  0.004606
# 50                               log_OpenPorchSF  0.004457  0.004457
# 51                                      BsmtQual  0.003724  0.003724
#
# skewness:  -0.637549619397723
#
# model_importances.shape:  (52, 3)

# %%
keeps = to_keep(elas20,0.005)

# %%
elas21 = regx3(model= ElasticNet(max_iter=40000), #max_iter=10000000000000
x_train = model_vars_data[keeps],
x_test = test_vars_data[keeps],
y_train = np.log(price_train.SalePrice),
y_test = np.log(price_test.SalePrice),
params = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,10,100],'tol':[0.02]},
cv_ = 5,
linear_reg = True,
tree_based = False)
# Out:
# best params:  {'alpha': 1e-15, 'tol': 0.02}
# score:  0.938793521812777
#
# test score:  0.923052777731109
# adj_r2:  0.9370639269851103
#
# adj_r2_test:  0.9177794715896046
#
# train RMSE: 0.09338459339798807
#
# test RMSE: 0.10338363722317973
#                                         features      coef   abs_val
# 0                                   bc_GrLivArea  0.133579  0.133579
# 1                                     house_age_ -0.067795  0.067795
# 2                                    OverallQual  0.061392  0.061392
# 3                                    OverallCond  0.051117  0.051117
# 4                                yeo_TotalBsmtSF  0.038952  0.038952
# 5                                GarageFinish_No  0.038448  0.038448
# 6                                     bc_LotArea  0.037730  0.037730
# 7   Neighborhood_NoRidge_NridgHt_Veenker_StoneBr  0.031083  0.031083
# 8                                       2ndFlrSF  0.026741  0.026741
# 9                                     GarageCars  0.023362  0.023362
# 10                                    Fireplaces  0.022746  0.022746
# 11                                  BsmtFullBath  0.022386  0.022386
# 12                                    GarageCond  0.021437  0.021437
# 13                                  BedroomAbvGr -0.021255  0.021255
# 14                   Neighborhood_Somerst_Timber  0.021245  0.021245
# 15                             HouseStyle_2Story -0.020273  0.020273
# 16                                  BsmtExposure  0.020179  0.020179
# 17                             GarageType_Attchd  0.019586  0.019586
# 18                             GarageType_Detchd  0.019083  0.019083
# 19                                    Functional  0.018130  0.018130
# 20          Neighborhood_ClearCr_CollgCr_Crawfor  0.016532  0.016532
# 21                                     HeatingQC  0.015989  0.015989
# 22                                yeo_GarageArea  0.015418  0.015418
# 23                                   KitchenQual  0.014952  0.014952
# 24                                  BsmtFinType1  0.014947  0.014947
# 25                               Condition1_Norm  0.014612  0.014612
# 26                                     ExterQual  0.014526  0.014526
# 27                                  KitchenAbvGr -0.014126  0.014126
# 28                                  TotRmsAbvGrd  0.013567  0.013567
# 29                                   MSZoning_RM -0.012687  0.012687
# 30                                    GarageQual  0.012680  0.012680
# 31                                   ScreenPorch  0.011809  0.011809
# 32                                 MSSubClass_70  0.011389  0.011389
# 33                        has_finsished_basement -0.011323  0.011323
# 34                                    MSSubClass -0.009868  0.009868
# 35                            GarageType_BuiltIn  0.009777  0.009777
# 36                                    BsmtFinSF2  0.009506  0.009506
# 37               Neighborhood_NAmes_SWISU_Sawyer  0.007685  0.007685
# 38                             HouseStyle_1Story  0.007291  0.007291
# 39                              GarageFinish_RFn -0.006946  0.006946
# 40                                 GarageType_No  0.006879  0.006879
# 41                  Neighborhood_Mitchel_NPkVill  0.006728  0.006728
# 42                                  CentralAir_Y  0.006491  0.006491
# 43                                      FullBath  0.005872  0.005872
# 44                                     3SsnPorch  0.005329  0.005329
# 45                                      MoSold_7  0.005298  0.005298
# 46                                  BsmtHalfBath  0.005204  0.005204
# 47                                  PavedDrive_Y  0.005103  0.005103
# 48                                  LowQualFinSF -0.004793  0.004793
#
# skewness:  -0.622637405617642
#
# model_importances.shape:  (49, 3)
